# %% [markdown]
# # Comparison between Cross Entropy Loss and DLITE for Shakespeare Corpus

# %% [markdown]
# 8/11/2023

# %% [markdown]
# ## Output Results

# %% [markdown]
# ### Cross Entropy Results

# %% [markdown]
# #### Cross entropy with 64 embedded nodes and 5 layers (BASELINE)
# 0.259521 M parameters

# %%
# CE_64embd_5layer
CE_64embd_5layer = """
step 0: train loss 4.3236, val loss 4.3261
step 100: train loss 2.6518, val loss 2.6635
step 200: train loss 2.4858, val loss 2.4939
step 300: train loss 2.4084, val loss 2.4107
step 400: train loss 2.3399, val loss 2.3383
step 500: train loss 2.2905, val loss 2.3104
step 600: train loss 2.2295, val loss 2.2375
step 700: train loss 2.2020, val loss 2.2191
step 800: train loss 2.1396, val loss 2.1760
step 900: train loss 2.1017, val loss 2.1535
step 1000: train loss 2.0809, val loss 2.1183
step 1100: train loss 2.0589, val loss 2.0974
step 1200: train loss 2.0188, val loss 2.0807
step 1300: train loss 1.9834, val loss 2.0529
step 1400: train loss 1.9596, val loss 2.0405
step 1500: train loss 1.9472, val loss 2.0206
step 1600: train loss 1.9287, val loss 2.0116
step 1700: train loss 1.9087, val loss 1.9895
step 1800: train loss 1.8941, val loss 1.9752
step 1900: train loss 1.8732, val loss 1.9760
step 2000: train loss 1.8547, val loss 1.9541
step 2100: train loss 1.8401, val loss 1.9462
step 2200: train loss 1.8308, val loss 1.9401
step 2300: train loss 1.8275, val loss 1.9368
step 2400: train loss 1.7995, val loss 1.9306
step 2500: train loss 1.7928, val loss 1.9278
step 2600: train loss 1.7768, val loss 1.9163
step 2700: train loss 1.7889, val loss 1.9192
step 2800: train loss 1.7695, val loss 1.9256
step 2900: train loss 1.7553, val loss 1.9015
step 3000: train loss 1.7417, val loss 1.9090
step 3100: train loss 1.7332, val loss 1.8804
step 3200: train loss 1.7247, val loss 1.8967
step 3300: train loss 1.7249, val loss 1.8766
step 3400: train loss 1.7171, val loss 1.8717
step 3500: train loss 1.7047, val loss 1.8635
step 3600: train loss 1.7073, val loss 1.8597
step 3700: train loss 1.7025, val loss 1.8514
step 3800: train loss 1.6937, val loss 1.8481
step 3900: train loss 1.6872, val loss 1.8404
step 4000: train loss 1.6865, val loss 1.8359
step 4100: train loss 1.6715, val loss 1.8346
step 4200: train loss 1.6596, val loss 1.8433
step 4300: train loss 1.6582, val loss 1.8285
step 4400: train loss 1.6637, val loss 1.8239
step 4500: train loss 1.6573, val loss 1.8272
step 4600: train loss 1.6500, val loss 1.8175
step 4700: train loss 1.6507, val loss 1.8115
step 4800: train loss 1.6554, val loss 1.8233
step 4900: train loss 1.6406, val loss 1.8159
step 4999: train loss 1.6419, val loss 1.7901
"""

# Split the data into lines
lines = CE_64embd_5layer.strip().split('\n')

# Initialize lists to store the data
CE_steps_64embd_5layer = []
CE_train_losses_64embd_5layer = []
CE_val_losses_64embd_5layer = []

# Parse the data
for line in lines:
    parts = line.split()
    CE_steps_64embd_5layer.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    CE_train_losses_64embd_5layer.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    CE_val_losses_64embd_5layer.append(float(parts[7]))  # Convert to float

# %% [markdown]
# Ind your before! That my plice endly griant highting;
# And I to Weary was deakly corituains!
# Caiu bring therefore's pay I, Sirrans:
# What We you; much oadd chur baguited,
# O heart her as suile this from horsaling,
# Willies nevery a land's thee, a genfore hambe thate would as your would of day.
# Caulant sway, for thou adderself vow, and what, the offents.
#
# ISABELLA:
# Lady a banche that our siur, sir,
# Who yea, but you know sharl fhat made lies and other's of you.
# Isay for a narrence of a guadern,-a
# Look and blided and a ower's beserving Richame
# And becreahity axtifteds such as
# Though with child saup.
#
# Boy--
#
# POLANTIO:
# But, put which a genape:
# That I bonsing Now it shen bants.
#
# First Marcare:
# I' wat cause; which fair, Jamother'd alpechard,
# To him armand I'lf take you to thrue to brace, my lord.
#
# First ANCHARET:
# For thine, teneth I in may I graceliaa,
# Nie, now a compatpus siria, he tyroal have like soth abuthiff
# Awerting that delf that kingle warwich,
# Hishourold
# Ufter hath But! your panishus; shame king shall bany
# 'Bague, 'tis see shoUC
# done think helps' thou, oway I before sword of thy worse for't now allow!
#
# KING Richnecive dea.
#
# ISTRANELA:
# Do will gentle thesenury andifter.

# %% [markdown]
# #### Cross entropy with 10 layers
# 0.508481 M parameters

# %%
# CE_10layer
CE_10layer = """
step 0: train loss 4.3059, val loss 4.3047
step 100: train loss 2.6366, val loss 2.6337
step 200: train loss 2.4830, val loss 2.4969
step 300: train loss 2.3975, val loss 2.3932
step 400: train loss 2.3242, val loss 2.3360
step 500: train loss 2.2725, val loss 2.2777
step 600: train loss 2.2236, val loss 2.2418
step 700: train loss 2.1771, val loss 2.1963
step 800: train loss 2.1231, val loss 2.1485
step 900: train loss 2.0794, val loss 2.1109
step 1000: train loss 2.0420, val loss 2.0909
step 1100: train loss 2.0056, val loss 2.0810
step 1200: train loss 1.9686, val loss 2.0417
step 1300: train loss 1.9576, val loss 2.0255
step 1400: train loss 1.9275, val loss 2.0109
step 1500: train loss 1.9094, val loss 2.0058
step 1600: train loss 1.8880, val loss 1.9754
step 1700: train loss 1.8657, val loss 1.9891
step 1800: train loss 1.8391, val loss 1.9514
step 1900: train loss 1.8374, val loss 1.9392
step 2000: train loss 1.8153, val loss 1.9287
step 2100: train loss 1.7849, val loss 1.9026
step 2200: train loss 1.7893, val loss 1.9160
step 2300: train loss 1.7728, val loss 1.9153
step 2400: train loss 1.7600, val loss 1.8964
step 2500: train loss 1.7601, val loss 1.9065
step 2600: train loss 1.7347, val loss 1.8871
step 2700: train loss 1.7249, val loss 1.8798
step 2800: train loss 1.7247, val loss 1.8612
step 2900: train loss 1.7143, val loss 1.8583
step 3000: train loss 1.6972, val loss 1.8595
step 3100: train loss 1.6868, val loss 1.8495
step 3200: train loss 1.6839, val loss 1.8459
step 3300: train loss 1.6721, val loss 1.8408
step 3400: train loss 1.6777, val loss 1.8306
step 3500: train loss 1.6546, val loss 1.8257
step 3600: train loss 1.6527, val loss 1.8074
step 3700: train loss 1.6538, val loss 1.8191
step 3800: train loss 1.6403, val loss 1.8196
step 3900: train loss 1.6419, val loss 1.8148
step 4000: train loss 1.6263, val loss 1.7943
step 4100: train loss 1.6293, val loss 1.7924
step 4200: train loss 1.6344, val loss 1.8048
step 4300: train loss 1.6187, val loss 1.7849
step 4400: train loss 1.6095, val loss 1.7872
step 4500: train loss 1.6211, val loss 1.7869
step 4600: train loss 1.6035, val loss 1.7747
step 4700: train loss 1.6093, val loss 1.8024
step 4800: train loss 1.6052, val loss 1.7881
step 4900: train loss 1.6025, val loss 1.7801
step 4999: train loss 1.5921, val loss 1.7858
"""

# Split the data into lines
lines = CE_10layer.strip().split('\n')

# Initialize lists to store the data
CE_steps_10layer = []
CE_train_losses_10layer = []
CE_val_losses_10layer = []

# Parse the data
for line in lines:
    parts = line.split()
    CE_steps_10layer.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    CE_train_losses_10layer.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    CE_val_losses_10layer.append(float(parts[7]))  # Convert to float

# %% [markdown]
# And wap one ourselves, my more prainly
# Will give a mimater marknighter togett hath,
# And thou so alm gently love Was
# As thus weep thy send to you, I sajectimate for
# Than my eyes wishings sland a full
# To slass,
# Alhove to shaming to a prigies.
# And me as fortune, and must brother
# By manim had sest well known our wishions and my life? though canfit that enclanisnes
# Contratt wave; of that's tongon they nouXrars to, blisg,
# Thereing in sighamenter at remont,
# Coutinue, weep, believ: ther; that live, the will nue.
#
# KING RICHARD II:
# Him their ose us antage to well us?
#
# DUKE VINCENTIO:
# Sill so passe.
#
# JOHN:
# Be it to sundil that man; well'd generlal:
# I mege sither. Lrdy, wet it is so aidquour
# Buqland toods on hour cowns. As, That I welland.
#
# DUET:
# Grane staty afoot!
# As done would arg ary of my life?
#
# Guive:
# The nat good let bewell which'd vaid a faes and lass'd rast
# To lady: out foull take your ape.
#
# Repaitar
# Nice it-bedged sland, you of gone;
# And my lord, do honest reculs a hath our victuted,
# O verget midds comphep will servy hours,
# Ie is taken thy fear Iply, Battly,
# What, till thereoving-somisheld, think inter matter:
# Prough is she man, gooms now, thel rudumness is hand
# Woe heward would post was it they of heart of Clumens:
# 'T the so apart fool ten, Sozelows not seem it who tire inter
# And no honot: Rich hath the hours!

# %% [markdown]
# #### Cross Entropy with 128 embedded nodes
# 0.812609 M parameters

# %%
# CE_128embd
CE_128embd = """
step 0: train loss 4.3250, val loss 4.3253
step 100: train loss 2.5138, val loss 2.5129
step 200: train loss 2.3704, val loss 2.3763
step 300: train loss 2.2478, val loss 2.2627
step 400: train loss 2.1632, val loss 2.1897
step 500: train loss 2.0957, val loss 2.1379
step 600: train loss 2.0454, val loss 2.1024
step 700: train loss 2.0033, val loss 2.0622
step 800: train loss 1.9624, val loss 2.0433
step 900: train loss 1.9213, val loss 2.0141
step 1000: train loss 1.9015, val loss 2.0199
step 1100: train loss 1.8747, val loss 1.9862
step 1200: train loss 1.8443, val loss 1.9676
step 1300: train loss 1.8011, val loss 1.9396
step 1400: train loss 1.7915, val loss 1.9226
step 1500: train loss 1.7731, val loss 1.9174
step 1600: train loss 1.7656, val loss 1.8908
step 1700: train loss 1.7446, val loss 1.8857
step 1800: train loss 1.7248, val loss 1.8845
step 1900: train loss 1.7126, val loss 1.8446
step 2000: train loss 1.6960, val loss 1.8547
step 2100: train loss 1.6964, val loss 1.8374
step 2200: train loss 1.6828, val loss 1.8331
step 2300: train loss 1.6728, val loss 1.8261
step 2400: train loss 1.6654, val loss 1.8167
step 2500: train loss 1.6703, val loss 1.8123
step 2600: train loss 1.6521, val loss 1.8146
step 2700: train loss 1.6350, val loss 1.7910
step 2800: train loss 1.6293, val loss 1.7893
step 2900: train loss 1.6267, val loss 1.7892
step 3000: train loss 1.6232, val loss 1.7852
step 3100: train loss 1.6370, val loss 1.7983
step 3200: train loss 1.6129, val loss 1.7853
step 3300: train loss 1.6126, val loss 1.7653
step 3400: train loss 1.6042, val loss 1.7666
step 3500: train loss 1.6020, val loss 1.7876
step 3600: train loss 1.5865, val loss 1.7747
step 3700: train loss 1.5910, val loss 1.7513
step 3800: train loss 1.5866, val loss 1.7455
step 3900: train loss 1.5791, val loss 1.7648
step 4000: train loss 1.5748, val loss 1.7458
step 4100: train loss 1.5680, val loss 1.7357
step 4200: train loss 1.5567, val loss 1.7437
step 4300: train loss 1.5579, val loss 1.7364
step 4400: train loss 1.5501, val loss 1.7259
step 4500: train loss 1.5465, val loss 1.7254
step 4600: train loss 1.5401, val loss 1.7222
step 4700: train loss 1.5489, val loss 1.7220
step 4800: train loss 1.5358, val loss 1.7196
step 4900: train loss 1.5463, val loss 1.7054
step 4999: train loss 1.5317, val loss 1.7003
"""

# Split the data into lines
lines = CE_128embd.strip().split('\n')

# Initialize lists to store the data
CE_steps_128embd = []
CE_train_losses_128embd = []
CE_val_losses_128embd = []

# Parse the data
for line in lines:
    parts = line.split()
    CE_steps_128embd.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    CE_train_losses_128embd.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    CE_val_losses_128embd.append(float(parts[7]))  # Convert to float

# %% [markdown]
# God mornerhichmentiple brother bush'd
# About say 'that I am to the namer,
# that plose you eyet is I will to refusoons!
# Though! he banetale, hopeled made life,
# Hvilly live, ghile ie us a plyore, say such not? And thou may die the other?
#
# Lord:
# I will love my lords: then thyself curn eal as eye.
#
# CLIFFORD:
# My lord law!
#
# KING HENRY VI:
# With thy bears her would with rolds you.
# Stag you look favour than I must was a lord and me and in
# your les thou deservater she was branch's for
# me high more this hax all doubt was that her I turn of fice!
#
# THUMBELLA:
# Ay, falship his still grough,
# To his natural was Irews: I beg, I' this disights,
# name time for honour falance age.
#
# ELBOW:
# For speak to waile, I know who day:
# In for give thy life thus alche
# That we thou------and he bud for have your chaws.
# Though thoughts to the worthin. Farewhat is her would 'I have crown in
# so look his defenrend: Angelo, I do not mine such and
# To sub see their was ra's were to their day of antiers.
# What to come you whose sight; I think proce
# Where shall I liith me myselfminies.
# Gok Warwick! law, thou leebel that friends report would wouldsing
# ttempt do more one thing all the dukine of this hath owe? Trush,
# Or rebreath o' that diest was you to timply.
#
# Provost:'tis chy these hope is world
# The herpicies with my pairing forth;
# Force mosse have my sail devost thou dise
# But love.
# Is I send to be diest.
#
# LEONTEG LOUCENTIO:
# Thu should nish'd make hence, I did you thou speak thee deliver call;
# Though you have with loyes by true-heart;
# Who have both my faither to the may pake,
# You do mine, I to to the enough: the
# That is you lives egar to his less?

# %% [markdown]
# #### Cross Entropy with 0.5 dropout
# 0.259521 M parameters

# %%
# CE_50dropout
CE_50dropout = """
step 0: train loss 4.3236, val loss 4.3261
step 100: train loss 2.7157, val loss 2.7401
step 200: train loss 2.5618, val loss 2.5632
step 300: train loss 2.5234, val loss 2.5262
step 400: train loss 2.4849, val loss 2.4830
step 500: train loss 2.4444, val loss 2.4336
step 600: train loss 2.4088, val loss 2.4034
step 700: train loss 2.3704, val loss 2.3924
step 800: train loss 2.3482, val loss 2.3540
step 900: train loss 2.3213, val loss 2.3275
step 1000: train loss 2.2988, val loss 2.3103
step 1100: train loss 2.2696, val loss 2.2831
step 1200: train loss 2.2535, val loss 2.2664
step 1300: train loss 2.2325, val loss 2.2497
step 1400: train loss 2.2183, val loss 2.2260
step 1500: train loss 2.2019, val loss 2.2164
step 1600: train loss 2.1885, val loss 2.1952
step 1700: train loss 2.1769, val loss 2.1985
step 1800: train loss 2.1587, val loss 2.1908
step 1900: train loss 2.1465, val loss 2.1788
step 2000: train loss 2.1444, val loss 2.1579
step 2100: train loss 2.1332, val loss 2.1624
step 2200: train loss 2.1140, val loss 2.1485
step 2300: train loss 2.0991, val loss 2.1425
step 2400: train loss 2.1024, val loss 2.1372
step 2500: train loss 2.0837, val loss 2.1181
step 2600: train loss 2.0643, val loss 2.1000
step 2700: train loss 2.0677, val loss 2.1196
step 2800: train loss 2.0598, val loss 2.1115
step 2900: train loss 2.0555, val loss 2.1001
step 3000: train loss 2.0404, val loss 2.0899
step 3100: train loss 2.0369, val loss 2.0877
step 3200: train loss 2.0296, val loss 2.0688
step 3300: train loss 2.0152, val loss 2.0719
step 3400: train loss 2.0140, val loss 2.0561
step 3500: train loss 2.0081, val loss 2.0569
step 3600: train loss 1.9924, val loss 2.0575
step 3700: train loss 1.9945, val loss 2.0498
step 3800: train loss 1.9794, val loss 2.0534
step 3900: train loss 1.9783, val loss 2.0426
step 4000: train loss 1.9788, val loss 2.0311
step 4100: train loss 1.9649, val loss 2.0287
step 4200: train loss 1.9682, val loss 2.0405
step 4300: train loss 1.9643, val loss 2.0266
step 4400: train loss 1.9487, val loss 2.0280
step 4500: train loss 1.9464, val loss 2.0212
step 4600: train loss 1.9602, val loss 2.0092
step 4700: train loss 1.9464, val loss 2.0167
step 4800: train loss 1.9349, val loss 2.0098
step 4900: train loss 1.9440, val loss 2.0052
step 4999: train loss 1.9221, val loss 2.0026
"""

# Split the data into lines
lines = CE_50dropout.strip().split('\n')

# Initialize lists to store the data
CE_steps_50dropout = []
CE_train_losses_50dropout = []
CE_val_losses_50dropout = []

# Parse the data
for line in lines:
    parts = line.split()
    CE_steps_50dropout.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    CE_train_losses_50dropout.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    CE_val_losses_50dropout.append(float(parts[7]))  # Convert to float

# %% [markdown]
# RIZA:
# When own my lushicie'l ruce that pridelest lour.
# Rome weas of try owith and go'n of it, in hur mare?
# To thou he war:
# I take ning andin I the to he bise snout sruke, wice wene; if whas for lohk:
# My ads fore reds drehts, Fartsme downaked recth and
# Whe of your his thip rand an
# The that jut themoli; thimace.
# Whice take
# Aprole, you shover-sho: my liss, the hisin my ovines, I is hins food thom muse than? thes ster?
#
# NAMIUSTIO:
# Han, at frove
# And, deetcht do that me lut ft. wroln, low?
# Stord wos the eve it heir way,
# Dood tot wifftawe's nour your ; thell and of tich is is to worquetsi-ngmave lad thre that king eass ss tuking wir
# Hle nemst mine hanlak with tam oue arind let,
# Yirt Fart hathou lelks! mus Mast there unge;
# Thet coad of's he you deix marsure arwer wall houne.
#
# York.
#
# Shen end vithte-
# Whou dom to me be prookn, brind that I heard's diwer.
# Pemotwath frate fence.
# Buch thear he me strett there cous,
# But may the he to mublead we brepectbece equere of ufences thath
# Pel mine wan's pet mody, pirm wid goode? and; tins in cand broun,
# Tho me,
# That. And Litidesen.
# Hick of I do.
#
# BORK:
# For, don ampy Bud mye ve, comith,
# Nruntlas we thor blisbid.
#
# MAM:
#
# Sce's, now thadn I why my the wear ar andat now,
# When to-pereach to, Youre a ming cate suTon
# thy they racixn the; gagod it he shir sir's and they slatht;
# Prust, shant hat
# Wh thou ark bost, to my the to f an Cary hanted mistherer to couc: kif:
# A hou ristleatiover excom.

# %% [markdown]
# ### DLITE Results

# %% [markdown]
# #### DLITE with 64 embedded nodes and 5 layers (BASELINE)
# 0.259521 M parameters

# %%
# DLITE_64embd_5layer
DLITE_64embd_5layer = '''step 0: train loss 0.9233, val loss 0.9233
step 100: train loss 0.6688, val loss 0.6699
step 200: train loss 0.6442, val loss 0.6483
step 300: train loss 0.6310, val loss 0.6343
step 400: train loss 0.6204, val loss 0.6219
step 500: train loss 0.6061, val loss 0.6129
step 600: train loss 0.5962, val loss 0.5998
step 700: train loss 0.5798, val loss 0.5818
step 800: train loss 0.5660, val loss 0.5712
step 900: train loss 0.5595, val loss 0.5672
step 1000: train loss 0.5553, val loss 0.5622
step 1100: train loss 0.5483, val loss 0.5566
step 1200: train loss 0.5416, val loss 0.5543
step 1300: train loss 0.5380, val loss 0.5501
step 1400: train loss 0.5340, val loss 0.5495
step 1500: train loss 0.5319, val loss 0.5419
step 1600: train loss 0.5252, val loss 0.5387
step 1700: train loss 0.5217, val loss 0.5342
step 1800: train loss 0.5175, val loss 0.5338
step 1900: train loss 0.5155, val loss 0.5304
step 2000: train loss 0.5114, val loss 0.5297
step 2100: train loss 0.5094, val loss 0.5271
step 2200: train loss 0.5068, val loss 0.5262
step 2300: train loss 0.5025, val loss 0.5239
step 2400: train loss 0.5003, val loss 0.5244
step 2500: train loss 0.4976, val loss 0.5221
step 2600: train loss 0.4957, val loss 0.5183
step 2700: train loss 0.4981, val loss 0.5189
step 2800: train loss 0.4942, val loss 0.5195
step 2900: train loss 0.4900, val loss 0.5167
step 3000: train loss 0.4883, val loss 0.5171
step 3100: train loss 0.4848, val loss 0.5078
step 3200: train loss 0.4824, val loss 0.5102
step 3300: train loss 0.4822, val loss 0.5092
step 3400: train loss 0.4808, val loss 0.5086
step 3500: train loss 0.4795, val loss 0.5054
step 3600: train loss 0.4762, val loss 0.5023
step 3700: train loss 0.4783, val loss 0.5048
step 3800: train loss 0.4746, val loss 0.5002
step 3900: train loss 0.4731, val loss 0.5017
step 4000: train loss 0.4738, val loss 0.4998
step 4100: train loss 0.4673, val loss 0.4961
step 4200: train loss 0.4680, val loss 0.5004
step 4300: train loss 0.4658, val loss 0.4976
step 4400: train loss 0.4671, val loss 0.4941
step 4500: train loss 0.4659, val loss 0.4973
step 4600: train loss 0.4647, val loss 0.4918
step 4700: train loss 0.4640, val loss 0.4944
step 4800: train loss 0.4653, val loss 0.4969
step 4900: train loss 0.4614, val loss 0.4934
step 4999: train loss 0.4613, val loss 0.4894'''

# Split the data into lines
lines = DLITE_64embd_5layer.strip().split('\n')

# Initialize lists to store the data
DLITE_steps_64embd_5layer = []
DLITE_train_losses_64embd_5layer = []
DLITE_val_losses_64embd_5layer = []

# Parse the data
for line in lines:
    parts = line.split()
    DLITE_steps_64embd_5layer.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    DLITE_train_losses_64embd_5layer.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    DLITE_val_losses_64embd_5layer.append(float(parts[7]))  # Convert to float

# %% [markdown]
# To be the need with of it you sent the bear stand,
# Which and the word the hand his the seath the pers the will the dear a was my ber and in the will the house for the stand he was the will a part a so and of say his near,
# The prince of well the shall now son,
# And the hath the house with who the soul not the to be made word,
# As that the heart sing and the so mone of his it be a a plamion.
#
# First all all hear his field heart a mand boor
# What so stand her some not for the house for the that shall honh a day more the to the are the band the seecr of the cans with the shall for the day of part hast,
# The was the are to be dear mest the heaven his bear,
# In that honour of the son, and a comes the God fall how say be a that the would so dear him plant for you sell the love a perest her so can me thou the pent the will not be you will be at the stall not the heart to the honour,
# That his man but come it the country with whom sin,
# And stand hear his both the pronder,
# And which his not not my lord, my shall shall for the word, that death his love,
# And the the are that be sint of the partion.
#
# DUKE I man, sir, and he so see this some to be his of the would his for the day he stand the was and we a was which do the has come a man stand her honour to dear you heart the a present thou present,
# That what the part it the hofor what fayer stand in the beling of honours hand be and bear so ball from hing son,
# As me that the well be his his the souls a shall the proy in to this neer of a notanger to well my was of the that do you that me a conting and the stay me to the would be and the will home,
# Which a the the some thou hath here the place in the dear,
# And the hath a should be him lady,
# As that his man a a this bear him feeld of it the shall stand of your brond and the bear of the his son the sir,
# To still the honou hand be my so bear,
# My stare the han chard that was the part in the can a partion,
# Angain the por the can that by the shall for the was in this fear me that the parding a

# %% [markdown]
# #### DLITE with 10 layers
# 0.508481 M parameters

# %%
# DLITE_10layer
DLITE_10layer = """
step 0: train loss 0.9228, val loss 0.9226
step 100: train loss 0.6717, val loss 0.6724
step 200: train loss 0.6439, val loss 0.6507
step 300: train loss 0.6294, val loss 0.6330
step 400: train loss 0.6160, val loss 0.6193
step 500: train loss 0.6054, val loss 0.6107
step 600: train loss 0.5920, val loss 0.5977
step 700: train loss 0.5839, val loss 0.5862
step 800: train loss 0.5682, val loss 0.5721
step 900: train loss 0.5618, val loss 0.5648
step 1000: train loss 0.5481, val loss 0.5565
step 1100: train loss 0.5458, val loss 0.5542
step 1200: train loss 0.5360, val loss 0.5469
step 1300: train loss 0.5299, val loss 0.5401
step 1400: train loss 0.5258, val loss 0.5389
step 1500: train loss 0.5233, val loss 0.5344
step 1600: train loss 0.5192, val loss 0.5298
step 1700: train loss 0.5130, val loss 0.5303
step 1800: train loss 0.5119, val loss 0.5296
step 1900: train loss 0.5068, val loss 0.5226
step 2000: train loss 0.5043, val loss 0.5185
step 2100: train loss 0.4995, val loss 0.5173
step 2200: train loss 0.4966, val loss 0.5180
step 2300: train loss 0.4940, val loss 0.5161
step 2400: train loss 0.4935, val loss 0.5135
step 2500: train loss 0.4897, val loss 0.5133
step 2600: train loss 0.4891, val loss 0.5130
step 2700: train loss 0.4833, val loss 0.5111
step 2800: train loss 0.4844, val loss 0.5062
step 2900: train loss 0.4829, val loss 0.5082
step 3000: train loss 0.4787, val loss 0.5061
step 3100: train loss 0.4796, val loss 0.5084
step 3200: train loss 0.4783, val loss 0.5059
step 3300: train loss 0.4736, val loss 0.5000
step 3400: train loss 0.4736, val loss 0.5008
step 3500: train loss 0.4707, val loss 0.5014
step 3600: train loss 0.4694, val loss 0.4956
step 3700: train loss 0.4684, val loss 0.5005
step 3800: train loss 0.4652, val loss 0.4972
step 3900: train loss 0.4669, val loss 0.4961
step 4000: train loss 0.4601, val loss 0.4910
step 4100: train loss 0.4632, val loss 0.4903
step 4200: train loss 0.4604, val loss 0.4885
step 4300: train loss 0.4585, val loss 0.4866
step 4400: train loss 0.4575, val loss 0.4883
step 4500: train loss 0.4621, val loss 0.4917
step 4600: train loss 0.4554, val loss 0.4880
step 4700: train loss 0.4556, val loss 0.4863
step 4800: train loss 0.4554, val loss 0.4882
step 4900: train loss 0.4543, val loss 0.4844
step 4999: train loss 0.4537, val loss 0.4862
"""

# Split the data into lines
lines = DLITE_10layer.strip().split('\n')

# Initialize lists to store the data
DLITE_steps_10layer = []
DLITE_train_losses_10layer = []
DLITE_val_losses_10layer = []

# Parse the data
for line in lines:
    parts = line.split()
    DLITE_steps_10layer.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    DLITE_train_losses_10layer.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    DLITE_val_losses_10layer.append(float(parts[7]))  # Convert to float

# %% [markdown]
# Lord you may are his come to that seen thou consere
# To in the will and to the so my poring
# To the mean of this please the that the weart or the controun of that, say be that be he lord is the to make our thand your thou been some hasten to the pray the to that is the bloods.
#
# Post seen the seen will as the call thou paint
# And in the the are thou art that well seen thou dead him with all the poor hath.
#
# CORIOLANUS:
# And the some it on theur seen some to our land died and to do this death thou hast to the do contal to detter the sound it thou dow,
# Hadise to thou hath are look of all the pray
# That is in the see him his words and that in it the contry
# Where will the that been to love the weart that we that his death and our the being
# And from so more to seen the are that in hand a death and as the love in son,
# And that you do the dain, the hast your been with.
#
# Second the howere
# And some to and the doth soul be sont the daded of the sease your for the hase of this winding of the death.
#
# POLINGAUnd the some the dear and one thank brother,
# Which he castil and to the seen been his leaven to the the done
# And lies and me my sound some as the will and some and in the for the bold of comanse,
# And whose than the seen and thou do beast to
# Make the that is a done of all heaven to dand my lord,
# I love to death of the your wearse,
# The deather him and wear and my words your all heart.
#
# CLARENTIO:
# The more word some that were he could haved
# And the band to the will a prove the look ose that seen more to the been the poor that sing the are one that heart on you to this side thank your to do the leave the thou dorth.

# %% [markdown]
# #### DLITE with 128 embedded nodes
# 1.010497 M parameters

# %%
# DLITE_128embd
DLITE_128embd = """
step 0: train loss 0.9278, val loss 0.9278
step 100: train loss 0.6531, val loss 0.6557
step 200: train loss 0.6251, val loss 0.6287
step 300: train loss 0.5997, val loss 0.6045
step 400: train loss 0.5858, val loss 0.5892
step 500: train loss 0.5691, val loss 0.5758
step 600: train loss 0.5555, val loss 0.5661
step 700: train loss 0.5449, val loss 0.5524
step 800: train loss 0.5355, val loss 0.5465
step 900: train loss 0.5248, val loss 0.5410
step 1000: train loss 0.5196, val loss 0.5377
step 1100: train loss 0.5178, val loss 0.5366
step 1200: train loss 0.5100, val loss 0.5285
step 1300: train loss 0.5053, val loss 0.5258
step 1400: train loss 0.5033, val loss 0.5232
step 1500: train loss 0.4955, val loss 0.5160
step 1600: train loss 0.4930, val loss 0.5123
step 1700: train loss 0.4872, val loss 0.5126
step 1800: train loss 0.4857, val loss 0.5126
step 1900: train loss 0.4819, val loss 0.5041
step 2000: train loss 0.4763, val loss 0.5036
step 2100: train loss 0.4785, val loss 0.5037
step 2200: train loss 0.4733, val loss 0.5010
step 2300: train loss 0.4692, val loss 0.5006
step 2400: train loss 0.4680, val loss 0.4999
step 2500: train loss 0.4692, val loss 0.4949
step 2600: train loss 0.4688, val loss 0.4930
step 2700: train loss 0.4620, val loss 0.4880
step 2800: train loss 0.4610, val loss 0.4894
step 2900: train loss 0.4604, val loss 0.4891
step 3000: train loss 0.4582, val loss 0.4866
step 3100: train loss 0.4533, val loss 0.4842
step 3200: train loss 0.4540, val loss 0.4812
step 3300: train loss 0.4547, val loss 0.4830
step 3400: train loss 0.4501, val loss 0.4793
step 3500: train loss 0.4500, val loss 0.4831
step 3600: train loss 0.4519, val loss 0.4797
step 3700: train loss 0.4464, val loss 0.4752
step 3800: train loss 0.4455, val loss 0.4767
step 3900: train loss 0.4442, val loss 0.4753
step 4000: train loss 0.4426, val loss 0.4722
step 4100: train loss 0.4418, val loss 0.4722
step 4200: train loss 0.4421, val loss 0.4707
step 4300: train loss 0.4383, val loss 0.4727
step 4400: train loss 0.4397, val loss 0.4684
step 4500: train loss 0.4401, val loss 0.4696
step 4600: train loss 0.4392, val loss 0.4683
step 4700: train loss 0.4355, val loss 0.4661
step 4800: train loss 0.4382, val loss 0.4660
step 4900: train loss 0.4396, val loss 0.4645
step 4999: train loss 0.4344, val loss 0.4667
"""

# Split the data into lines
lines = DLITE_128embd.strip().split('\n')

# Initialize lists to store the data
DLITE_steps_128embd = []
DLITE_train_losses_128embd = []
DLITE_val_losses_128embd = []

# Parse the data
for line in lines:
    parts = line.split()
    DLITE_steps_128embd.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    DLITE_train_losses_128embd.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    DLITE_val_losses_128embd.append(float(parts[7]))  # Convert to float

# %% [markdown]
# CORIOLANUS:
# We may a so man for homan, and the soulds of so the dies of my son
# That man the shall be the brother first of him the sure
# To make the thouse of the blood to do the brother and the shall distrect,
# Where me the make your him seat
# As which for was the ham stred and and brother friends and the princess of hands what
# As my heart of hath sent the shand for him and the coment of menine of man.
#
# WARICHARD II:
# And make you stand him to be the content of my seen your son.
#
# DUKE not dear say it is a man of the parting,
# The hear shall and the blood worst the so see him him coment,
# Who say that she caster say and here than my blood do stands my man,
# That shall be hath and the his son,
# And not not she have and the send of her me
# That be a band of your son, be all my leave than be some,
# And not love to him this wears and she in a thearn for man to such a part than to see man the dead.
#
# KING RICHARD III:
# What of this that and the find of the paint of men,
# What as heart of men the come of the day.
#
# First the be sought this Of the band that and say
# For the thus in so shall did not so more be thou countrection the coment of the dater bood the worst of him the chnows,
# And by the prince of the stand to me annother.
#
# CORIOLANUS:
# I will the as a hastill of the for I have down the said and blood not sheare the dis is hath strucked him to me peace your the hath so sands to not me to the ground.
#
# GLOUCESTER:
# Not a for the needs is father of the than a shold man my lan old with the deads son so man the sun of the first of the liver of the coment sorn, and that for the part of the gentle father,
# Where here are this blood his forth.

# %% [markdown]
# #### DLITE with 0.5 dropout
# 0.259521 M parameters

# %%
# DLITE_50dropout
DLITE_50dropout = """
step 0: train loss 0.9233, val loss 0.9233
step 100: train loss 0.6763, val loss 0.6790
step 200: train loss 0.6583, val loss 0.6604
step 300: train loss 0.6520, val loss 0.6523
step 400: train loss 0.6439, val loss 0.6474
step 500: train loss 0.6397, val loss 0.6406
step 600: train loss 0.6290, val loss 0.6329
step 700: train loss 0.6237, val loss 0.6305
step 800: train loss 0.6150, val loss 0.6197
step 900: train loss 0.6114, val loss 0.6144
step 1000: train loss 0.6040, val loss 0.6080
step 1100: train loss 0.5956, val loss 0.5981
step 1200: train loss 0.5888, val loss 0.5907
step 1300: train loss 0.5858, val loss 0.5903
step 1400: train loss 0.5826, val loss 0.5843
step 1500: train loss 0.5784, val loss 0.5815
step 1600: train loss 0.5761, val loss 0.5776
step 1700: train loss 0.5741, val loss 0.5782
step 1800: train loss 0.5668, val loss 0.5749
step 1900: train loss 0.5654, val loss 0.5725
step 2000: train loss 0.5640, val loss 0.5682
step 2100: train loss 0.5617, val loss 0.5678
step 2200: train loss 0.5578, val loss 0.5656
step 2300: train loss 0.5563, val loss 0.5664
step 2400: train loss 0.5543, val loss 0.5658
step 2500: train loss 0.5494, val loss 0.5601
step 2600: train loss 0.5478, val loss 0.5557
step 2700: train loss 0.5482, val loss 0.5592
step 2800: train loss 0.5468, val loss 0.5566
step 2900: train loss 0.5462, val loss 0.5556
step 3000: train loss 0.5435, val loss 0.5537
step 3100: train loss 0.5436, val loss 0.5538
step 3200: train loss 0.5414, val loss 0.5506
step 3300: train loss 0.5390, val loss 0.5514
step 3400: train loss 0.5370, val loss 0.5484
step 3500: train loss 0.5362, val loss 0.5481
step 3600: train loss 0.5320, val loss 0.5455
step 3700: train loss 0.5320, val loss 0.5438
step 3800: train loss 0.5322, val loss 0.5463
step 3900: train loss 0.5299, val loss 0.5440
step 4000: train loss 0.5314, val loss 0.5417
step 4100: train loss 0.5275, val loss 0.5424
step 4200: train loss 0.5275, val loss 0.5415
step 4300: train loss 0.5261, val loss 0.5370
step 4400: train loss 0.5233, val loss 0.5398
step 4500: train loss 0.5231, val loss 0.5383
step 4600: train loss 0.5257, val loss 0.5351
step 4700: train loss 0.5225, val loss 0.5361
step 4800: train loss 0.5199, val loss 0.5324
step 4900: train loss 0.5213, val loss 0.5349
step 4999: train loss 0.5164, val loss 0.5321
"""

# Split the data into lines
lines = DLITE_50dropout.strip().split('\n')

# Initialize lists to store the data
DLITE_steps_50dropout = []
DLITE_train_losses_50dropout = []
DLITE_val_losses_50dropout = []

# Parse the data
for line in lines:
    parts = line.split()
    DLITE_steps_50dropout.append(int(parts[1][:-1]))  # Remove the colon and convert to int
    DLITE_train_losses_50dropout.append(float(parts[4][:-1]))  # Remove the comma and convert to float
    DLITE_val_losses_50dropout.append(float(parts[7]))  # Convert to float

# %% [markdown]
# And me here with withe ciend the shou in the the the mues were soold thoull with sell word that shat that thour of to whath me the be all in man houst my word not shim tor for wen we to she fake cheurst the fore as there to so the hear card do that for with thath his the sir thae the that she the ward that the are mance,
# And li, the should shall wellan, the the the the the and seent, for and me the that your wout the mo for the the and be arlant hat ant there till den the wenlourd wher with that cour his hour wall woun to the mante win,
# And my she hast his wore this thou hour the in stane sall bre that my be wost sorde hall hould now to dake the sing with woull be doestere to Fear hath the the the whath the whe be shour thall the he to seell mans to ard this shall ent the that wore have will thould my now the ben to the this so I hat do my we cand to a thot thise wis ther the the for stienthe thou me herear and stat thour,
# And ward be ston comesend wo full strale, my we my soule his mame the is herese be shall so nould cand brown she mor,
# That shall the well which me a do bit the weard not my his with we to mis there that we tho for sird wall lore thou now that so whour for herer and that nour be seee thall sill the teare,
# To cateater wore heres make on the so to my he shis so thou me hath should sto liks and hath and hour the shat lies the to stand tike and the so where the wich and me be thou ward the to mest the mest for chis and sent in hime be sirs the shing with he seard shis to he so leardee hath the the that the sire theo fuld the fand of fase come with of neard the sort and sing not alove st she me thou make the me the so that hat have sye werome stan in wilin should be the can he my hour the is he fathis would shis his thare an the the thou my he in son wirs the sh leath thathere the be wither the the to man sould the the thourse ell love that shon the the me my nowre thet and sire this will have and the to stas seneard ther mall so cant with the ward ther

# %% [markdown]
# ## Result Comparisons

# %%
import matplotlib.pyplot as plt

# Visualization
plt.figure(figsize=(16, 8))

# Colors for the subseries of CE and DLITE
CE_colors = ['blue', 'deepskyblue', 'dodgerblue', 'royalblue']
DLITE_colors = ['red', 'lightsalmon', 'darkred', 'indianred']

# Line styles for each subseries to differentiate them
line_styles = ['-', '--', '-.', ':']

# Plotting the CE series validation losses
CE_subseries_names = ['64embd_5layer', '10layer', '128embd', '50dropout']
for idx, subseries in enumerate(CE_subseries_names):
    steps = globals()[f"CE_steps_{subseries}"]
    val_losses = globals()[f"CE_val_losses_{subseries}"]
    plt.plot(steps, val_losses, label=f"CE_{subseries}", color=CE_colors[idx], linestyle=line_styles[idx])

# Plotting the DLITE series validation losses
DLITE_subseries_names = ['64embd_5layer', '10layer', '128embd', '50dropout']
for idx, subseries in enumerate(DLITE_subseries_names):
    steps = globals()[f"DLITE_steps_{subseries}"]
    val_losses = globals()[f"DLITE_val_losses_{subseries}"]
    plt.plot(steps, val_losses, label=f"DLITE_{subseries}", color=DLITE_colors[idx], linestyle=line_styles[idx])

plt.title("Validation Losses")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 12))
axes[0].set_title("CE Validation Losses")
axes[1].set_title("DLITE Validation Losses")

# Colors for the subseries of CE and DLITE
CE_colors = ['blue', 'deepskyblue', 'dodgerblue', 'royalblue']
DLITE_colors = ['red', 'lightsalmon', 'darkred', 'indianred']

# Line styles for each subseries to differentiate them
line_styles = ['-', '--', '-.', ':']

# Plotting the CE series validation losses
CE_subseries_names = ['64embd_5layer', '10layer', '128embd', '50dropout']
for idx, subseries in enumerate(CE_subseries_names):
    steps = globals()[f"CE_steps_{subseries}"]
    val_losses = globals()[f"CE_val_losses_{subseries}"]
    axes[0].plot(steps, val_losses, label=f"CE_{subseries}", color=CE_colors[idx], linestyle=line_styles[idx])

# Plotting the DLITE series validation losses
DLITE_subseries_names = ['64embd_5layer', '10layer', '128embd', '50dropout']
for idx, subseries in enumerate(DLITE_subseries_names):
    steps = globals()[f"DLITE_steps_{subseries}"]
    val_losses = globals()[f"DLITE_val_losses_{subseries}"]
    axes[1].plot(steps, val_losses, label=f"DLITE_{subseries}", color=DLITE_colors[idx], linestyle=line_styles[idx])

# Setting common attributes
for ax in axes:
    ax.set_xlabel("Steps")
    ax.set_ylabel("Loss")
    ax.legend(loc="upper right")
    ax.grid(True)

plt.tight_layout()
plt.show()
