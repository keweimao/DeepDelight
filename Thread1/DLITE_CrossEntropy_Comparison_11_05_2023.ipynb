# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.functional import kl_div

torch.manual_seed(1337)

# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    # Define the loss functions
    ce_loss_func = nn.CrossEntropyLoss()

    # Prepare dictionaries to store the output losses
    dlite_out = {}
    ce_out = {}
    kl_out = {}

    model.eval()  # Set the model to evaluation mode
    for split in ['train', 'val']:
        dlite_losses = torch.zeros(eval_iters)
        ce_losses = torch.zeros(eval_iters)
        kl_losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, _ = model(X, Y)

            # Reshape the logits
            logits_flat = logits.view(-1, logits.size(-1))  # Flattening the logits

            # Convert targets to one-hot encoding
            targets_flat = Y.view(-1)

            # Calculate the losses
            dlite_losses[k] = dlite_loss(logits_flat, targets_flat).item()
            ce_losses[k] = ce_loss_func(logits_flat, targets_flat).item()  # Assuming vocab_size is the same as logits.size(-1)
            kl_losses[k] = kl_loss(logits_flat, targets_flat).item()

        # Store the mean loss for each metric
        dlite_out[split] = dlite_losses.mean().item()
        ce_out[split] = ce_losses.mean().item()
        kl_out[split] = kl_losses.mean().item()


    model.train()  # Set the model back to training mode
    return dlite_out, ce_out, kl_out



class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, targets=None):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)

        if targets is not None:
            # Calculate L1 Loss
            B, T, C = out.shape
            out_flat = out.view(B * T, C)
            targets_flat = targets.view(B * T)
            l1_loss = F.l1_loss(out_flat, targets_flat.float())
            return out, l1_loss
        else:
            return out


class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


# DLITE Loss function
class DLITELoss(nn.Module):
    def __init__(self):
        super(DLITELoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = g_values - delta_h_values

        # Sum over all classes and average over the batch size
        loss = dl_values.sum(dim=-1).mean()

        return loss





class KLDivergenceLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super(KLDivergenceLoss, self).__init__()
        self.reduction = reduction

    def forward(self, input_logits, target_labels):
        # Calculate the model's predicted probability distribution corresponding to input logits
        input_probs = F.log_softmax(input_logits, dim=-1)

        # Create a zero tensor with the same shape as input logits to represent the true probability distribution
        target_probs = torch.zeros_like(input_probs)

        # Fill the target probability distribution with true labels
        target_probs.scatter_(dim=-1, index=target_labels.unsqueeze(-1), value=1)

        # Compute KL divergence
        loss = F.kl_div(input_probs, target_probs, reduction=self.reduction)

        return loss





# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.loss_func = DLITELoss()  # Initialize the DLITE loss function

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = self.loss_func(logits, targets)  # Use DLITE loss here

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
# Out:
# --2023-11-07 15:23:15--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.07s
#
# 2023-11-07 15:23:15 (15.2 MB/s) - ‘input.txt’ saved [1115394/1115394]

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

# %% [markdown]
# ## Train with dlite

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
kl_loss = KLDivergenceLoss()

# Lists to store the loss values
dlite_train_losses_dlite = []
dlite_val_losses_dlite = []
ce_train_losses_dlite = []
ce_val_losses_dlite = []
kl_train_losses_dlite = []
kl_val_losses_dlite = []



for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses_dlite.append(dlite_losses['train'])
        dlite_val_losses_dlite.append(dlite_losses['val'])
        ce_train_losses_dlite.append(ce_losses['train'])
        ce_val_losses_dlite.append(ce_losses['val'])
        kl_train_losses_dlite.append(kl_losses['train'])
        kl_val_losses_dlite.append(kl_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the DLITE loss using the flattened logits and targets
    loss = dlite_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


# !pip install matplotlib
import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Convert evaluation interval steps to actual iterations
eval_points = [i * eval_interval for i in range(len(dlite_train_losses_dlite))]

# Plotting DLITE Loss
plot_losses(dlite_train_losses_dlite, dlite_val_losses_dlite, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses_dlite, ce_val_losses_dlite, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses_dlite, kl_val_losses_dlite, 'KL Divergence Loss Over Time')
# Out:
# 0.209729 M parameters
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2943: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# step 0: KL train loss 0.0679, KL val loss 0.0677
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
#
# step 100: KL train loss 0.0512, KL val loss 0.0523
# DLITE train loss 0.6724, DLITE val loss 0.6736
# CE train loss 3.3285, CE val loss 3.4019
#
# step 200: KL train loss 0.0513, KL val loss 0.0526
# DLITE train loss 0.6473, DLITE val loss 0.6496
# CE train loss 3.3348, CE val loss 3.4162
#
# step 300: KL train loss 0.0512, KL val loss 0.0530
# DLITE train loss 0.6312, DLITE val loss 0.6367
# CE train loss 3.3302, CE val loss 3.4447
#
# step 400: KL train loss 0.0501, KL val loss 0.0516
# DLITE train loss 0.6191, DLITE val loss 0.6233
# CE train loss 3.2562, CE val loss 3.3508
#
# step 500: KL train loss 0.0496, KL val loss 0.0510
# DLITE train loss 0.6064, DLITE val loss 0.6122
# CE train loss 3.2239, CE val loss 3.3129
#
# step 600: KL train loss 0.0474, KL val loss 0.0479
# DLITE train loss 0.5898, DLITE val loss 0.5910
# CE train loss 3.0820, CE val loss 3.1104
#
# step 700: KL train loss 0.0474, KL val loss 0.0480
# DLITE train loss 0.5811, DLITE val loss 0.5854
# CE train loss 3.0818, CE val loss 3.1230
#
# step 800: KL train loss 0.0465, KL val loss 0.0473
# DLITE train loss 0.5681, DLITE val loss 0.5752
# CE train loss 3.0226, CE val loss 3.0732
#
# step 900: KL train loss 0.0460, KL val loss 0.0466
# DLITE train loss 0.5615, DLITE val loss 0.5681
# CE train loss 2.9890, CE val loss 3.0315
#
# step 1000: KL train loss 0.0476, KL val loss 0.0481
# DLITE train loss 0.5568, DLITE val loss 0.5633
# CE train loss 3.0921, CE val loss 3.1269
#
# step 1100: KL train loss 0.0478, KL val loss 0.0487
# DLITE train loss 0.5531, DLITE val loss 0.5625
# CE train loss 3.1042, CE val loss 3.1637
#
# step 1200: KL train loss 0.0463, KL val loss 0.0467
# DLITE train loss 0.5447, DLITE val loss 0.5521
# CE train loss 3.0100, CE val loss 3.0383
#
# step 1300: KL train loss 0.0461, KL val loss 0.0466
# DLITE train loss 0.5441, DLITE val loss 0.5512
# CE train loss 2.9979, CE val loss 3.0304
#
# step 1400: KL train loss 0.0455, KL val loss 0.0462
# DLITE train loss 0.5346, DLITE val loss 0.5444
# CE train loss 2.9547, CE val loss 3.0034
#
# step 1500: KL train loss 0.0456, KL val loss 0.0466
# DLITE train loss 0.5329, DLITE val loss 0.5444
# CE train loss 2.9647, CE val loss 3.0288
#
# step 1600: KL train loss 0.0454, KL val loss 0.0475
# DLITE train loss 0.5266, DLITE val loss 0.5440
# CE train loss 2.9536, CE val loss 3.0843
#
# step 1700: KL train loss 0.0465, KL val loss 0.0477
# DLITE train loss 0.5266, DLITE val loss 0.5403
# CE train loss 3.0228, CE val loss 3.1036
#
# step 1800: KL train loss 0.0455, KL val loss 0.0474
# DLITE train loss 0.5180, DLITE val loss 0.5372
# CE train loss 2.9604, CE val loss 3.0811
#
# step 1900: KL train loss 0.0465, KL val loss 0.0477
# DLITE train loss 0.5215, DLITE val loss 0.5350
# CE train loss 3.0241, CE val loss 3.1025
#
# step 2000: KL train loss 0.0462, KL val loss 0.0483
# DLITE train loss 0.5161, DLITE val loss 0.5376
# CE train loss 3.0036, CE val loss 3.1368
#
# step 2100: KL train loss 0.0458, KL val loss 0.0478
# DLITE train loss 0.5112, DLITE val loss 0.5316
# CE train loss 2.9773, CE val loss 3.1057
#
# step 2200: KL train loss 0.0452, KL val loss 0.0470
# DLITE train loss 0.5077, DLITE val loss 0.5257
# CE train loss 2.9409, CE val loss 3.0550
#
# step 2300: KL train loss 0.0446, KL val loss 0.0467
# DLITE train loss 0.5065, DLITE val loss 0.5266
# CE train loss 2.8962, CE val loss 3.0371
#
# step 2400: KL train loss 0.0459, KL val loss 0.0477
# DLITE train loss 0.5047, DLITE val loss 0.5244
# CE train loss 2.9803, CE val loss 3.1026
#
# step 2500: KL train loss 0.0451, KL val loss 0.0474
# DLITE train loss 0.4988, DLITE val loss 0.5227
# CE train loss 2.9322, CE val loss 3.0780
#
# step 2600: KL train loss 0.0452, KL val loss 0.0470
# DLITE train loss 0.5019, DLITE val loss 0.5223
# CE train loss 2.9355, CE val loss 3.0528
#
# step 2700: KL train loss 0.0459, KL val loss 0.0480
# DLITE train loss 0.4974, DLITE val loss 0.5192
# CE train loss 2.9856, CE val loss 3.1210
#
# step 2800: KL train loss 0.0439, KL val loss 0.0463
# DLITE train loss 0.4975, DLITE val loss 0.5193
# CE train loss 2.8535, CE val loss 3.0112
#
# step 2900: KL train loss 0.0442, KL val loss 0.0468
# DLITE train loss 0.4931, DLITE val loss 0.5174
# CE train loss 2.8715, CE val loss 3.0405
#
# step 3000: KL train loss 0.0451, KL val loss 0.0473
# DLITE train loss 0.4931, DLITE val loss 0.5159
# CE train loss 2.9288, CE val loss 3.0763
#
# step 3100: KL train loss 0.0444, KL val loss 0.0475
# DLITE train loss 0.4886, DLITE val loss 0.5154
# CE train loss 2.8880, CE val loss 3.0887
#
# step 3200: KL train loss 0.0439, KL val loss 0.0466
# DLITE train loss 0.4847, DLITE val loss 0.5114
# CE train loss 2.8557, CE val loss 3.0320
#
# step 3300: KL train loss 0.0455, KL val loss 0.0477
# DLITE train loss 0.4861, DLITE val loss 0.5124
# CE train loss 2.9584, CE val loss 3.1002
#
# step 3400: KL train loss 0.0443, KL val loss 0.0468
# DLITE train loss 0.4852, DLITE val loss 0.5071
# CE train loss 2.8768, CE val loss 3.0425
#
# step 3500: KL train loss 0.0446, KL val loss 0.0472
# DLITE train loss 0.4819, DLITE val loss 0.5092
# CE train loss 2.9004, CE val loss 3.0688
#
# step 3600: KL train loss 0.0446, KL val loss 0.0474
# DLITE train loss 0.4789, DLITE val loss 0.5070
# CE train loss 2.8984, CE val loss 3.0782
#
# step 3700: KL train loss 0.0444, KL val loss 0.0469
# DLITE train loss 0.4805, DLITE val loss 0.5067
# CE train loss 2.8862, CE val loss 3.0508
#
# step 3800: KL train loss 0.0437, KL val loss 0.0468
# DLITE train loss 0.4798, DLITE val loss 0.5100
# CE train loss 2.8387, CE val loss 3.0409
#
# step 3900: KL train loss 0.0437, KL val loss 0.0468
# DLITE train loss 0.4748, DLITE val loss 0.5036
# CE train loss 2.8380, CE val loss 3.0397
#
# step 4000: KL train loss 0.0436, KL val loss 0.0463
# DLITE train loss 0.4740, DLITE val loss 0.5006
# CE train loss 2.8317, CE val loss 3.0074
#
# step 4100: KL train loss 0.0442, KL val loss 0.0470
# DLITE train loss 0.4752, DLITE val loss 0.5032
# CE train loss 2.8725, CE val loss 3.0577
#
# step 4200: KL train loss 0.0436, KL val loss 0.0464
# DLITE train loss 0.4720, DLITE val loss 0.5007
# CE train loss 2.8360, CE val loss 3.0157
#
# step 4300: KL train loss 0.0452, KL val loss 0.0478
# DLITE train loss 0.4737, DLITE val loss 0.5017
# CE train loss 2.9375, CE val loss 3.1085
#
# step 4400: KL train loss 0.0441, KL val loss 0.0465
# DLITE train loss 0.4717, DLITE val loss 0.4968
# CE train loss 2.8653, CE val loss 3.0257
#
# step 4500: KL train loss 0.0433, KL val loss 0.0459
# DLITE train loss 0.4688, DLITE val loss 0.4960
# CE train loss 2.8151, CE val loss 2.9840
#
# step 4600: KL train loss 0.0437, KL val loss 0.0461
# DLITE train loss 0.4690, DLITE val loss 0.4955
# CE train loss 2.8390, CE val loss 2.9942
#
# step 4700: KL train loss 0.0439, KL val loss 0.0465
# DLITE train loss 0.4660, DLITE val loss 0.4944
# CE train loss 2.8544, CE val loss 3.0205
#
# step 4800: KL train loss 0.0437, KL val loss 0.0473
# DLITE train loss 0.4624, DLITE val loss 0.4947
# CE train loss 2.8407, CE val loss 3.0772
#
# step 4900: KL train loss 0.0440, KL val loss 0.0470
# DLITE train loss 0.4648, DLITE val loss 0.4936
# CE train loss 2.8598, CE val loss 3.0563
#
# step 5000: KL train loss 0.0436, KL val loss 0.0461
# DLITE train loss 0.4628, DLITE val loss 0.4896
# CE train loss 2.8336, CE val loss 2.9980
#
# step 5100: KL train loss 0.0430, KL val loss 0.0461
# DLITE train loss 0.4651, DLITE val loss 0.4922
# CE train loss 2.7926, CE val loss 2.9947
#
# step 5200: KL train loss 0.0438, KL val loss 0.0472
# DLITE train loss 0.4615, DLITE val loss 0.4900
# CE train loss 2.8439, CE val loss 3.0662
#
# step 5300: KL train loss 0.0431, KL val loss 0.0460
# DLITE train loss 0.4613, DLITE val loss 0.4910
# CE train loss 2.8014, CE val loss 2.9878
#
# step 5400: KL train loss 0.0437, KL val loss 0.0467
# DLITE train loss 0.4624, DLITE val loss 0.4912
# CE train loss 2.8395, CE val loss 3.0350
#
# step 5500: KL train loss 0.0433, KL val loss 0.0462
# DLITE train loss 0.4603, DLITE val loss 0.4888
# CE train loss 2.8147, CE val loss 3.0003
#
# step 5600: KL train loss 0.0442, KL val loss 0.0468
# DLITE train loss 0.4621, DLITE val loss 0.4877
# CE train loss 2.8742, CE val loss 3.0390
#
# step 5700: KL train loss 0.0435, KL val loss 0.0464
# DLITE train loss 0.4602, DLITE val loss 0.4891
# CE train loss 2.8276, CE val loss 3.0175
#
# step 5800: KL train loss 0.0438, KL val loss 0.0467
# DLITE train loss 0.4575, DLITE val loss 0.4865
# CE train loss 2.8483, CE val loss 3.0333
#
# step 5900: KL train loss 0.0439, KL val loss 0.0466
# DLITE train loss 0.4603, DLITE val loss 0.4883
# CE train loss 2.8559, CE val loss 3.0286
#
# step 6000: KL train loss 0.0436, KL val loss 0.0469
# DLITE train loss 0.4568, DLITE val loss 0.4899
# CE train loss 2.8330, CE val loss 3.0515
#
# step 6100: KL train loss 0.0442, KL val loss 0.0464
# DLITE train loss 0.4589, DLITE val loss 0.4843
# CE train loss 2.8740, CE val loss 3.0185
#
# step 6200: KL train loss 0.0435, KL val loss 0.0465
# DLITE train loss 0.4567, DLITE val loss 0.4841
# CE train loss 2.8272, CE val loss 3.0219
#
# step 6300: KL train loss 0.0436, KL val loss 0.0469
# DLITE train loss 0.4552, DLITE val loss 0.4865
# CE train loss 2.8338, CE val loss 3.0503
#
# step 6400: KL train loss 0.0428, KL val loss 0.0463
# DLITE train loss 0.4559, DLITE val loss 0.4871
# CE train loss 2.7814, CE val loss 3.0067
#
# step 6500: KL train loss 0.0432, KL val loss 0.0456
# DLITE train loss 0.4526, DLITE val loss 0.4779
# CE train loss 2.8058, CE val loss 2.9659
#
# step 6600: KL train loss 0.0432, KL val loss 0.0462
# DLITE train loss 0.4536, DLITE val loss 0.4818
# CE train loss 2.8095, CE val loss 3.0001
#
# step 6700: KL train loss 0.0427, KL val loss 0.0461
# DLITE train loss 0.4516, DLITE val loss 0.4825
# CE train loss 2.7773, CE val loss 2.9940
#
# step 6800: KL train loss 0.0434, KL val loss 0.0467
# DLITE train loss 0.4532, DLITE val loss 0.4823
# CE train loss 2.8216, CE val loss 3.0387
#
# step 6900: KL train loss 0.0430, KL val loss 0.0459
# DLITE train loss 0.4518, DLITE val loss 0.4805
# CE train loss 2.7966, CE val loss 2.9824
#
# step 7000: KL train loss 0.0430, KL val loss 0.0461
# DLITE train loss 0.4509, DLITE val loss 0.4791
# CE train loss 2.7927, CE val loss 2.9942
#
# step 7100: KL train loss 0.0434, KL val loss 0.0461
# DLITE train loss 0.4527, DLITE val loss 0.4799
# CE train loss 2.8237, CE val loss 2.9973
#
# step 7200: KL train loss 0.0435, KL val loss 0.0473
# DLITE train loss 0.4491, DLITE val loss 0.4806
# CE train loss 2.8289, CE val loss 3.0719
#
# step 7300: KL train loss 0.0436, KL val loss 0.0468
# DLITE train loss 0.4502, DLITE val loss 0.4766
# CE train loss 2.8363, CE val loss 3.0395
#
# step 7400: KL train loss 0.0435, KL val loss 0.0468
# DLITE train loss 0.4490, DLITE val loss 0.4793
# CE train loss 2.8251, CE val loss 3.0435
#
# step 7500: KL train loss 0.0426, KL val loss 0.0462
# DLITE train loss 0.4451, DLITE val loss 0.4751
# CE train loss 2.7695, CE val loss 3.0031
#
# step 7600: KL train loss 0.0430, KL val loss 0.0465
# DLITE train loss 0.4489, DLITE val loss 0.4783
# CE train loss 2.7963, CE val loss 3.0214
#
# step 7700: KL train loss 0.0427, KL val loss 0.0461
# DLITE train loss 0.4458, DLITE val loss 0.4749
# CE train loss 2.7741, CE val loss 2.9954
#
# step 7800: KL train loss 0.0437, KL val loss 0.0467
# DLITE train loss 0.4505, DLITE val loss 0.4744
# CE train loss 2.8397, CE val loss 3.0345
#
# step 7900: KL train loss 0.0434, KL val loss 0.0469
# DLITE train loss 0.4477, DLITE val loss 0.4756
# CE train loss 2.8181, CE val loss 3.0458
#
# step 8000: KL train loss 0.0427, KL val loss 0.0460
# DLITE train loss 0.4461, DLITE val loss 0.4747
# CE train loss 2.7784, CE val loss 2.9874
#
# step 8100: KL train loss 0.0419, KL val loss 0.0454
# DLITE train loss 0.4462, DLITE val loss 0.4765
# CE train loss 2.7253, CE val loss 2.9480
#
# step 8200: KL train loss 0.0429, KL val loss 0.0461
# DLITE train loss 0.4465, DLITE val loss 0.4761
# CE train loss 2.7887, CE val loss 2.9966
#
# step 8300: KL train loss 0.0427, KL val loss 0.0461
# DLITE train loss 0.4459, DLITE val loss 0.4753
# CE train loss 2.7755, CE val loss 2.9940
#
# step 8400: KL train loss 0.0419, KL val loss 0.0457
# DLITE train loss 0.4442, DLITE val loss 0.4739
# CE train loss 2.7240, CE val loss 2.9694
#
# step 8500: KL train loss 0.0422, KL val loss 0.0457
# DLITE train loss 0.4449, DLITE val loss 0.4745
# CE train loss 2.7446, CE val loss 2.9720
#
# step 8600: KL train loss 0.0426, KL val loss 0.0463
# DLITE train loss 0.4435, DLITE val loss 0.4745
# CE train loss 2.7695, CE val loss 3.0113
#
# step 8700: KL train loss 0.0418, KL val loss 0.0455
# DLITE train loss 0.4418, DLITE val loss 0.4748
# CE train loss 2.7199, CE val loss 2.9591
#
# step 8800: KL train loss 0.0416, KL val loss 0.0454
# DLITE train loss 0.4385, DLITE val loss 0.4748
# CE train loss 2.7050, CE val loss 2.9509
#
# step 8900: KL train loss 0.0422, KL val loss 0.0452
# DLITE train loss 0.4408, DLITE val loss 0.4697
# CE train loss 2.7435, CE val loss 2.9385
#
# step 9000: KL train loss 0.0418, KL val loss 0.0453
# DLITE train loss 0.4418, DLITE val loss 0.4727
# CE train loss 2.7178, CE val loss 2.9473
#
# step 9100: KL train loss 0.0418, KL val loss 0.0455
# DLITE train loss 0.4393, DLITE val loss 0.4715
# CE train loss 2.7178, CE val loss 2.9555
#
# step 9200: KL train loss 0.0427, KL val loss 0.0460
# DLITE train loss 0.4426, DLITE val loss 0.4696
# CE train loss 2.7726, CE val loss 2.9916
#
# step 9300: KL train loss 0.0415, KL val loss 0.0454
# DLITE train loss 0.4385, DLITE val loss 0.4675
# CE train loss 2.6948, CE val loss 2.9485
#
# step 9400: KL train loss 0.0417, KL val loss 0.0451
# DLITE train loss 0.4391, DLITE val loss 0.4677
# CE train loss 2.7124, CE val loss 2.9322
#
# step 9500: KL train loss 0.0417, KL val loss 0.0457
# DLITE train loss 0.4398, DLITE val loss 0.4713
# CE train loss 2.7114, CE val loss 2.9713
#
# step 9600: KL train loss 0.0423, KL val loss 0.0460
# DLITE train loss 0.4393, DLITE val loss 0.4702
# CE train loss 2.7510, CE val loss 2.9893
#
# step 9700: KL train loss 0.0418, KL val loss 0.0452
# DLITE train loss 0.4386, DLITE val loss 0.4707
# CE train loss 2.7161, CE val loss 2.9381
#
# step 9800: KL train loss 0.0422, KL val loss 0.0458
# DLITE train loss 0.4375, DLITE val loss 0.4726
# CE train loss 2.7451, CE val loss 2.9792
#
# step 9900: KL train loss 0.0419, KL val loss 0.0456
# DLITE train loss 0.4378, DLITE val loss 0.4684
# CE train loss 2.7243, CE val loss 2.9665
#
# step 9999: KL train loss 0.0423, KL val loss 0.0457
# DLITE train loss 0.4371, DLITE val loss 0.4678
# CE train loss 2.7516, CE val loss 2.9701
#
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Train with CE

# %%
torch.manual_seed(1337)


model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')



# Create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()  # Cross-Entropy loss
kl_loss = KLDivergenceLoss()


# Lists to store the loss values
dlite_train_losses_ce = []
dlite_val_losses_ce = []
ce_train_losses_ce = []  # Cross-Entropy train losses
ce_val_losses_ce = []    # Cross-Entropy validation losses
kl_train_losses_ce = []
kl_val_losses_ce = []


for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses_ce.append(dlite_losses['train'])
        dlite_val_losses_ce.append(dlite_losses['val'])
        ce_train_losses_ce.append(ce_losses['train'])
        ce_val_losses_ce.append(ce_losses['val'])
        kl_train_losses_ce.append(kl_losses['train'])
        kl_val_losses_ce.append(kl_losses['val'])



    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the CE loss using the flattened logits and targets
    loss = ce_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Convert evaluation interval steps to actual iterations
eval_points = [i * eval_interval for i in range(len(dlite_train_losses_dlite))]

# Plotting DLITE Loss
plot_losses(dlite_train_losses_ce, dlite_val_losses_ce, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses_ce, ce_val_losses_ce, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses_ce, kl_val_losses_ce, 'KL Divergence Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 0.0679, KL val loss 0.0677
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
#
# step 100: KL train loss 0.0409, KL val loss 0.0410
# DLITE train loss 0.6977, DLITE val loss 0.6981
# CE train loss 2.6568, CE val loss 2.6670
#
# step 200: KL train loss 0.0386, KL val loss 0.0386
# DLITE train loss 0.6712, DLITE val loss 0.6701
# CE train loss 2.5091, CE val loss 2.5060
#
# step 300: KL train loss 0.0372, KL val loss 0.0374
# DLITE train loss 0.6491, DLITE val loss 0.6506
# CE train loss 2.4199, CE val loss 2.4337
#
# step 400: KL train loss 0.0362, KL val loss 0.0363
# DLITE train loss 0.6344, DLITE val loss 0.6347
# CE train loss 2.3500, CE val loss 2.3563
#
# step 500: KL train loss 0.0353, KL val loss 0.0356
# DLITE train loss 0.6187, DLITE val loss 0.6209
# CE train loss 2.2961, CE val loss 2.3126
#
# step 600: KL train loss 0.0345, KL val loss 0.0346
# DLITE train loss 0.6099, DLITE val loss 0.6097
# CE train loss 2.2408, CE val loss 2.2501
#
# step 700: KL train loss 0.0339, KL val loss 0.0341
# DLITE train loss 0.5983, DLITE val loss 0.5998
# CE train loss 2.2053, CE val loss 2.2187
#
# step 800: KL train loss 0.0333, KL val loss 0.0336
# DLITE train loss 0.5913, DLITE val loss 0.5943
# CE train loss 2.1636, CE val loss 2.1870
#
# step 900: KL train loss 0.0327, KL val loss 0.0331
# DLITE train loss 0.5822, DLITE val loss 0.5860
# CE train loss 2.1226, CE val loss 2.1483
#
# step 1000: KL train loss 0.0323, KL val loss 0.0327
# DLITE train loss 0.5737, DLITE val loss 0.5772
# CE train loss 2.1017, CE val loss 2.1283
#
# step 1100: KL train loss 0.0318, KL val loss 0.0326
# DLITE train loss 0.5697, DLITE val loss 0.5770
# CE train loss 2.0683, CE val loss 2.1174
#
# step 1200: KL train loss 0.0313, KL val loss 0.0320
# DLITE train loss 0.5615, DLITE val loss 0.5675
# CE train loss 2.0376, CE val loss 2.0798
#
# step 1300: KL train loss 0.0312, KL val loss 0.0318
# DLITE train loss 0.5549, DLITE val loss 0.5610
# CE train loss 2.0256, CE val loss 2.0645
#
# step 1400: KL train loss 0.0306, KL val loss 0.0313
# DLITE train loss 0.5483, DLITE val loss 0.5555
# CE train loss 1.9919, CE val loss 2.0362
#
# step 1500: KL train loss 0.0303, KL val loss 0.0312
# DLITE train loss 0.5448, DLITE val loss 0.5552
# CE train loss 1.9696, CE val loss 2.0304
#
# step 1600: KL train loss 0.0302, KL val loss 0.0315
# DLITE train loss 0.5415, DLITE val loss 0.5553
# CE train loss 1.9625, CE val loss 2.0470
#
# step 1700: KL train loss 0.0298, KL val loss 0.0310
# DLITE train loss 0.5356, DLITE val loss 0.5473
# CE train loss 1.9402, CE val loss 2.0119
#
# step 1800: KL train loss 0.0294, KL val loss 0.0307
# DLITE train loss 0.5269, DLITE val loss 0.5430
# CE train loss 1.9085, CE val loss 1.9957
#
# step 1900: KL train loss 0.0294, KL val loss 0.0306
# DLITE train loss 0.5276, DLITE val loss 0.5404
# CE train loss 1.9080, CE val loss 1.9869
#
# step 2000: KL train loss 0.0290, KL val loss 0.0307
# DLITE train loss 0.5210, DLITE val loss 0.5402
# CE train loss 1.8834, CE val loss 1.9941
#
# step 2100: KL train loss 0.0288, KL val loss 0.0304
# DLITE train loss 0.5212, DLITE val loss 0.5399
# CE train loss 1.8727, CE val loss 1.9758
#
# step 2200: KL train loss 0.0286, KL val loss 0.0302
# DLITE train loss 0.5172, DLITE val loss 0.5355
# CE train loss 1.8585, CE val loss 1.9622
#
# step 2300: KL train loss 0.0285, KL val loss 0.0300
# DLITE train loss 0.5167, DLITE val loss 0.5344
# CE train loss 1.8537, CE val loss 1.9503
#
# step 2400: KL train loss 0.0283, KL val loss 0.0299
# DLITE train loss 0.5114, DLITE val loss 0.5293
# CE train loss 1.8419, CE val loss 1.9424
#
# step 2500: KL train loss 0.0279, KL val loss 0.0299
# DLITE train loss 0.5027, DLITE val loss 0.5263
# CE train loss 1.8153, CE val loss 1.9407
#
# step 2600: KL train loss 0.0281, KL val loss 0.0298
# DLITE train loss 0.5040, DLITE val loss 0.5246
# CE train loss 1.8267, CE val loss 1.9374
#
# step 2700: KL train loss 0.0279, KL val loss 0.0298
# DLITE train loss 0.5032, DLITE val loss 0.5266
# CE train loss 1.8126, CE val loss 1.9344
#
# step 2800: KL train loss 0.0278, KL val loss 0.0296
# DLITE train loss 0.5031, DLITE val loss 0.5249
# CE train loss 1.8054, CE val loss 1.9230
#
# step 2900: KL train loss 0.0278, KL val loss 0.0298
# DLITE train loss 0.5026, DLITE val loss 0.5255
# CE train loss 1.8045, CE val loss 1.9339
#
# step 3000: KL train loss 0.0276, KL val loss 0.0296
# DLITE train loss 0.4957, DLITE val loss 0.5196
# CE train loss 1.7963, CE val loss 1.9243
#
# step 3100: KL train loss 0.0272, KL val loss 0.0296
# DLITE train loss 0.4956, DLITE val loss 0.5228
# CE train loss 1.7691, CE val loss 1.9208
#
# step 3200: KL train loss 0.0269, KL val loss 0.0294
# DLITE train loss 0.4873, DLITE val loss 0.5159
# CE train loss 1.7506, CE val loss 1.9092
#
# step 3300: KL train loss 0.0270, KL val loss 0.0293
# DLITE train loss 0.4908, DLITE val loss 0.5188
# CE train loss 1.7548, CE val loss 1.9038
#
# step 3400: KL train loss 0.0270, KL val loss 0.0292
# DLITE train loss 0.4906, DLITE val loss 0.5151
# CE train loss 1.7582, CE val loss 1.8960
#
# step 3500: KL train loss 0.0267, KL val loss 0.0291
# DLITE train loss 0.4852, DLITE val loss 0.5132
# CE train loss 1.7376, CE val loss 1.8934
#
# step 3600: KL train loss 0.0265, KL val loss 0.0291
# DLITE train loss 0.4796, DLITE val loss 0.5107
# CE train loss 1.7232, CE val loss 1.8888
#
# step 3700: KL train loss 0.0266, KL val loss 0.0289
# DLITE train loss 0.4819, DLITE val loss 0.5110
# CE train loss 1.7280, CE val loss 1.8814
#
# step 3800: KL train loss 0.0265, KL val loss 0.0292
# DLITE train loss 0.4800, DLITE val loss 0.5123
# CE train loss 1.7221, CE val loss 1.8951
#
# step 3900: KL train loss 0.0265, KL val loss 0.0289
# DLITE train loss 0.4779, DLITE val loss 0.5063
# CE train loss 1.7228, CE val loss 1.8789
#
# step 4000: KL train loss 0.0264, KL val loss 0.0287
# DLITE train loss 0.4774, DLITE val loss 0.5047
# CE train loss 1.7168, CE val loss 1.8635
#
# step 4100: KL train loss 0.0264, KL val loss 0.0289
# DLITE train loss 0.4792, DLITE val loss 0.5093
# CE train loss 1.7168, CE val loss 1.8798
#
# step 4200: KL train loss 0.0263, KL val loss 0.0287
# DLITE train loss 0.4763, DLITE val loss 0.5064
# CE train loss 1.7088, CE val loss 1.8672
#
# step 4300: KL train loss 0.0261, KL val loss 0.0285
# DLITE train loss 0.4718, DLITE val loss 0.5006
# CE train loss 1.6995, CE val loss 1.8501
#
# step 4400: KL train loss 0.0263, KL val loss 0.0287
# DLITE train loss 0.4784, DLITE val loss 0.5074
# CE train loss 1.7096, CE val loss 1.8686
#
# step 4500: KL train loss 0.0260, KL val loss 0.0285
# DLITE train loss 0.4741, DLITE val loss 0.5041
# CE train loss 1.6907, CE val loss 1.8546
#
# step 4600: KL train loss 0.0260, KL val loss 0.0282
# DLITE train loss 0.4710, DLITE val loss 0.4995
# CE train loss 1.6868, CE val loss 1.8348
#
# step 4700: KL train loss 0.0258, KL val loss 0.0282
# DLITE train loss 0.4675, DLITE val loss 0.4969
# CE train loss 1.6786, CE val loss 1.8346
#
# step 4800: KL train loss 0.0256, KL val loss 0.0284
# DLITE train loss 0.4651, DLITE val loss 0.4984
# CE train loss 1.6659, CE val loss 1.8445
#
# step 4900: KL train loss 0.0257, KL val loss 0.0283
# DLITE train loss 0.4679, DLITE val loss 0.4990
# CE train loss 1.6711, CE val loss 1.8384
#
# step 5000: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4669, DLITE val loss 0.4963
# CE train loss 1.6623, CE val loss 1.8231
#
# step 5100: KL train loss 0.0257, KL val loss 0.0282
# DLITE train loss 0.4693, DLITE val loss 0.4981
# CE train loss 1.6695, CE val loss 1.8326
#
# step 5200: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4625, DLITE val loss 0.4915
# CE train loss 1.6639, CE val loss 1.8206
#
# step 5300: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4646, DLITE val loss 0.4943
# CE train loss 1.6657, CE val loss 1.8215
#
# step 5400: KL train loss 0.0254, KL val loss 0.0280
# DLITE train loss 0.4605, DLITE val loss 0.4927
# CE train loss 1.6510, CE val loss 1.8186
#
# step 5500: KL train loss 0.0254, KL val loss 0.0277
# DLITE train loss 0.4616, DLITE val loss 0.4900
# CE train loss 1.6533, CE val loss 1.7999
#
# step 5600: KL train loss 0.0255, KL val loss 0.0279
# DLITE train loss 0.4650, DLITE val loss 0.4944
# CE train loss 1.6572, CE val loss 1.8126
#
# step 5700: KL train loss 0.0254, KL val loss 0.0279
# DLITE train loss 0.4640, DLITE val loss 0.4939
# CE train loss 1.6538, CE val loss 1.8137
#
# step 5800: KL train loss 0.0252, KL val loss 0.0278
# DLITE train loss 0.4596, DLITE val loss 0.4906
# CE train loss 1.6408, CE val loss 1.8069
#
# step 5900: KL train loss 0.0253, KL val loss 0.0277
# DLITE train loss 0.4580, DLITE val loss 0.4889
# CE train loss 1.6427, CE val loss 1.8025
#
# step 6000: KL train loss 0.0253, KL val loss 0.0278
# DLITE train loss 0.4590, DLITE val loss 0.4902
# CE train loss 1.6416, CE val loss 1.8054
#
# step 6100: KL train loss 0.0252, KL val loss 0.0275
# DLITE train loss 0.4572, DLITE val loss 0.4847
# CE train loss 1.6378, CE val loss 1.7866
#
# step 6200: KL train loss 0.0253, KL val loss 0.0276
# DLITE train loss 0.4580, DLITE val loss 0.4843
# CE train loss 1.6419, CE val loss 1.7910
#
# step 6300: KL train loss 0.0250, KL val loss 0.0276
# DLITE train loss 0.4572, DLITE val loss 0.4872
# CE train loss 1.6263, CE val loss 1.7916
#
# step 6400: KL train loss 0.0250, KL val loss 0.0277
# DLITE train loss 0.4575, DLITE val loss 0.4890
# CE train loss 1.6266, CE val loss 1.8014
#
# step 6500: KL train loss 0.0250, KL val loss 0.0275
# DLITE train loss 0.4553, DLITE val loss 0.4849
# CE train loss 1.6252, CE val loss 1.7859
#
# step 6600: KL train loss 0.0250, KL val loss 0.0274
# DLITE train loss 0.4536, DLITE val loss 0.4819
# CE train loss 1.6222, CE val loss 1.7820
#
# step 6700: KL train loss 0.0250, KL val loss 0.0278
# DLITE train loss 0.4550, DLITE val loss 0.4862
# CE train loss 1.6225, CE val loss 1.8044
#
# step 6800: KL train loss 0.0249, KL val loss 0.0277
# DLITE train loss 0.4523, DLITE val loss 0.4845
# CE train loss 1.6205, CE val loss 1.7999
#
# step 6900: KL train loss 0.0248, KL val loss 0.0275
# DLITE train loss 0.4528, DLITE val loss 0.4849
# CE train loss 1.6149, CE val loss 1.7875
#
# step 7000: KL train loss 0.0249, KL val loss 0.0274
# DLITE train loss 0.4547, DLITE val loss 0.4847
# CE train loss 1.6156, CE val loss 1.7827
#
# step 7100: KL train loss 0.0249, KL val loss 0.0275
# DLITE train loss 0.4528, DLITE val loss 0.4839
# CE train loss 1.6201, CE val loss 1.7854
#
# step 7200: KL train loss 0.0248, KL val loss 0.0276
# DLITE train loss 0.4508, DLITE val loss 0.4822
# CE train loss 1.6111, CE val loss 1.7919
#
# step 7300: KL train loss 0.0248, KL val loss 0.0272
# DLITE train loss 0.4503, DLITE val loss 0.4788
# CE train loss 1.6096, CE val loss 1.7709
#
# step 7400: KL train loss 0.0248, KL val loss 0.0275
# DLITE train loss 0.4490, DLITE val loss 0.4811
# CE train loss 1.6096, CE val loss 1.7861
#
# step 7500: KL train loss 0.0246, KL val loss 0.0275
# DLITE train loss 0.4493, DLITE val loss 0.4833
# CE train loss 1.5971, CE val loss 1.7893
#
# step 7600: KL train loss 0.0247, KL val loss 0.0274
# DLITE train loss 0.4496, DLITE val loss 0.4817
# CE train loss 1.6028, CE val loss 1.7803
#
# step 7700: KL train loss 0.0245, KL val loss 0.0273
# DLITE train loss 0.4490, DLITE val loss 0.4808
# CE train loss 1.5944, CE val loss 1.7718
#
# step 7800: KL train loss 0.0247, KL val loss 0.0272
# DLITE train loss 0.4509, DLITE val loss 0.4791
# CE train loss 1.6075, CE val loss 1.7672
#
# step 7900: KL train loss 0.0247, KL val loss 0.0272
# DLITE train loss 0.4497, DLITE val loss 0.4788
# CE train loss 1.6053, CE val loss 1.7707
#
# step 8000: KL train loss 0.0246, KL val loss 0.0273
# DLITE train loss 0.4491, DLITE val loss 0.4815
# CE train loss 1.5975, CE val loss 1.7717
#
# step 8100: KL train loss 0.0246, KL val loss 0.0273
# DLITE train loss 0.4513, DLITE val loss 0.4845
# CE train loss 1.6001, CE val loss 1.7770
#
# step 8200: KL train loss 0.0246, KL val loss 0.0274
# DLITE train loss 0.4469, DLITE val loss 0.4798
# CE train loss 1.6006, CE val loss 1.7825
#
# step 8300: KL train loss 0.0244, KL val loss 0.0271
# DLITE train loss 0.4460, DLITE val loss 0.4761
# CE train loss 1.5888, CE val loss 1.7603
#
# step 8400: KL train loss 0.0245, KL val loss 0.0273
# DLITE train loss 0.4476, DLITE val loss 0.4795
# CE train loss 1.5945, CE val loss 1.7733
#
# step 8500: KL train loss 0.0245, KL val loss 0.0272
# DLITE train loss 0.4478, DLITE val loss 0.4799
# CE train loss 1.5904, CE val loss 1.7711
#
# step 8600: KL train loss 0.0245, KL val loss 0.0272
# DLITE train loss 0.4429, DLITE val loss 0.4749
# CE train loss 1.5917, CE val loss 1.7695
#
# step 8700: KL train loss 0.0244, KL val loss 0.0272
# DLITE train loss 0.4453, DLITE val loss 0.4802
# CE train loss 1.5844, CE val loss 1.7701
#
# step 8800: KL train loss 0.0242, KL val loss 0.0272
# DLITE train loss 0.4414, DLITE val loss 0.4773
# CE train loss 1.5731, CE val loss 1.7677
#
# step 8900: KL train loss 0.0244, KL val loss 0.0268
# DLITE train loss 0.4444, DLITE val loss 0.4736
# CE train loss 1.5850, CE val loss 1.7448
#
# step 9000: KL train loss 0.0244, KL val loss 0.0271
# DLITE train loss 0.4480, DLITE val loss 0.4804
# CE train loss 1.5847, CE val loss 1.7643
#
# step 9100: KL train loss 0.0243, KL val loss 0.0271
# DLITE train loss 0.4423, DLITE val loss 0.4763
# CE train loss 1.5767, CE val loss 1.7637
#
# step 9200: KL train loss 0.0244, KL val loss 0.0271
# DLITE train loss 0.4426, DLITE val loss 0.4743
# CE train loss 1.5841, CE val loss 1.7616
#
# step 9300: KL train loss 0.0241, KL val loss 0.0269
# DLITE train loss 0.4443, DLITE val loss 0.4755
# CE train loss 1.5687, CE val loss 1.7457
#
# step 9400: KL train loss 0.0242, KL val loss 0.0269
# DLITE train loss 0.4454, DLITE val loss 0.4768
# CE train loss 1.5737, CE val loss 1.7483
#
# step 9500: KL train loss 0.0242, KL val loss 0.0271
# DLITE train loss 0.4433, DLITE val loss 0.4768
# CE train loss 1.5743, CE val loss 1.7633
#
# step 9600: KL train loss 0.0242, KL val loss 0.0270
# DLITE train loss 0.4424, DLITE val loss 0.4751
# CE train loss 1.5738, CE val loss 1.7561
#
# step 9700: KL train loss 0.0241, KL val loss 0.0268
# DLITE train loss 0.4416, DLITE val loss 0.4733
# CE train loss 1.5693, CE val loss 1.7401
#
# step 9800: KL train loss 0.0239, KL val loss 0.0270
# DLITE train loss 0.4373, DLITE val loss 0.4740
# CE train loss 1.5567, CE val loss 1.7577
#
# step 9900: KL train loss 0.0241, KL val loss 0.0269
# DLITE train loss 0.4406, DLITE val loss 0.4713
# CE train loss 1.5692, CE val loss 1.7480
#
# step 9999: KL train loss 0.0240, KL val loss 0.0269
# DLITE train loss 0.4388, DLITE val loss 0.4716
# CE train loss 1.5600, CE val loss 1.7477

# %% [markdown]
# ## Train with KL divergence loss

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters()) / 1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()  # Cross-Entropy loss
kl_loss = KLDivergenceLoss()

# Lists to store the loss values
kl_train_losses_kl = []
kl_val_losses_kl = []
dlite_train_losses_kl = []
dlite_val_losses_kl = []
ce_train_losses_kl = []
ce_val_losses_kl = []

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}\n")

        # Append the losses for this iteration
        kl_train_losses_kl.append(kl_losses['train'])
        kl_val_losses_kl.append(kl_losses['val'])
        dlite_train_losses_kl.append(dlite_losses['train'])
        dlite_val_losses_kl.append(dlite_losses['val'])
        ce_train_losses_kl.append(ce_losses['train'])
        ce_val_losses_kl.append(ce_losses['val'])

    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)

    # Compute the KL Divergence loss using the flattened logits and targets
    kl_loss_value = kl_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    kl_loss_value.backward()
    optimizer.step()

# Plotting DLITE Loss
plot_losses(dlite_train_losses_kl, dlite_val_losses_kl, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses_kl, ce_val_losses_kl, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses_kl, kl_val_losses_kl, 'KL Divergence Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 0.0679, KL val loss 0.0677
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
#
# step 100: KL train loss 0.0409, KL val loss 0.0410
# DLITE train loss 0.6977, DLITE val loss 0.6982
# CE train loss 2.6571, CE val loss 2.6673
#
# step 200: KL train loss 0.0386, KL val loss 0.0386
# DLITE train loss 0.6712, DLITE val loss 0.6702
# CE train loss 2.5095, CE val loss 2.5063
#
# step 300: KL train loss 0.0372, KL val loss 0.0374
# DLITE train loss 0.6491, DLITE val loss 0.6506
# CE train loss 2.4197, CE val loss 2.4338
#
# step 400: KL train loss 0.0362, KL val loss 0.0363
# DLITE train loss 0.6344, DLITE val loss 0.6348
# CE train loss 2.3508, CE val loss 2.3571
#
# step 500: KL train loss 0.0353, KL val loss 0.0356
# DLITE train loss 0.6188, DLITE val loss 0.6211
# CE train loss 2.2967, CE val loss 2.3134
#
# step 600: KL train loss 0.0345, KL val loss 0.0346
# DLITE train loss 0.6102, DLITE val loss 0.6097
# CE train loss 2.2413, CE val loss 2.2498
#
# step 700: KL train loss 0.0339, KL val loss 0.0341
# DLITE train loss 0.5984, DLITE val loss 0.5999
# CE train loss 2.2055, CE val loss 2.2188
#
# step 800: KL train loss 0.0333, KL val loss 0.0336
# DLITE train loss 0.5910, DLITE val loss 0.5941
# CE train loss 2.1632, CE val loss 2.1866
#
# step 900: KL train loss 0.0327, KL val loss 0.0331
# DLITE train loss 0.5825, DLITE val loss 0.5863
# CE train loss 2.1245, CE val loss 2.1505
#
# step 1000: KL train loss 0.0323, KL val loss 0.0328
# DLITE train loss 0.5735, DLITE val loss 0.5771
# CE train loss 2.1027, CE val loss 2.1291
#
# step 1100: KL train loss 0.0319, KL val loss 0.0326
# DLITE train loss 0.5703, DLITE val loss 0.5775
# CE train loss 2.0705, CE val loss 2.1190
#
# step 1200: KL train loss 0.0313, KL val loss 0.0320
# DLITE train loss 0.5618, DLITE val loss 0.5677
# CE train loss 2.0372, CE val loss 2.0785
#
# step 1300: KL train loss 0.0312, KL val loss 0.0318
# DLITE train loss 0.5548, DLITE val loss 0.5610
# CE train loss 2.0255, CE val loss 2.0649
#
# step 1400: KL train loss 0.0306, KL val loss 0.0313
# DLITE train loss 0.5482, DLITE val loss 0.5553
# CE train loss 1.9913, CE val loss 2.0351
#
# step 1500: KL train loss 0.0303, KL val loss 0.0312
# DLITE train loss 0.5446, DLITE val loss 0.5547
# CE train loss 1.9688, CE val loss 2.0287
#
# step 1600: KL train loss 0.0302, KL val loss 0.0315
# DLITE train loss 0.5422, DLITE val loss 0.5558
# CE train loss 1.9655, CE val loss 2.0495
#
# step 1700: KL train loss 0.0298, KL val loss 0.0310
# DLITE train loss 0.5352, DLITE val loss 0.5473
# CE train loss 1.9394, CE val loss 2.0128
#
# step 1800: KL train loss 0.0294, KL val loss 0.0307
# DLITE train loss 0.5268, DLITE val loss 0.5432
# CE train loss 1.9093, CE val loss 1.9972
#
# step 1900: KL train loss 0.0294, KL val loss 0.0306
# DLITE train loss 0.5285, DLITE val loss 0.5412
# CE train loss 1.9109, CE val loss 1.9902
#
# step 2000: KL train loss 0.0290, KL val loss 0.0307
# DLITE train loss 0.5209, DLITE val loss 0.5402
# CE train loss 1.8828, CE val loss 1.9939
#
# step 2100: KL train loss 0.0288, KL val loss 0.0304
# DLITE train loss 0.5210, DLITE val loss 0.5400
# CE train loss 1.8718, CE val loss 1.9764
#
# step 2200: KL train loss 0.0286, KL val loss 0.0302
# DLITE train loss 0.5169, DLITE val loss 0.5351
# CE train loss 1.8597, CE val loss 1.9612
#
# step 2300: KL train loss 0.0285, KL val loss 0.0300
# DLITE train loss 0.5172, DLITE val loss 0.5345
# CE train loss 1.8547, CE val loss 1.9508
#
# step 2400: KL train loss 0.0284, KL val loss 0.0300
# DLITE train loss 0.5115, DLITE val loss 0.5301
# CE train loss 1.8432, CE val loss 1.9472
#
# step 2500: KL train loss 0.0280, KL val loss 0.0299
# DLITE train loss 0.5030, DLITE val loss 0.5270
# CE train loss 1.8172, CE val loss 1.9445
#
# step 2600: KL train loss 0.0281, KL val loss 0.0299
# DLITE train loss 0.5045, DLITE val loss 0.5259
# CE train loss 1.8272, CE val loss 1.9414
#
# step 2700: KL train loss 0.0279, KL val loss 0.0297
# DLITE train loss 0.5033, DLITE val loss 0.5263
# CE train loss 1.8105, CE val loss 1.9305
#
# step 2800: KL train loss 0.0277, KL val loss 0.0295
# DLITE train loss 0.5018, DLITE val loss 0.5236
# CE train loss 1.8020, CE val loss 1.9186
#
# step 2900: KL train loss 0.0277, KL val loss 0.0297
# DLITE train loss 0.5031, DLITE val loss 0.5255
# CE train loss 1.8032, CE val loss 1.9290
#
# step 3000: KL train loss 0.0276, KL val loss 0.0296
# DLITE train loss 0.4963, DLITE val loss 0.5196
# CE train loss 1.7969, CE val loss 1.9216
#
# step 3100: KL train loss 0.0272, KL val loss 0.0295
# DLITE train loss 0.4954, DLITE val loss 0.5223
# CE train loss 1.7670, CE val loss 1.9182
#
# step 3200: KL train loss 0.0270, KL val loss 0.0294
# DLITE train loss 0.4873, DLITE val loss 0.5158
# CE train loss 1.7523, CE val loss 1.9086
#
# step 3300: KL train loss 0.0270, KL val loss 0.0293
# DLITE train loss 0.4900, DLITE val loss 0.5183
# CE train loss 1.7558, CE val loss 1.9048
#
# step 3400: KL train loss 0.0270, KL val loss 0.0292
# DLITE train loss 0.4901, DLITE val loss 0.5149
# CE train loss 1.7535, CE val loss 1.8953
#
# step 3500: KL train loss 0.0267, KL val loss 0.0291
# DLITE train loss 0.4836, DLITE val loss 0.5120
# CE train loss 1.7362, CE val loss 1.8923
#
# step 3600: KL train loss 0.0265, KL val loss 0.0290
# DLITE train loss 0.4804, DLITE val loss 0.5111
# CE train loss 1.7242, CE val loss 1.8875
#
# step 3700: KL train loss 0.0266, KL val loss 0.0290
# DLITE train loss 0.4822, DLITE val loss 0.5120
# CE train loss 1.7282, CE val loss 1.8850
#
# step 3800: KL train loss 0.0265, KL val loss 0.0291
# DLITE train loss 0.4800, DLITE val loss 0.5119
# CE train loss 1.7205, CE val loss 1.8925
#
# step 3900: KL train loss 0.0265, KL val loss 0.0288
# DLITE train loss 0.4774, DLITE val loss 0.5055
# CE train loss 1.7217, CE val loss 1.8716
#
# step 4000: KL train loss 0.0263, KL val loss 0.0286
# DLITE train loss 0.4772, DLITE val loss 0.5050
# CE train loss 1.7114, CE val loss 1.8621
#
# step 4100: KL train loss 0.0264, KL val loss 0.0289
# DLITE train loss 0.4798, DLITE val loss 0.5095
# CE train loss 1.7158, CE val loss 1.8781
#
# step 4200: KL train loss 0.0263, KL val loss 0.0287
# DLITE train loss 0.4773, DLITE val loss 0.5071
# CE train loss 1.7074, CE val loss 1.8664
#
# step 4300: KL train loss 0.0262, KL val loss 0.0285
# DLITE train loss 0.4724, DLITE val loss 0.5009
# CE train loss 1.6998, CE val loss 1.8499
#
# step 4400: KL train loss 0.0263, KL val loss 0.0288
# DLITE train loss 0.4767, DLITE val loss 0.5070
# CE train loss 1.7065, CE val loss 1.8691
#
# step 4500: KL train loss 0.0260, KL val loss 0.0284
# DLITE train loss 0.4735, DLITE val loss 0.5031
# CE train loss 1.6918, CE val loss 1.8491
#
# step 4600: KL train loss 0.0260, KL val loss 0.0282
# DLITE train loss 0.4710, DLITE val loss 0.4995
# CE train loss 1.6880, CE val loss 1.8339
#
# step 4700: KL train loss 0.0259, KL val loss 0.0283
# DLITE train loss 0.4692, DLITE val loss 0.4988
# CE train loss 1.6847, CE val loss 1.8403
#
# step 4800: KL train loss 0.0257, KL val loss 0.0284
# DLITE train loss 0.4649, DLITE val loss 0.4980
# CE train loss 1.6684, CE val loss 1.8464
#
# step 4900: KL train loss 0.0257, KL val loss 0.0282
# DLITE train loss 0.4671, DLITE val loss 0.4971
# CE train loss 1.6676, CE val loss 1.8310
#
# step 5000: KL train loss 0.0256, KL val loss 0.0281
# DLITE train loss 0.4658, DLITE val loss 0.4957
# CE train loss 1.6645, CE val loss 1.8287
#
# step 5100: KL train loss 0.0257, KL val loss 0.0282
# DLITE train loss 0.4693, DLITE val loss 0.4984
# CE train loss 1.6732, CE val loss 1.8362
#
# step 5200: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4627, DLITE val loss 0.4927
# CE train loss 1.6609, CE val loss 1.8226
#
# step 5300: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4650, DLITE val loss 0.4960
# CE train loss 1.6624, CE val loss 1.8214
#
# step 5400: KL train loss 0.0254, KL val loss 0.0279
# DLITE train loss 0.4616, DLITE val loss 0.4932
# CE train loss 1.6524, CE val loss 1.8156
#
# step 5500: KL train loss 0.0254, KL val loss 0.0277
# DLITE train loss 0.4611, DLITE val loss 0.4903
# CE train loss 1.6488, CE val loss 1.7976
#
# step 5600: KL train loss 0.0256, KL val loss 0.0280
# DLITE train loss 0.4657, DLITE val loss 0.4951
# CE train loss 1.6616, CE val loss 1.8173
#
# step 5700: KL train loss 0.0255, KL val loss 0.0279
# DLITE train loss 0.4646, DLITE val loss 0.4940
# CE train loss 1.6574, CE val loss 1.8159
#
# step 5800: KL train loss 0.0252, KL val loss 0.0279
# DLITE train loss 0.4592, DLITE val loss 0.4912
# CE train loss 1.6412, CE val loss 1.8157
#
# step 5900: KL train loss 0.0253, KL val loss 0.0278
# DLITE train loss 0.4606, DLITE val loss 0.4917
# CE train loss 1.6474, CE val loss 1.8086
#
# step 6000: KL train loss 0.0253, KL val loss 0.0278
# DLITE train loss 0.4597, DLITE val loss 0.4909
# CE train loss 1.6428, CE val loss 1.8039
#
# step 6100: KL train loss 0.0252, KL val loss 0.0276
# DLITE train loss 0.4572, DLITE val loss 0.4856
# CE train loss 1.6383, CE val loss 1.7909
#
# step 6200: KL train loss 0.0253, KL val loss 0.0276
# DLITE train loss 0.4595, DLITE val loss 0.4851
# CE train loss 1.6459, CE val loss 1.7922
#
# step 6300: KL train loss 0.0250, KL val loss 0.0277
# DLITE train loss 0.4579, DLITE val loss 0.4886
# CE train loss 1.6274, CE val loss 1.7984
#
# step 6400: KL train loss 0.0250, KL val loss 0.0277
# DLITE train loss 0.4581, DLITE val loss 0.4900
# CE train loss 1.6271, CE val loss 1.7990
#
# step 6500: KL train loss 0.0250, KL val loss 0.0274
# DLITE train loss 0.4560, DLITE val loss 0.4856
# CE train loss 1.6237, CE val loss 1.7835
#
# step 6600: KL train loss 0.0250, KL val loss 0.0274
# DLITE train loss 0.4536, DLITE val loss 0.4824
# CE train loss 1.6234, CE val loss 1.7823
#
# step 6700: KL train loss 0.0250, KL val loss 0.0277
# DLITE train loss 0.4550, DLITE val loss 0.4860
# CE train loss 1.6227, CE val loss 1.7986
#
# step 6800: KL train loss 0.0250, KL val loss 0.0277
# DLITE train loss 0.4517, DLITE val loss 0.4837
# CE train loss 1.6243, CE val loss 1.7991
#
# step 6900: KL train loss 0.0249, KL val loss 0.0275
# DLITE train loss 0.4521, DLITE val loss 0.4834
# CE train loss 1.6162, CE val loss 1.7867
#
# step 7000: KL train loss 0.0248, KL val loss 0.0274
# DLITE train loss 0.4529, DLITE val loss 0.4834
# CE train loss 1.6114, CE val loss 1.7839
#
# step 7100: KL train loss 0.0249, KL val loss 0.0275
# DLITE train loss 0.4527, DLITE val loss 0.4837
# CE train loss 1.6170, CE val loss 1.7852
#
# step 7200: KL train loss 0.0248, KL val loss 0.0276
# DLITE train loss 0.4504, DLITE val loss 0.4823
# CE train loss 1.6093, CE val loss 1.7941
#
# step 7300: KL train loss 0.0248, KL val loss 0.0273
# DLITE train loss 0.4508, DLITE val loss 0.4797
# CE train loss 1.6100, CE val loss 1.7769
#
# step 7400: KL train loss 0.0248, KL val loss 0.0274
# DLITE train loss 0.4494, DLITE val loss 0.4811
# CE train loss 1.6108, CE val loss 1.7835
#
# step 7500: KL train loss 0.0246, KL val loss 0.0275
# DLITE train loss 0.4497, DLITE val loss 0.4830
# CE train loss 1.5993, CE val loss 1.7898
#
# step 7600: KL train loss 0.0247, KL val loss 0.0275
# DLITE train loss 0.4493, DLITE val loss 0.4819
# CE train loss 1.6051, CE val loss 1.7868
#
# step 7700: KL train loss 0.0246, KL val loss 0.0273
# DLITE train loss 0.4490, DLITE val loss 0.4810
# CE train loss 1.5980, CE val loss 1.7777
#
# step 7800: KL train loss 0.0247, KL val loss 0.0272
# DLITE train loss 0.4510, DLITE val loss 0.4778
# CE train loss 1.6070, CE val loss 1.7648
#
# step 7900: KL train loss 0.0248, KL val loss 0.0274
# DLITE train loss 0.4509, DLITE val loss 0.4805
# CE train loss 1.6125, CE val loss 1.7811
#
# step 8000: KL train loss 0.0246, KL val loss 0.0274
# DLITE train loss 0.4485, DLITE val loss 0.4820
# CE train loss 1.5980, CE val loss 1.7812
#
# step 8100: KL train loss 0.0246, KL val loss 0.0273
# DLITE train loss 0.4507, DLITE val loss 0.4839
# CE train loss 1.5968, CE val loss 1.7743
#
# step 8200: KL train loss 0.0247, KL val loss 0.0275
# DLITE train loss 0.4479, DLITE val loss 0.4806
# CE train loss 1.6046, CE val loss 1.7848
#
# step 8300: KL train loss 0.0245, KL val loss 0.0271
# DLITE train loss 0.4473, DLITE val loss 0.4772
# CE train loss 1.5935, CE val loss 1.7634
#
# step 8400: KL train loss 0.0245, KL val loss 0.0273
# DLITE train loss 0.4477, DLITE val loss 0.4791
# CE train loss 1.5915, CE val loss 1.7715
#
# step 8500: KL train loss 0.0245, KL val loss 0.0272
# DLITE train loss 0.4491, DLITE val loss 0.4802
# CE train loss 1.5941, CE val loss 1.7706
#
# step 8600: KL train loss 0.0245, KL val loss 0.0274
# DLITE train loss 0.4429, DLITE val loss 0.4760
# CE train loss 1.5924, CE val loss 1.7820
#
# step 8700: KL train loss 0.0244, KL val loss 0.0272
# DLITE train loss 0.4458, DLITE val loss 0.4806
# CE train loss 1.5830, CE val loss 1.7706
#
# step 8800: KL train loss 0.0242, KL val loss 0.0272
# DLITE train loss 0.4416, DLITE val loss 0.4786
# CE train loss 1.5715, CE val loss 1.7680
#
# step 8900: KL train loss 0.0244, KL val loss 0.0268
# DLITE train loss 0.4442, DLITE val loss 0.4735
# CE train loss 1.5830, CE val loss 1.7423
#
# step 9000: KL train loss 0.0244, KL val loss 0.0270
# DLITE train loss 0.4474, DLITE val loss 0.4792
# CE train loss 1.5847, CE val loss 1.7574
#
# step 9100: KL train loss 0.0242, KL val loss 0.0270
# DLITE train loss 0.4422, DLITE val loss 0.4750
# CE train loss 1.5758, CE val loss 1.7547
#
# step 9200: KL train loss 0.0245, KL val loss 0.0272
# DLITE train loss 0.4460, DLITE val loss 0.4759
# CE train loss 1.5935, CE val loss 1.7648
#
# step 9300: KL train loss 0.0243, KL val loss 0.0268
# DLITE train loss 0.4469, DLITE val loss 0.4763
# CE train loss 1.5776, CE val loss 1.7445
#
# step 9400: KL train loss 0.0243, KL val loss 0.0268
# DLITE train loss 0.4467, DLITE val loss 0.4771
# CE train loss 1.5769, CE val loss 1.7437
#
# step 9500: KL train loss 0.0243, KL val loss 0.0271
# DLITE train loss 0.4437, DLITE val loss 0.4770
# CE train loss 1.5776, CE val loss 1.7634
#
# step 9600: KL train loss 0.0242, KL val loss 0.0270
# DLITE train loss 0.4435, DLITE val loss 0.4760
# CE train loss 1.5745, CE val loss 1.7540
#
# step 9700: KL train loss 0.0242, KL val loss 0.0268
# DLITE train loss 0.4418, DLITE val loss 0.4734
# CE train loss 1.5730, CE val loss 1.7427
#
# step 9800: KL train loss 0.0240, KL val loss 0.0270
# DLITE train loss 0.4384, DLITE val loss 0.4739
# CE train loss 1.5608, CE val loss 1.7544
#
# step 9900: KL train loss 0.0241, KL val loss 0.0268
# DLITE train loss 0.4405, DLITE val loss 0.4707
# CE train loss 1.5669, CE val loss 1.7396
#
# step 9999: KL train loss 0.0241, KL val loss 0.0267
# DLITE train loss 0.4403, DLITE val loss 0.4714
# CE train loss 1.5638, CE val loss 1.7381

# %% [markdown]
# ## Train with DLITE and CE

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters()) / 1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()  # Cross-Entropy loss
kl_loss = KLDivergenceLoss()

# Lists to store the loss values
kl_train_losses_mix = []
kl_val_losses_mix = []
dlite_train_losses_mix = []
dlite_val_losses_mix = []
ce_train_losses_mix = []
ce_val_losses_mix = []



for iter in range(int(max_iters / 2)):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}\n")


        # Append the losses for this iteration
        kl_train_losses_mix.append(kl_losses['train'])
        kl_val_losses_mix.append(kl_losses['val'])
        dlite_train_losses_mix.append(dlite_losses['train'])
        dlite_val_losses_mix.append(dlite_losses['val'])
        ce_train_losses_mix.append(ce_losses['train'])
        ce_val_losses_mix.append(ce_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the DLITE loss using the flattened logits and targets
    loss = dlite_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()





for iter in range(int(max_iters / 2), max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}\n")

        # Append the losses for this iteration
        kl_train_losses_mix.append(kl_losses['train'])
        kl_val_losses_mix.append(kl_losses['val'])
        dlite_train_losses_mix.append(dlite_losses['train'])
        dlite_val_losses_mix.append(dlite_losses['val'])
        ce_train_losses_mix.append(ce_losses['train'])
        ce_val_losses_mix.append(ce_losses['val'])

    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the CE loss using the flattened logits and targets
    loss = ce_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()





# Plotting DLITE Loss
plot_losses(dlite_train_losses_mix, dlite_val_losses_mix, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses_mix, ce_val_losses_mix, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses_mix, kl_val_losses_mix, 'KL Divergence Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 0.0679, KL val loss 0.0677
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
#
# step 100: KL train loss 0.0512, KL val loss 0.0523
# DLITE train loss 0.6724, DLITE val loss 0.6736
# CE train loss 3.3285, CE val loss 3.4019
#
# step 200: KL train loss 0.0513, KL val loss 0.0526
# DLITE train loss 0.6473, DLITE val loss 0.6496
# CE train loss 3.3348, CE val loss 3.4162
#
# step 300: KL train loss 0.0512, KL val loss 0.0530
# DLITE train loss 0.6312, DLITE val loss 0.6367
# CE train loss 3.3302, CE val loss 3.4447
#
# step 400: KL train loss 0.0501, KL val loss 0.0516
# DLITE train loss 0.6191, DLITE val loss 0.6233
# CE train loss 3.2562, CE val loss 3.3508
#
# step 500: KL train loss 0.0496, KL val loss 0.0510
# DLITE train loss 0.6064, DLITE val loss 0.6122
# CE train loss 3.2239, CE val loss 3.3129
#
# step 600: KL train loss 0.0474, KL val loss 0.0479
# DLITE train loss 0.5898, DLITE val loss 0.5910
# CE train loss 3.0820, CE val loss 3.1104
#
# step 700: KL train loss 0.0474, KL val loss 0.0480
# DLITE train loss 0.5811, DLITE val loss 0.5854
# CE train loss 3.0818, CE val loss 3.1230
#
# step 800: KL train loss 0.0465, KL val loss 0.0473
# DLITE train loss 0.5681, DLITE val loss 0.5752
# CE train loss 3.0226, CE val loss 3.0732
#
# step 900: KL train loss 0.0460, KL val loss 0.0466
# DLITE train loss 0.5615, DLITE val loss 0.5681
# CE train loss 2.9890, CE val loss 3.0315
#
# step 1000: KL train loss 0.0476, KL val loss 0.0481
# DLITE train loss 0.5568, DLITE val loss 0.5633
# CE train loss 3.0921, CE val loss 3.1269
#
# step 1100: KL train loss 0.0478, KL val loss 0.0487
# DLITE train loss 0.5531, DLITE val loss 0.5625
# CE train loss 3.1042, CE val loss 3.1637
#
# step 1200: KL train loss 0.0463, KL val loss 0.0467
# DLITE train loss 0.5447, DLITE val loss 0.5521
# CE train loss 3.0100, CE val loss 3.0383
#
# step 1300: KL train loss 0.0461, KL val loss 0.0466
# DLITE train loss 0.5441, DLITE val loss 0.5512
# CE train loss 2.9979, CE val loss 3.0304
#
# step 1400: KL train loss 0.0455, KL val loss 0.0462
# DLITE train loss 0.5346, DLITE val loss 0.5444
# CE train loss 2.9547, CE val loss 3.0034
#
# step 1500: KL train loss 0.0456, KL val loss 0.0466
# DLITE train loss 0.5329, DLITE val loss 0.5444
# CE train loss 2.9647, CE val loss 3.0288
#
# step 1600: KL train loss 0.0454, KL val loss 0.0475
# DLITE train loss 0.5266, DLITE val loss 0.5440
# CE train loss 2.9536, CE val loss 3.0843
#
# step 1700: KL train loss 0.0465, KL val loss 0.0477
# DLITE train loss 0.5266, DLITE val loss 0.5403
# CE train loss 3.0228, CE val loss 3.1036
#
# step 1800: KL train loss 0.0455, KL val loss 0.0474
# DLITE train loss 0.5180, DLITE val loss 0.5372
# CE train loss 2.9604, CE val loss 3.0811
#
# step 1900: KL train loss 0.0465, KL val loss 0.0477
# DLITE train loss 0.5215, DLITE val loss 0.5350
# CE train loss 3.0241, CE val loss 3.1025
#
# step 2000: KL train loss 0.0462, KL val loss 0.0483
# DLITE train loss 0.5161, DLITE val loss 0.5376
# CE train loss 3.0036, CE val loss 3.1368
#
# step 2100: KL train loss 0.0458, KL val loss 0.0478
# DLITE train loss 0.5112, DLITE val loss 0.5316
# CE train loss 2.9773, CE val loss 3.1057
#
# step 2200: KL train loss 0.0452, KL val loss 0.0470
# DLITE train loss 0.5077, DLITE val loss 0.5257
# CE train loss 2.9409, CE val loss 3.0550
#
# step 2300: KL train loss 0.0446, KL val loss 0.0467
# DLITE train loss 0.5065, DLITE val loss 0.5266
# CE train loss 2.8962, CE val loss 3.0371
#
# step 2400: KL train loss 0.0459, KL val loss 0.0477
# DLITE train loss 0.5047, DLITE val loss 0.5244
# CE train loss 2.9803, CE val loss 3.1026
#
# step 2500: KL train loss 0.0451, KL val loss 0.0474
# DLITE train loss 0.4988, DLITE val loss 0.5227
# CE train loss 2.9322, CE val loss 3.0780
#
# step 2600: KL train loss 0.0452, KL val loss 0.0470
# DLITE train loss 0.5019, DLITE val loss 0.5223
# CE train loss 2.9355, CE val loss 3.0528
#
# step 2700: KL train loss 0.0459, KL val loss 0.0480
# DLITE train loss 0.4974, DLITE val loss 0.5192
# CE train loss 2.9856, CE val loss 3.1210
#
# step 2800: KL train loss 0.0439, KL val loss 0.0463
# DLITE train loss 0.4975, DLITE val loss 0.5193
# CE train loss 2.8535, CE val loss 3.0112
#
# step 2900: KL train loss 0.0442, KL val loss 0.0468
# DLITE train loss 0.4931, DLITE val loss 0.5174
# CE train loss 2.8715, CE val loss 3.0405
#
# step 3000: KL train loss 0.0451, KL val loss 0.0473
# DLITE train loss 0.4931, DLITE val loss 0.5159
# CE train loss 2.9288, CE val loss 3.0763
#
# step 3100: KL train loss 0.0444, KL val loss 0.0475
# DLITE train loss 0.4886, DLITE val loss 0.5154
# CE train loss 2.8880, CE val loss 3.0887
#
# step 3200: KL train loss 0.0439, KL val loss 0.0466
# DLITE train loss 0.4847, DLITE val loss 0.5114
# CE train loss 2.8557, CE val loss 3.0320
#
# step 3300: KL train loss 0.0455, KL val loss 0.0477
# DLITE train loss 0.4861, DLITE val loss 0.5124
# CE train loss 2.9584, CE val loss 3.1002
#
# step 3400: KL train loss 0.0443, KL val loss 0.0468
# DLITE train loss 0.4852, DLITE val loss 0.5071
# CE train loss 2.8768, CE val loss 3.0425
#
# step 3500: KL train loss 0.0446, KL val loss 0.0472
# DLITE train loss 0.4819, DLITE val loss 0.5092
# CE train loss 2.9004, CE val loss 3.0688
#
# step 3600: KL train loss 0.0446, KL val loss 0.0474
# DLITE train loss 0.4789, DLITE val loss 0.5070
# CE train loss 2.8984, CE val loss 3.0782
#
# step 3700: KL train loss 0.0444, KL val loss 0.0469
# DLITE train loss 0.4805, DLITE val loss 0.5067
# CE train loss 2.8862, CE val loss 3.0508
#
# step 3800: KL train loss 0.0437, KL val loss 0.0468
# DLITE train loss 0.4798, DLITE val loss 0.5100
# CE train loss 2.8387, CE val loss 3.0409
#
# step 3900: KL train loss 0.0437, KL val loss 0.0468
# DLITE train loss 0.4748, DLITE val loss 0.5036
# CE train loss 2.8380, CE val loss 3.0397
#
# step 4000: KL train loss 0.0436, KL val loss 0.0463
# DLITE train loss 0.4740, DLITE val loss 0.5006
# CE train loss 2.8317, CE val loss 3.0074
#
# step 4100: KL train loss 0.0442, KL val loss 0.0470
# DLITE train loss 0.4752, DLITE val loss 0.5032
# CE train loss 2.8725, CE val loss 3.0577
#
# step 4200: KL train loss 0.0436, KL val loss 0.0464
# DLITE train loss 0.4720, DLITE val loss 0.5007
# CE train loss 2.8360, CE val loss 3.0157
#
# step 4300: KL train loss 0.0452, KL val loss 0.0478
# DLITE train loss 0.4737, DLITE val loss 0.5017
# CE train loss 2.9375, CE val loss 3.1085
#
# step 4400: KL train loss 0.0441, KL val loss 0.0465
# DLITE train loss 0.4717, DLITE val loss 0.4968
# CE train loss 2.8653, CE val loss 3.0257
#
# step 4500: KL train loss 0.0433, KL val loss 0.0459
# DLITE train loss 0.4688, DLITE val loss 0.4960
# CE train loss 2.8151, CE val loss 2.9840
#
# step 4600: KL train loss 0.0437, KL val loss 0.0461
# DLITE train loss 0.4690, DLITE val loss 0.4955
# CE train loss 2.8390, CE val loss 2.9942
#
# step 4700: KL train loss 0.0439, KL val loss 0.0465
# DLITE train loss 0.4660, DLITE val loss 0.4944
# CE train loss 2.8544, CE val loss 3.0205
#
# step 4800: KL train loss 0.0437, KL val loss 0.0473
# DLITE train loss 0.4624, DLITE val loss 0.4947
# CE train loss 2.8407, CE val loss 3.0772
#
# step 4900: KL train loss 0.0440, KL val loss 0.0470
# DLITE train loss 0.4648, DLITE val loss 0.4936
# CE train loss 2.8598, CE val loss 3.0563
#
# step 5000: KL train loss 0.0436, KL val loss 0.0461
# DLITE train loss 0.4628, DLITE val loss 0.4896
# CE train loss 2.8336, CE val loss 2.9980
#
# step 5100: KL train loss 0.0295, KL val loss 0.0310
# DLITE train loss 0.5228, DLITE val loss 0.5390
# CE train loss 1.9200, CE val loss 2.0173
#
# step 5200: KL train loss 0.0284, KL val loss 0.0303
# DLITE train loss 0.5013, DLITE val loss 0.5222
# CE train loss 1.8491, CE val loss 1.9699
#
# step 5300: KL train loss 0.0283, KL val loss 0.0300
# DLITE train loss 0.4977, DLITE val loss 0.5189
# CE train loss 1.8364, CE val loss 1.9507
#
# step 5400: KL train loss 0.0276, KL val loss 0.0296
# DLITE train loss 0.4904, DLITE val loss 0.5145
# CE train loss 1.7964, CE val loss 1.9232
#
# step 5500: KL train loss 0.0272, KL val loss 0.0292
# DLITE train loss 0.4871, DLITE val loss 0.5105
# CE train loss 1.7696, CE val loss 1.8953
#
# step 5600: KL train loss 0.0273, KL val loss 0.0293
# DLITE train loss 0.4918, DLITE val loss 0.5160
# CE train loss 1.7751, CE val loss 1.9068
#
# step 5700: KL train loss 0.0270, KL val loss 0.0290
# DLITE train loss 0.4831, DLITE val loss 0.5073
# CE train loss 1.7549, CE val loss 1.8851
#
# step 5800: KL train loss 0.0267, KL val loss 0.0288
# DLITE train loss 0.4804, DLITE val loss 0.5061
# CE train loss 1.7327, CE val loss 1.8752
#
# step 5900: KL train loss 0.0266, KL val loss 0.0288
# DLITE train loss 0.4749, DLITE val loss 0.5014
# CE train loss 1.7311, CE val loss 1.8716
#
# step 6000: KL train loss 0.0264, KL val loss 0.0288
# DLITE train loss 0.4743, DLITE val loss 0.5033
# CE train loss 1.7132, CE val loss 1.8694
#
# step 6100: KL train loss 0.0263, KL val loss 0.0285
# DLITE train loss 0.4728, DLITE val loss 0.4971
# CE train loss 1.7121, CE val loss 1.8518
#
# step 6200: KL train loss 0.0262, KL val loss 0.0284
# DLITE train loss 0.4726, DLITE val loss 0.4975
# CE train loss 1.7024, CE val loss 1.8441
#
# step 6300: KL train loss 0.0260, KL val loss 0.0284
# DLITE train loss 0.4708, DLITE val loss 0.4984
# CE train loss 1.6886, CE val loss 1.8452
#
# step 6400: KL train loss 0.0259, KL val loss 0.0284
# DLITE train loss 0.4710, DLITE val loss 0.5001
# CE train loss 1.6835, CE val loss 1.8435
#
# step 6500: KL train loss 0.0258, KL val loss 0.0280
# DLITE train loss 0.4667, DLITE val loss 0.4932
# CE train loss 1.6772, CE val loss 1.8199
#
# step 6600: KL train loss 0.0257, KL val loss 0.0281
# DLITE train loss 0.4621, DLITE val loss 0.4896
# CE train loss 1.6714, CE val loss 1.8280
#
# step 6700: KL train loss 0.0256, KL val loss 0.0282
# DLITE train loss 0.4646, DLITE val loss 0.4939
# CE train loss 1.6662, CE val loss 1.8303
#
# step 6800: KL train loss 0.0256, KL val loss 0.0282
# DLITE train loss 0.4607, DLITE val loss 0.4903
# CE train loss 1.6669, CE val loss 1.8310
#
# step 6900: KL train loss 0.0255, KL val loss 0.0280
# DLITE train loss 0.4616, DLITE val loss 0.4914
# CE train loss 1.6570, CE val loss 1.8217
#
# step 7000: KL train loss 0.0254, KL val loss 0.0279
# DLITE train loss 0.4599, DLITE val loss 0.4889
# CE train loss 1.6508, CE val loss 1.8159
#
# step 7100: KL train loss 0.0254, KL val loss 0.0279
# DLITE train loss 0.4595, DLITE val loss 0.4892
# CE train loss 1.6517, CE val loss 1.8147
#
# step 7200: KL train loss 0.0253, KL val loss 0.0280
# DLITE train loss 0.4569, DLITE val loss 0.4871
# CE train loss 1.6451, CE val loss 1.8208
#
# step 7300: KL train loss 0.0252, KL val loss 0.0276
# DLITE train loss 0.4571, DLITE val loss 0.4838
# CE train loss 1.6402, CE val loss 1.7956
#
# step 7400: KL train loss 0.0252, KL val loss 0.0279
# DLITE train loss 0.4552, DLITE val loss 0.4859
# CE train loss 1.6402, CE val loss 1.8136
#
# step 7500: KL train loss 0.0249, KL val loss 0.0277
# DLITE train loss 0.4529, DLITE val loss 0.4849
# CE train loss 1.6201, CE val loss 1.7991
#
# step 7600: KL train loss 0.0251, KL val loss 0.0279
# DLITE train loss 0.4542, DLITE val loss 0.4868
# CE train loss 1.6293, CE val loss 1.8109
#
# step 7700: KL train loss 0.0249, KL val loss 0.0276
# DLITE train loss 0.4526, DLITE val loss 0.4832
# CE train loss 1.6207, CE val loss 1.7913
#
# step 7800: KL train loss 0.0250, KL val loss 0.0275
# DLITE train loss 0.4547, DLITE val loss 0.4815
# CE train loss 1.6252, CE val loss 1.7850
#
# step 7900: KL train loss 0.0250, KL val loss 0.0276
# DLITE train loss 0.4527, DLITE val loss 0.4815
# CE train loss 1.6258, CE val loss 1.7922
#
# step 8000: KL train loss 0.0249, KL val loss 0.0276
# DLITE train loss 0.4519, DLITE val loss 0.4831
# CE train loss 1.6179, CE val loss 1.7935
#
# step 8100: KL train loss 0.0249, KL val loss 0.0276
# DLITE train loss 0.4528, DLITE val loss 0.4853
# CE train loss 1.6167, CE val loss 1.7917
#
# step 8200: KL train loss 0.0249, KL val loss 0.0276
# DLITE train loss 0.4514, DLITE val loss 0.4821
# CE train loss 1.6201, CE val loss 1.7942
#
# step 8300: KL train loss 0.0249, KL val loss 0.0275
# DLITE train loss 0.4524, DLITE val loss 0.4822
# CE train loss 1.6167, CE val loss 1.7895
#
# step 8400: KL train loss 0.0248, KL val loss 0.0275
# DLITE train loss 0.4517, DLITE val loss 0.4826
# CE train loss 1.6108, CE val loss 1.7902
#
# step 8500: KL train loss 0.0247, KL val loss 0.0275
# DLITE train loss 0.4514, DLITE val loss 0.4828
# CE train loss 1.6062, CE val loss 1.7885
#
# step 8600: KL train loss 0.0247, KL val loss 0.0275
# DLITE train loss 0.4454, DLITE val loss 0.4772
# CE train loss 1.6041, CE val loss 1.7863
#
# step 8700: KL train loss 0.0246, KL val loss 0.0275
# DLITE train loss 0.4476, DLITE val loss 0.4825
# CE train loss 1.5982, CE val loss 1.7874
#
# step 8800: KL train loss 0.0244, KL val loss 0.0274
# DLITE train loss 0.4439, DLITE val loss 0.4802
# CE train loss 1.5863, CE val loss 1.7820
#
# step 8900: KL train loss 0.0245, KL val loss 0.0270
# DLITE train loss 0.4471, DLITE val loss 0.4757
# CE train loss 1.5955, CE val loss 1.7536
#
# step 9000: KL train loss 0.0246, KL val loss 0.0273
# DLITE train loss 0.4505, DLITE val loss 0.4825
# CE train loss 1.5968, CE val loss 1.7716
#
# step 9100: KL train loss 0.0244, KL val loss 0.0271
# DLITE train loss 0.4433, DLITE val loss 0.4763
# CE train loss 1.5829, CE val loss 1.7640
#
# step 9200: KL train loss 0.0245, KL val loss 0.0273
# DLITE train loss 0.4447, DLITE val loss 0.4759
# CE train loss 1.5928, CE val loss 1.7722
#
# step 9300: KL train loss 0.0244, KL val loss 0.0269
# DLITE train loss 0.4474, DLITE val loss 0.4765
# CE train loss 1.5831, CE val loss 1.7489
#
# step 9400: KL train loss 0.0244, KL val loss 0.0270
# DLITE train loss 0.4467, DLITE val loss 0.4780
# CE train loss 1.5848, CE val loss 1.7572
#
# step 9500: KL train loss 0.0244, KL val loss 0.0271
# DLITE train loss 0.4445, DLITE val loss 0.4762
# CE train loss 1.5831, CE val loss 1.7617
#
# step 9600: KL train loss 0.0243, KL val loss 0.0271
# DLITE train loss 0.4434, DLITE val loss 0.4754
# CE train loss 1.5802, CE val loss 1.7602
#
# step 9700: KL train loss 0.0243, KL val loss 0.0268
# DLITE train loss 0.4428, DLITE val loss 0.4729
# CE train loss 1.5777, CE val loss 1.7450
#
# step 9800: KL train loss 0.0242, KL val loss 0.0272
# DLITE train loss 0.4409, DLITE val loss 0.4759
# CE train loss 1.5722, CE val loss 1.7665
#
# step 9900: KL train loss 0.0243, KL val loss 0.0270
# DLITE train loss 0.4423, DLITE val loss 0.4734
# CE train loss 1.5768, CE val loss 1.7581
#
# step 9999: KL train loss 0.0242, KL val loss 0.0268
# DLITE train loss 0.4423, DLITE val loss 0.4720
# CE train loss 1.5723, CE val loss 1.7393
