# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.functional import kl_div

torch.manual_seed(1337)

# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    # Define the loss functions
    ce_loss_func = nn.CrossEntropyLoss()

    # Prepare dictionaries to store the output losses
    dlite_out = {}
    ce_out = {}
    kl_out = {}
    dlite_cuberoot_out = {}
    lit_out = {}

    model.eval()  # Set the model to evaluation mode
    for split in ['train', 'val']:
        dlite_losses = torch.zeros(eval_iters)
        ce_losses = torch.zeros(eval_iters)
        kl_losses = torch.zeros(eval_iters)
        dlite_cuberoot_losses = torch.zeros(eval_iters)
        lit_losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, _ = model(X, Y)

            # Reshape the logits
            logits_flat = logits.view(-1, logits.size(-1))  # Flattening the logits

            # Convert targets to one-hot encoding
            targets_flat = Y.view(-1)

            # Calculate the losses
            dlite_losses[k] = dlite_loss(logits_flat, targets_flat).item()
            ce_losses[k] = ce_loss_func(logits_flat, targets_flat).item()  # Assuming vocab_size is the same as logits.size(-1)
            kl_losses[k] = kl_loss(logits_flat, targets_flat).item()
            dlite_cuberoot_losses[k] = dlite_cuberoot_loss(logits_flat, targets_flat).item()
            lit_losses[k] = lit_loss(logits_flat, targets_flat).item()

        # Store the mean loss for each metric
        dlite_out[split] = dlite_losses.mean().item()
        ce_out[split] = ce_losses.mean().item()
        kl_out[split] = kl_losses.mean().item()
        dlite_cuberoot_out[split] = dlite_cuberoot_losses.mean().item()
        lit_out[split] = lit_losses.mean().item()


    model.train()  # Set the model back to training mode
    return dlite_out, ce_out, kl_out, dlite_cuberoot_out, lit_out



class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, targets=None):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)

        if targets is not None:
            # Calculate L1 Loss
            B, T, C = out.shape
            out_flat = out.view(B * T, C)
            targets_flat = targets.view(B * T)
            l1_loss = F.l1_loss(out_flat, targets_flat.float())
            return out, l1_loss
        else:
            return out


class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


# DLITE Loss function
class DLITELoss(nn.Module):
    def __init__(self):
        super(DLITELoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = g_values - delta_h_values

        # Sum over all classes and average over the batch size
        loss = dl_values.sum(dim=-1).mean()

        return loss


# DLITE Cube Root Loss function
class DLITECubeRootLoss(nn.Module):
    def __init__(self):
        super(DLITECubeRootLoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = (g_values - delta_h_values)** 1/3

        # Sum over all classes and average over the batch size
        # loss = dl_values.sum(dim=-1).mean() 
        loss = dl_values.sum(dim=-1).mean() 

        return loss


# LIT Loss function
class LITLoss(nn.Module):
    def __init__(self):
        super(LITLoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)


        # Sum over all classes and average over the batch size
        loss = g_values.sum(dim=-1).mean()

        return loss

# DLITE Loss: delta H ONLY
class DHLoss(nn.Module):
    def __init__(self):
        super(DHLoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = 1-delta_h_values

        # Sum over all classes and average over the batch size
        loss = dl_values.sum(dim=-1).mean()

        return loss

class KLDivergenceLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super(KLDivergenceLoss, self).__init__()
        self.reduction = reduction

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        kl_values = torch.zeros_like(probs)
        kl_values[mask_true_probs] = true_probs[mask_true_probs] * torch.log(true_probs[mask_true_probs]/probs[mask_true_probs])

        # Sum over all classes and average over the batch size
        loss = kl_values.sum(dim=-1).mean()

        return loss


# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.loss_func = DLITELoss()  # Initialize the DLITE loss function

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = self.loss_func(logits, targets)  # Use DLITE loss here

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

# %% [markdown]
# ## Train with DLITE and CE

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()
kl_loss = KLDivergenceLoss()
dlite_cuberoot_loss = DLITECubeRootLoss()
lit_loss = LITLoss()

# Lists to store the loss values
dlite_train_losses = []
dlite_val_losses = []
ce_train_losses = []
ce_val_losses = []
kl_train_losses = []
kl_val_losses = []
dlite_cuberoot_train_losses = []
dlite_cuberoot_val_losses = []
lit_train_losses = []
lit_val_losses = []

# lf: 0 for CE, 1 for DLITE loss function
def run(lf):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}")
        print(f"DLITE Cube Root train loss {dlite_cuberoot_losses['train']:.4f}, DLITE Cube Root val loss {dlite_cuberoot_losses['val']:.4f}")
        print(f"LIT train loss {lit_losses['train']:.4f}, LIT val loss {lit_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses.append(dlite_losses['train'])
        dlite_val_losses.append(dlite_losses['val'])
        ce_train_losses.append(ce_losses['train'])
        ce_val_losses.append(ce_losses['val'])
        kl_train_losses.append(kl_losses['train'])
        kl_val_losses.append(kl_losses['val'])
        dlite_cuberoot_train_losses.append(dlite_cuberoot_losses['train'])
        dlite_cuberoot_val_losses.append(dlite_cuberoot_losses['val'])
        lit_train_losses.append(lit_losses['train'])
        lit_val_losses.append(lit_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)
    
    if(lf==0):
        # Compute the CE loss using the flattened logits and targets
        loss = ce_loss(logits_flat, targets_flat)
    else:
        # Compute the DLITE loss using the flattened logits and targets
        loss = dlite_cuberoot_loss(logits_flat, targets_flat)


    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 0.209729 M parameters

# %%
# 5 alternative runs
run_splits = 5
for i in range(run_splits): 
    lf = 0 if i%2==0 else 1
    lf_name = "CE" if i%2==0 else "DL"
    print(f"Training based on {lf_name}")
    for iter in range(int(max_iters*i/run_splits), int(max_iters*(i+1)/run_splits)):
        run(lf)
# Out:
# Training based on CE
# step 0: KL train loss 4.4116, KL val loss 4.4022
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
# DLITE Cube Root train loss 0.3278, DLITE Cube Root val loss 0.3277
# LIT train loss 5.8604, LIT val loss 5.8589
#
# step 100: KL train loss 2.6568, KL val loss 2.6670
# DLITE train loss 0.6977, DLITE val loss 0.6981
# CE train loss 2.6568, CE val loss 2.6670
# DLITE Cube Root train loss 0.3304, DLITE Cube Root val loss 0.3303
# LIT train loss 4.1988, LIT val loss 4.2071
#
# step 200: KL train loss 2.5090, KL val loss 2.5059
# DLITE train loss 0.6711, DLITE val loss 0.6700
# CE train loss 2.5090, CE val loss 2.5059
# DLITE Cube Root train loss 0.3312, DLITE Cube Root val loss 0.3311
# LIT train loss 3.9302, LIT val loss 3.9323
#
# step 300: KL train loss 2.4196, KL val loss 2.4336
# DLITE train loss 0.6489, DLITE val loss 0.6505
# CE train loss 2.4196, CE val loss 2.4336
# DLITE Cube Root train loss 0.3313, DLITE Cube Root val loss 0.3313
# LIT train loss 3.7250, LIT val loss 3.7330
#
# step 400: KL train loss 2.3502, KL val loss 2.3565
# DLITE train loss 0.6343, DLITE val loss 0.6347
# CE train loss 2.3502, CE val loss 2.3565
# DLITE Cube Root train loss 0.3314, DLITE Cube Root val loss 0.3312
# LIT train loss 3.6069, LIT val loss 3.6097
#
# step 500: KL train loss 2.2965, KL val loss 2.3127
# DLITE train loss 0.6187, DLITE val loss 0.6208
# CE train loss 2.2965, CE val loss 2.3127
# DLITE Cube Root train loss 0.3314, DLITE Cube Root val loss 0.3315
# LIT train loss 3.4755, LIT val loss 3.4812
#
# step 600: KL train loss 2.2408, KL val loss 2.2498
# DLITE train loss 0.6100, DLITE val loss 0.6097
# CE train loss 2.2408, CE val loss 2.2498
# DLITE Cube Root train loss 0.3313, DLITE Cube Root val loss 0.3315
# LIT train loss 3.4457, LIT val loss 3.4378
#
# step 700: KL train loss 2.2051, KL val loss 2.2190
# DLITE train loss 0.5982, DLITE val loss 0.5998
# CE train loss 2.2051, CE val loss 2.2190
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3317
# LIT train loss 3.3498, LIT val loss 3.3505
#
# step 800: KL train loss 2.1630, KL val loss 2.1861
# DLITE train loss 0.5911, DLITE val loss 0.5942
# CE train loss 2.1630, CE val loss 2.1861
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3317
# LIT train loss 3.3271, LIT val loss 3.3315
#
# step 900: KL train loss 2.1240, KL val loss 2.1501
# DLITE train loss 0.5825, DLITE val loss 0.5863
# CE train loss 2.1240, CE val loss 2.1501
# DLITE Cube Root train loss 0.3314, DLITE Cube Root val loss 0.3318
# LIT train loss 3.2717, LIT val loss 3.2773
#
# step 1000: KL train loss 2.1024, KL val loss 2.1297
# DLITE train loss 0.5735, DLITE val loss 0.5771
# CE train loss 2.1024, CE val loss 2.1297
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3319
# LIT train loss 3.1758, LIT val loss 3.1754
#
# step 1100: KL train loss 2.0696, KL val loss 2.1174
# DLITE train loss 0.5701, DLITE val loss 0.5772
# CE train loss 2.0696, CE val loss 2.1174
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3319
# LIT train loss 3.1915, LIT val loss 3.2014
#
# step 1200: KL train loss 2.0384, KL val loss 2.0801
# DLITE train loss 0.5617, DLITE val loss 0.5675
# CE train loss 2.0384, CE val loss 2.0801
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3318
# LIT train loss 3.1318, LIT val loss 3.1420
#
# step 1300: KL train loss 2.0260, KL val loss 2.0646
# DLITE train loss 0.5542, DLITE val loss 0.5603
# CE train loss 2.0260, CE val loss 2.0646
# DLITE Cube Root train loss 0.3320, DLITE Cube Root val loss 0.3322
# LIT train loss 3.0372, LIT val loss 3.0430
#
# step 1400: KL train loss 1.9918, KL val loss 2.0366
# DLITE train loss 0.5484, DLITE val loss 0.5557
# CE train loss 1.9918, CE val loss 2.0366
# DLITE Cube Root train loss 0.3314, DLITE Cube Root val loss 0.3317
# LIT train loss 3.0344, LIT val loss 3.0387
#
# step 1500: KL train loss 1.9707, KL val loss 2.0308
# DLITE train loss 0.5456, DLITE val loss 0.5557
# CE train loss 1.9707, CE val loss 2.0308
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3318
# LIT train loss 3.0211, LIT val loss 3.0461
#
# step 1600: KL train loss 1.9651, KL val loss 2.0503
# DLITE train loss 0.5422, DLITE val loss 0.5558
# CE train loss 1.9651, CE val loss 2.0503
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3322
# LIT train loss 2.9813, LIT val loss 3.0094
#
# step 1700: KL train loss 1.9410, KL val loss 2.0126
# DLITE train loss 0.5355, DLITE val loss 0.5471
# CE train loss 1.9410, CE val loss 2.0126
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3320
# LIT train loss 2.9395, LIT val loss 2.9609
#
# step 1800: KL train loss 1.9077, KL val loss 1.9934
# DLITE train loss 0.5265, DLITE val loss 0.5423
# CE train loss 1.9077, CE val loss 1.9934
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3320
# LIT train loss 2.8866, LIT val loss 2.9267
#
# step 1900: KL train loss 1.9062, KL val loss 1.9849
# DLITE train loss 0.5271, DLITE val loss 0.5397
# CE train loss 1.9062, CE val loss 1.9849
# DLITE Cube Root train loss 0.3319, DLITE Cube Root val loss 0.3323
# LIT train loss 2.8789, LIT val loss 2.9044
#
# Training based on DL
# step 2000: KL train loss 1.8855, KL val loss 1.9965
# DLITE train loss 0.5214, DLITE val loss 0.5405
# CE train loss 1.8855, CE val loss 1.9965
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3321
# LIT train loss 2.8464, LIT val loss 2.8926
#
# step 2100: KL train loss 2.0340, KL val loss 2.1424
# DLITE train loss 0.5602, DLITE val loss 0.5764
# CE train loss 2.0340, CE val loss 2.1424
# DLITE Cube Root train loss 0.3311, DLITE Cube Root val loss 0.3322
# LIT train loss 3.0734, LIT val loss 3.1054
#
# step 2200: KL train loss 2.0864, KL val loss 2.1770
# DLITE train loss 0.5809, DLITE val loss 0.5932
# CE train loss 2.0864, CE val loss 2.1770
# DLITE Cube Root train loss 0.3303, DLITE Cube Root val loss 0.3320
# LIT train loss 3.3022, LIT val loss 3.3257
#
# step 2300: KL train loss 2.1985, KL val loss 2.2667
# DLITE train loss 0.6149, DLITE val loss 0.6257
# CE train loss 2.1985, CE val loss 2.2667
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3301
# LIT train loss 3.6249, LIT val loss 3.6462
#
# step 2400: KL train loss 2.2142, KL val loss 2.2703
# DLITE train loss 0.6209, DLITE val loss 0.6291
# CE train loss 2.2142, CE val loss 2.2703
# DLITE Cube Root train loss 0.3269, DLITE Cube Root val loss 0.3289
# LIT train loss 3.7368, LIT val loss 3.7502
#
# step 2500: KL train loss 2.4804, KL val loss 2.5186
# DLITE train loss 0.6840, DLITE val loss 0.6900
# CE train loss 2.4804, CE val loss 2.5186
# DLITE Cube Root train loss 0.3239, DLITE Cube Root val loss 0.3257
# LIT train loss 4.2280, LIT val loss 4.2289
#
# step 2600: KL train loss 2.7319, KL val loss 2.7432
# DLITE train loss 0.7347, DLITE val loss 0.7348
# CE train loss 2.7319, CE val loss 2.7432
# DLITE Cube Root train loss 0.3199, DLITE Cube Root val loss 0.3235
# LIT train loss 4.6673, LIT val loss 4.6607
#
# step 2700: KL train loss 2.8747, KL val loss 2.8861
# DLITE train loss 0.7690, DLITE val loss 0.7691
# CE train loss 2.8747, CE val loss 2.8861
# DLITE Cube Root train loss 0.3183, DLITE Cube Root val loss 0.3202
# LIT train loss 5.0077, LIT val loss 5.0061
#
# step 2800: KL train loss 3.1670, KL val loss 3.1659
# DLITE train loss 0.8138, DLITE val loss 0.8128
# CE train loss 3.1670, CE val loss 3.1659
# DLITE Cube Root train loss 0.3154, DLITE Cube Root val loss 0.3180
# LIT train loss 5.2662, LIT val loss 5.2631
#
# step 2900: KL train loss 3.2255, KL val loss 3.2316
# DLITE train loss 0.8255, DLITE val loss 0.8254
# CE train loss 3.2255, CE val loss 3.2316
# DLITE Cube Root train loss 0.3140, DLITE Cube Root val loss 0.3158
# LIT train loss 5.3480, LIT val loss 5.3508
#
# step 3000: KL train loss 3.2532, KL val loss 3.2498
# DLITE train loss 0.8292, DLITE val loss 0.8283
# CE train loss 3.2532, CE val loss 3.2498
# DLITE Cube Root train loss 0.3134, DLITE Cube Root val loss 0.3144
# LIT train loss 5.3844, LIT val loss 5.3832
#
# step 3100: KL train loss 3.2607, KL val loss 3.2612
# DLITE train loss 0.8291, DLITE val loss 0.8286
# CE train loss 3.2607, CE val loss 3.2612
# DLITE Cube Root train loss 0.3130, DLITE Cube Root val loss 0.3151
# LIT train loss 5.4027, LIT val loss 5.4009
#
# step 3200: KL train loss 3.2225, KL val loss 3.2283
# DLITE train loss 0.8289, DLITE val loss 0.8294
# CE train loss 3.2225, CE val loss 3.2283
# DLITE Cube Root train loss 0.3121, DLITE Cube Root val loss 0.3145
# LIT train loss 5.4220, LIT val loss 5.4250
#
# step 3300: KL train loss 3.3175, KL val loss 3.3165
# DLITE train loss 0.8394, DLITE val loss 0.8390
# CE train loss 3.3175, CE val loss 3.3165
# DLITE Cube Root train loss 0.3105, DLITE Cube Root val loss 0.3116
# LIT train loss 5.4924, LIT val loss 5.4908
#
# step 3400: KL train loss 3.3634, KL val loss 3.3671
# DLITE train loss 0.8451, DLITE val loss 0.8452
# CE train loss 3.3634, CE val loss 3.3671
# DLITE Cube Root train loss 0.3113, DLITE Cube Root val loss 0.3143
# LIT train loss 5.4982, LIT val loss 5.4998
#
# step 3500: KL train loss 3.3724, KL val loss 3.3742
# DLITE train loss 0.8478, DLITE val loss 0.8478
# CE train loss 3.3724, CE val loss 3.3742
# DLITE Cube Root train loss 0.3097, DLITE Cube Root val loss 0.3106
# LIT train loss 5.5569, LIT val loss 5.5563
#
# step 3600: KL train loss 3.3806, KL val loss 3.3791
# DLITE train loss 0.8458, DLITE val loss 0.8450
# CE train loss 3.3806, CE val loss 3.3791
# DLITE Cube Root train loss 0.3107, DLITE Cube Root val loss 0.3111
# LIT train loss 5.5107, LIT val loss 5.5074
#
# step 3700: KL train loss 3.4211, KL val loss 3.4208
# DLITE train loss 0.8525, DLITE val loss 0.8523
# CE train loss 3.4211, CE val loss 3.4208
# DLITE Cube Root train loss 0.3106, DLITE Cube Root val loss 0.3116
# LIT train loss 5.5612, LIT val loss 5.5609
#
# step 3800: KL train loss 3.4929, KL val loss 3.4903
# DLITE train loss 0.8616, DLITE val loss 0.8612
# CE train loss 3.4929, CE val loss 3.4903
# DLITE Cube Root train loss 0.3106, DLITE Cube Root val loss 0.3111
# LIT train loss 5.5956, LIT val loss 5.5956
#
# step 3900: KL train loss 3.4439, KL val loss 3.4410
# DLITE train loss 0.8547, DLITE val loss 0.8539
# CE train loss 3.4439, CE val loss 3.4410
# DLITE Cube Root train loss 0.3101, DLITE Cube Root val loss 0.3115
# LIT train loss 5.5814, LIT val loss 5.5801
#
# Training based on CE
# step 4000: KL train loss 3.5304, KL val loss 3.5326
# DLITE train loss 0.8660, DLITE val loss 0.8661
# CE train loss 3.5304, CE val loss 3.5326
# DLITE Cube Root train loss 0.3101, DLITE Cube Root val loss 0.3108
# LIT train loss 5.5718, LIT val loss 5.5752
#
# step 4100: KL train loss 1.9453, KL val loss 2.0356
# DLITE train loss 0.5386, DLITE val loss 0.5545
# CE train loss 1.9453, CE val loss 2.0356
# DLITE Cube Root train loss 0.3313, DLITE Cube Root val loss 0.3317
# LIT train loss 2.9937, LIT val loss 3.0336
#
# step 4200: KL train loss 1.9046, KL val loss 2.0006
# DLITE train loss 0.5282, DLITE val loss 0.5462
# CE train loss 1.9046, CE val loss 2.0006
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3316
# LIT train loss 2.9149, LIT val loss 2.9581
#
# step 4300: KL train loss 1.8875, KL val loss 1.9755
# DLITE train loss 0.5161, DLITE val loss 0.5319
# CE train loss 1.8875, CE val loss 1.9755
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3321
# LIT train loss 2.7715, LIT val loss 2.8131
#
# step 4400: KL train loss 1.8635, KL val loss 1.9654
# DLITE train loss 0.5147, DLITE val loss 0.5332
# CE train loss 1.8635, CE val loss 1.9654
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3320
# LIT train loss 2.7975, LIT val loss 2.8458
#
# step 4500: KL train loss 1.8423, KL val loss 1.9549
# DLITE train loss 0.5123, DLITE val loss 0.5324
# CE train loss 1.8423, CE val loss 1.9549
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3322
# LIT train loss 2.8087, LIT val loss 2.8636
#
# step 4600: KL train loss 1.8159, KL val loss 1.9231
# DLITE train loss 0.5029, DLITE val loss 0.5234
# CE train loss 1.8159, CE val loss 1.9231
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3318
# LIT train loss 2.7326, LIT val loss 2.7882
#
# step 4700: KL train loss 1.8125, KL val loss 1.9345
# DLITE train loss 0.5022, DLITE val loss 0.5246
# CE train loss 1.8125, CE val loss 1.9345
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3322
# LIT train loss 2.7330, LIT val loss 2.7933
#
# step 4800: KL train loss 1.7809, KL val loss 1.9187
# DLITE train loss 0.4944, DLITE val loss 0.5205
# CE train loss 1.7809, CE val loss 1.9187
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3321
# LIT train loss 2.6856, LIT val loss 2.7638
#
# step 4900: KL train loss 1.7854, KL val loss 1.9181
# DLITE train loss 0.4969, DLITE val loss 0.5218
# CE train loss 1.7854, CE val loss 1.9181
# DLITE Cube Root train loss 0.3319, DLITE Cube Root val loss 0.3321
# LIT train loss 2.7108, LIT val loss 2.7830
#
# step 5000: KL train loss 1.7727, KL val loss 1.9021
# DLITE train loss 0.4931, DLITE val loss 0.5171
# CE train loss 1.7727, CE val loss 1.9021
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3323
# LIT train loss 2.6769, LIT val loss 2.7467
#
# step 5100: KL train loss 1.7637, KL val loss 1.8926
# DLITE train loss 0.4947, DLITE val loss 0.5183
# CE train loss 1.7637, CE val loss 1.8926
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3323
# LIT train loss 2.7170, LIT val loss 2.7833
#
# step 5200: KL train loss 1.7474, KL val loss 1.8829
# DLITE train loss 0.4868, DLITE val loss 0.5118
# CE train loss 1.7474, CE val loss 1.8829
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3323
# LIT train loss 2.6391, LIT val loss 2.7102
#
# step 5300: KL train loss 1.7546, KL val loss 1.8861
# DLITE train loss 0.4873, DLITE val loss 0.5127
# CE train loss 1.7546, CE val loss 1.8861
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3323
# LIT train loss 2.6326, LIT val loss 2.7069
#
# step 5400: KL train loss 1.7390, KL val loss 1.8832
# DLITE train loss 0.4829, DLITE val loss 0.5112
# CE train loss 1.7390, CE val loss 1.8832
# DLITE Cube Root train loss 0.3319, DLITE Cube Root val loss 0.3324
# LIT train loss 2.6002, LIT val loss 2.6883
#
# step 5500: KL train loss 1.7265, KL val loss 1.8621
# DLITE train loss 0.4820, DLITE val loss 0.5086
# CE train loss 1.7265, CE val loss 1.8621
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3321
# LIT train loss 2.6128, LIT val loss 2.6927
#
# step 5600: KL train loss 1.7384, KL val loss 1.8772
# DLITE train loss 0.4845, DLITE val loss 0.5116
# CE train loss 1.7384, CE val loss 1.8772
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3323
# LIT train loss 2.6233, LIT val loss 2.7073
#
# step 5700: KL train loss 1.7269, KL val loss 1.8686
# DLITE train loss 0.4833, DLITE val loss 0.5104
# CE train loss 1.7269, CE val loss 1.8686
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3325
# LIT train loss 2.6254, LIT val loss 2.7034
#
# step 5800: KL train loss 1.7106, KL val loss 1.8576
# DLITE train loss 0.4789, DLITE val loss 0.5069
# CE train loss 1.7106, CE val loss 1.8576
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3324
# LIT train loss 2.6031, LIT val loss 2.6842
#
# step 5900: KL train loss 1.7097, KL val loss 1.8495
# DLITE train loss 0.4746, DLITE val loss 0.5020
# CE train loss 1.7097, CE val loss 1.8495
# DLITE Cube Root train loss 0.3319, DLITE Cube Root val loss 0.3323
# LIT train loss 2.5497, LIT val loss 2.6340
#
# Training based on DL
# step 6000: KL train loss 1.6981, KL val loss 1.8458
# DLITE train loss 0.4742, DLITE val loss 0.5040
# CE train loss 1.6981, CE val loss 1.8458
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3323
# LIT train loss 2.5695, LIT val loss 2.6651
#
# step 6100: KL train loss 1.7892, KL val loss 1.9322
# DLITE train loss 0.4986, DLITE val loss 0.5264
# CE train loss 1.7892, CE val loss 1.9322
# DLITE Cube Root train loss 0.3313, DLITE Cube Root val loss 0.3321
# LIT train loss 2.7235, LIT val loss 2.8117
#
# step 6200: KL train loss 1.8337, KL val loss 1.9651
# DLITE train loss 0.5186, DLITE val loss 0.5430
# CE train loss 1.8337, CE val loss 1.9651
# DLITE Cube Root train loss 0.3303, DLITE Cube Root val loss 0.3315
# LIT train loss 2.9514, LIT val loss 3.0216
#
# step 6300: KL train loss 1.9776, KL val loss 2.1137
# DLITE train loss 0.5631, DLITE val loss 0.5873
# CE train loss 1.9776, CE val loss 2.1137
# DLITE Cube Root train loss 0.3281, DLITE Cube Root val loss 0.3307
# LIT train loss 3.3109, LIT val loss 3.3816
#
# step 6400: KL train loss 2.1741, KL val loss 2.2886
# DLITE train loss 0.6182, DLITE val loss 0.6349
# CE train loss 2.1741, CE val loss 2.2886
# DLITE Cube Root train loss 0.3257, DLITE Cube Root val loss 0.3300
# LIT train loss 3.7812, LIT val loss 3.8231
#
# step 6500: KL train loss 2.5416, KL val loss 2.6020
# DLITE train loss 0.6992, DLITE val loss 0.7077
# CE train loss 2.5416, CE val loss 2.6020
# DLITE Cube Root train loss 0.3202, DLITE Cube Root val loss 0.3245
# LIT train loss 4.4092, LIT val loss 4.4241
#
# step 6600: KL train loss 2.8174, KL val loss 2.8453
# DLITE train loss 0.7561, DLITE val loss 0.7593
# CE train loss 2.8174, CE val loss 2.8453
# DLITE Cube Root train loss 0.3153, DLITE Cube Root val loss 0.3201
# LIT train loss 4.8736, LIT val loss 4.8741
#
# step 6700: KL train loss 3.0493, KL val loss 3.0636
# DLITE train loss 0.7993, DLITE val loss 0.8001
# CE train loss 3.0493, CE val loss 3.0636
# DLITE Cube Root train loss 0.3132, DLITE Cube Root val loss 0.3168
# LIT train loss 5.2007, LIT val loss 5.1991
#
# step 6800: KL train loss 3.1451, KL val loss 3.1590
# DLITE train loss 0.8135, DLITE val loss 0.8148
# CE train loss 3.1451, CE val loss 3.1590
# DLITE Cube Root train loss 0.3125, DLITE Cube Root val loss 0.3159
# LIT train loss 5.3265, LIT val loss 5.3305
#
# step 6900: KL train loss 3.1985, KL val loss 3.2076
# DLITE train loss 0.8223, DLITE val loss 0.8227
# CE train loss 3.1985, CE val loss 3.2076
# DLITE Cube Root train loss 0.3114, DLITE Cube Root val loss 0.3120
# LIT train loss 5.3691, LIT val loss 5.3705
#
# step 7000: KL train loss 3.1575, KL val loss 3.1694
# DLITE train loss 0.8183, DLITE val loss 0.8193
# CE train loss 3.1575, CE val loss 3.1694
# DLITE Cube Root train loss 0.3113, DLITE Cube Root val loss 0.3130
# LIT train loss 5.4144, LIT val loss 5.4150
#
# step 7100: KL train loss 3.2211, KL val loss 3.2287
# DLITE train loss 0.8274, DLITE val loss 0.8278
# CE train loss 3.2211, CE val loss 3.2287
# DLITE Cube Root train loss 0.3103, DLITE Cube Root val loss 0.3125
# LIT train loss 5.4394, LIT val loss 5.4396
#
# step 7200: KL train loss 3.2233, KL val loss 3.2314
# DLITE train loss 0.8258, DLITE val loss 0.8259
# CE train loss 3.2233, CE val loss 3.2314
# DLITE Cube Root train loss 0.3109, DLITE Cube Root val loss 0.3134
# LIT train loss 5.4287, LIT val loss 5.4298
#
# step 7300: KL train loss 3.2546, KL val loss 3.2592
# DLITE train loss 0.8328, DLITE val loss 0.8329
# CE train loss 3.2546, CE val loss 3.2592
# DLITE Cube Root train loss 0.3099, DLITE Cube Root val loss 0.3132
# LIT train loss 5.4798, LIT val loss 5.4802
#
# step 7400: KL train loss 3.3508, KL val loss 3.3557
# DLITE train loss 0.8435, DLITE val loss 0.8435
# CE train loss 3.3508, CE val loss 3.3557
# DLITE Cube Root train loss 0.3099, DLITE Cube Root val loss 0.3134
# LIT train loss 5.4924, LIT val loss 5.4944
#
# step 7500: KL train loss 3.2377, KL val loss 3.2386
# DLITE train loss 0.8286, DLITE val loss 0.8281
# CE train loss 3.2377, CE val loss 3.2386
# DLITE Cube Root train loss 0.3090, DLITE Cube Root val loss 0.3112
# LIT train loss 5.4575, LIT val loss 5.4562
#
# step 7600: KL train loss 3.2907, KL val loss 3.3008
# DLITE train loss 0.8371, DLITE val loss 0.8380
# CE train loss 3.2907, CE val loss 3.3008
# DLITE Cube Root train loss 0.3102, DLITE Cube Root val loss 0.3113
# LIT train loss 5.4943, LIT val loss 5.4989
#
# step 7700: KL train loss 3.2702, KL val loss 3.2782
# DLITE train loss 0.8354, DLITE val loss 0.8360
# CE train loss 3.2702, CE val loss 3.2782
# DLITE Cube Root train loss 0.3081, DLITE Cube Root val loss 0.3103
# LIT train loss 5.4596, LIT val loss 5.4628
#
# step 7800: KL train loss 3.3552, KL val loss 3.3594
# DLITE train loss 0.8455, DLITE val loss 0.8456
# CE train loss 3.3552, CE val loss 3.3594
# DLITE Cube Root train loss 0.3092, DLITE Cube Root val loss 0.3121
# LIT train loss 5.5041, LIT val loss 5.5064
#
# step 7900: KL train loss 3.3537, KL val loss 3.3554
# DLITE train loss 0.8455, DLITE val loss 0.8454
# CE train loss 3.3537, CE val loss 3.3554
# DLITE Cube Root train loss 0.3087, DLITE Cube Root val loss 0.3091
# LIT train loss 5.5480, LIT val loss 5.5478
#
# Training based on CE
# step 8000: KL train loss 3.3333, KL val loss 3.3379
# DLITE train loss 0.8430, DLITE val loss 0.8434
# CE train loss 3.3333, CE val loss 3.3379
# DLITE Cube Root train loss 0.3079, DLITE Cube Root val loss 0.3079
# LIT train loss 5.5357, LIT val loss 5.5370
#
# step 8100: KL train loss 1.7856, KL val loss 1.9212
# DLITE train loss 0.4991, DLITE val loss 0.5252
# CE train loss 1.7856, CE val loss 1.9212
# DLITE Cube Root train loss 0.3312, DLITE Cube Root val loss 0.3321
# LIT train loss 2.7377, LIT val loss 2.8129
#
# step 8200: KL train loss 1.7612, KL val loss 1.8992
# DLITE train loss 0.4878, DLITE val loss 0.5139
# CE train loss 1.7612, CE val loss 1.8992
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3322
# LIT train loss 2.6245, LIT val loss 2.7042
#
# step 8300: KL train loss 1.7287, KL val loss 1.8658
# DLITE train loss 0.4844, DLITE val loss 0.5099
# CE train loss 1.7287, CE val loss 1.8658
# DLITE Cube Root train loss 0.3313, DLITE Cube Root val loss 0.3324
# LIT train loss 2.6477, LIT val loss 2.7210
#
# step 8400: KL train loss 1.7180, KL val loss 1.8733
# DLITE train loss 0.4811, DLITE val loss 0.5089
# CE train loss 1.7180, CE val loss 1.8733
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3325
# LIT train loss 2.6153, LIT val loss 2.6953
#
# step 8500: KL train loss 1.7095, KL val loss 1.8626
# DLITE train loss 0.4789, DLITE val loss 0.5065
# CE train loss 1.7095, CE val loss 1.8626
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5952, LIT val loss 2.6761
#
# step 8600: KL train loss 1.6932, KL val loss 1.8544
# DLITE train loss 0.4704, DLITE val loss 0.5005
# CE train loss 1.6932, CE val loss 1.8544
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5139, LIT val loss 2.6027
#
# step 8700: KL train loss 1.6857, KL val loss 1.8499
# DLITE train loss 0.4720, DLITE val loss 0.5041
# CE train loss 1.6857, CE val loss 1.8499
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5577, LIT val loss 2.6579
#
# step 8800: KL train loss 1.6702, KL val loss 1.8469
# DLITE train loss 0.4651, DLITE val loss 0.5001
# CE train loss 1.6702, CE val loss 1.8469
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3325
# LIT train loss 2.4972, LIT val loss 2.6095
#
# step 8900: KL train loss 1.6772, KL val loss 1.8267
# DLITE train loss 0.4689, DLITE val loss 0.4966
# CE train loss 1.6772, CE val loss 1.8267
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3326
# LIT train loss 2.5250, LIT val loss 2.6078
#
# step 9000: KL train loss 1.6724, KL val loss 1.8294
# DLITE train loss 0.4706, DLITE val loss 0.5002
# CE train loss 1.6724, CE val loss 1.8294
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3324
# LIT train loss 2.5575, LIT val loss 2.6437
#
# step 9100: KL train loss 1.6599, KL val loss 1.8265
# DLITE train loss 0.4655, DLITE val loss 0.4971
# CE train loss 1.6599, CE val loss 1.8265
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5159, LIT val loss 2.6105
#
# step 9200: KL train loss 1.6669, KL val loss 1.8213
# DLITE train loss 0.4651, DLITE val loss 0.4927
# CE train loss 1.6669, CE val loss 1.8213
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3326
# LIT train loss 2.4920, LIT val loss 2.5726
#
# step 9300: KL train loss 1.6434, KL val loss 1.7992
# DLITE train loss 0.4630, DLITE val loss 0.4913
# CE train loss 1.6434, CE val loss 1.7992
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5107, LIT val loss 2.5945
#
# step 9400: KL train loss 1.6437, KL val loss 1.7962
# DLITE train loss 0.4632, DLITE val loss 0.4917
# CE train loss 1.6437, CE val loss 1.7962
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3325
# LIT train loss 2.5111, LIT val loss 2.5965
#
# step 9500: KL train loss 1.6451, KL val loss 1.8097
# DLITE train loss 0.4614, DLITE val loss 0.4920
# CE train loss 1.6451, CE val loss 1.8097
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3325
# LIT train loss 2.4796, LIT val loss 2.5723
#
# step 9600: KL train loss 1.6370, KL val loss 1.8048
# DLITE train loss 0.4583, DLITE val loss 0.4887
# CE train loss 1.6370, CE val loss 1.8048
# DLITE Cube Root train loss 0.3315, DLITE Cube Root val loss 0.3326
# LIT train loss 2.4600, LIT val loss 2.5509
#
# step 9700: KL train loss 1.6328, KL val loss 1.7873
# DLITE train loss 0.4581, DLITE val loss 0.4869
# CE train loss 1.6328, CE val loss 1.7873
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3324
# LIT train loss 2.4684, LIT val loss 2.5541
#
# step 9800: KL train loss 1.6243, KL val loss 1.8048
# DLITE train loss 0.4557, DLITE val loss 0.4893
# CE train loss 1.6243, CE val loss 1.8048
# DLITE Cube Root train loss 0.3317, DLITE Cube Root val loss 0.3327
# LIT train loss 2.4501, LIT val loss 2.5525
#
# step 9900: KL train loss 1.6291, KL val loss 1.7943
# DLITE train loss 0.4559, DLITE val loss 0.4848
# CE train loss 1.6291, CE val loss 1.7943
# DLITE Cube Root train loss 0.3318, DLITE Cube Root val loss 0.3327
# LIT train loss 2.4502, LIT val loss 2.5351
#
# step 9999: KL train loss 1.6258, KL val loss 1.7876
# DLITE train loss 0.4571, DLITE val loss 0.4868
# CE train loss 1.6258, CE val loss 1.7876
# DLITE Cube Root train loss 0.3316, DLITE Cube Root val loss 0.3326
# LIT train loss 2.4620, LIT val loss 2.5534

# %%
print(f"Training based on DLITE Cuberoot")
for iter in range(10000):
    run(1)
# Out:
# Training based on DLITE Cuberoot
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 print(f"Training based on DLITE Cuberoot")
#       2 for iter in range(10000):
# ----> 3     run(1)
#
# Cell In[12], line 32, in run(lf)
#      30 def run(lf):
#      31     if iter % eval_interval == 0 or iter == max_iters - 1:
# ---> 32         dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses = estimate_loss()
#      33         print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
#      34         print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[10], line 70, in estimate_loss()
#      68     ce_losses[k] = ce_loss_func(logits_flat, targets_flat).item()  # Assuming vocab_size is the same as logits.size(-1)
#      69     kl_losses[k] = kl_loss(logits_flat, targets_flat).item()
# ---> 70     dlite_cuberoot_losses[k] = dlite_cuberoot_loss(logits_flat, targets_flat).item()
#      71     lit_losses[k] = lit_loss(logits_flat, targets_flat).item()
#      73 # Store the mean loss for each metric
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[10], line 243, in DLITECubeRootLoss.forward(self, logits, targets)
#     239 dl_values = (g_values - delta_h_values)** 1/3
#     241 # Sum over all classes and average over the batch size
#     242 # loss = dl_values.sum(dim=-1).mean()
# --> 243 loss = dl_values.max(dim=-1).mean()
#     245 return loss
#
# AttributeError: 'torch.return_types.max' object has no attribute 'mean'

# %%
import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()


# Plotting DLITE Loss
plot_losses(dlite_train_losses, dlite_val_losses, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses, ce_val_losses, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses, kl_val_losses, 'KL Divergence Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(dlite_cuberoot_train_losses, dlite_cuberoot_val_losses, 'DLITE Cube Root Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(lit_train_losses, lit_val_losses, 'LIT Loss Over Time')
