# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.nn.functional import kl_div

torch.manual_seed(1337)

# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    # Define the loss functions
    ce_loss_func = nn.CrossEntropyLoss()

    # Prepare dictionaries to store the output losses
    dlite_out = {}
    ce_out = {}
    kl_out = {}
    dlite_cuberoot_out = {}
    lit_out = {}
    delta_out = {}

    model.eval()  # Set the model to evaluation mode
    for split in ['train', 'val']:
        dlite_losses = torch.zeros(eval_iters)
        ce_losses = torch.zeros(eval_iters)
        kl_losses = torch.zeros(eval_iters)
        dlite_cuberoot_losses = torch.zeros(eval_iters)
        lit_losses = torch.zeros(eval_iters)
        delta_losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, _ = model(X, Y)

            # Reshape the logits
            logits_flat = logits.view(-1, logits.size(-1))  # Flattening the logits

            # Convert targets to one-hot encoding
            targets_flat = Y.view(-1)

            # Calculate the losses
            dlite_losses[k] = dlite_loss(logits_flat, targets_flat).item()
            ce_losses[k] = ce_loss_func(logits_flat, targets_flat).item()  # Assuming vocab_size is the same as logits.size(-1)
            kl_losses[k] = kl_loss(logits_flat, targets_flat).item()
            dlite_cuberoot_losses[k] = dlite_cuberoot_loss(logits_flat, targets_flat).item()
            lit_losses[k] = lit_loss(logits_flat, targets_flat).item()
            delta_losses[k] = delta_loss(logits_flat, targets_flat).item()

        # Store the mean loss for each metric
        dlite_out[split] = dlite_losses.mean().item()
        ce_out[split] = ce_losses.mean().item()
        kl_out[split] = kl_losses.mean().item()
        dlite_cuberoot_out[split] = dlite_cuberoot_losses.mean().item()
        lit_out[split] = lit_losses.mean().item()
        delta_out[split] = lit_losses.mean().item()


    model.train()  # Set the model back to training mode
    return dlite_out, ce_out, kl_out, dlite_cuberoot_out, lit_out, delta_out



class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, targets=None):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)

        if targets is not None:
            # Calculate L1 Loss
            B, T, C = out.shape
            out_flat = out.view(B * T, C)
            targets_flat = targets.view(B * T)
            l1_loss = F.l1_loss(out_flat, targets_flat.float())
            return out, l1_loss
        else:
            return out


class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


# DLITE Loss function
class DLITELoss(nn.Module):
    def __init__(self):
        super(DLITELoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = g_values - delta_h_values

        # Sum over all classes and average over the batch size
        loss = dl_values.sum(dim=-1).mean()

        return loss


# DLITE Cube Root Loss function
class DLITECubeRootLoss(nn.Module):
    def __init__(self):
        super(DLITECubeRootLoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        dl_values = g_values - delta_h_values

        # Sum over all classes and average over the batch size
        loss = dl_values.sum(dim=-1).mean() ** 1/3

        return loss


# LIT Loss function
class LITLoss(nn.Module):
    def __init__(self):
        super(LITLoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        g_probs = torch.zeros_like(probs)
        g_true_probs = torch.zeros_like(true_probs)
        g_probs[mask_probs] = probs[mask_probs] * (1 - torch.log(probs[mask_probs]))
        g_true_probs[mask_true_probs] = true_probs[mask_true_probs] * (1 - torch.log(true_probs[mask_true_probs]))
        g_values = torch.abs(g_probs - g_true_probs)


        # Sum over all classes and average over the batch size
        loss = g_values.sum(dim=-1).mean()

        return loss


class KLDivergenceLoss(nn.Module):
    def __init__(self, reduction='mean'):
        super(KLDivergenceLoss, self).__init__()
        self.reduction = reduction

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate g function for non-zero elements using the mask
        kl_values = torch.zeros_like(probs)
        kl_values[mask_true_probs] = true_probs[mask_true_probs] * torch.log(true_probs[mask_true_probs]/probs[mask_true_probs])

        # Sum over all classes and average over the batch size
        loss = kl_values.sum(dim=-1).mean()

        return loss


# DELTA Loss function
class DELTALoss(nn.Module):
    def __init__(self):
        super(DELTALoss, self).__init__()

    def forward(self, logits, targets):
        # Convert logits to probabilities using softmax
        probs = F.softmax(logits, dim=-1)

        # One-hot encode the targets to get true probabilities
        true_probs = F.one_hot(targets, num_classes=probs.size(-1)).float()

        # Masks for non-zero elements of probs and true_probs
        mask_probs = probs > 0
        mask_true_probs = true_probs > 0

        # Calculate delta_h function for non-zero elements using the mask
        delta_h_probs = torch.zeros_like(probs)
        delta_h_true_probs = torch.zeros_like(true_probs)
        delta_h_probs[mask_probs] = probs[mask_probs]**2 * (1 - 2 * torch.log(probs[mask_probs]))
        delta_h_true_probs[mask_true_probs] = true_probs[mask_true_probs]**2 * (1 - 2 * torch.log(true_probs[mask_true_probs]))
        delta_h_values = torch.abs(delta_h_probs - delta_h_true_probs) / (2 * (probs + true_probs))

        # Compute DLITE loss for each class
        delta_h_values

        # Sum over all classes and average over the batch size
        loss = delta_h_values.sum(dim=-1).mean()

        return loss


# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.loss_func = DLITELoss()  # Initialize the DLITE loss function

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = self.loss_func(logits, targets)  # Use DLITE loss here

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
# Out:
# --2023-11-30 03:56:02--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.3’
#
# input.txt.3         100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2023-11-30 03:56:02 (18.0 MB/s) - ‘input.txt.3’ saved [1115394/1115394]

# %% [markdown]
# ## Hyperparameters

# %%
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

# %% [markdown]
# ## Train with DLITE

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()
kl_loss = KLDivergenceLoss()
dlite_cuberoot_loss = DLITECubeRootLoss()
lit_loss = LITLoss()
delta_loss = DELTALoss()

# Lists to store the loss values
dlite_train_losses = []
dlite_val_losses = []
ce_train_losses = []
ce_val_losses = []
kl_train_losses = []
kl_val_losses = []
dlite_cuberoot_train_losses = []
dlite_cuberoot_val_losses = []
lit_train_losses = []
lit_val_losses = []
delta_train_losses = []
delta_val_losses = []




for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses , delta_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}")
        print(f"DLITE Cube Root train loss {dlite_cuberoot_losses['train']:.4f}, DLITE Cube Root val loss {dlite_cuberoot_losses['val']:.4f}")
        print(f"LIT train loss {lit_losses['train']:.4f}, LIT val loss {lit_losses['val']:.4f}")
        print(f"DELTA train loss {delta_losses['train']:.4f}, DELTA val loss {delta_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses.append(dlite_losses['train'])
        dlite_val_losses.append(dlite_losses['val'])
        ce_train_losses.append(ce_losses['train'])
        ce_val_losses.append(ce_losses['val'])
        kl_train_losses.append(kl_losses['train'])
        kl_val_losses.append(kl_losses['val'])
        dlite_cuberoot_train_losses.append(dlite_cuberoot_losses['train'])
        dlite_cuberoot_val_losses.append(dlite_cuberoot_losses['val'])
        lit_train_losses.append(lit_losses['train'])
        lit_val_losses.append(lit_losses['val'])
        delta_train_losses.append(delta_losses['train'])
        delta_val_losses.append(delta_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the DLITE loss using the flattened logits and targets
    loss = dlite_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Plotting DLITE Loss
plot_losses(dlite_train_losses, dlite_val_losses, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses, ce_val_losses, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses, kl_val_losses, 'KL Divergence Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(dlite_cuberoot_train_losses, dlite_cuberoot_val_losses, 'DLITE Cube Root Loss Over Time')

# Plotting LIT Loss
plot_losses(lit_train_losses, lit_val_losses, 'LIT Loss Over Time')

# Plotting DELTA Loss
plot_losses(delta_train_losses, delta_val_losses, 'DELTA Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 4.4116, KL val loss 4.4022
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
# DLITE Cube Root train loss 0.3094, DLITE Cube Root val loss 0.3092
# LIT train loss 5.8604, LIT val loss 5.8589
# DELTA train loss 5.8604, DELTA val loss 5.8589
#
# step 100: KL train loss 3.3285, KL val loss 3.4019
# DLITE train loss 0.6724, DLITE val loss 0.6736
# CE train loss 3.3285, CE val loss 3.4019
# DLITE Cube Root train loss 0.2241, DLITE Cube Root val loss 0.2245
# LIT train loss 3.0371, LIT val loss 3.0244
# DELTA train loss 3.0371, DELTA val loss 3.0244
#
# step 200: KL train loss 3.3348, KL val loss 3.4162
# DLITE train loss 0.6473, DLITE val loss 0.6496
# CE train loss 3.3348, CE val loss 3.4162
# DLITE Cube Root train loss 0.2158, DLITE Cube Root val loss 0.2165
# LIT train loss 2.7270, LIT val loss 2.7251
# DELTA train loss 2.7270, DELTA val loss 2.7251
#
# step 300: KL train loss 3.3302, KL val loss 3.4447
# DLITE train loss 0.6312, DLITE val loss 0.6367
# CE train loss 3.3302, CE val loss 3.4447
# DLITE Cube Root train loss 0.2104, DLITE Cube Root val loss 0.2122
# LIT train loss 2.5815, LIT val loss 2.5790
# DELTA train loss 2.5815, DELTA val loss 2.5790
#
# step 400: KL train loss 3.2562, KL val loss 3.3508
# DLITE train loss 0.6191, DLITE val loss 0.6233
# CE train loss 3.2562, CE val loss 3.3508
# DLITE Cube Root train loss 0.2064, DLITE Cube Root val loss 0.2078
# LIT train loss 2.5382, LIT val loss 2.5344
# DELTA train loss 2.5382, DELTA val loss 2.5344
#
# step 500: KL train loss 3.2239, KL val loss 3.3129
# DLITE train loss 0.6064, DLITE val loss 0.6122
# CE train loss 3.2239, CE val loss 3.3129
# DLITE Cube Root train loss 0.2021, DLITE Cube Root val loss 0.2041
# LIT train loss 2.5084, LIT val loss 2.5071
# DELTA train loss 2.5084, DELTA val loss 2.5071
#
# step 600: KL train loss 3.0820, KL val loss 3.1104
# DLITE train loss 0.5898, DLITE val loss 0.5910
# CE train loss 3.0820, CE val loss 3.1104
# DLITE Cube Root train loss 0.1966, DLITE Cube Root val loss 0.1970
# LIT train loss 2.4195, LIT val loss 2.4160
# DELTA train loss 2.4195, DELTA val loss 2.4160
#
# step 700: KL train loss 3.0818, KL val loss 3.1230
# DLITE train loss 0.5811, DLITE val loss 0.5854
# CE train loss 3.0818, CE val loss 3.1230
# DLITE Cube Root train loss 0.1937, DLITE Cube Root val loss 0.1951
# LIT train loss 2.3584, LIT val loss 2.3636
# DELTA train loss 2.3584, DELTA val loss 2.3636
#
# step 800: KL train loss 3.0226, KL val loss 3.0732
# DLITE train loss 0.5681, DLITE val loss 0.5752
# CE train loss 3.0226, CE val loss 3.0732
# DLITE Cube Root train loss 0.1894, DLITE Cube Root val loss 0.1917
# LIT train loss 2.3085, LIT val loss 2.3224
# DELTA train loss 2.3085, DELTA val loss 2.3224
#
# step 900: KL train loss 2.9890, KL val loss 3.0315
# DLITE train loss 0.5615, DLITE val loss 0.5681
# CE train loss 2.9890, CE val loss 3.0315
# DLITE Cube Root train loss 0.1872, DLITE Cube Root val loss 0.1894
# LIT train loss 2.2962, LIT val loss 2.3113
# DELTA train loss 2.2962, DELTA val loss 2.3113
#
# step 1000: KL train loss 3.0921, KL val loss 3.1269
# DLITE train loss 0.5568, DLITE val loss 0.5633
# CE train loss 3.0921, CE val loss 3.1269
# DLITE Cube Root train loss 0.1856, DLITE Cube Root val loss 0.1878
# LIT train loss 2.1958, LIT val loss 2.2069
# DELTA train loss 2.1958, DELTA val loss 2.2069
#
# step 1100: KL train loss 3.1042, KL val loss 3.1637
# DLITE train loss 0.5531, DLITE val loss 0.5625
# CE train loss 3.1042, CE val loss 3.1637
# DLITE Cube Root train loss 0.1844, DLITE Cube Root val loss 0.1875
# LIT train loss 2.1241, LIT val loss 2.1437
# DELTA train loss 2.1241, DELTA val loss 2.1437
#
# step 1200: KL train loss 3.0100, KL val loss 3.0383
# DLITE train loss 0.5447, DLITE val loss 0.5521
# CE train loss 3.0100, CE val loss 3.0383
# DLITE Cube Root train loss 0.1816, DLITE Cube Root val loss 0.1840
# LIT train loss 2.1767, LIT val loss 2.1861
# DELTA train loss 2.1767, DELTA val loss 2.1861
#
# step 1300: KL train loss 2.9979, KL val loss 3.0304
# DLITE train loss 0.5441, DLITE val loss 0.5512
# CE train loss 2.9979, CE val loss 3.0304
# DLITE Cube Root train loss 0.1814, DLITE Cube Root val loss 0.1837
# LIT train loss 2.1684, LIT val loss 2.1781
# DELTA train loss 2.1684, DELTA val loss 2.1781
#
# step 1400: KL train loss 2.9547, KL val loss 3.0034
# DLITE train loss 0.5346, DLITE val loss 0.5444
# CE train loss 2.9547, CE val loss 3.0034
# DLITE Cube Root train loss 0.1782, DLITE Cube Root val loss 0.1815
# LIT train loss 2.1227, LIT val loss 2.1366
# DELTA train loss 2.1227, DELTA val loss 2.1366
#
# step 1500: KL train loss 2.9647, KL val loss 3.0288
# DLITE train loss 0.5329, DLITE val loss 0.5444
# CE train loss 2.9647, CE val loss 3.0288
# DLITE Cube Root train loss 0.1776, DLITE Cube Root val loss 0.1815
# LIT train loss 2.1050, LIT val loss 2.1315
# DELTA train loss 2.1050, DELTA val loss 2.1315
#
# step 1600: KL train loss 2.9536, KL val loss 3.0843
# DLITE train loss 0.5266, DLITE val loss 0.5440
# CE train loss 2.9536, CE val loss 3.0843
# DLITE Cube Root train loss 0.1755, DLITE Cube Root val loss 0.1813
# LIT train loss 2.0705, LIT val loss 2.1041
# DELTA train loss 2.0705, DELTA val loss 2.1041
#
# step 1700: KL train loss 3.0228, KL val loss 3.1036
# DLITE train loss 0.5266, DLITE val loss 0.5403
# CE train loss 3.0228, CE val loss 3.1036
# DLITE Cube Root train loss 0.1755, DLITE Cube Root val loss 0.1801
# LIT train loss 2.0430, LIT val loss 2.0737
# DELTA train loss 2.0430, DELTA val loss 2.0737
#
# step 1800: KL train loss 2.9604, KL val loss 3.0811
# DLITE train loss 0.5180, DLITE val loss 0.5372
# CE train loss 2.9604, CE val loss 3.0811
# DLITE Cube Root train loss 0.1727, DLITE Cube Root val loss 0.1791
# LIT train loss 2.0203, LIT val loss 2.0618
# DELTA train loss 2.0203, DELTA val loss 2.0618
#
# step 1900: KL train loss 3.0241, KL val loss 3.1025
# DLITE train loss 0.5215, DLITE val loss 0.5350
# CE train loss 3.0241, CE val loss 3.1025
# DLITE Cube Root train loss 0.1738, DLITE Cube Root val loss 0.1783
# LIT train loss 1.9934, LIT val loss 2.0201
# DELTA train loss 1.9934, DELTA val loss 2.0201
#
# step 2000: KL train loss 3.0036, KL val loss 3.1368
# DLITE train loss 0.5161, DLITE val loss 0.5376
# CE train loss 3.0036, CE val loss 3.1368
# DLITE Cube Root train loss 0.1720, DLITE Cube Root val loss 0.1792
# LIT train loss 1.9512, LIT val loss 2.0011
# DELTA train loss 1.9512, DELTA val loss 2.0011
#
# step 2100: KL train loss 2.9773, KL val loss 3.1057
# DLITE train loss 0.5112, DLITE val loss 0.5316
# CE train loss 2.9773, CE val loss 3.1057
# DLITE Cube Root train loss 0.1704, DLITE Cube Root val loss 0.1772
# LIT train loss 1.9707, LIT val loss 2.0234
# DELTA train loss 1.9707, DELTA val loss 2.0234
#
# step 2200: KL train loss 2.9409, KL val loss 3.0550
# DLITE train loss 0.5077, DLITE val loss 0.5257
# CE train loss 2.9409, CE val loss 3.0550
# DLITE Cube Root train loss 0.1692, DLITE Cube Root val loss 0.1752
# LIT train loss 1.9706, LIT val loss 2.0127
# DELTA train loss 1.9706, DELTA val loss 2.0127
#
# step 2300: KL train loss 2.8962, KL val loss 3.0371
# DLITE train loss 0.5065, DLITE val loss 0.5266
# CE train loss 2.8962, CE val loss 3.0371
# DLITE Cube Root train loss 0.1688, DLITE Cube Root val loss 0.1755
# LIT train loss 1.9988, LIT val loss 2.0420
# DELTA train loss 1.9988, DELTA val loss 2.0420
#
# step 2400: KL train loss 2.9803, KL val loss 3.1026
# DLITE train loss 0.5047, DLITE val loss 0.5244
# CE train loss 2.9803, CE val loss 3.1026
# DLITE Cube Root train loss 0.1682, DLITE Cube Root val loss 0.1748
# LIT train loss 1.9145, LIT val loss 1.9623
# DELTA train loss 1.9145, DELTA val loss 1.9623
#
# step 2500: KL train loss 2.9322, KL val loss 3.0780
# DLITE train loss 0.4988, DLITE val loss 0.5227
# CE train loss 2.9322, CE val loss 3.0780
# DLITE Cube Root train loss 0.1663, DLITE Cube Root val loss 0.1742
# LIT train loss 1.9107, LIT val loss 1.9707
# DELTA train loss 1.9107, DELTA val loss 1.9707
#
# step 2600: KL train loss 2.9355, KL val loss 3.0528
# DLITE train loss 0.5019, DLITE val loss 0.5223
# CE train loss 2.9355, CE val loss 3.0528
# DLITE Cube Root train loss 0.1673, DLITE Cube Root val loss 0.1741
# LIT train loss 1.9223, LIT val loss 1.9757
# DELTA train loss 1.9223, DELTA val loss 1.9757
#
# step 2700: KL train loss 2.9856, KL val loss 3.1210
# DLITE train loss 0.4974, DLITE val loss 0.5192
# CE train loss 2.9856, CE val loss 3.1210
# DLITE Cube Root train loss 0.1658, DLITE Cube Root val loss 0.1731
# LIT train loss 1.8645, LIT val loss 1.9189
# DELTA train loss 1.8645, DELTA val loss 1.9189
#
# step 2800: KL train loss 2.8535, KL val loss 3.0112
# DLITE train loss 0.4975, DLITE val loss 0.5193
# CE train loss 2.8535, CE val loss 3.0112
# DLITE Cube Root train loss 0.1658, DLITE Cube Root val loss 0.1731
# LIT train loss 1.9452, LIT val loss 1.9980
# DELTA train loss 1.9452, DELTA val loss 1.9980
#
# step 2900: KL train loss 2.8715, KL val loss 3.0405
# DLITE train loss 0.4931, DLITE val loss 0.5174
# CE train loss 2.8715, CE val loss 3.0405
# DLITE Cube Root train loss 0.1644, DLITE Cube Root val loss 0.1725
# LIT train loss 1.9183, LIT val loss 1.9754
# DELTA train loss 1.9183, DELTA val loss 1.9754
#
# step 3000: KL train loss 2.9288, KL val loss 3.0763
# DLITE train loss 0.4931, DLITE val loss 0.5159
# CE train loss 2.9288, CE val loss 3.0763
# DLITE Cube Root train loss 0.1644, DLITE Cube Root val loss 0.1720
# LIT train loss 1.8804, LIT val loss 1.9378
# DELTA train loss 1.8804, DELTA val loss 1.9378
#
# step 3100: KL train loss 2.8880, KL val loss 3.0887
# DLITE train loss 0.4886, DLITE val loss 0.5154
# CE train loss 2.8880, CE val loss 3.0887
# DLITE Cube Root train loss 0.1629, DLITE Cube Root val loss 0.1718
# LIT train loss 1.8596, LIT val loss 1.9202
# DELTA train loss 1.8596, DELTA val loss 1.9202
#
# step 3200: KL train loss 2.8557, KL val loss 3.0320
# DLITE train loss 0.4847, DLITE val loss 0.5114
# CE train loss 2.8557, CE val loss 3.0320
# DLITE Cube Root train loss 0.1616, DLITE Cube Root val loss 0.1705
# LIT train loss 1.8629, LIT val loss 1.9265
# DELTA train loss 1.8629, DELTA val loss 1.9265
#
# step 3300: KL train loss 2.9584, KL val loss 3.1002
# DLITE train loss 0.4861, DLITE val loss 0.5124
# CE train loss 2.9584, CE val loss 3.1002
# DLITE Cube Root train loss 0.1620, DLITE Cube Root val loss 0.1708
# LIT train loss 1.8249, LIT val loss 1.8923
# DELTA train loss 1.8249, DELTA val loss 1.8923
#
# step 3400: KL train loss 2.8768, KL val loss 3.0425
# DLITE train loss 0.4852, DLITE val loss 0.5071
# CE train loss 2.8768, CE val loss 3.0425
# DLITE Cube Root train loss 0.1617, DLITE Cube Root val loss 0.1690
# LIT train loss 1.8658, LIT val loss 1.9160
# DELTA train loss 1.8658, DELTA val loss 1.9160
#
# step 3500: KL train loss 2.9004, KL val loss 3.0688
# DLITE train loss 0.4819, DLITE val loss 0.5092
# CE train loss 2.9004, CE val loss 3.0688
# DLITE Cube Root train loss 0.1606, DLITE Cube Root val loss 0.1697
# LIT train loss 1.8181, LIT val loss 1.8868
# DELTA train loss 1.8181, DELTA val loss 1.8868
#
# step 3600: KL train loss 2.8984, KL val loss 3.0782
# DLITE train loss 0.4789, DLITE val loss 0.5070
# CE train loss 2.8984, CE val loss 3.0782
# DLITE Cube Root train loss 0.1596, DLITE Cube Root val loss 0.1690
# LIT train loss 1.8051, LIT val loss 1.8791
# DELTA train loss 1.8051, DELTA val loss 1.8791
#
# step 3700: KL train loss 2.8862, KL val loss 3.0508
# DLITE train loss 0.4805, DLITE val loss 0.5067
# CE train loss 2.8862, CE val loss 3.0508
# DLITE Cube Root train loss 0.1602, DLITE Cube Root val loss 0.1689
# LIT train loss 1.8212, LIT val loss 1.8933
# DELTA train loss 1.8212, DELTA val loss 1.8933
#
# step 3800: KL train loss 2.8387, KL val loss 3.0409
# DLITE train loss 0.4798, DLITE val loss 0.5100
# CE train loss 2.8387, CE val loss 3.0409
# DLITE Cube Root train loss 0.1599, DLITE Cube Root val loss 0.1700
# LIT train loss 1.8199, LIT val loss 1.8945
# DELTA train loss 1.8199, DELTA val loss 1.8945
#
# step 3900: KL train loss 2.8380, KL val loss 3.0397
# DLITE train loss 0.4748, DLITE val loss 0.5036
# CE train loss 2.8380, CE val loss 3.0397
# DLITE Cube Root train loss 0.1583, DLITE Cube Root val loss 0.1679
# LIT train loss 1.8181, LIT val loss 1.8824
# DELTA train loss 1.8181, DELTA val loss 1.8824
#
# step 4000: KL train loss 2.8317, KL val loss 3.0074
# DLITE train loss 0.4740, DLITE val loss 0.5006
# CE train loss 2.8317, CE val loss 3.0074
# DLITE Cube Root train loss 0.1580, DLITE Cube Root val loss 0.1669
# LIT train loss 1.7931, LIT val loss 1.8551
# DELTA train loss 1.7931, DELTA val loss 1.8551
#
# step 4100: KL train loss 2.8725, KL val loss 3.0577
# DLITE train loss 0.4752, DLITE val loss 0.5032
# CE train loss 2.8725, CE val loss 3.0577
# DLITE Cube Root train loss 0.1584, DLITE Cube Root val loss 0.1677
# LIT train loss 1.8003, LIT val loss 1.8695
# DELTA train loss 1.8003, DELTA val loss 1.8695
#
# step 4200: KL train loss 2.8360, KL val loss 3.0157
# DLITE train loss 0.4720, DLITE val loss 0.5007
# CE train loss 2.8360, CE val loss 3.0157
# DLITE Cube Root train loss 0.1573, DLITE Cube Root val loss 0.1669
# LIT train loss 1.7800, LIT val loss 1.8501
# DELTA train loss 1.7800, DELTA val loss 1.8501
#
# step 4300: KL train loss 2.9375, KL val loss 3.1085
# DLITE train loss 0.4737, DLITE val loss 0.5017
# CE train loss 2.9375, CE val loss 3.1085
# DLITE Cube Root train loss 0.1579, DLITE Cube Root val loss 0.1672
# LIT train loss 1.7184, LIT val loss 1.7854
# DELTA train loss 1.7184, DELTA val loss 1.7854
#
# step 4400: KL train loss 2.8653, KL val loss 3.0257
# DLITE train loss 0.4717, DLITE val loss 0.4968
# CE train loss 2.8653, CE val loss 3.0257
# DLITE Cube Root train loss 0.1572, DLITE Cube Root val loss 0.1656
# LIT train loss 1.7857, LIT val loss 1.8452
# DELTA train loss 1.7857, DELTA val loss 1.8452
#
# step 4500: KL train loss 2.8151, KL val loss 2.9840
# DLITE train loss 0.4688, DLITE val loss 0.4960
# CE train loss 2.8151, CE val loss 2.9840
# DLITE Cube Root train loss 0.1563, DLITE Cube Root val loss 0.1653
# LIT train loss 1.8045, LIT val loss 1.8727
# DELTA train loss 1.8045, DELTA val loss 1.8727
#
# step 4600: KL train loss 2.8390, KL val loss 2.9942
# DLITE train loss 0.4690, DLITE val loss 0.4955
# CE train loss 2.8390, CE val loss 2.9942
# DLITE Cube Root train loss 0.1563, DLITE Cube Root val loss 0.1652
# LIT train loss 1.7794, LIT val loss 1.8458
# DELTA train loss 1.7794, DELTA val loss 1.8458
#
# step 4700: KL train loss 2.8544, KL val loss 3.0205
# DLITE train loss 0.4660, DLITE val loss 0.4944
# CE train loss 2.8544, CE val loss 3.0205
# DLITE Cube Root train loss 0.1553, DLITE Cube Root val loss 0.1648
# LIT train loss 1.7512, LIT val loss 1.8252
# DELTA train loss 1.7512, DELTA val loss 1.8252
#
# step 4800: KL train loss 2.8407, KL val loss 3.0772
# DLITE train loss 0.4624, DLITE val loss 0.4947
# CE train loss 2.8407, CE val loss 3.0772
# DLITE Cube Root train loss 0.1541, DLITE Cube Root val loss 0.1649
# LIT train loss 1.7285, LIT val loss 1.8064
# DELTA train loss 1.7285, DELTA val loss 1.8064
#
# step 4900: KL train loss 2.8598, KL val loss 3.0563
# DLITE train loss 0.4648, DLITE val loss 0.4936
# CE train loss 2.8598, CE val loss 3.0563
# DLITE Cube Root train loss 0.1549, DLITE Cube Root val loss 0.1645
# LIT train loss 1.7453, LIT val loss 1.8177
# DELTA train loss 1.7453, DELTA val loss 1.8177
#
# step 5000: KL train loss 2.8336, KL val loss 2.9980
# DLITE train loss 0.4628, DLITE val loss 0.4896
# CE train loss 2.8336, CE val loss 2.9980
# DLITE Cube Root train loss 0.1543, DLITE Cube Root val loss 0.1632
# LIT train loss 1.7374, LIT val loss 1.8060
# DELTA train loss 1.7374, DELTA val loss 1.8060
#
# step 5100: KL train loss 2.7926, KL val loss 2.9947
# DLITE train loss 0.4651, DLITE val loss 0.4922
# CE train loss 2.7926, CE val loss 2.9947
# DLITE Cube Root train loss 0.1550, DLITE Cube Root val loss 0.1641
# LIT train loss 1.7819, LIT val loss 1.8458
# DELTA train loss 1.7819, DELTA val loss 1.8458
#
# step 5200: KL train loss 2.8439, KL val loss 3.0662
# DLITE train loss 0.4615, DLITE val loss 0.4900
# CE train loss 2.8439, CE val loss 3.0662
# DLITE Cube Root train loss 0.1538, DLITE Cube Root val loss 0.1633
# LIT train loss 1.7016, LIT val loss 1.7703
# DELTA train loss 1.7016, DELTA val loss 1.7703
#
# step 5300: KL train loss 2.8014, KL val loss 2.9878
# DLITE train loss 0.4613, DLITE val loss 0.4910
# CE train loss 2.8014, CE val loss 2.9878
# DLITE Cube Root train loss 0.1538, DLITE Cube Root val loss 0.1637
# LIT train loss 1.7633, LIT val loss 1.8358
# DELTA train loss 1.7633, DELTA val loss 1.8358
#
# step 5400: KL train loss 2.8395, KL val loss 3.0350
# DLITE train loss 0.4624, DLITE val loss 0.4912
# CE train loss 2.8395, CE val loss 3.0350
# DLITE Cube Root train loss 0.1541, DLITE Cube Root val loss 0.1637
# LIT train loss 1.7195, LIT val loss 1.7922
# DELTA train loss 1.7195, DELTA val loss 1.7922
#
# step 5500: KL train loss 2.8147, KL val loss 3.0003
# DLITE train loss 0.4603, DLITE val loss 0.4888
# CE train loss 2.8147, CE val loss 3.0003
# DLITE Cube Root train loss 0.1534, DLITE Cube Root val loss 0.1629
# LIT train loss 1.7375, LIT val loss 1.8060
# DELTA train loss 1.7375, DELTA val loss 1.8060
#
# step 5600: KL train loss 2.8742, KL val loss 3.0390
# DLITE train loss 0.4621, DLITE val loss 0.4877
# CE train loss 2.8742, CE val loss 3.0390
# DLITE Cube Root train loss 0.1540, DLITE Cube Root val loss 0.1626
# LIT train loss 1.7192, LIT val loss 1.7815
# DELTA train loss 1.7192, DELTA val loss 1.7815
#
# step 5700: KL train loss 2.8276, KL val loss 3.0175
# DLITE train loss 0.4602, DLITE val loss 0.4891
# CE train loss 2.8276, CE val loss 3.0175
# DLITE Cube Root train loss 0.1534, DLITE Cube Root val loss 0.1630
# LIT train loss 1.7371, LIT val loss 1.8105
# DELTA train loss 1.7371, DELTA val loss 1.8105
#
# step 5800: KL train loss 2.8483, KL val loss 3.0333
# DLITE train loss 0.4575, DLITE val loss 0.4865
# CE train loss 2.8483, CE val loss 3.0333
# DLITE Cube Root train loss 0.1525, DLITE Cube Root val loss 0.1622
# LIT train loss 1.7031, LIT val loss 1.7742
# DELTA train loss 1.7031, DELTA val loss 1.7742
#
# step 5900: KL train loss 2.8559, KL val loss 3.0286
# DLITE train loss 0.4603, DLITE val loss 0.4883
# CE train loss 2.8559, CE val loss 3.0286
# DLITE Cube Root train loss 0.1534, DLITE Cube Root val loss 0.1628
# LIT train loss 1.7192, LIT val loss 1.7899
# DELTA train loss 1.7192, DELTA val loss 1.7899
#
# step 6000: KL train loss 2.8330, KL val loss 3.0515
# DLITE train loss 0.4568, DLITE val loss 0.4899
# CE train loss 2.8330, CE val loss 3.0515
# DLITE Cube Root train loss 0.1523, DLITE Cube Root val loss 0.1633
# LIT train loss 1.6950, LIT val loss 1.7799
# DELTA train loss 1.6950, DELTA val loss 1.7799
#
# step 6100: KL train loss 2.8740, KL val loss 3.0185
# DLITE train loss 0.4589, DLITE val loss 0.4843
# CE train loss 2.8740, CE val loss 3.0185
# DLITE Cube Root train loss 0.1530, DLITE Cube Root val loss 0.1614
# LIT train loss 1.7088, LIT val loss 1.7752
# DELTA train loss 1.7088, DELTA val loss 1.7752
#
# step 6200: KL train loss 2.8272, KL val loss 3.0219
# DLITE train loss 0.4567, DLITE val loss 0.4841
# CE train loss 2.8272, CE val loss 3.0219
# DLITE Cube Root train loss 0.1522, DLITE Cube Root val loss 0.1614
# LIT train loss 1.7104, LIT val loss 1.7758
# DELTA train loss 1.7104, DELTA val loss 1.7758
#
# step 6300: KL train loss 2.8338, KL val loss 3.0503
# DLITE train loss 0.4552, DLITE val loss 0.4865
# CE train loss 2.8338, CE val loss 3.0503
# DLITE Cube Root train loss 0.1517, DLITE Cube Root val loss 0.1622
# LIT train loss 1.7008, LIT val loss 1.7799
# DELTA train loss 1.7008, DELTA val loss 1.7799
#
# step 6400: KL train loss 2.7814, KL val loss 3.0067
# DLITE train loss 0.4559, DLITE val loss 0.4871
# CE train loss 2.7814, CE val loss 3.0067
# DLITE Cube Root train loss 0.1520, DLITE Cube Root val loss 0.1624
# LIT train loss 1.7255, LIT val loss 1.8008
# DELTA train loss 1.7255, DELTA val loss 1.8008
#
# step 6500: KL train loss 2.8058, KL val loss 2.9659
# DLITE train loss 0.4526, DLITE val loss 0.4779
# CE train loss 2.8058, CE val loss 2.9659
# DLITE Cube Root train loss 0.1509, DLITE Cube Root val loss 0.1593
# LIT train loss 1.7085, LIT val loss 1.7753
# DELTA train loss 1.7085, DELTA val loss 1.7753
#
# step 6600: KL train loss 2.8095, KL val loss 3.0001
# DLITE train loss 0.4536, DLITE val loss 0.4818
# CE train loss 2.8095, CE val loss 3.0001
# DLITE Cube Root train loss 0.1512, DLITE Cube Root val loss 0.1606
# LIT train loss 1.6852, LIT val loss 1.7580
# DELTA train loss 1.6852, DELTA val loss 1.7580
#
# step 6700: KL train loss 2.7773, KL val loss 2.9940
# DLITE train loss 0.4516, DLITE val loss 0.4825
# CE train loss 2.7773, CE val loss 2.9940
# DLITE Cube Root train loss 0.1505, DLITE Cube Root val loss 0.1608
# LIT train loss 1.7093, LIT val loss 1.7855
# DELTA train loss 1.7093, DELTA val loss 1.7855
#
# step 6800: KL train loss 2.8216, KL val loss 3.0387
# DLITE train loss 0.4532, DLITE val loss 0.4823
# CE train loss 2.8216, CE val loss 3.0387
# DLITE Cube Root train loss 0.1511, DLITE Cube Root val loss 0.1608
# LIT train loss 1.6860, LIT val loss 1.7561
# DELTA train loss 1.6860, DELTA val loss 1.7561
#
# step 6900: KL train loss 2.7966, KL val loss 2.9824
# DLITE train loss 0.4518, DLITE val loss 0.4805
# CE train loss 2.7966, CE val loss 2.9824
# DLITE Cube Root train loss 0.1506, DLITE Cube Root val loss 0.1602
# LIT train loss 1.6970, LIT val loss 1.7704
# DELTA train loss 1.6970, DELTA val loss 1.7704
#
# step 7000: KL train loss 2.7927, KL val loss 2.9942
# DLITE train loss 0.4509, DLITE val loss 0.4791
# CE train loss 2.7927, CE val loss 2.9942
# DLITE Cube Root train loss 0.1503, DLITE Cube Root val loss 0.1597
# LIT train loss 1.6829, LIT val loss 1.7526
# DELTA train loss 1.6829, DELTA val loss 1.7526
#
# step 7100: KL train loss 2.8237, KL val loss 2.9973
# DLITE train loss 0.4527, DLITE val loss 0.4799
# CE train loss 2.8237, CE val loss 2.9973
# DLITE Cube Root train loss 0.1509, DLITE Cube Root val loss 0.1600
# LIT train loss 1.6991, LIT val loss 1.7675
# DELTA train loss 1.6991, DELTA val loss 1.7675
#
# step 7200: KL train loss 2.8289, KL val loss 3.0719
# DLITE train loss 0.4491, DLITE val loss 0.4806
# CE train loss 2.8289, CE val loss 3.0719
# DLITE Cube Root train loss 0.1497, DLITE Cube Root val loss 0.1602
# LIT train loss 1.6493, LIT val loss 1.7248
# DELTA train loss 1.6493, DELTA val loss 1.7248
#
# step 7300: KL train loss 2.8363, KL val loss 3.0395
# DLITE train loss 0.4502, DLITE val loss 0.4766
# CE train loss 2.8363, CE val loss 3.0395
# DLITE Cube Root train loss 0.1501, DLITE Cube Root val loss 0.1589
# LIT train loss 1.6678, LIT val loss 1.7322
# DELTA train loss 1.6678, DELTA val loss 1.7322
#
# step 7400: KL train loss 2.8251, KL val loss 3.0435
# DLITE train loss 0.4490, DLITE val loss 0.4793
# CE train loss 2.8251, CE val loss 3.0435
# DLITE Cube Root train loss 0.1497, DLITE Cube Root val loss 0.1597
# LIT train loss 1.6644, LIT val loss 1.7409
# DELTA train loss 1.6644, DELTA val loss 1.7409
#
# step 7500: KL train loss 2.7695, KL val loss 3.0031
# DLITE train loss 0.4451, DLITE val loss 0.4751
# CE train loss 2.7695, CE val loss 3.0031
# DLITE Cube Root train loss 0.1484, DLITE Cube Root val loss 0.1584
# LIT train loss 1.6742, LIT val loss 1.7491
# DELTA train loss 1.6742, DELTA val loss 1.7491
#
# step 7600: KL train loss 2.7963, KL val loss 3.0214
# DLITE train loss 0.4489, DLITE val loss 0.4783
# CE train loss 2.7963, CE val loss 3.0214
# DLITE Cube Root train loss 0.1496, DLITE Cube Root val loss 0.1594
# LIT train loss 1.6653, LIT val loss 1.7401
# DELTA train loss 1.6653, DELTA val loss 1.7401
#
# step 7700: KL train loss 2.7741, KL val loss 2.9954
# DLITE train loss 0.4458, DLITE val loss 0.4749
# CE train loss 2.7741, CE val loss 2.9954
# DLITE Cube Root train loss 0.1486, DLITE Cube Root val loss 0.1583
# LIT train loss 1.6690, LIT val loss 1.7416
# DELTA train loss 1.6690, DELTA val loss 1.7416
#
# step 7800: KL train loss 2.8397, KL val loss 3.0345
# DLITE train loss 0.4505, DLITE val loss 0.4744
# CE train loss 2.8397, CE val loss 3.0345
# DLITE Cube Root train loss 0.1502, DLITE Cube Root val loss 0.1581
# LIT train loss 1.6650, LIT val loss 1.7233
# DELTA train loss 1.6650, DELTA val loss 1.7233
#
# step 7900: KL train loss 2.8181, KL val loss 3.0458
# DLITE train loss 0.4477, DLITE val loss 0.4756
# CE train loss 2.8181, CE val loss 3.0458
# DLITE Cube Root train loss 0.1492, DLITE Cube Root val loss 0.1585
# LIT train loss 1.6504, LIT val loss 1.7170
# DELTA train loss 1.6504, DELTA val loss 1.7170
#
# step 8000: KL train loss 2.7784, KL val loss 2.9874
# DLITE train loss 0.4461, DLITE val loss 0.4747
# CE train loss 2.7784, CE val loss 2.9874
# DLITE Cube Root train loss 0.1487, DLITE Cube Root val loss 0.1582
# LIT train loss 1.6826, LIT val loss 1.7494
# DELTA train loss 1.6826, DELTA val loss 1.7494
#
# step 8100: KL train loss 2.7253, KL val loss 2.9480
# DLITE train loss 0.4462, DLITE val loss 0.4765
# CE train loss 2.7253, CE val loss 2.9480
# DLITE Cube Root train loss 0.1487, DLITE Cube Root val loss 0.1588
# LIT train loss 1.6943, LIT val loss 1.7731
# DELTA train loss 1.6943, DELTA val loss 1.7731
#
# step 8200: KL train loss 2.7887, KL val loss 2.9966
# DLITE train loss 0.4465, DLITE val loss 0.4761
# CE train loss 2.7887, CE val loss 2.9966
# DLITE Cube Root train loss 0.1488, DLITE Cube Root val loss 0.1587
# LIT train loss 1.6560, LIT val loss 1.7292
# DELTA train loss 1.6560, DELTA val loss 1.7292
#
# step 8300: KL train loss 2.7755, KL val loss 2.9940
# DLITE train loss 0.4459, DLITE val loss 0.4753
# CE train loss 2.7755, CE val loss 2.9940
# DLITE Cube Root train loss 0.1486, DLITE Cube Root val loss 0.1584
# LIT train loss 1.6565, LIT val loss 1.7280
# DELTA train loss 1.6565, DELTA val loss 1.7280
#
# step 8400: KL train loss 2.7240, KL val loss 2.9694
# DLITE train loss 0.4442, DLITE val loss 0.4739
# CE train loss 2.7240, CE val loss 2.9694
# DLITE Cube Root train loss 0.1481, DLITE Cube Root val loss 0.1580
# LIT train loss 1.6666, LIT val loss 1.7396
# DELTA train loss 1.6666, DELTA val loss 1.7396
#
# step 8500: KL train loss 2.7446, KL val loss 2.9720
# DLITE train loss 0.4449, DLITE val loss 0.4745
# CE train loss 2.7446, CE val loss 2.9720
# DLITE Cube Root train loss 0.1483, DLITE Cube Root val loss 0.1582
# LIT train loss 1.6633, LIT val loss 1.7387
# DELTA train loss 1.6633, DELTA val loss 1.7387
#
# step 8600: KL train loss 2.7695, KL val loss 3.0113
# DLITE train loss 0.4435, DLITE val loss 0.4745
# CE train loss 2.7695, CE val loss 3.0113
# DLITE Cube Root train loss 0.1478, DLITE Cube Root val loss 0.1582
# LIT train loss 1.6425, LIT val loss 1.7162
# DELTA train loss 1.6425, DELTA val loss 1.7162
#
# step 8700: KL train loss 2.7199, KL val loss 2.9591
# DLITE train loss 0.4418, DLITE val loss 0.4748
# CE train loss 2.7199, CE val loss 2.9591
# DLITE Cube Root train loss 0.1473, DLITE Cube Root val loss 0.1583
# LIT train loss 1.6594, LIT val loss 1.7427
# DELTA train loss 1.6594, DELTA val loss 1.7427
#
# step 8800: KL train loss 2.7050, KL val loss 2.9509
# DLITE train loss 0.4385, DLITE val loss 0.4748
# CE train loss 2.7050, CE val loss 2.9509
# DLITE Cube Root train loss 0.1462, DLITE Cube Root val loss 0.1583
# LIT train loss 1.6457, LIT val loss 1.7411
# DELTA train loss 1.6457, DELTA val loss 1.7411
#
# step 8900: KL train loss 2.7435, KL val loss 2.9385
# DLITE train loss 0.4408, DLITE val loss 0.4697
# CE train loss 2.7435, CE val loss 2.9385
# DLITE Cube Root train loss 0.1469, DLITE Cube Root val loss 0.1566
# LIT train loss 1.6371, LIT val loss 1.7089
# DELTA train loss 1.6371, DELTA val loss 1.7089
#
# step 9000: KL train loss 2.7178, KL val loss 2.9473
# DLITE train loss 0.4418, DLITE val loss 0.4727
# CE train loss 2.7178, CE val loss 2.9473
# DLITE Cube Root train loss 0.1473, DLITE Cube Root val loss 0.1576
# LIT train loss 1.6634, LIT val loss 1.7382
# DELTA train loss 1.6634, DELTA val loss 1.7382
#
# step 9100: KL train loss 2.7178, KL val loss 2.9555
# DLITE train loss 0.4393, DLITE val loss 0.4715
# CE train loss 2.7178, CE val loss 2.9555
# DLITE Cube Root train loss 0.1464, DLITE Cube Root val loss 0.1572
# LIT train loss 1.6542, LIT val loss 1.7334
# DELTA train loss 1.6542, DELTA val loss 1.7334
#
# step 9200: KL train loss 2.7726, KL val loss 2.9916
# DLITE train loss 0.4426, DLITE val loss 0.4696
# CE train loss 2.7726, CE val loss 2.9916
# DLITE Cube Root train loss 0.1475, DLITE Cube Root val loss 0.1565
# LIT train loss 1.6268, LIT val loss 1.6957
# DELTA train loss 1.6268, DELTA val loss 1.6957
#
# step 9300: KL train loss 2.6948, KL val loss 2.9485
# DLITE train loss 0.4385, DLITE val loss 0.4675
# CE train loss 2.6948, CE val loss 2.9485
# DLITE Cube Root train loss 0.1462, DLITE Cube Root val loss 0.1558
# LIT train loss 1.6422, LIT val loss 1.7104
# DELTA train loss 1.6422, DELTA val loss 1.7104
#
# step 9400: KL train loss 2.7124, KL val loss 2.9322
# DLITE train loss 0.4391, DLITE val loss 0.4677
# CE train loss 2.7124, CE val loss 2.9322
# DLITE Cube Root train loss 0.1464, DLITE Cube Root val loss 0.1559
# LIT train loss 1.6537, LIT val loss 1.7218
# DELTA train loss 1.6537, DELTA val loss 1.7218
#
# step 9500: KL train loss 2.7114, KL val loss 2.9713
# DLITE train loss 0.4398, DLITE val loss 0.4713
# CE train loss 2.7114, CE val loss 2.9713
# DLITE Cube Root train loss 0.1466, DLITE Cube Root val loss 0.1571
# LIT train loss 1.6447, LIT val loss 1.7202
# DELTA train loss 1.6447, DELTA val loss 1.7202
#
# step 9600: KL train loss 2.7510, KL val loss 2.9893
# DLITE train loss 0.4393, DLITE val loss 0.4702
# CE train loss 2.7510, CE val loss 2.9893
# DLITE Cube Root train loss 0.1464, DLITE Cube Root val loss 0.1567
# LIT train loss 1.6359, LIT val loss 1.7142
# DELTA train loss 1.6359, DELTA val loss 1.7142
#
# step 9700: KL train loss 2.7161, KL val loss 2.9381
# DLITE train loss 0.4386, DLITE val loss 0.4707
# CE train loss 2.7161, CE val loss 2.9381
# DLITE Cube Root train loss 0.1462, DLITE Cube Root val loss 0.1569
# LIT train loss 1.6368, LIT val loss 1.7170
# DELTA train loss 1.6368, DELTA val loss 1.7170
#
# step 9800: KL train loss 2.7451, KL val loss 2.9792
# DLITE train loss 0.4375, DLITE val loss 0.4726
# CE train loss 2.7451, CE val loss 2.9792
# DLITE Cube Root train loss 0.1458, DLITE Cube Root val loss 0.1575
# LIT train loss 1.6195, LIT val loss 1.7099
# DELTA train loss 1.6195, DELTA val loss 1.7099
#
# step 9900: KL train loss 2.7243, KL val loss 2.9665
# DLITE train loss 0.4378, DLITE val loss 0.4684
# CE train loss 2.7243, CE val loss 2.9665
# DLITE Cube Root train loss 0.1459, DLITE Cube Root val loss 0.1561
# LIT train loss 1.6382, LIT val loss 1.7142
# DELTA train loss 1.6382, DELTA val loss 1.7142
#
# step 9999: KL train loss 2.7516, KL val loss 2.9701
# DLITE train loss 0.4371, DLITE val loss 0.4678
# CE train loss 2.7516, CE val loss 2.9701
# DLITE Cube Root train loss 0.1457, DLITE Cube Root val loss 0.1559
# LIT train loss 1.6219, LIT val loss 1.7033
# DELTA train loss 1.6219, DELTA val loss 1.7033

# %% [markdown]
# ## Train with CE

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()
kl_loss = KLDivergenceLoss()
dlite_cuberoot_loss = DLITECubeRootLoss()
lit_loss = LITLoss()
delta_loss = DELTALoss()

# Lists to store the loss values
dlite_train_losses = []
dlite_val_losses = []
ce_train_losses = []
ce_val_losses = []
kl_train_losses = []
kl_val_losses = []
dlite_cuberoot_train_losses = []
dlite_cuberoot_val_losses = []
lit_train_losses = []
lit_val_losses = []
delta_train_losses = []
delta_val_losses = []




for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses , delta_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}")
        print(f"DLITE Cube Root train loss {dlite_cuberoot_losses['train']:.4f}, DLITE Cube Root val loss {dlite_cuberoot_losses['val']:.4f}")
        print(f"LIT train loss {lit_losses['train']:.4f}, LIT val loss {lit_losses['val']:.4f}")
        print(f"DELTA train loss {delta_losses['train']:.4f}, DELTA val loss {delta_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses.append(dlite_losses['train'])
        dlite_val_losses.append(dlite_losses['val'])
        ce_train_losses.append(ce_losses['train'])
        ce_val_losses.append(ce_losses['val'])
        kl_train_losses.append(kl_losses['train'])
        kl_val_losses.append(kl_losses['val'])
        dlite_cuberoot_train_losses.append(dlite_cuberoot_losses['train'])
        dlite_cuberoot_val_losses.append(dlite_cuberoot_losses['val'])
        lit_train_losses.append(lit_losses['train'])
        lit_val_losses.append(lit_losses['val'])
        delta_train_losses.append(delta_losses['train'])
        delta_val_losses.append(delta_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the CE loss using the flattened logits and targets
    loss = ce_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Plotting DLITE Loss
plot_losses(dlite_train_losses, dlite_val_losses, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses, ce_val_losses, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses, kl_val_losses, 'KL Divergence Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(dlite_cuberoot_train_losses, dlite_cuberoot_val_losses, 'DLITE Cube Root Loss Over Time')

# Plotting LIT Loss
plot_losses(lit_train_losses, lit_val_losses, 'LIT Loss Over Time')

# Plotting DELTA Loss
plot_losses(delta_train_losses, delta_val_losses, 'DELTA Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 4.4116, KL val loss 4.4022
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
# DLITE Cube Root train loss 0.3094, DLITE Cube Root val loss 0.3092
# LIT train loss 5.8604, LIT val loss 5.8589
# DELTA train loss 5.8604, DELTA val loss 5.8589
#
# step 100: KL train loss 2.6568, KL val loss 2.6670
# DLITE train loss 0.6977, DLITE val loss 0.6981
# CE train loss 2.6568, CE val loss 2.6670
# DLITE Cube Root train loss 0.2326, DLITE Cube Root val loss 0.2327
# LIT train loss 4.1986, LIT val loss 4.2068
# DELTA train loss 4.1986, DELTA val loss 4.2068
#
# step 200: KL train loss 2.5091, KL val loss 2.5060
# DLITE train loss 0.6712, DLITE val loss 0.6701
# CE train loss 2.5091, CE val loss 2.5060
# DLITE Cube Root train loss 0.2237, DLITE Cube Root val loss 0.2234
# LIT train loss 3.9304, LIT val loss 3.9325
# DELTA train loss 3.9304, DELTA val loss 3.9325
#
# step 300: KL train loss 2.4199, KL val loss 2.4337
# DLITE train loss 0.6491, DLITE val loss 0.6506
# CE train loss 2.4199, CE val loss 2.4337
# DLITE Cube Root train loss 0.2164, DLITE Cube Root val loss 0.2169
# LIT train loss 3.7271, LIT val loss 3.7351
# DELTA train loss 3.7271, DELTA val loss 3.7351
#
# step 400: KL train loss 2.3500, KL val loss 2.3563
# DLITE train loss 0.6344, DLITE val loss 0.6347
# CE train loss 2.3500, CE val loss 2.3563
# DLITE Cube Root train loss 0.2115, DLITE Cube Root val loss 0.2116
# LIT train loss 3.6080, LIT val loss 3.6107
# DELTA train loss 3.6080, DELTA val loss 3.6107
#
# step 500: KL train loss 2.2961, KL val loss 2.3126
# DLITE train loss 0.6187, DLITE val loss 0.6209
# CE train loss 2.2961, CE val loss 2.3126
# DLITE Cube Root train loss 0.2062, DLITE Cube Root val loss 0.2070
# LIT train loss 3.4767, LIT val loss 3.4827
# DELTA train loss 3.4767, DELTA val loss 3.4827
#
# step 600: KL train loss 2.2408, KL val loss 2.2501
# DLITE train loss 0.6099, DLITE val loss 0.6097
# CE train loss 2.2408, CE val loss 2.2501
# DLITE Cube Root train loss 0.2033, DLITE Cube Root val loss 0.2032
# LIT train loss 3.4452, LIT val loss 3.4371
# DELTA train loss 3.4452, DELTA val loss 3.4371
#
# step 700: KL train loss 2.2053, KL val loss 2.2187
# DLITE train loss 0.5983, DLITE val loss 0.5998
# CE train loss 2.2053, CE val loss 2.2187
# DLITE Cube Root train loss 0.1994, DLITE Cube Root val loss 0.1999
# LIT train loss 3.3509, LIT val loss 3.3506
# DELTA train loss 3.3509, DELTA val loss 3.3506
#
# step 800: KL train loss 2.1636, KL val loss 2.1870
# DLITE train loss 0.5913, DLITE val loss 0.5943
# CE train loss 2.1636, CE val loss 2.1870
# DLITE Cube Root train loss 0.1971, DLITE Cube Root val loss 0.1981
# LIT train loss 3.3274, LIT val loss 3.3318
# DELTA train loss 3.3274, DELTA val loss 3.3318
#
# step 900: KL train loss 2.1226, KL val loss 2.1483
# DLITE train loss 0.5822, DLITE val loss 0.5860
# CE train loss 2.1226, CE val loss 2.1483
# DLITE Cube Root train loss 0.1941, DLITE Cube Root val loss 0.1953
# LIT train loss 3.2700, LIT val loss 3.2755
# DELTA train loss 3.2700, DELTA val loss 3.2755
#
# step 1000: KL train loss 2.1017, KL val loss 2.1283
# DLITE train loss 0.5737, DLITE val loss 0.5772
# CE train loss 2.1017, CE val loss 2.1283
# DLITE Cube Root train loss 0.1912, DLITE Cube Root val loss 0.1924
# LIT train loss 3.1790, LIT val loss 3.1784
# DELTA train loss 3.1790, DELTA val loss 3.1784
#
# step 1100: KL train loss 2.0683, KL val loss 2.1174
# DLITE train loss 0.5697, DLITE val loss 0.5770
# CE train loss 2.0683, CE val loss 2.1174
# DLITE Cube Root train loss 0.1899, DLITE Cube Root val loss 0.1923
# LIT train loss 3.1871, LIT val loss 3.1974
# DELTA train loss 3.1871, DELTA val loss 3.1974
#
# step 1200: KL train loss 2.0376, KL val loss 2.0798
# DLITE train loss 0.5615, DLITE val loss 0.5675
# CE train loss 2.0376, CE val loss 2.0798
# DLITE Cube Root train loss 0.1872, DLITE Cube Root val loss 0.1892
# LIT train loss 3.1314, LIT val loss 3.1412
# DELTA train loss 3.1314, DELTA val loss 3.1412
#
# step 1300: KL train loss 2.0256, KL val loss 2.0645
# DLITE train loss 0.5549, DLITE val loss 0.5610
# CE train loss 2.0256, CE val loss 2.0645
# DLITE Cube Root train loss 0.1850, DLITE Cube Root val loss 0.1870
# LIT train loss 3.0478, LIT val loss 3.0531
# DELTA train loss 3.0478, DELTA val loss 3.0531
#
# step 1400: KL train loss 1.9919, KL val loss 2.0362
# DLITE train loss 0.5483, DLITE val loss 0.5555
# CE train loss 1.9919, CE val loss 2.0362
# DLITE Cube Root train loss 0.1828, DLITE Cube Root val loss 0.1852
# LIT train loss 3.0339, LIT val loss 3.0385
# DELTA train loss 3.0339, DELTA val loss 3.0385
#
# step 1500: KL train loss 1.9696, KL val loss 2.0304
# DLITE train loss 0.5448, DLITE val loss 0.5552
# CE train loss 1.9696, CE val loss 2.0304
# DLITE Cube Root train loss 0.1816, DLITE Cube Root val loss 0.1851
# LIT train loss 3.0138, LIT val loss 3.0389
# DELTA train loss 3.0138, DELTA val loss 3.0389
#
# step 1600: KL train loss 1.9625, KL val loss 2.0470
# DLITE train loss 0.5415, DLITE val loss 0.5553
# CE train loss 1.9625, CE val loss 2.0470
# DLITE Cube Root train loss 0.1805, DLITE Cube Root val loss 0.1851
# LIT train loss 2.9787, LIT val loss 3.0070
# DELTA train loss 2.9787, DELTA val loss 3.0070
#
# step 1700: KL train loss 1.9402, KL val loss 2.0119
# DLITE train loss 0.5356, DLITE val loss 0.5473
# CE train loss 1.9402, CE val loss 2.0119
# DLITE Cube Root train loss 0.1785, DLITE Cube Root val loss 0.1824
# LIT train loss 2.9422, LIT val loss 2.9644
# DELTA train loss 2.9422, DELTA val loss 2.9644
#
# step 1800: KL train loss 1.9085, KL val loss 1.9957
# DLITE train loss 0.5269, DLITE val loss 0.5430
# CE train loss 1.9085, CE val loss 1.9957
# DLITE Cube Root train loss 0.1756, DLITE Cube Root val loss 0.1810
# LIT train loss 2.8912, LIT val loss 2.9326
# DELTA train loss 2.8912, DELTA val loss 2.9326
#
# step 1900: KL train loss 1.9080, KL val loss 1.9869
# DLITE train loss 0.5276, DLITE val loss 0.5404
# CE train loss 1.9080, CE val loss 1.9869
# DLITE Cube Root train loss 0.1759, DLITE Cube Root val loss 0.1801
# LIT train loss 2.8821, LIT val loss 2.9080
# DELTA train loss 2.8821, DELTA val loss 2.9080
#
# step 2000: KL train loss 1.8834, KL val loss 1.9941
# DLITE train loss 0.5210, DLITE val loss 0.5402
# CE train loss 1.8834, CE val loss 1.9941
# DLITE Cube Root train loss 0.1737, DLITE Cube Root val loss 0.1801
# LIT train loss 2.8483, LIT val loss 2.8953
# DELTA train loss 2.8483, DELTA val loss 2.8953
#
# step 2100: KL train loss 1.8727, KL val loss 1.9758
# DLITE train loss 0.5212, DLITE val loss 0.5399
# CE train loss 1.8727, CE val loss 1.9758
# DLITE Cube Root train loss 0.1737, DLITE Cube Root val loss 0.1800
# LIT train loss 2.8776, LIT val loss 2.9279
# DELTA train loss 2.8776, DELTA val loss 2.9279
#
# step 2200: KL train loss 1.8585, KL val loss 1.9622
# DLITE train loss 0.5172, DLITE val loss 0.5355
# CE train loss 1.8585, CE val loss 1.9622
# DLITE Cube Root train loss 0.1724, DLITE Cube Root val loss 0.1785
# LIT train loss 2.8455, LIT val loss 2.8928
# DELTA train loss 2.8455, DELTA val loss 2.8928
#
# step 2300: KL train loss 1.8537, KL val loss 1.9503
# DLITE train loss 0.5167, DLITE val loss 0.5344
# CE train loss 1.8537, CE val loss 1.9503
# DLITE Cube Root train loss 0.1722, DLITE Cube Root val loss 0.1781
# LIT train loss 2.8513, LIT val loss 2.8954
# DELTA train loss 2.8513, DELTA val loss 2.8954
#
# step 2400: KL train loss 1.8419, KL val loss 1.9424
# DLITE train loss 0.5114, DLITE val loss 0.5293
# CE train loss 1.8419, CE val loss 1.9424
# DLITE Cube Root train loss 0.1705, DLITE Cube Root val loss 0.1764
# LIT train loss 2.7908, LIT val loss 2.8370
# DELTA train loss 2.7908, DELTA val loss 2.8370
#
# step 2500: KL train loss 1.8153, KL val loss 1.9407
# DLITE train loss 0.5027, DLITE val loss 0.5263
# CE train loss 1.8153, CE val loss 1.9407
# DLITE Cube Root train loss 0.1676, DLITE Cube Root val loss 0.1754
# LIT train loss 2.7298, LIT val loss 2.7981
# DELTA train loss 2.7298, DELTA val loss 2.7981
#
# step 2600: KL train loss 1.8267, KL val loss 1.9374
# DLITE train loss 0.5040, DLITE val loss 0.5246
# CE train loss 1.8267, CE val loss 1.9374
# DLITE Cube Root train loss 0.1680, DLITE Cube Root val loss 0.1749
# LIT train loss 2.7143, LIT val loss 2.7748
# DELTA train loss 2.7143, DELTA val loss 2.7748
#
# step 2700: KL train loss 1.8126, KL val loss 1.9344
# DLITE train loss 0.5032, DLITE val loss 0.5266
# CE train loss 1.8126, CE val loss 1.9344
# DLITE Cube Root train loss 0.1677, DLITE Cube Root val loss 0.1755
# LIT train loss 2.7434, LIT val loss 2.8122
# DELTA train loss 2.7434, DELTA val loss 2.8122
#
# step 2800: KL train loss 1.8054, KL val loss 1.9230
# DLITE train loss 0.5031, DLITE val loss 0.5249
# CE train loss 1.8054, CE val loss 1.9230
# DLITE Cube Root train loss 0.1677, DLITE Cube Root val loss 0.1750
# LIT train loss 2.7514, LIT val loss 2.8091
# DELTA train loss 2.7514, DELTA val loss 2.8091
#
# step 2900: KL train loss 1.8045, KL val loss 1.9339
# DLITE train loss 0.5026, DLITE val loss 0.5255
# CE train loss 1.8045, CE val loss 1.9339
# DLITE Cube Root train loss 0.1675, DLITE Cube Root val loss 0.1752
# LIT train loss 2.7480, LIT val loss 2.8082
# DELTA train loss 2.7480, DELTA val loss 2.8082
#
# step 3000: KL train loss 1.7963, KL val loss 1.9243
# DLITE train loss 0.4957, DLITE val loss 0.5196
# CE train loss 1.7963, CE val loss 1.9243
# DLITE Cube Root train loss 0.1652, DLITE Cube Root val loss 0.1732
# LIT train loss 2.6624, LIT val loss 2.7334
# DELTA train loss 2.6624, DELTA val loss 2.7334
#
# step 3100: KL train loss 1.7691, KL val loss 1.9208
# DLITE train loss 0.4956, DLITE val loss 0.5228
# CE train loss 1.7691, CE val loss 1.9208
# DLITE Cube Root train loss 0.1652, DLITE Cube Root val loss 0.1743
# LIT train loss 2.7124, LIT val loss 2.7911
# DELTA train loss 2.7124, DELTA val loss 2.7911
#
# step 3200: KL train loss 1.7506, KL val loss 1.9092
# DLITE train loss 0.4873, DLITE val loss 0.5159
# CE train loss 1.7506, CE val loss 1.9092
# DLITE Cube Root train loss 0.1624, DLITE Cube Root val loss 0.1720
# LIT train loss 2.6380, LIT val loss 2.7149
# DELTA train loss 2.6380, DELTA val loss 2.7149
#
# step 3300: KL train loss 1.7548, KL val loss 1.9038
# DLITE train loss 0.4908, DLITE val loss 0.5188
# CE train loss 1.7548, CE val loss 1.9038
# DLITE Cube Root train loss 0.1636, DLITE Cube Root val loss 0.1729
# LIT train loss 2.6833, LIT val loss 2.7642
# DELTA train loss 2.6833, DELTA val loss 2.7642
#
# step 3400: KL train loss 1.7582, KL val loss 1.8960
# DLITE train loss 0.4906, DLITE val loss 0.5151
# CE train loss 1.7582, CE val loss 1.8960
# DLITE Cube Root train loss 0.1635, DLITE Cube Root val loss 0.1717
# LIT train loss 2.6698, LIT val loss 2.7307
# DELTA train loss 2.6698, DELTA val loss 2.7307
#
# step 3500: KL train loss 1.7376, KL val loss 1.8934
# DLITE train loss 0.4852, DLITE val loss 0.5132
# CE train loss 1.7376, CE val loss 1.8934
# DLITE Cube Root train loss 0.1617, DLITE Cube Root val loss 0.1711
# LIT train loss 2.6373, LIT val loss 2.7127
# DELTA train loss 2.6373, DELTA val loss 2.7127
#
# step 3600: KL train loss 1.7232, KL val loss 1.8888
# DLITE train loss 0.4796, DLITE val loss 0.5107
# CE train loss 1.7232, CE val loss 1.8888
# DLITE Cube Root train loss 0.1599, DLITE Cube Root val loss 0.1702
# LIT train loss 2.5884, LIT val loss 2.6799
# DELTA train loss 2.5884, DELTA val loss 2.6799
#
# step 3700: KL train loss 1.7280, KL val loss 1.8814
# DLITE train loss 0.4819, DLITE val loss 0.5110
# CE train loss 1.7280, CE val loss 1.8814
# DLITE Cube Root train loss 0.1606, DLITE Cube Root val loss 0.1703
# LIT train loss 2.6157, LIT val loss 2.7032
# DELTA train loss 2.6157, DELTA val loss 2.7032
#
# step 3800: KL train loss 1.7221, KL val loss 1.8951
# DLITE train loss 0.4800, DLITE val loss 0.5123
# CE train loss 1.7221, CE val loss 1.8951
# DLITE Cube Root train loss 0.1600, DLITE Cube Root val loss 0.1708
# LIT train loss 2.5928, LIT val loss 2.6842
# DELTA train loss 2.5928, DELTA val loss 2.6842
#
# step 3900: KL train loss 1.7228, KL val loss 1.8789
# DLITE train loss 0.4779, DLITE val loss 0.5063
# CE train loss 1.7228, CE val loss 1.8789
# DLITE Cube Root train loss 0.1593, DLITE Cube Root val loss 0.1688
# LIT train loss 2.5683, LIT val loss 2.6446
# DELTA train loss 2.5683, DELTA val loss 2.6446
#
# step 4000: KL train loss 1.7168, KL val loss 1.8635
# DLITE train loss 0.4774, DLITE val loss 0.5047
# CE train loss 1.7168, CE val loss 1.8635
# DLITE Cube Root train loss 0.1591, DLITE Cube Root val loss 0.1682
# LIT train loss 2.5703, LIT val loss 2.6447
# DELTA train loss 2.5703, DELTA val loss 2.6447
#
# step 4100: KL train loss 1.7168, KL val loss 1.8798
# DLITE train loss 0.4792, DLITE val loss 0.5093
# CE train loss 1.7168, CE val loss 1.8798
# DLITE Cube Root train loss 0.1597, DLITE Cube Root val loss 0.1698
# LIT train loss 2.5878, LIT val loss 2.6750
# DELTA train loss 2.5878, DELTA val loss 2.6750
#
# step 4200: KL train loss 1.7088, KL val loss 1.8672
# DLITE train loss 0.4763, DLITE val loss 0.5064
# CE train loss 1.7088, CE val loss 1.8672
# DLITE Cube Root train loss 0.1588, DLITE Cube Root val loss 0.1688
# LIT train loss 2.5655, LIT val loss 2.6546
# DELTA train loss 2.5655, DELTA val loss 2.6546
#
# step 4300: KL train loss 1.6995, KL val loss 1.8501
# DLITE train loss 0.4718, DLITE val loss 0.5006
# CE train loss 1.6995, CE val loss 1.8501
# DLITE Cube Root train loss 0.1573, DLITE Cube Root val loss 0.1669
# LIT train loss 2.5149, LIT val loss 2.5993
# DELTA train loss 2.5149, DELTA val loss 2.5993
#
# step 4400: KL train loss 1.7096, KL val loss 1.8686
# DLITE train loss 0.4784, DLITE val loss 0.5074
# CE train loss 1.7096, CE val loss 1.8686
# DLITE Cube Root train loss 0.1595, DLITE Cube Root val loss 0.1691
# LIT train loss 2.5867, LIT val loss 2.6709
# DELTA train loss 2.5867, DELTA val loss 2.6709
#
# step 4500: KL train loss 1.6907, KL val loss 1.8546
# DLITE train loss 0.4741, DLITE val loss 0.5041
# CE train loss 1.6907, CE val loss 1.8546
# DLITE Cube Root train loss 0.1580, DLITE Cube Root val loss 0.1680
# LIT train loss 2.5730, LIT val loss 2.6655
# DELTA train loss 2.5730, DELTA val loss 2.6655
#
# step 4600: KL train loss 1.6868, KL val loss 1.8348
# DLITE train loss 0.4710, DLITE val loss 0.4995
# CE train loss 1.6868, CE val loss 1.8348
# DLITE Cube Root train loss 0.1570, DLITE Cube Root val loss 0.1665
# LIT train loss 2.5382, LIT val loss 2.6251
# DELTA train loss 2.5382, DELTA val loss 2.6251
#
# step 4700: KL train loss 1.6786, KL val loss 1.8346
# DLITE train loss 0.4675, DLITE val loss 0.4969
# CE train loss 1.6786, CE val loss 1.8346
# DLITE Cube Root train loss 0.1558, DLITE Cube Root val loss 0.1656
# LIT train loss 2.5110, LIT val loss 2.6005
# DELTA train loss 2.5110, DELTA val loss 2.6005
#
# step 4800: KL train loss 1.6659, KL val loss 1.8445
# DLITE train loss 0.4651, DLITE val loss 0.4984
# CE train loss 1.6659, CE val loss 1.8445
# DLITE Cube Root train loss 0.1550, DLITE Cube Root val loss 0.1661
# LIT train loss 2.4968, LIT val loss 2.6008
# DELTA train loss 2.4968, DELTA val loss 2.6008
#
# step 4900: KL train loss 1.6711, KL val loss 1.8384
# DLITE train loss 0.4679, DLITE val loss 0.4990
# CE train loss 1.6711, CE val loss 1.8384
# DLITE Cube Root train loss 0.1560, DLITE Cube Root val loss 0.1663
# LIT train loss 2.5256, LIT val loss 2.6209
# DELTA train loss 2.5256, DELTA val loss 2.6209
#
# step 5000: KL train loss 1.6623, KL val loss 1.8231
# DLITE train loss 0.4669, DLITE val loss 0.4963
# CE train loss 1.6623, CE val loss 1.8231
# DLITE Cube Root train loss 0.1556, DLITE Cube Root val loss 0.1654
# LIT train loss 2.5262, LIT val loss 2.6124
# DELTA train loss 2.5262, DELTA val loss 2.6124
#
# step 5100: KL train loss 1.6695, KL val loss 1.8326
# DLITE train loss 0.4693, DLITE val loss 0.4981
# CE train loss 1.6695, CE val loss 1.8326
# DLITE Cube Root train loss 0.1564, DLITE Cube Root val loss 0.1660
# LIT train loss 2.5494, LIT val loss 2.6327
# DELTA train loss 2.5494, DELTA val loss 2.6327
#
# step 5200: KL train loss 1.6639, KL val loss 1.8206
# DLITE train loss 0.4625, DLITE val loss 0.4915
# CE train loss 1.6639, CE val loss 1.8206
# DLITE Cube Root train loss 0.1542, DLITE Cube Root val loss 0.1638
# LIT train loss 2.4653, LIT val loss 2.5510
# DELTA train loss 2.4653, DELTA val loss 2.5510
#
# step 5300: KL train loss 1.6657, KL val loss 1.8215
# DLITE train loss 0.4646, DLITE val loss 0.4943
# CE train loss 1.6657, CE val loss 1.8215
# DLITE Cube Root train loss 0.1549, DLITE Cube Root val loss 0.1648
# LIT train loss 2.4947, LIT val loss 2.5824
# DELTA train loss 2.4947, DELTA val loss 2.5824
#
# step 5400: KL train loss 1.6510, KL val loss 1.8186
# DLITE train loss 0.4605, DLITE val loss 0.4927
# CE train loss 1.6510, CE val loss 1.8186
# DLITE Cube Root train loss 0.1535, DLITE Cube Root val loss 0.1642
# LIT train loss 2.4633, LIT val loss 2.5671
# DELTA train loss 2.4633, DELTA val loss 2.5671
#
# step 5500: KL train loss 1.6533, KL val loss 1.7999
# DLITE train loss 0.4616, DLITE val loss 0.4900
# CE train loss 1.6533, CE val loss 1.7999
# DLITE Cube Root train loss 0.1539, DLITE Cube Root val loss 0.1633
# LIT train loss 2.4743, LIT val loss 2.5643
# DELTA train loss 2.4743, DELTA val loss 2.5643
#
# step 5600: KL train loss 1.6572, KL val loss 1.8126
# DLITE train loss 0.4650, DLITE val loss 0.4944
# CE train loss 1.6572, CE val loss 1.8126
# DLITE Cube Root train loss 0.1550, DLITE Cube Root val loss 0.1648
# LIT train loss 2.5114, LIT val loss 2.6029
# DELTA train loss 2.5114, DELTA val loss 2.6029
#
# step 5700: KL train loss 1.6538, KL val loss 1.8137
# DLITE train loss 0.4640, DLITE val loss 0.4939
# CE train loss 1.6538, CE val loss 1.8137
# DLITE Cube Root train loss 0.1547, DLITE Cube Root val loss 0.1646
# LIT train loss 2.5063, LIT val loss 2.5998
# DELTA train loss 2.5063, DELTA val loss 2.5998
#
# step 5800: KL train loss 1.6408, KL val loss 1.8069
# DLITE train loss 0.4596, DLITE val loss 0.4906
# CE train loss 1.6408, CE val loss 1.8069
# DLITE Cube Root train loss 0.1532, DLITE Cube Root val loss 0.1635
# LIT train loss 2.4748, LIT val loss 2.5705
# DELTA train loss 2.4748, DELTA val loss 2.5705
#
# step 5900: KL train loss 1.6427, KL val loss 1.8025
# DLITE train loss 0.4580, DLITE val loss 0.4889
# CE train loss 1.6427, CE val loss 1.8025
# DLITE Cube Root train loss 0.1527, DLITE Cube Root val loss 0.1630
# LIT train loss 2.4527, LIT val loss 2.5492
# DELTA train loss 2.4527, DELTA val loss 2.5492
#
# step 6000: KL train loss 1.6416, KL val loss 1.8054
# DLITE train loss 0.4590, DLITE val loss 0.4902
# CE train loss 1.6416, CE val loss 1.8054
# DLITE Cube Root train loss 0.1530, DLITE Cube Root val loss 0.1634
# LIT train loss 2.4682, LIT val loss 2.5661
# DELTA train loss 2.4682, DELTA val loss 2.5661
#
# step 6100: KL train loss 1.6378, KL val loss 1.7866
# DLITE train loss 0.4572, DLITE val loss 0.4847
# CE train loss 1.6378, CE val loss 1.7866
# DLITE Cube Root train loss 0.1524, DLITE Cube Root val loss 0.1616
# LIT train loss 2.4524, LIT val loss 2.5403
# DELTA train loss 2.4524, DELTA val loss 2.5403
#
# step 6200: KL train loss 1.6419, KL val loss 1.7910
# DLITE train loss 0.4580, DLITE val loss 0.4843
# CE train loss 1.6419, CE val loss 1.7910
# DLITE Cube Root train loss 0.1527, DLITE Cube Root val loss 0.1614
# LIT train loss 2.4427, LIT val loss 2.5206
# DELTA train loss 2.4427, DELTA val loss 2.5206
#
# step 6300: KL train loss 1.6263, KL val loss 1.7916
# DLITE train loss 0.4572, DLITE val loss 0.4872
# CE train loss 1.6263, CE val loss 1.7916
# DLITE Cube Root train loss 0.1524, DLITE Cube Root val loss 0.1624
# LIT train loss 2.4681, LIT val loss 2.5610
# DELTA train loss 2.4681, DELTA val loss 2.5610
#
# step 6400: KL train loss 1.6266, KL val loss 1.8014
# DLITE train loss 0.4575, DLITE val loss 0.4890
# CE train loss 1.6266, CE val loss 1.8014
# DLITE Cube Root train loss 0.1525, DLITE Cube Root val loss 0.1630
# LIT train loss 2.4672, LIT val loss 2.5622
# DELTA train loss 2.4672, DELTA val loss 2.5622
#
# step 6500: KL train loss 1.6252, KL val loss 1.7859
# DLITE train loss 0.4553, DLITE val loss 0.4849
# CE train loss 1.6252, CE val loss 1.7859
# DLITE Cube Root train loss 0.1518, DLITE Cube Root val loss 0.1616
# LIT train loss 2.4373, LIT val loss 2.5265
# DELTA train loss 2.4373, DELTA val loss 2.5265
#
# step 6600: KL train loss 1.6222, KL val loss 1.7820
# DLITE train loss 0.4536, DLITE val loss 0.4819
# CE train loss 1.6222, CE val loss 1.7820
# DLITE Cube Root train loss 0.1512, DLITE Cube Root val loss 0.1606
# LIT train loss 2.4261, LIT val loss 2.5066
# DELTA train loss 2.4261, DELTA val loss 2.5066
#
# step 6700: KL train loss 1.6225, KL val loss 1.8044
# DLITE train loss 0.4550, DLITE val loss 0.4862
# CE train loss 1.6225, CE val loss 1.8044
# DLITE Cube Root train loss 0.1517, DLITE Cube Root val loss 0.1621
# LIT train loss 2.4422, LIT val loss 2.5324
# DELTA train loss 2.4422, DELTA val loss 2.5324
#
# step 6800: KL train loss 1.6205, KL val loss 1.7999
# DLITE train loss 0.4523, DLITE val loss 0.4845
# CE train loss 1.6205, CE val loss 1.7999
# DLITE Cube Root train loss 0.1508, DLITE Cube Root val loss 0.1615
# LIT train loss 2.4132, LIT val loss 2.5085
# DELTA train loss 2.4132, DELTA val loss 2.5085
#
# step 6900: KL train loss 1.6149, KL val loss 1.7875
# DLITE train loss 0.4528, DLITE val loss 0.4849
# CE train loss 1.6149, CE val loss 1.7875
# DLITE Cube Root train loss 0.1509, DLITE Cube Root val loss 0.1616
# LIT train loss 2.4287, LIT val loss 2.5247
# DELTA train loss 2.4287, DELTA val loss 2.5247
#
# step 7000: KL train loss 1.6156, KL val loss 1.7827
# DLITE train loss 0.4547, DLITE val loss 0.4847
# CE train loss 1.6156, CE val loss 1.7827
# DLITE Cube Root train loss 0.1516, DLITE Cube Root val loss 0.1616
# LIT train loss 2.4563, LIT val loss 2.5425
# DELTA train loss 2.4563, DELTA val loss 2.5425
#
# step 7100: KL train loss 1.6201, KL val loss 1.7854
# DLITE train loss 0.4528, DLITE val loss 0.4839
# CE train loss 1.6201, CE val loss 1.7854
# DLITE Cube Root train loss 0.1509, DLITE Cube Root val loss 0.1613
# LIT train loss 2.4239, LIT val loss 2.5178
# DELTA train loss 2.4239, DELTA val loss 2.5178
#
# step 7200: KL train loss 1.6111, KL val loss 1.7919
# DLITE train loss 0.4508, DLITE val loss 0.4822
# CE train loss 1.6111, CE val loss 1.7919
# DLITE Cube Root train loss 0.1503, DLITE Cube Root val loss 0.1607
# LIT train loss 2.4025, LIT val loss 2.4880
# DELTA train loss 2.4025, DELTA val loss 2.4880
#
# step 7300: KL train loss 1.6096, KL val loss 1.7709
# DLITE train loss 0.4503, DLITE val loss 0.4788
# CE train loss 1.6096, CE val loss 1.7709
# DLITE Cube Root train loss 0.1501, DLITE Cube Root val loss 0.1596
# LIT train loss 2.4082, LIT val loss 2.4872
# DELTA train loss 2.4082, DELTA val loss 2.4872
#
# step 7400: KL train loss 1.6096, KL val loss 1.7861
# DLITE train loss 0.4490, DLITE val loss 0.4811
# CE train loss 1.6096, CE val loss 1.7861
# DLITE Cube Root train loss 0.1497, DLITE Cube Root val loss 0.1604
# LIT train loss 2.3860, LIT val loss 2.4864
# DELTA train loss 2.3860, DELTA val loss 2.4864
#
# step 7500: KL train loss 1.5971, KL val loss 1.7893
# DLITE train loss 0.4493, DLITE val loss 0.4833
# CE train loss 1.5971, CE val loss 1.7893
# DLITE Cube Root train loss 0.1498, DLITE Cube Root val loss 0.1611
# LIT train loss 2.4136, LIT val loss 2.5173
# DELTA train loss 2.4136, DELTA val loss 2.5173
#
# step 7600: KL train loss 1.6028, KL val loss 1.7803
# DLITE train loss 0.4496, DLITE val loss 0.4817
# CE train loss 1.6028, CE val loss 1.7803
# DLITE Cube Root train loss 0.1499, DLITE Cube Root val loss 0.1606
# LIT train loss 2.4043, LIT val loss 2.4988
# DELTA train loss 2.4043, DELTA val loss 2.4988
#
# step 7700: KL train loss 1.5944, KL val loss 1.7718
# DLITE train loss 0.4490, DLITE val loss 0.4808
# CE train loss 1.5944, CE val loss 1.7718
# DLITE Cube Root train loss 0.1497, DLITE Cube Root val loss 0.1603
# LIT train loss 2.4200, LIT val loss 2.5134
# DELTA train loss 2.4200, DELTA val loss 2.5134
#
# step 7800: KL train loss 1.6075, KL val loss 1.7672
# DLITE train loss 0.4509, DLITE val loss 0.4791
# CE train loss 1.6075, CE val loss 1.7672
# DLITE Cube Root train loss 0.1503, DLITE Cube Root val loss 0.1597
# LIT train loss 2.4154, LIT val loss 2.4983
# DELTA train loss 2.4154, DELTA val loss 2.4983
#
# step 7900: KL train loss 1.6053, KL val loss 1.7707
# DLITE train loss 0.4497, DLITE val loss 0.4788
# CE train loss 1.6053, CE val loss 1.7707
# DLITE Cube Root train loss 0.1499, DLITE Cube Root val loss 0.1596
# LIT train loss 2.4001, LIT val loss 2.4874
# DELTA train loss 2.4001, DELTA val loss 2.4874
#
# step 8000: KL train loss 1.5975, KL val loss 1.7717
# DLITE train loss 0.4491, DLITE val loss 0.4815
# CE train loss 1.5975, CE val loss 1.7717
# DLITE Cube Root train loss 0.1497, DLITE Cube Root val loss 0.1605
# LIT train loss 2.4106, LIT val loss 2.5072
# DELTA train loss 2.4106, DELTA val loss 2.5072
#
# step 8100: KL train loss 1.6001, KL val loss 1.7770
# DLITE train loss 0.4513, DLITE val loss 0.4845
# CE train loss 1.6001, CE val loss 1.7770
# DLITE Cube Root train loss 0.1504, DLITE Cube Root val loss 0.1615
# LIT train loss 2.4438, LIT val loss 2.5459
# DELTA train loss 2.4438, DELTA val loss 2.5459
#
# step 8200: KL train loss 1.6006, KL val loss 1.7825
# DLITE train loss 0.4469, DLITE val loss 0.4798
# CE train loss 1.6006, CE val loss 1.7825
# DLITE Cube Root train loss 0.1490, DLITE Cube Root val loss 0.1599
# LIT train loss 2.3743, LIT val loss 2.4738
# DELTA train loss 2.3743, DELTA val loss 2.4738
#
# step 8300: KL train loss 1.5888, KL val loss 1.7603
# DLITE train loss 0.4460, DLITE val loss 0.4761
# CE train loss 1.5888, CE val loss 1.7603
# DLITE Cube Root train loss 0.1487, DLITE Cube Root val loss 0.1587
# LIT train loss 2.3865, LIT val loss 2.4764
# DELTA train loss 2.3865, DELTA val loss 2.4764
#
# step 8400: KL train loss 1.5945, KL val loss 1.7733
# DLITE train loss 0.4476, DLITE val loss 0.4795
# CE train loss 1.5945, CE val loss 1.7733
# DLITE Cube Root train loss 0.1492, DLITE Cube Root val loss 0.1598
# LIT train loss 2.3909, LIT val loss 2.4831
# DELTA train loss 2.3909, DELTA val loss 2.4831
#
# step 8500: KL train loss 1.5904, KL val loss 1.7711
# DLITE train loss 0.4478, DLITE val loss 0.4799
# CE train loss 1.5904, CE val loss 1.7711
# DLITE Cube Root train loss 0.1493, DLITE Cube Root val loss 0.1600
# LIT train loss 2.4048, LIT val loss 2.5026
# DELTA train loss 2.4048, DELTA val loss 2.5026
#
# step 8600: KL train loss 1.5917, KL val loss 1.7695
# DLITE train loss 0.4429, DLITE val loss 0.4749
# CE train loss 1.5917, CE val loss 1.7695
# DLITE Cube Root train loss 0.1476, DLITE Cube Root val loss 0.1583
# LIT train loss 2.3346, LIT val loss 2.4295
# DELTA train loss 2.3346, DELTA val loss 2.4295
#
# step 8700: KL train loss 1.5844, KL val loss 1.7701
# DLITE train loss 0.4453, DLITE val loss 0.4802
# CE train loss 1.5844, CE val loss 1.7701
# DLITE Cube Root train loss 0.1484, DLITE Cube Root val loss 0.1601
# LIT train loss 2.3893, LIT val loss 2.4963
# DELTA train loss 2.3893, DELTA val loss 2.4963
#
# step 8800: KL train loss 1.5731, KL val loss 1.7677
# DLITE train loss 0.4414, DLITE val loss 0.4773
# CE train loss 1.5731, CE val loss 1.7677
# DLITE Cube Root train loss 0.1471, DLITE Cube Root val loss 0.1591
# LIT train loss 2.3565, LIT val loss 2.4703
# DELTA train loss 2.3565, DELTA val loss 2.4703
#
# step 8900: KL train loss 1.5850, KL val loss 1.7448
# DLITE train loss 0.4444, DLITE val loss 0.4736
# CE train loss 1.5850, CE val loss 1.7448
# DLITE Cube Root train loss 0.1481, DLITE Cube Root val loss 0.1579
# LIT train loss 2.3717, LIT val loss 2.4596
# DELTA train loss 2.3717, DELTA val loss 2.4596
#
# step 9000: KL train loss 1.5847, KL val loss 1.7643
# DLITE train loss 0.4480, DLITE val loss 0.4804
# CE train loss 1.5847, CE val loss 1.7643
# DLITE Cube Root train loss 0.1493, DLITE Cube Root val loss 0.1601
# LIT train loss 2.4208, LIT val loss 2.5135
# DELTA train loss 2.4208, DELTA val loss 2.5135
#
# step 9100: KL train loss 1.5767, KL val loss 1.7637
# DLITE train loss 0.4423, DLITE val loss 0.4763
# CE train loss 1.5767, CE val loss 1.7637
# DLITE Cube Root train loss 0.1474, DLITE Cube Root val loss 0.1588
# LIT train loss 2.3631, LIT val loss 2.4631
# DELTA train loss 2.3631, DELTA val loss 2.4631
#
# step 9200: KL train loss 1.5841, KL val loss 1.7616
# DLITE train loss 0.4426, DLITE val loss 0.4743
# CE train loss 1.5841, CE val loss 1.7616
# DLITE Cube Root train loss 0.1475, DLITE Cube Root val loss 0.1581
# LIT train loss 2.3444, LIT val loss 2.4362
# DELTA train loss 2.3444, DELTA val loss 2.4362
#
# step 9300: KL train loss 1.5687, KL val loss 1.7457
# DLITE train loss 0.4443, DLITE val loss 0.4755
# CE train loss 1.5687, CE val loss 1.7457
# DLITE Cube Root train loss 0.1481, DLITE Cube Root val loss 0.1585
# LIT train loss 2.4023, LIT val loss 2.4947
# DELTA train loss 2.4023, DELTA val loss 2.4947
#
# step 9400: KL train loss 1.5737, KL val loss 1.7483
# DLITE train loss 0.4454, DLITE val loss 0.4768
# CE train loss 1.5737, CE val loss 1.7483
# DLITE Cube Root train loss 0.1485, DLITE Cube Root val loss 0.1589
# LIT train loss 2.4059, LIT val loss 2.4953
# DELTA train loss 2.4059, DELTA val loss 2.4953
#
# step 9500: KL train loss 1.5743, KL val loss 1.7633
# DLITE train loss 0.4433, DLITE val loss 0.4768
# CE train loss 1.5743, CE val loss 1.7633
# DLITE Cube Root train loss 0.1478, DLITE Cube Root val loss 0.1589
# LIT train loss 2.3700, LIT val loss 2.4688
# DELTA train loss 2.3700, DELTA val loss 2.4688
#
# step 9600: KL train loss 1.5738, KL val loss 1.7561
# DLITE train loss 0.4424, DLITE val loss 0.4751
# CE train loss 1.5738, CE val loss 1.7561
# DLITE Cube Root train loss 0.1475, DLITE Cube Root val loss 0.1584
# LIT train loss 2.3666, LIT val loss 2.4642
# DELTA train loss 2.3666, DELTA val loss 2.4642
#
# step 9700: KL train loss 1.5693, KL val loss 1.7401
# DLITE train loss 0.4416, DLITE val loss 0.4733
# CE train loss 1.5693, CE val loss 1.7401
# DLITE Cube Root train loss 0.1472, DLITE Cube Root val loss 0.1578
# LIT train loss 2.3666, LIT val loss 2.4622
# DELTA train loss 2.3666, DELTA val loss 2.4622
#
# step 9800: KL train loss 1.5567, KL val loss 1.7577
# DLITE train loss 0.4373, DLITE val loss 0.4740
# CE train loss 1.5567, CE val loss 1.7577
# DLITE Cube Root train loss 0.1458, DLITE Cube Root val loss 0.1580
# LIT train loss 2.3345, LIT val loss 2.4484
# DELTA train loss 2.3345, DELTA val loss 2.4484
#
# step 9900: KL train loss 1.5692, KL val loss 1.7480
# DLITE train loss 0.4406, DLITE val loss 0.4713
# CE train loss 1.5692, CE val loss 1.7480
# DLITE Cube Root train loss 0.1469, DLITE Cube Root val loss 0.1571
# LIT train loss 2.3565, LIT val loss 2.4453
# DELTA train loss 2.3565, DELTA val loss 2.4453
#
# step 9999: KL train loss 1.5600, KL val loss 1.7477
# DLITE train loss 0.4388, DLITE val loss 0.4716
# CE train loss 1.5600, CE val loss 1.7477
# DLITE Cube Root train loss 0.1463, DLITE Cube Root val loss 0.1572
# LIT train loss 2.3436, LIT val loss 2.4405
# DELTA train loss 2.3436, DELTA val loss 2.4405

# %% [markdown]
# ## Train with LIT loss

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()
kl_loss = KLDivergenceLoss()
dlite_cuberoot_loss = DLITECubeRootLoss()
lit_loss = LITLoss()
delta_loss = DELTALoss()

# Lists to store the loss values
dlite_train_losses = []
dlite_val_losses = []
ce_train_losses = []
ce_val_losses = []
kl_train_losses = []
kl_val_losses = []
dlite_cuberoot_train_losses = []
dlite_cuberoot_val_losses = []
lit_train_losses = []
lit_val_losses = []
delta_train_losses = []
delta_val_losses = []




for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses , delta_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}")
        print(f"DLITE Cube Root train loss {dlite_cuberoot_losses['train']:.4f}, DLITE Cube Root val loss {dlite_cuberoot_losses['val']:.4f}")
        print(f"LIT train loss {lit_losses['train']:.4f}, LIT val loss {lit_losses['val']:.4f}")
        print(f"DELTA train loss {delta_losses['train']:.4f}, DELTA val loss {delta_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses.append(dlite_losses['train'])
        dlite_val_losses.append(dlite_losses['val'])
        ce_train_losses.append(ce_losses['train'])
        ce_val_losses.append(ce_losses['val'])
        kl_train_losses.append(kl_losses['train'])
        kl_val_losses.append(kl_losses['val'])
        dlite_cuberoot_train_losses.append(dlite_cuberoot_losses['train'])
        dlite_cuberoot_val_losses.append(dlite_cuberoot_losses['val'])
        lit_train_losses.append(lit_losses['train'])
        lit_val_losses.append(lit_losses['val'])
        delta_train_losses.append(delta_losses['train'])
        delta_val_losses.append(delta_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the LIT loss using the flattened logits and targets
    loss = lit_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Plotting DLITE Loss
plot_losses(dlite_train_losses, dlite_val_losses, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses, ce_val_losses, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses, kl_val_losses, 'KL Divergence Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(dlite_cuberoot_train_losses, dlite_cuberoot_val_losses, 'DLITE Cube Root Loss Over Time')

# Plotting LIT Loss
plot_losses(lit_train_losses, lit_val_losses, 'LIT Loss Over Time')

# Plotting DELTA Loss
plot_losses(delta_train_losses, delta_val_losses, 'DELTA Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 4.4116, KL val loss 4.4022
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
# DLITE Cube Root train loss 0.3094, DLITE Cube Root val loss 0.3092
# LIT train loss 5.8604, LIT val loss 5.8589
# DELTA train loss 5.8604, DELTA val loss 5.8589
#
# step 100: KL train loss 8.9321, KL val loss 8.9730
# DLITE train loss 0.8473, DLITE val loss 0.8514
# CE train loss 8.9321, CE val loss 8.9730
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2838
# LIT train loss 1.7170, LIT val loss 1.7252
# DELTA train loss 1.7170, DELTA val loss 1.7252
#
# step 200: KL train loss 9.8126, KL val loss 9.8599
# DLITE train loss 0.8475, DLITE val loss 0.8516
# CE train loss 9.8126, CE val loss 9.8599
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2839
# LIT train loss 1.7036, LIT val loss 1.7118
# DELTA train loss 1.7036, DELTA val loss 1.7118
#
# step 300: KL train loss 10.3810, KL val loss 10.4245
# DLITE train loss 0.8478, DLITE val loss 0.8518
# CE train loss 10.3810, CE val loss 10.4245
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2839
# LIT train loss 1.7002, LIT val loss 1.7082
# DELTA train loss 1.7002, DELTA val loss 1.7082
#
# step 400: KL train loss 10.7816, KL val loss 10.8215
# DLITE train loss 0.8466, DLITE val loss 0.8499
# CE train loss 10.7816, CE val loss 10.8215
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6962, LIT val loss 1.7027
# DELTA train loss 1.6962, DELTA val loss 1.7027
#
# step 500: KL train loss 11.1391, KL val loss 11.1851
# DLITE train loss 0.8486, DLITE val loss 0.8523
# CE train loss 11.1391, CE val loss 11.1851
# DLITE Cube Root train loss 0.2829, DLITE Cube Root val loss 0.2841
# LIT train loss 1.6992, LIT val loss 1.7066
# DELTA train loss 1.6992, DELTA val loss 1.7066
#
# step 600: KL train loss 11.3761, KL val loss 11.4438
# DLITE train loss 0.8455, DLITE val loss 0.8507
# CE train loss 11.3761, CE val loss 11.4438
# DLITE Cube Root train loss 0.2818, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6925, LIT val loss 1.7029
# DELTA train loss 1.6925, DELTA val loss 1.7029
#
# step 700: KL train loss 11.6482, KL val loss 11.6789
# DLITE train loss 0.8482, DLITE val loss 0.8504
# CE train loss 11.6482, CE val loss 11.6789
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6976, LIT val loss 1.7020
# DELTA train loss 1.6976, DELTA val loss 1.7020
#
# step 800: KL train loss 11.8355, KL val loss 11.8859
# DLITE train loss 0.8465, DLITE val loss 0.8500
# CE train loss 11.8355, CE val loss 11.8859
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6939, LIT val loss 1.7010
# DELTA train loss 1.6939, DELTA val loss 1.7010
#
# step 900: KL train loss 12.0507, KL val loss 12.0926
# DLITE train loss 0.8483, DLITE val loss 0.8516
# CE train loss 12.0507, CE val loss 12.0926
# DLITE Cube Root train loss 0.2828, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6974, LIT val loss 1.7040
# DELTA train loss 1.6974, DELTA val loss 1.7040
#
# step 1000: KL train loss 12.2101, KL val loss 12.2447
# DLITE train loss 0.8477, DLITE val loss 0.8500
# CE train loss 12.2101, CE val loss 12.2447
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6960, LIT val loss 1.7006
# DELTA train loss 1.6960, DELTA val loss 1.7006
#
# step 1100: KL train loss 12.3607, KL val loss 12.4187
# DLITE train loss 0.8472, DLITE val loss 0.8512
# CE train loss 12.3607, CE val loss 12.4187
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6948, LIT val loss 1.7029
# DELTA train loss 1.6948, DELTA val loss 1.7029
#
# step 1200: KL train loss 12.5126, KL val loss 12.5536
# DLITE train loss 0.8475, DLITE val loss 0.8505
# CE train loss 12.5126, CE val loss 12.5536
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6954, LIT val loss 1.7015
# DELTA train loss 1.6954, DELTA val loss 1.7015
#
# step 1300: KL train loss 12.6418, KL val loss 12.7005
# DLITE train loss 0.8470, DLITE val loss 0.8509
# CE train loss 12.6418, CE val loss 12.7005
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6943, LIT val loss 1.7022
# DELTA train loss 1.6943, DELTA val loss 1.7022
#
# step 1400: KL train loss 12.7707, KL val loss 12.8136
# DLITE train loss 0.8472, DLITE val loss 0.8499
# CE train loss 12.7707, CE val loss 12.8136
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6948, LIT val loss 1.7002
# DELTA train loss 1.6948, DELTA val loss 1.7002
#
# step 1500: KL train loss 12.8905, KL val loss 12.9366
# DLITE train loss 0.8469, DLITE val loss 0.8500
# CE train loss 12.8905, CE val loss 12.9366
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6940, LIT val loss 1.7003
# DELTA train loss 1.6940, DELTA val loss 1.7003
#
# step 1600: KL train loss 13.0101, KL val loss 13.0528
# DLITE train loss 0.8473, DLITE val loss 0.8502
# CE train loss 13.0101, CE val loss 13.0528
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6948, LIT val loss 1.7006
# DELTA train loss 1.6948, DELTA val loss 1.7006
#
# step 1700: KL train loss 13.1436, KL val loss 13.1805
# DLITE train loss 0.8488, DLITE val loss 0.8513
# CE train loss 13.1436, CE val loss 13.1805
# DLITE Cube Root train loss 0.2829, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6979, LIT val loss 1.7029
# DELTA train loss 1.6979, DELTA val loss 1.7029
#
# step 1800: KL train loss 13.2208, KL val loss 13.2839
# DLITE train loss 0.8469, DLITE val loss 0.8512
# CE train loss 13.2208, CE val loss 13.2839
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6940, LIT val loss 1.7026
# DELTA train loss 1.6940, DELTA val loss 1.7026
#
# step 1900: KL train loss 13.3272, KL val loss 13.3761
# DLITE train loss 0.8472, DLITE val loss 0.8506
# CE train loss 13.3272, CE val loss 13.3761
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6945, LIT val loss 1.7013
# DELTA train loss 1.6945, DELTA val loss 1.7013
#
# step 2000: KL train loss 13.4312, KL val loss 13.4902
# DLITE train loss 0.8477, DLITE val loss 0.8514
# CE train loss 13.4312, CE val loss 13.4902
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6956, LIT val loss 1.7029
# DELTA train loss 1.6956, DELTA val loss 1.7029
#
# step 2100: KL train loss 13.5135, KL val loss 13.5801
# DLITE train loss 0.8469, DLITE val loss 0.8510
# CE train loss 13.5135, CE val loss 13.5801
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6938, LIT val loss 1.7022
# DELTA train loss 1.6938, DELTA val loss 1.7022
#
# step 2200: KL train loss 13.6044, KL val loss 13.6743
# DLITE train loss 0.8467, DLITE val loss 0.8511
# CE train loss 13.6044, CE val loss 13.6743
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6936, LIT val loss 1.7023
# DELTA train loss 1.6936, DELTA val loss 1.7023
#
# step 2300: KL train loss 13.6853, KL val loss 13.7471
# DLITE train loss 0.8462, DLITE val loss 0.8500
# CE train loss 13.6853, CE val loss 13.7471
# DLITE Cube Root train loss 0.2821, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6925, LIT val loss 1.7000
# DELTA train loss 1.6925, DELTA val loss 1.7000
#
# step 2400: KL train loss 13.7798, KL val loss 13.8399
# DLITE train loss 0.8466, DLITE val loss 0.8502
# CE train loss 13.7798, CE val loss 13.8399
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6932, LIT val loss 1.7006
# DELTA train loss 1.6932, DELTA val loss 1.7006
#
# step 2500: KL train loss 13.8811, KL val loss 13.9486
# DLITE train loss 0.8474, DLITE val loss 0.8516
# CE train loss 13.8811, CE val loss 13.9486
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6948, LIT val loss 1.7033
# DELTA train loss 1.6948, DELTA val loss 1.7033
#
# step 2600: KL train loss 13.9617, KL val loss 14.0374
# DLITE train loss 0.8473, DLITE val loss 0.8519
# CE train loss 13.9617, CE val loss 14.0374
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2840
# LIT train loss 1.6947, LIT val loss 1.7039
# DELTA train loss 1.6947, DELTA val loss 1.7039
#
# step 2700: KL train loss 14.0525, KL val loss 14.0938
# DLITE train loss 0.8477, DLITE val loss 0.8503
# CE train loss 14.0525, CE val loss 14.0938
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6955, LIT val loss 1.7006
# DELTA train loss 1.6955, DELTA val loss 1.7006
#
# step 2800: KL train loss 14.1302, KL val loss 14.1889
# DLITE train loss 0.8475, DLITE val loss 0.8511
# CE train loss 14.1302, CE val loss 14.1889
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6950, LIT val loss 1.7023
# DELTA train loss 1.6950, DELTA val loss 1.7023
#
# step 2900: KL train loss 14.2078, KL val loss 14.2849
# DLITE train loss 0.8472, DLITE val loss 0.8518
# CE train loss 14.2078, CE val loss 14.2849
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6944, LIT val loss 1.7036
# DELTA train loss 1.6944, DELTA val loss 1.7036
#
# step 3000: KL train loss 14.2911, KL val loss 14.3232
# DLITE train loss 0.8475, DLITE val loss 0.8494
# CE train loss 14.2911, CE val loss 14.3232
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2831
# LIT train loss 1.6950, LIT val loss 1.6989
# DELTA train loss 1.6950, DELTA val loss 1.6989
#
# step 3100: KL train loss 14.3560, KL val loss 14.4107
# DLITE train loss 0.8466, DLITE val loss 0.8500
# CE train loss 14.3560, CE val loss 14.4107
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6933, LIT val loss 1.7000
# DELTA train loss 1.6933, DELTA val loss 1.7000
#
# step 3200: KL train loss 14.4458, KL val loss 14.5132
# DLITE train loss 0.8474, DLITE val loss 0.8513
# CE train loss 14.4458, CE val loss 14.5132
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6949, LIT val loss 1.7026
# DELTA train loss 1.6949, DELTA val loss 1.7026
#
# step 3300: KL train loss 14.5344, KL val loss 14.5875
# DLITE train loss 0.8481, DLITE val loss 0.8512
# CE train loss 14.5344, CE val loss 14.5875
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6963, LIT val loss 1.7024
# DELTA train loss 1.6963, DELTA val loss 1.7024
#
# step 3400: KL train loss 14.5964, KL val loss 14.6584
# DLITE train loss 0.8472, DLITE val loss 0.8507
# CE train loss 14.5964, CE val loss 14.6584
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6945, LIT val loss 1.7015
# DELTA train loss 1.6945, DELTA val loss 1.7015
#
# step 3500: KL train loss 14.6708, KL val loss 14.7251
# DLITE train loss 0.8471, DLITE val loss 0.8503
# CE train loss 14.6708, CE val loss 14.7251
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6942, LIT val loss 1.7006
# DELTA train loss 1.6942, DELTA val loss 1.7006
#
# step 3600: KL train loss 14.7422, KL val loss 14.8164
# DLITE train loss 0.8469, DLITE val loss 0.8510
# CE train loss 14.7422, CE val loss 14.8164
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6938, LIT val loss 1.7021
# DELTA train loss 1.6938, DELTA val loss 1.7021
#
# step 3700: KL train loss 14.8488, KL val loss 14.8789
# DLITE train loss 0.8489, DLITE val loss 0.8504
# CE train loss 14.8488, CE val loss 14.8789
# DLITE Cube Root train loss 0.2830, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6978, LIT val loss 1.7009
# DELTA train loss 1.6978, DELTA val loss 1.7009
#
# step 3800: KL train loss 14.9091, KL val loss 14.9908
# DLITE train loss 0.8479, DLITE val loss 0.8526
# CE train loss 14.9091, CE val loss 14.9908
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2842
# LIT train loss 1.6958, LIT val loss 1.7052
# DELTA train loss 1.6958, DELTA val loss 1.7052
#
# step 3900: KL train loss 14.9598, KL val loss 15.0697
# DLITE train loss 0.8467, DLITE val loss 0.8527
# CE train loss 14.9598, CE val loss 15.0697
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2842
# LIT train loss 1.6934, LIT val loss 1.7055
# DELTA train loss 1.6934, DELTA val loss 1.7055
#
# step 4000: KL train loss 15.0579, KL val loss 15.1209
# DLITE train loss 0.8481, DLITE val loss 0.8514
# CE train loss 15.0579, CE val loss 15.1209
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6962, LIT val loss 1.7029
# DELTA train loss 1.6962, DELTA val loss 1.7029
#
# step 4100: KL train loss 15.1104, KL val loss 15.1849
# DLITE train loss 0.8467, DLITE val loss 0.8508
# CE train loss 15.1104, CE val loss 15.1849
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6935, LIT val loss 1.7017
# DELTA train loss 1.6935, DELTA val loss 1.7017
#
# step 4200: KL train loss 15.1802, KL val loss 15.2600
# DLITE train loss 0.8466, DLITE val loss 0.8510
# CE train loss 15.1802, CE val loss 15.2600
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6933, LIT val loss 1.7021
# DELTA train loss 1.6933, DELTA val loss 1.7021
#
# step 4300: KL train loss 15.2589, KL val loss 15.3434
# DLITE train loss 0.8468, DLITE val loss 0.8515
# CE train loss 15.2589, CE val loss 15.3434
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6937, LIT val loss 1.7030
# DELTA train loss 1.6937, DELTA val loss 1.7030
#
# step 4400: KL train loss 15.3350, KL val loss 15.4275
# DLITE train loss 0.8470, DLITE val loss 0.8521
# CE train loss 15.3350, CE val loss 15.4275
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2840
# LIT train loss 1.6940, LIT val loss 1.7043
# DELTA train loss 1.6940, DELTA val loss 1.7043
#
# step 4500: KL train loss 15.4173, KL val loss 15.4552
# DLITE train loss 0.8476, DLITE val loss 0.8495
# CE train loss 15.4173, CE val loss 15.4552
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2832
# LIT train loss 1.6953, LIT val loss 1.6991
# DELTA train loss 1.6953, DELTA val loss 1.6991
#
# step 4600: KL train loss 15.4861, KL val loss 15.5259
# DLITE train loss 0.8475, DLITE val loss 0.8495
# CE train loss 15.4861, CE val loss 15.5259
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2832
# LIT train loss 1.6949, LIT val loss 1.6990
# DELTA train loss 1.6949, DELTA val loss 1.6990
#
# step 4700: KL train loss 15.5700, KL val loss 15.6280
# DLITE train loss 0.8481, DLITE val loss 0.8511
# CE train loss 15.5700, CE val loss 15.6280
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6962, LIT val loss 1.7022
# DELTA train loss 1.6962, DELTA val loss 1.7022
#
# step 4800: KL train loss 15.6215, KL val loss 15.6898
# DLITE train loss 0.8468, DLITE val loss 0.8506
# CE train loss 15.6215, CE val loss 15.6898
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6935, LIT val loss 1.7013
# DELTA train loss 1.6935, DELTA val loss 1.7013
#
# step 4900: KL train loss 15.7109, KL val loss 15.8127
# DLITE train loss 0.8478, DLITE val loss 0.8534
# CE train loss 15.7109, CE val loss 15.8127
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2845
# LIT train loss 1.6956, LIT val loss 1.7068
# DELTA train loss 1.6956, DELTA val loss 1.7068
#
# step 5000: KL train loss 15.7723, KL val loss 15.8416
# DLITE train loss 0.8472, DLITE val loss 0.8509
# CE train loss 15.7723, CE val loss 15.8416
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6945, LIT val loss 1.7018
# DELTA train loss 1.6945, DELTA val loss 1.7018
#
# step 5100: KL train loss 15.8426, KL val loss 15.9326
# DLITE train loss 0.8472, DLITE val loss 0.8519
# CE train loss 15.8426, CE val loss 15.9326
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2840
# LIT train loss 1.6945, LIT val loss 1.7039
# DELTA train loss 1.6945, DELTA val loss 1.7039
#
# step 5200: KL train loss 15.9049, KL val loss 15.9700
# DLITE train loss 0.8466, DLITE val loss 0.8501
# CE train loss 15.9049, CE val loss 15.9700
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6932, LIT val loss 1.7002
# DELTA train loss 1.6932, DELTA val loss 1.7002
#
# step 5300: KL train loss 16.0067, KL val loss 16.0555
# DLITE train loss 0.8484, DLITE val loss 0.8508
# CE train loss 16.0067, CE val loss 16.0555
# DLITE Cube Root train loss 0.2828, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6967, LIT val loss 1.7017
# DELTA train loss 1.6967, DELTA val loss 1.7017
#
# step 5400: KL train loss 16.0511, KL val loss 16.1195
# DLITE train loss 0.8469, DLITE val loss 0.8504
# CE train loss 16.0511, CE val loss 16.1195
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6937, LIT val loss 1.7008
# DELTA train loss 1.6937, DELTA val loss 1.7008
#
# step 5500: KL train loss 16.1381, KL val loss 16.2033
# DLITE train loss 0.8478, DLITE val loss 0.8511
# CE train loss 16.1381, CE val loss 16.2033
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6956, LIT val loss 1.7022
# DELTA train loss 1.6956, DELTA val loss 1.7022
#
# step 5600: KL train loss 16.2000, KL val loss 16.2730
# DLITE train loss 0.8471, DLITE val loss 0.8509
# CE train loss 16.2000, CE val loss 16.2730
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6941, LIT val loss 1.7018
# DELTA train loss 1.6941, DELTA val loss 1.7018
#
# step 5700: KL train loss 16.2546, KL val loss 16.3382
# DLITE train loss 0.8464, DLITE val loss 0.8506
# CE train loss 16.2546, CE val loss 16.3382
# DLITE Cube Root train loss 0.2821, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6929, LIT val loss 1.7011
# DELTA train loss 1.6929, DELTA val loss 1.7011
#
# step 5800: KL train loss 16.3468, KL val loss 16.4267
# DLITE train loss 0.8475, DLITE val loss 0.8515
# CE train loss 16.3468, CE val loss 16.4267
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6950, LIT val loss 1.7030
# DELTA train loss 1.6950, DELTA val loss 1.7030
#
# step 5900: KL train loss 16.4217, KL val loss 16.4961
# DLITE train loss 0.8476, DLITE val loss 0.8515
# CE train loss 16.4217, CE val loss 16.4961
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6953, LIT val loss 1.7029
# DELTA train loss 1.6953, DELTA val loss 1.7029
#
# step 6000: KL train loss 16.4956, KL val loss 16.5277
# DLITE train loss 0.8478, DLITE val loss 0.8495
# CE train loss 16.4956, CE val loss 16.5277
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2832
# LIT train loss 1.6956, LIT val loss 1.6990
# DELTA train loss 1.6956, DELTA val loss 1.6990
#
# step 6100: KL train loss 16.5689, KL val loss 16.6187
# DLITE train loss 0.8481, DLITE val loss 0.8505
# CE train loss 16.5689, CE val loss 16.6187
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6962, LIT val loss 1.7010
# DELTA train loss 1.6962, DELTA val loss 1.7010
#
# step 6200: KL train loss 16.6173, KL val loss 16.7163
# DLITE train loss 0.8469, DLITE val loss 0.8518
# CE train loss 16.6173, CE val loss 16.7163
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6938, LIT val loss 1.7037
# DELTA train loss 1.6938, DELTA val loss 1.7037
#
# step 6300: KL train loss 16.7122, KL val loss 16.7977
# DLITE train loss 0.8481, DLITE val loss 0.8524
# CE train loss 16.7122, CE val loss 16.7977
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2841
# LIT train loss 1.6963, LIT val loss 1.7047
# DELTA train loss 1.6963, DELTA val loss 1.7047
#
# step 6400: KL train loss 16.7773, KL val loss 16.8373
# DLITE train loss 0.8479, DLITE val loss 0.8510
# CE train loss 16.7773, CE val loss 16.8373
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6959, LIT val loss 1.7019
# DELTA train loss 1.6959, DELTA val loss 1.7019
#
# step 6500: KL train loss 16.8408, KL val loss 16.8778
# DLITE train loss 0.8476, DLITE val loss 0.8494
# CE train loss 16.8408, CE val loss 16.8778
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2831
# LIT train loss 1.6952, LIT val loss 1.6988
# DELTA train loss 1.6952, DELTA val loss 1.6988
#
# step 6600: KL train loss 16.9252, KL val loss 16.9997
# DLITE train loss 0.8484, DLITE val loss 0.8520
# CE train loss 16.9252, CE val loss 16.9997
# DLITE Cube Root train loss 0.2828, DLITE Cube Root val loss 0.2840
# LIT train loss 1.6968, LIT val loss 1.7039
# DELTA train loss 1.6968, DELTA val loss 1.7039
#
# step 6700: KL train loss 16.9633, KL val loss 17.0730
# DLITE train loss 0.8469, DLITE val loss 0.8522
# CE train loss 16.9633, CE val loss 17.0730
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2841
# LIT train loss 1.6939, LIT val loss 1.7045
# DELTA train loss 1.6939, DELTA val loss 1.7045
#
# step 6800: KL train loss 17.0342, KL val loss 17.1159
# DLITE train loss 0.8469, DLITE val loss 0.8508
# CE train loss 17.0342, CE val loss 17.1159
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6938, LIT val loss 1.7016
# DELTA train loss 1.6938, DELTA val loss 1.7016
#
# step 6900: KL train loss 17.1100, KL val loss 17.1817
# DLITE train loss 0.8473, DLITE val loss 0.8508
# CE train loss 17.1100, CE val loss 17.1817
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6946, LIT val loss 1.7015
# DELTA train loss 1.6946, DELTA val loss 1.7015
#
# step 7000: KL train loss 17.1566, KL val loss 17.2502
# DLITE train loss 0.8462, DLITE val loss 0.8505
# CE train loss 17.1566, CE val loss 17.2502
# DLITE Cube Root train loss 0.2821, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6925, LIT val loss 1.7011
# DELTA train loss 1.6925, DELTA val loss 1.7011
#
# step 7100: KL train loss 17.2555, KL val loss 17.3126
# DLITE train loss 0.8479, DLITE val loss 0.8504
# CE train loss 17.2555, CE val loss 17.3126
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6958, LIT val loss 1.7009
# DELTA train loss 1.6958, DELTA val loss 1.7009
#
# step 7200: KL train loss 17.2991, KL val loss 17.4017
# DLITE train loss 0.8465, DLITE val loss 0.8515
# CE train loss 17.2991, CE val loss 17.4017
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6929, LIT val loss 1.7030
# DELTA train loss 1.6929, DELTA val loss 1.7030
#
# step 7300: KL train loss 17.3616, KL val loss 17.4739
# DLITE train loss 0.8464, DLITE val loss 0.8516
# CE train loss 17.3616, CE val loss 17.4739
# DLITE Cube Root train loss 0.2821, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6927, LIT val loss 1.7032
# DELTA train loss 1.6927, DELTA val loss 1.7032
#
# step 7400: KL train loss 17.4503, KL val loss 17.5511
# DLITE train loss 0.8473, DLITE val loss 0.8521
# CE train loss 17.4503, CE val loss 17.5511
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2840
# LIT train loss 1.6946, LIT val loss 1.7042
# DELTA train loss 1.6946, DELTA val loss 1.7042
#
# step 7500: KL train loss 17.5134, KL val loss 17.5839
# DLITE train loss 0.8471, DLITE val loss 0.8505
# CE train loss 17.5134, CE val loss 17.5839
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6943, LIT val loss 1.7009
# DELTA train loss 1.6943, DELTA val loss 1.7009
#
# step 7600: KL train loss 17.5896, KL val loss 17.6795
# DLITE train loss 0.8476, DLITE val loss 0.8518
# CE train loss 17.5896, CE val loss 17.6795
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6951, LIT val loss 1.7035
# DELTA train loss 1.6951, DELTA val loss 1.7035
#
# step 7700: KL train loss 17.6650, KL val loss 17.7239
# DLITE train loss 0.8480, DLITE val loss 0.8508
# CE train loss 17.6650, CE val loss 17.7239
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6960, LIT val loss 1.7015
# DELTA train loss 1.6960, DELTA val loss 1.7015
#
# step 7800: KL train loss 17.7016, KL val loss 17.7811
# DLITE train loss 0.8468, DLITE val loss 0.8503
# CE train loss 17.7016, CE val loss 17.7811
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2834
# LIT train loss 1.6935, LIT val loss 1.7006
# DELTA train loss 1.6935, DELTA val loss 1.7006
#
# step 7900: KL train loss 17.7422, KL val loss 17.8746
# DLITE train loss 0.8455, DLITE val loss 0.8517
# CE train loss 17.7422, CE val loss 17.8746
# DLITE Cube Root train loss 0.2818, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6910, LIT val loss 1.7033
# DELTA train loss 1.6910, DELTA val loss 1.7033
#
# step 8000: KL train loss 17.8174, KL val loss 17.9165
# DLITE train loss 0.8459, DLITE val loss 0.8504
# CE train loss 17.8174, CE val loss 17.9165
# DLITE Cube Root train loss 0.2820, DLITE Cube Root val loss 0.2835
# LIT train loss 1.6917, LIT val loss 1.7009
# DELTA train loss 1.6917, DELTA val loss 1.7009
#
# step 8100: KL train loss 17.9110, KL val loss 17.9867
# DLITE train loss 0.8472, DLITE val loss 0.8507
# CE train loss 17.9110, CE val loss 17.9867
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6944, LIT val loss 1.7015
# DELTA train loss 1.6944, DELTA val loss 1.7015
#
# step 8200: KL train loss 17.9824, KL val loss 18.0664
# DLITE train loss 0.8475, DLITE val loss 0.8514
# CE train loss 17.9824, CE val loss 18.0664
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6949, LIT val loss 1.7029
# DELTA train loss 1.6949, DELTA val loss 1.7029
#
# step 8300: KL train loss 18.0254, KL val loss 18.1239
# DLITE train loss 0.8465, DLITE val loss 0.8509
# CE train loss 18.0254, CE val loss 18.1239
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6930, LIT val loss 1.7019
# DELTA train loss 1.6930, DELTA val loss 1.7019
#
# step 8400: KL train loss 18.0779, KL val loss 18.1901
# DLITE train loss 0.8460, DLITE val loss 0.8511
# CE train loss 18.0779, CE val loss 18.1901
# DLITE Cube Root train loss 0.2820, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6920, LIT val loss 1.7021
# DELTA train loss 1.6920, DELTA val loss 1.7021
#
# step 8500: KL train loss 18.1620, KL val loss 18.2518
# DLITE train loss 0.8469, DLITE val loss 0.8510
# CE train loss 18.1620, CE val loss 18.2518
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6938, LIT val loss 1.7020
# DELTA train loss 1.6938, DELTA val loss 1.7020
#
# step 8600: KL train loss 18.2126, KL val loss 18.3327
# DLITE train loss 0.8463, DLITE val loss 0.8517
# CE train loss 18.2126, CE val loss 18.3327
# DLITE Cube Root train loss 0.2821, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6926, LIT val loss 1.7034
# DELTA train loss 1.6926, DELTA val loss 1.7034
#
# step 8700: KL train loss 18.3067, KL val loss 18.3867
# DLITE train loss 0.8477, DLITE val loss 0.8512
# CE train loss 18.3067, CE val loss 18.3867
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6953, LIT val loss 1.7024
# DELTA train loss 1.6953, DELTA val loss 1.7024
#
# step 8800: KL train loss 18.3691, KL val loss 18.4386
# DLITE train loss 0.8476, DLITE val loss 0.8508
# CE train loss 18.3691, CE val loss 18.4386
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6952, LIT val loss 1.7015
# DELTA train loss 1.6952, DELTA val loss 1.7015
#
# step 8900: KL train loss 18.4090, KL val loss 18.4865
# DLITE train loss 0.8466, DLITE val loss 0.8500
# CE train loss 18.4090, CE val loss 18.4865
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6933, LIT val loss 1.6999
# DELTA train loss 1.6933, DELTA val loss 1.6999
#
# step 9000: KL train loss 18.4736, KL val loss 18.5666
# DLITE train loss 0.8467, DLITE val loss 0.8508
# CE train loss 18.4736, CE val loss 18.5666
# DLITE Cube Root train loss 0.2822, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6934, LIT val loss 1.7015
# DELTA train loss 1.6934, DELTA val loss 1.7015
#
# step 9100: KL train loss 18.5447, KL val loss 18.6580
# DLITE train loss 0.8471, DLITE val loss 0.8523
# CE train loss 18.5447, CE val loss 18.6580
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2841
# LIT train loss 1.6942, LIT val loss 1.7046
# DELTA train loss 1.6942, DELTA val loss 1.7046
#
# step 9200: KL train loss 18.6264, KL val loss 18.6723
# DLITE train loss 0.8480, DLITE val loss 0.8500
# CE train loss 18.6264, CE val loss 18.6723
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2833
# LIT train loss 1.6960, LIT val loss 1.6999
# DELTA train loss 1.6960, DELTA val loss 1.6999
#
# step 9300: KL train loss 18.6779, KL val loss 18.7717
# DLITE train loss 0.8475, DLITE val loss 0.8517
# CE train loss 18.6779, CE val loss 18.7717
# DLITE Cube Root train loss 0.2825, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6951, LIT val loss 1.7035
# DELTA train loss 1.6951, DELTA val loss 1.7035
#
# step 9400: KL train loss 18.7334, KL val loss 18.8210
# DLITE train loss 0.8472, DLITE val loss 0.8510
# CE train loss 18.7334, CE val loss 18.8210
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6944, LIT val loss 1.7020
# DELTA train loss 1.6944, DELTA val loss 1.7020
#
# step 9500: KL train loss 18.7881, KL val loss 18.8926
# DLITE train loss 0.8469, DLITE val loss 0.8515
# CE train loss 18.7881, CE val loss 18.8926
# DLITE Cube Root train loss 0.2823, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6938, LIT val loss 1.7030
# DELTA train loss 1.6938, DELTA val loss 1.7030
#
# step 9600: KL train loss 18.8645, KL val loss 18.9544
# DLITE train loss 0.8477, DLITE val loss 0.8515
# CE train loss 18.8645, CE val loss 18.9544
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2838
# LIT train loss 1.6953, LIT val loss 1.7030
# DELTA train loss 1.6953, DELTA val loss 1.7030
#
# step 9700: KL train loss 18.9167, KL val loss 18.9973
# DLITE train loss 0.8473, DLITE val loss 0.8508
# CE train loss 18.9167, CE val loss 18.9973
# DLITE Cube Root train loss 0.2824, DLITE Cube Root val loss 0.2836
# LIT train loss 1.6945, LIT val loss 1.7015
# DELTA train loss 1.6945, DELTA val loss 1.7015
#
# step 9800: KL train loss 18.9894, KL val loss 19.0636
# DLITE train loss 0.8478, DLITE val loss 0.8511
# CE train loss 18.9894, CE val loss 19.0636
# DLITE Cube Root train loss 0.2826, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6955, LIT val loss 1.7022
# DELTA train loss 1.6955, DELTA val loss 1.7022
#
# step 9900: KL train loss 19.0543, KL val loss 19.1406
# DLITE train loss 0.8481, DLITE val loss 0.8518
# CE train loss 19.0543, CE val loss 19.1406
# DLITE Cube Root train loss 0.2827, DLITE Cube Root val loss 0.2839
# LIT train loss 1.6962, LIT val loss 1.7036
# DELTA train loss 1.6962, DELTA val loss 1.7036
#
# step 9999: KL train loss 19.1339, KL val loss 19.1851
# DLITE train loss 0.8490, DLITE val loss 0.8511
# CE train loss 19.1339, CE val loss 19.1851
# DLITE Cube Root train loss 0.2830, DLITE Cube Root val loss 0.2837
# LIT train loss 1.6980, LIT val loss 1.7022
# DELTA train loss 1.6980, DELTA val loss 1.7022

# %% [markdown]
# ## Train with DELTA loss

# %%
torch.manual_seed(1337)

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')


# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
dlite_loss = DLITELoss()
ce_loss = nn.CrossEntropyLoss()
kl_loss = KLDivergenceLoss()
dlite_cuberoot_loss = DLITECubeRootLoss()
lit_loss = LITLoss()
delta_loss = DELTALoss()

# Lists to store the loss values
dlite_train_losses = []
dlite_val_losses = []
ce_train_losses = []
ce_val_losses = []
kl_train_losses = []
kl_val_losses = []
dlite_cuberoot_train_losses = []
dlite_cuberoot_val_losses = []
lit_train_losses = []
lit_val_losses = []
delta_train_losses = []
delta_val_losses = []




for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        dlite_losses, ce_losses, kl_losses, dlite_cuberoot_losses, lit_losses , delta_losses = estimate_loss()
        print(f"step {iter}: KL train loss {kl_losses['train']:.4f}, KL val loss {kl_losses['val']:.4f}")
        print(f"DLITE train loss {dlite_losses['train']:.4f}, DLITE val loss {dlite_losses['val']:.4f}")
        print(f"CE train loss {ce_losses['train']:.4f}, CE val loss {ce_losses['val']:.4f}")
        print(f"DLITE Cube Root train loss {dlite_cuberoot_losses['train']:.4f}, DLITE Cube Root val loss {dlite_cuberoot_losses['val']:.4f}")
        print(f"LIT train loss {lit_losses['train']:.4f}, LIT val loss {lit_losses['val']:.4f}")
        print(f"DELTA train loss {delta_losses['train']:.4f}, DELTA val loss {delta_losses['val']:.4f}\n")


        # Append the losses for this iteration
        dlite_train_losses.append(dlite_losses['train'])
        dlite_val_losses.append(dlite_losses['val'])
        ce_train_losses.append(ce_losses['train'])
        ce_val_losses.append(ce_losses['val'])
        kl_train_losses.append(kl_losses['train'])
        kl_val_losses.append(kl_losses['val'])
        dlite_cuberoot_train_losses.append(dlite_cuberoot_losses['train'])
        dlite_cuberoot_val_losses.append(dlite_cuberoot_losses['val'])
        lit_train_losses.append(lit_losses['train'])
        lit_val_losses.append(lit_losses['val'])
        delta_train_losses.append(delta_losses['train'])
        delta_val_losses.append(delta_losses['val'])


    # Sample a batch of data
    xb, yb = get_batch('train')

    # Evaluate the logits
    logits, _ = model(xb, yb)

    # Flatten the logits and target tensor
    logits_flat = logits.view(-1, logits.shape[-1])
    targets_flat = yb.view(-1)


    # Compute the DELTA loss using the flattened logits and targets
    loss = delta_loss(logits_flat, targets_flat)

    # Backpropagation and optimization step
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()


import matplotlib.pyplot as plt

def plot_losses(train_losses, val_losses, title):
    # Convert the lists to arrays for mathematical operations.
    train_losses = np.array(train_losses)
    val_losses = np.array(val_losses)

    # Create a new figure
    plt.figure()

    # Plot training and validation losses.
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')

    # Add titles, labels, and legend.
    plt.title(title)
    plt.xlabel('Evaluation Interval')
    plt.ylabel('Loss')
    plt.legend()

    # Show plot
    plt.show()

# Plotting DLITE Loss
plot_losses(dlite_train_losses, dlite_val_losses, 'DLITE Loss Over Time')

# Plotting Cross-Entropy Loss
plot_losses(ce_train_losses, ce_val_losses, 'Cross-Entropy Loss Over Time')

# Plotting KL Divergence Loss
plot_losses(kl_train_losses, kl_val_losses, 'KL Divergence Loss Over Time')

# Plotting DLITE Cube Root Loss
plot_losses(dlite_cuberoot_train_losses, dlite_cuberoot_val_losses, 'DLITE Cube Root Loss Over Time')

# Plotting LIT Loss
plot_losses(lit_train_losses, lit_val_losses, 'LIT Loss Over Time')

# Plotting DELTA Loss
plot_losses(delta_train_losses, delta_val_losses, 'DELTA Loss Over Time')
# Out:
# 0.209729 M parameters
# step 0: KL train loss 4.4116, KL val loss 4.4022
# DLITE train loss 0.9281, DLITE val loss 0.9275
# CE train loss 4.4116, CE val loss 4.4022
# DLITE Cube Root train loss 0.3094, DLITE Cube Root val loss 0.3092
# LIT train loss 5.8604, LIT val loss 5.8589
# DELTA train loss 5.8604, DELTA val loss 5.8589
#
# step 100: KL train loss 10.0727, KL val loss 10.1146
# DLITE train loss 0.9848, DLITE val loss 0.9864
# CE train loss 10.0727, CE val loss 10.1146
# DLITE Cube Root train loss 0.3283, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9912, LIT val loss 1.9943
# DELTA train loss 1.9912, DELTA val loss 1.9943
#
# step 200: KL train loss 11.1171, KL val loss 11.1683
# DLITE train loss 0.9851, DLITE val loss 0.9871
# CE train loss 11.1171, CE val loss 11.1683
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9783, LIT val loss 1.9823
# DELTA train loss 1.9783, DELTA val loss 1.9823
#
# step 300: KL train loss 11.7937, KL val loss 11.8294
# DLITE train loss 0.9858, DLITE val loss 0.9868
# CE train loss 11.7937, CE val loss 11.8294
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9760, LIT val loss 1.9779
# DELTA train loss 1.9760, DELTA val loss 1.9779
#
# step 400: KL train loss 12.2821, KL val loss 12.3242
# DLITE train loss 0.9857, DLITE val loss 0.9869
# CE train loss 12.2821, CE val loss 12.3242
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9741, LIT val loss 1.9766
# DELTA train loss 1.9741, DELTA val loss 1.9766
#
# step 500: KL train loss 12.6896, KL val loss 12.7292
# DLITE train loss 0.9862, DLITE val loss 0.9874
# CE train loss 12.6896, CE val loss 12.7292
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9743, LIT val loss 1.9767
# DELTA train loss 1.9743, DELTA val loss 1.9767
#
# step 600: KL train loss 13.0055, KL val loss 13.0541
# DLITE train loss 0.9854, DLITE val loss 0.9872
# CE train loss 13.0055, CE val loss 13.0541
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9721, LIT val loss 1.9757
# DELTA train loss 1.9721, DELTA val loss 1.9757
#
# step 700: KL train loss 13.2957, KL val loss 13.3461
# DLITE train loss 0.9854, DLITE val loss 0.9873
# CE train loss 13.2957, CE val loss 13.3461
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9718, LIT val loss 1.9757
# DELTA train loss 1.9718, DELTA val loss 1.9757
#
# step 800: KL train loss 13.5474, KL val loss 13.5918
# DLITE train loss 0.9858, DLITE val loss 0.9866
# CE train loss 13.5474, CE val loss 13.5918
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9725, LIT val loss 1.9741
# DELTA train loss 1.9725, DELTA val loss 1.9741
#
# step 900: KL train loss 13.7871, KL val loss 13.8171
# DLITE train loss 0.9854, DLITE val loss 0.9864
# CE train loss 13.7871, CE val loss 13.8171
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9715, LIT val loss 1.9734
# DELTA train loss 1.9715, DELTA val loss 1.9734
#
# step 1000: KL train loss 13.9868, KL val loss 14.0392
# DLITE train loss 0.9855, DLITE val loss 0.9874
# CE train loss 13.9868, CE val loss 14.0392
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9715, LIT val loss 1.9754
# DELTA train loss 1.9715, DELTA val loss 1.9754
#
# step 1100: KL train loss 14.1794, KL val loss 14.2318
# DLITE train loss 0.9853, DLITE val loss 0.9872
# CE train loss 14.1794, CE val loss 14.2318
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9711, LIT val loss 1.9749
# DELTA train loss 1.9711, DELTA val loss 1.9749
#
# step 1200: KL train loss 14.3662, KL val loss 14.4037
# DLITE train loss 0.9854, DLITE val loss 0.9866
# CE train loss 14.3662, CE val loss 14.4037
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9712, LIT val loss 1.9736
# DELTA train loss 1.9712, DELTA val loss 1.9736
#
# step 1300: KL train loss 14.5507, KL val loss 14.5837
# DLITE train loss 0.9866, DLITE val loss 0.9870
# CE train loss 14.5507, CE val loss 14.5837
# DLITE Cube Root train loss 0.3289, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9735, LIT val loss 1.9744
# DELTA train loss 1.9735, DELTA val loss 1.9744
#
# step 1400: KL train loss 14.6962, KL val loss 14.7454
# DLITE train loss 0.9858, DLITE val loss 0.9873
# CE train loss 14.6962, CE val loss 14.7454
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9719, LIT val loss 1.9750
# DELTA train loss 1.9719, DELTA val loss 1.9750
#
# step 1500: KL train loss 14.8635, KL val loss 14.8904
# DLITE train loss 0.9862, DLITE val loss 0.9865
# CE train loss 14.8635, CE val loss 14.8904
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9727, LIT val loss 1.9733
# DELTA train loss 1.9727, DELTA val loss 1.9733
#
# step 1600: KL train loss 14.9953, KL val loss 15.0408
# DLITE train loss 0.9854, DLITE val loss 0.9868
# CE train loss 14.9953, CE val loss 15.0408
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9711, LIT val loss 1.9739
# DELTA train loss 1.9711, DELTA val loss 1.9739
#
# step 1700: KL train loss 15.1498, KL val loss 15.1835
# DLITE train loss 0.9860, DLITE val loss 0.9868
# CE train loss 15.1498, CE val loss 15.1835
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9721, LIT val loss 1.9739
# DELTA train loss 1.9721, DELTA val loss 1.9739
#
# step 1800: KL train loss 15.2837, KL val loss 15.3205
# DLITE train loss 0.9857, DLITE val loss 0.9867
# CE train loss 15.2837, CE val loss 15.3205
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9715, LIT val loss 1.9736
# DELTA train loss 1.9715, DELTA val loss 1.9736
#
# step 1900: KL train loss 15.4250, KL val loss 15.4478
# DLITE train loss 0.9862, DLITE val loss 0.9865
# CE train loss 15.4250, CE val loss 15.4478
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9726, LIT val loss 1.9732
# DELTA train loss 1.9726, DELTA val loss 1.9732
#
# step 2000: KL train loss 15.5530, KL val loss 15.5884
# DLITE train loss 0.9859, DLITE val loss 0.9868
# CE train loss 15.5530, CE val loss 15.5884
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9720, LIT val loss 1.9737
# DELTA train loss 1.9720, DELTA val loss 1.9737
#
# step 2100: KL train loss 15.6753, KL val loss 15.7171
# DLITE train loss 0.9858, DLITE val loss 0.9871
# CE train loss 15.6753, CE val loss 15.7171
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9717, LIT val loss 1.9742
# DELTA train loss 1.9717, DELTA val loss 1.9742
#
# step 2200: KL train loss 15.7989, KL val loss 15.8410
# DLITE train loss 0.9856, DLITE val loss 0.9869
# CE train loss 15.7989, CE val loss 15.8410
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9714, LIT val loss 1.9740
# DELTA train loss 1.9714, DELTA val loss 1.9740
#
# step 2300: KL train loss 15.9195, KL val loss 15.9612
# DLITE train loss 0.9855, DLITE val loss 0.9867
# CE train loss 15.9195, CE val loss 15.9612
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9711, LIT val loss 1.9735
# DELTA train loss 1.9711, DELTA val loss 1.9735
#
# step 2400: KL train loss 16.0346, KL val loss 16.0855
# DLITE train loss 0.9852, DLITE val loss 0.9870
# CE train loss 16.0345, CE val loss 16.0855
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9705, LIT val loss 1.9740
# DELTA train loss 1.9705, DELTA val loss 1.9740
#
# step 2500: KL train loss 16.1676, KL val loss 16.2132
# DLITE train loss 0.9858, DLITE val loss 0.9874
# CE train loss 16.1676, CE val loss 16.2132
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9717, LIT val loss 1.9749
# DELTA train loss 1.9717, DELTA val loss 1.9749
#
# step 2600: KL train loss 16.2782, KL val loss 16.3253
# DLITE train loss 0.9856, DLITE val loss 0.9872
# CE train loss 16.2782, CE val loss 16.3253
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9713, LIT val loss 1.9745
# DELTA train loss 1.9713, DELTA val loss 1.9745
#
# step 2700: KL train loss 16.3968, KL val loss 16.4254
# DLITE train loss 0.9858, DLITE val loss 0.9864
# CE train loss 16.3968, CE val loss 16.4254
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9716, LIT val loss 1.9728
# DELTA train loss 1.9716, DELTA val loss 1.9728
#
# step 2800: KL train loss 16.5104, KL val loss 16.5421
# DLITE train loss 0.9859, DLITE val loss 0.9865
# CE train loss 16.5104, CE val loss 16.5421
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9718, LIT val loss 1.9730
# DELTA train loss 1.9718, DELTA val loss 1.9730
#
# step 2900: KL train loss 16.6291, KL val loss 16.6652
# DLITE train loss 0.9862, DLITE val loss 0.9869
# CE train loss 16.6291, CE val loss 16.6652
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9725, LIT val loss 1.9739
# DELTA train loss 1.9725, DELTA val loss 1.9739
#
# step 3000: KL train loss 16.7386, KL val loss 16.7618
# DLITE train loss 0.9861, DLITE val loss 0.9865
# CE train loss 16.7386, CE val loss 16.7618
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9722, LIT val loss 1.9730
# DELTA train loss 1.9722, DELTA val loss 1.9730
#
# step 3100: KL train loss 16.8470, KL val loss 16.8818
# DLITE train loss 0.9859, DLITE val loss 0.9869
# CE train loss 16.8470, CE val loss 16.8818
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9719, LIT val loss 1.9737
# DELTA train loss 1.9719, DELTA val loss 1.9737
#
# step 3200: KL train loss 16.9581, KL val loss 17.0000
# DLITE train loss 0.9862, DLITE val loss 0.9872
# CE train loss 16.9581, CE val loss 17.0000
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9723, LIT val loss 1.9745
# DELTA train loss 1.9723, DELTA val loss 1.9745
#
# step 3300: KL train loss 17.0594, KL val loss 17.0964
# DLITE train loss 0.9858, DLITE val loss 0.9867
# CE train loss 17.0594, CE val loss 17.0964
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9716, LIT val loss 1.9734
# DELTA train loss 1.9716, DELTA val loss 1.9734
#
# step 3400: KL train loss 17.1637, KL val loss 17.2144
# DLITE train loss 0.9859, DLITE val loss 0.9873
# CE train loss 17.1637, CE val loss 17.2144
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9717, LIT val loss 1.9746
# DELTA train loss 1.9717, DELTA val loss 1.9746
#
# step 3500: KL train loss 17.2708, KL val loss 17.3104
# DLITE train loss 0.9857, DLITE val loss 0.9868
# CE train loss 17.2708, CE val loss 17.3104
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9714, LIT val loss 1.9737
# DELTA train loss 1.9714, DELTA val loss 1.9737
#
# step 3600: KL train loss 17.3759, KL val loss 17.4135
# DLITE train loss 0.9859, DLITE val loss 0.9866
# CE train loss 17.3759, CE val loss 17.4136
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9718, LIT val loss 1.9733
# DELTA train loss 1.9718, DELTA val loss 1.9733
#
# step 3700: KL train loss 17.4782, KL val loss 17.5156
# DLITE train loss 0.9858, DLITE val loss 0.9868
# CE train loss 17.4782, CE val loss 17.5156
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9716, LIT val loss 1.9737
# DELTA train loss 1.9716, DELTA val loss 1.9737
#
# step 3800: KL train loss 17.5821, KL val loss 17.6230
# DLITE train loss 0.9856, DLITE val loss 0.9869
# CE train loss 17.5821, CE val loss 17.6230
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9711, LIT val loss 1.9738
# DELTA train loss 1.9711, DELTA val loss 1.9738
#
# step 3900: KL train loss 17.6732, KL val loss 17.7317
# DLITE train loss 0.9854, DLITE val loss 0.9870
# CE train loss 17.6732, CE val loss 17.7317
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9707, LIT val loss 1.9741
# DELTA train loss 1.9707, DELTA val loss 1.9741
#
# step 4000: KL train loss 17.7829, KL val loss 17.8327
# DLITE train loss 0.9859, DLITE val loss 0.9872
# CE train loss 17.7829, CE val loss 17.8327
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9719, LIT val loss 1.9745
# DELTA train loss 1.9719, DELTA val loss 1.9745
#
# step 4100: KL train loss 17.8896, KL val loss 17.9201
# DLITE train loss 0.9862, DLITE val loss 0.9867
# CE train loss 17.8896, CE val loss 17.9201
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9725, LIT val loss 1.9735
# DELTA train loss 1.9725, DELTA val loss 1.9735
#
# step 4200: KL train loss 17.9745, KL val loss 18.0225
# DLITE train loss 0.9856, DLITE val loss 0.9869
# CE train loss 17.9745, CE val loss 18.0225
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9713, LIT val loss 1.9738
# DELTA train loss 1.9713, DELTA val loss 1.9738
#
# step 4300: KL train loss 18.0811, KL val loss 18.1175
# DLITE train loss 0.9861, DLITE val loss 0.9868
# CE train loss 18.0811, CE val loss 18.1175
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9721, LIT val loss 1.9736
# DELTA train loss 1.9721, DELTA val loss 1.9736
#
# step 4400: KL train loss 18.1820, KL val loss 18.2190
# DLITE train loss 0.9864, DLITE val loss 0.9871
# CE train loss 18.1820, CE val loss 18.2190
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9728, LIT val loss 1.9742
# DELTA train loss 1.9728, DELTA val loss 1.9742
#
# step 4500: KL train loss 18.2568, KL val loss 18.3058
# DLITE train loss 0.9850, DLITE val loss 0.9868
# CE train loss 18.2568, CE val loss 18.3058
# DLITE Cube Root train loss 0.3283, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9701, LIT val loss 1.9736
# DELTA train loss 1.9701, DELTA val loss 1.9736
#
# step 4600: KL train loss 18.3613, KL val loss 18.3953
# DLITE train loss 0.9858, DLITE val loss 0.9867
# CE train loss 18.3613, CE val loss 18.3953
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9717, LIT val loss 1.9733
# DELTA train loss 1.9717, DELTA val loss 1.9733
#
# step 4700: KL train loss 18.4472, KL val loss 18.4987
# DLITE train loss 0.9852, DLITE val loss 0.9870
# CE train loss 18.4472, CE val loss 18.4987
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9704, LIT val loss 1.9740
# DELTA train loss 1.9704, DELTA val loss 1.9740
#
# step 4800: KL train loss 18.5622, KL val loss 18.5782
# DLITE train loss 0.9867, DLITE val loss 0.9866
# CE train loss 18.5622, CE val loss 18.5782
# DLITE Cube Root train loss 0.3289, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9734, LIT val loss 1.9732
# DELTA train loss 1.9734, DELTA val loss 1.9732
#
# step 4900: KL train loss 18.6369, KL val loss 18.6900
# DLITE train loss 0.9857, DLITE val loss 0.9873
# CE train loss 18.6369, CE val loss 18.6900
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9714, LIT val loss 1.9745
# DELTA train loss 1.9714, DELTA val loss 1.9745
#
# step 5000: KL train loss 18.7304, KL val loss 18.7735
# DLITE train loss 0.9856, DLITE val loss 0.9871
# CE train loss 18.7304, CE val loss 18.7735
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9712, LIT val loss 1.9742
# DELTA train loss 1.9712, DELTA val loss 1.9742
#
# step 5100: KL train loss 18.8138, KL val loss 18.8728
# DLITE train loss 0.9858, DLITE val loss 0.9875
# CE train loss 18.8138, CE val loss 18.8728
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3292
# LIT train loss 1.9715, LIT val loss 1.9750
# DELTA train loss 1.9715, DELTA val loss 1.9750
#
# step 5200: KL train loss 18.9158, KL val loss 18.9473
# DLITE train loss 0.9863, DLITE val loss 0.9870
# CE train loss 18.9158, CE val loss 18.9473
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9726, LIT val loss 1.9740
# DELTA train loss 1.9726, DELTA val loss 1.9740
#
# step 5300: KL train loss 18.9881, KL val loss 19.0320
# DLITE train loss 0.9854, DLITE val loss 0.9867
# CE train loss 18.9881, CE val loss 19.0320
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9708, LIT val loss 1.9733
# DELTA train loss 1.9708, DELTA val loss 1.9733
#
# step 5400: KL train loss 19.0774, KL val loss 19.1179
# DLITE train loss 0.9856, DLITE val loss 0.9867
# CE train loss 19.0774, CE val loss 19.1179
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9712, LIT val loss 1.9734
# DELTA train loss 1.9712, DELTA val loss 1.9734
#
# step 5500: KL train loss 19.1653, KL val loss 19.2071
# DLITE train loss 0.9858, DLITE val loss 0.9868
# CE train loss 19.1653, CE val loss 19.2071
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9715, LIT val loss 1.9735
# DELTA train loss 1.9715, DELTA val loss 1.9735
#
# step 5600: KL train loss 19.2689, KL val loss 19.2904
# DLITE train loss 0.9865, DLITE val loss 0.9867
# CE train loss 19.2689, CE val loss 19.2904
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9731, LIT val loss 1.9734
# DELTA train loss 1.9731, DELTA val loss 1.9734
#
# step 5700: KL train loss 19.3236, KL val loss 19.3784
# DLITE train loss 0.9853, DLITE val loss 0.9868
# CE train loss 19.3236, CE val loss 19.3784
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9706, LIT val loss 1.9735
# DELTA train loss 1.9706, DELTA val loss 1.9735
#
# step 5800: KL train loss 19.4194, KL val loss 19.4640
# DLITE train loss 0.9858, DLITE val loss 0.9871
# CE train loss 19.4194, CE val loss 19.4640
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9717, LIT val loss 1.9742
# DELTA train loss 1.9717, DELTA val loss 1.9742
#
# step 5900: KL train loss 19.5011, KL val loss 19.5445
# DLITE train loss 0.9855, DLITE val loss 0.9867
# CE train loss 19.5011, CE val loss 19.5445
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9711, LIT val loss 1.9735
# DELTA train loss 1.9711, DELTA val loss 1.9735
#
# step 6000: KL train loss 19.5943, KL val loss 19.6092
# DLITE train loss 0.9860, DLITE val loss 0.9860
# CE train loss 19.5943, CE val loss 19.6092
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3287
# LIT train loss 1.9721, LIT val loss 1.9720
# DELTA train loss 1.9721, DELTA val loss 1.9720
#
# step 6100: KL train loss 19.6646, KL val loss 19.7069
# DLITE train loss 0.9857, DLITE val loss 0.9868
# CE train loss 19.6646, CE val loss 19.7069
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9714, LIT val loss 1.9736
# DELTA train loss 1.9714, DELTA val loss 1.9736
#
# step 6200: KL train loss 19.7545, KL val loss 19.7938
# DLITE train loss 0.9861, DLITE val loss 0.9869
# CE train loss 19.7545, CE val loss 19.7938
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9722, LIT val loss 1.9738
# DELTA train loss 1.9722, DELTA val loss 1.9738
#
# step 6300: KL train loss 19.8430, KL val loss 19.8826
# DLITE train loss 0.9863, DLITE val loss 0.9871
# CE train loss 19.8430, CE val loss 19.8826
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9726, LIT val loss 1.9743
# DELTA train loss 1.9726, DELTA val loss 1.9743
#
# step 6400: KL train loss 19.9095, KL val loss 19.9429
# DLITE train loss 0.9857, DLITE val loss 0.9866
# CE train loss 19.9095, CE val loss 19.9429
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9714, LIT val loss 1.9731
# DELTA train loss 1.9714, DELTA val loss 1.9731
#
# step 6500: KL train loss 19.9921, KL val loss 20.0154
# DLITE train loss 0.9860, DLITE val loss 0.9865
# CE train loss 19.9921, CE val loss 20.0154
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9720, LIT val loss 1.9729
# DELTA train loss 1.9720, DELTA val loss 1.9729
#
# step 6600: KL train loss 20.0620, KL val loss 20.1149
# DLITE train loss 0.9855, DLITE val loss 0.9870
# CE train loss 20.0620, CE val loss 20.1149
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9710, LIT val loss 1.9740
# DELTA train loss 1.9710, DELTA val loss 1.9740
#
# step 6700: KL train loss 20.1240, KL val loss 20.1948
# DLITE train loss 0.9850, DLITE val loss 0.9872
# CE train loss 20.1240, CE val loss 20.1948
# DLITE Cube Root train loss 0.3283, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9700, LIT val loss 1.9745
# DELTA train loss 1.9700, DELTA val loss 1.9745
#
# step 6800: KL train loss 20.2209, KL val loss 20.2551
# DLITE train loss 0.9858, DLITE val loss 0.9864
# CE train loss 20.2209, CE val loss 20.2551
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9715, LIT val loss 1.9727
# DELTA train loss 1.9715, DELTA val loss 1.9727
#
# step 6900: KL train loss 20.2840, KL val loss 20.3300
# DLITE train loss 0.9852, DLITE val loss 0.9865
# CE train loss 20.2840, CE val loss 20.3300
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9704, LIT val loss 1.9730
# DELTA train loss 1.9704, DELTA val loss 1.9730
#
# step 7000: KL train loss 20.3725, KL val loss 20.4323
# DLITE train loss 0.9859, DLITE val loss 0.9876
# CE train loss 20.3725, CE val loss 20.4323
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3292
# LIT train loss 1.9718, LIT val loss 1.9753
# DELTA train loss 1.9718, DELTA val loss 1.9753
#
# step 7100: KL train loss 20.4392, KL val loss 20.4873
# DLITE train loss 0.9853, DLITE val loss 0.9867
# CE train loss 20.4392, CE val loss 20.4873
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9706, LIT val loss 1.9734
# DELTA train loss 1.9706, DELTA val loss 1.9734
#
# step 7200: KL train loss 20.5333, KL val loss 20.5684
# DLITE train loss 0.9864, DLITE val loss 0.9870
# CE train loss 20.5333, CE val loss 20.5684
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9728, LIT val loss 1.9739
# DELTA train loss 1.9728, DELTA val loss 1.9739
#
# step 7300: KL train loss 20.5853, KL val loss 20.6471
# DLITE train loss 0.9854, DLITE val loss 0.9871
# CE train loss 20.5853, CE val loss 20.6471
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9708, LIT val loss 1.9743
# DELTA train loss 1.9708, DELTA val loss 1.9743
#
# step 7400: KL train loss 20.6774, KL val loss 20.7178
# DLITE train loss 0.9862, DLITE val loss 0.9872
# CE train loss 20.6774, CE val loss 20.7178
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9725, LIT val loss 1.9744
# DELTA train loss 1.9725, DELTA val loss 1.9744
#
# step 7500: KL train loss 20.7349, KL val loss 20.7862
# DLITE train loss 0.9855, DLITE val loss 0.9870
# CE train loss 20.7349, CE val loss 20.7862
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9710, LIT val loss 1.9739
# DELTA train loss 1.9710, DELTA val loss 1.9739
#
# step 7600: KL train loss 20.8209, KL val loss 20.8552
# DLITE train loss 0.9862, DLITE val loss 0.9868
# CE train loss 20.8209, CE val loss 20.8552
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9723, LIT val loss 1.9735
# DELTA train loss 1.9723, DELTA val loss 1.9735
#
# step 7700: KL train loss 20.8985, KL val loss 20.9288
# DLITE train loss 0.9865, DLITE val loss 0.9870
# CE train loss 20.8985, CE val loss 20.9288
# DLITE Cube Root train loss 0.3288, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9729, LIT val loss 1.9740
# DELTA train loss 1.9729, DELTA val loss 1.9740
#
# step 7800: KL train loss 20.9408, KL val loss 20.9966
# DLITE train loss 0.9852, DLITE val loss 0.9868
# CE train loss 20.9408, CE val loss 20.9966
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9705, LIT val loss 1.9736
# DELTA train loss 1.9705, DELTA val loss 1.9736
#
# step 7900: KL train loss 21.0231, KL val loss 21.0726
# DLITE train loss 0.9858, DLITE val loss 0.9870
# CE train loss 21.0231, CE val loss 21.0726
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9715, LIT val loss 1.9739
# DELTA train loss 1.9715, DELTA val loss 1.9739
#
# step 8000: KL train loss 21.0946, KL val loss 21.1253
# DLITE train loss 0.9858, DLITE val loss 0.9865
# CE train loss 21.0946, CE val loss 21.1253
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9716, LIT val loss 1.9729
# DELTA train loss 1.9716, DELTA val loss 1.9729
#
# step 8100: KL train loss 21.1638, KL val loss 21.2009
# DLITE train loss 0.9857, DLITE val loss 0.9866
# CE train loss 21.1638, CE val loss 21.2009
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9714, LIT val loss 1.9731
# DELTA train loss 1.9714, DELTA val loss 1.9731
#
# step 8200: KL train loss 21.2485, KL val loss 21.2703
# DLITE train loss 0.9862, DLITE val loss 0.9864
# CE train loss 21.2485, CE val loss 21.2703
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9723, LIT val loss 1.9728
# DELTA train loss 1.9723, DELTA val loss 1.9728
#
# step 8300: KL train loss 21.3082, KL val loss 21.3538
# DLITE train loss 0.9857, DLITE val loss 0.9870
# CE train loss 21.3082, CE val loss 21.3538
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9714, LIT val loss 1.9739
# DELTA train loss 1.9714, DELTA val loss 1.9739
#
# step 8400: KL train loss 21.3585, KL val loss 21.4171
# DLITE train loss 0.9852, DLITE val loss 0.9867
# CE train loss 21.3585, CE val loss 21.4171
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9704, LIT val loss 1.9735
# DELTA train loss 1.9704, DELTA val loss 1.9735
#
# step 8500: KL train loss 21.4331, KL val loss 21.4951
# DLITE train loss 0.9855, DLITE val loss 0.9873
# CE train loss 21.4331, CE val loss 21.4951
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9710, LIT val loss 1.9747
# DELTA train loss 1.9710, DELTA val loss 1.9747
#
# step 8600: KL train loss 21.5110, KL val loss 21.5615
# DLITE train loss 0.9860, DLITE val loss 0.9872
# CE train loss 21.5110, CE val loss 21.5615
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9719, LIT val loss 1.9744
# DELTA train loss 1.9719, DELTA val loss 1.9744
#
# step 8700: KL train loss 21.5820, KL val loss 21.6345
# DLITE train loss 0.9860, DLITE val loss 0.9873
# CE train loss 21.5820, CE val loss 21.6345
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9719, LIT val loss 1.9747
# DELTA train loss 1.9719, DELTA val loss 1.9747
#
# step 8800: KL train loss 21.6511, KL val loss 21.6948
# DLITE train loss 0.9859, DLITE val loss 0.9869
# CE train loss 21.6511, CE val loss 21.6948
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9717, LIT val loss 1.9738
# DELTA train loss 1.9717, DELTA val loss 1.9738
#
# step 8900: KL train loss 21.7104, KL val loss 21.7549
# DLITE train loss 0.9856, DLITE val loss 0.9867
# CE train loss 21.7104, CE val loss 21.7549
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9712, LIT val loss 1.9734
# DELTA train loss 1.9712, DELTA val loss 1.9734
#
# step 9000: KL train loss 21.7831, KL val loss 21.8346
# DLITE train loss 0.9859, DLITE val loss 0.9874
# CE train loss 21.7831, CE val loss 21.8346
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9717, LIT val loss 1.9747
# DELTA train loss 1.9717, DELTA val loss 1.9747
#
# step 9100: KL train loss 21.8466, KL val loss 21.8951
# DLITE train loss 0.9856, DLITE val loss 0.9869
# CE train loss 21.8466, CE val loss 21.8951
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9712, LIT val loss 1.9738
# DELTA train loss 1.9712, DELTA val loss 1.9738
#
# step 9200: KL train loss 21.9262, KL val loss 21.9507
# DLITE train loss 0.9860, DLITE val loss 0.9865
# CE train loss 21.9262, CE val loss 21.9507
# DLITE Cube Root train loss 0.3287, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9721, LIT val loss 1.9730
# DELTA train loss 1.9721, DELTA val loss 1.9730
#
# step 9300: KL train loss 21.9868, KL val loss 22.0271
# DLITE train loss 0.9858, DLITE val loss 0.9869
# CE train loss 21.9868, CE val loss 22.0271
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9716, LIT val loss 1.9738
# DELTA train loss 1.9716, DELTA val loss 1.9738
#
# step 9400: KL train loss 22.0521, KL val loss 22.1075
# DLITE train loss 0.9857, DLITE val loss 0.9873
# CE train loss 22.0521, CE val loss 22.1075
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3291
# LIT train loss 1.9715, LIT val loss 1.9746
# DELTA train loss 1.9715, DELTA val loss 1.9746
#
# step 9500: KL train loss 22.1226, KL val loss 22.1789
# DLITE train loss 0.9857, DLITE val loss 0.9875
# CE train loss 22.1226, CE val loss 22.1789
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3292
# LIT train loss 1.9715, LIT val loss 1.9750
# DELTA train loss 1.9715, DELTA val loss 1.9750
#
# step 9600: KL train loss 22.1874, KL val loss 22.2370
# DLITE train loss 0.9856, DLITE val loss 0.9868
# CE train loss 22.1874, CE val loss 22.2370
# DLITE Cube Root train loss 0.3285, DLITE Cube Root val loss 0.3289
# LIT train loss 1.9712, LIT val loss 1.9736
# DELTA train loss 1.9712, DELTA val loss 1.9736
#
# step 9700: KL train loss 22.2543, KL val loss 22.2922
# DLITE train loss 0.9857, DLITE val loss 0.9865
# CE train loss 22.2543, CE val loss 22.2922
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3288
# LIT train loss 1.9713, LIT val loss 1.9729
# DELTA train loss 1.9713, DELTA val loss 1.9729
#
# step 9800: KL train loss 22.3217, KL val loss 22.3614
# DLITE train loss 0.9858, DLITE val loss 0.9869
# CE train loss 22.3217, CE val loss 22.3614
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9715, LIT val loss 1.9738
# DELTA train loss 1.9715, DELTA val loss 1.9738
#
# step 9900: KL train loss 22.3728, KL val loss 22.4350
# DLITE train loss 0.9852, DLITE val loss 0.9870
# CE train loss 22.3728, CE val loss 22.4350
# DLITE Cube Root train loss 0.3284, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9705, LIT val loss 1.9740
# DELTA train loss 1.9705, DELTA val loss 1.9740
#
# step 9999: KL train loss 22.4505, KL val loss 22.4991
# DLITE train loss 0.9858, DLITE val loss 0.9871
# CE train loss 22.4505, CE val loss 22.4991
# DLITE Cube Root train loss 0.3286, DLITE Cube Root val loss 0.3290
# LIT train loss 1.9715, LIT val loss 1.9741
# DELTA train loss 1.9715, DELTA val loss 1.9741
