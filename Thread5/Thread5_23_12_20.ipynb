# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# --2023-12-20 15:57:13--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.3’
#
# input.txt.3         100%[===================>]   1.06M  --.-KB/s    in 0.03s
#
# 2023-12-20 15:57:13 (34.5 MB/s) - ‘input.txt.3’ saved [1115394/1115394]

# %%
# import the package
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.2

# %%
torch.manual_seed(1337)


# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# ### Original code

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_original = []
val_losses_original = []


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_original.append(losses['train'].item())
        val_losses_original.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6807, val loss 2.6919
# step 200: train loss 2.5271, val loss 2.5234
# step 300: train loss 2.4552, val loss 2.4683
# step 400: train loss 2.3958, val loss 2.3998
# step 500: train loss 2.3442, val loss 2.3562
# step 600: train loss 2.3016, val loss 2.3027
# step 700: train loss 2.2674, val loss 2.2771
# step 800: train loss 2.2288, val loss 2.2443
# step 900: train loss 2.1966, val loss 2.2064
# step 1000: train loss 2.1722, val loss 2.1762
# step 1100: train loss 2.1449, val loss 2.1749
# step 1200: train loss 2.1249, val loss 2.1430
# step 1300: train loss 2.1135, val loss 2.1324
# step 1400: train loss 2.0824, val loss 2.1022
# step 1500: train loss 2.0606, val loss 2.0979
# step 1600: train loss 2.0388, val loss 2.0947
# step 1700: train loss 2.0402, val loss 2.0754
# step 1800: train loss 2.0115, val loss 2.0689
# step 1900: train loss 2.0007, val loss 2.0454
# step 2000: train loss 1.9811, val loss 2.0497
# step 2100: train loss 1.9696, val loss 2.0385
# step 2200: train loss 1.9557, val loss 2.0186
# step 2300: train loss 1.9507, val loss 2.0189
# step 2400: train loss 1.9443, val loss 2.0028
# step 2500: train loss 1.9272, val loss 2.0076
# step 2600: train loss 1.9336, val loss 2.0020
# step 2700: train loss 1.9175, val loss 1.9981
# step 2800: train loss 1.9048, val loss 1.9829
# step 2900: train loss 1.9015, val loss 1.9883
# step 3000: train loss 1.8949, val loss 1.9787
# step 3100: train loss 1.8733, val loss 1.9719
# step 3200: train loss 1.8576, val loss 1.9623
# step 3300: train loss 1.8614, val loss 1.9623
# step 3400: train loss 1.8579, val loss 1.9537
# step 3500: train loss 1.8461, val loss 1.9496
# step 3600: train loss 1.8348, val loss 1.9546
# step 3700: train loss 1.8407, val loss 1.9492
# step 3800: train loss 1.8273, val loss 1.9467
# step 3900: train loss 1.8230, val loss 1.9351
# step 4000: train loss 1.8172, val loss 1.9296
# step 4100: train loss 1.8140, val loss 1.9333
# step 4200: train loss 1.8058, val loss 1.9297
# step 4300: train loss 1.8112, val loss 1.9185
# step 4400: train loss 1.8060, val loss 1.9265
# step 4500: train loss 1.7947, val loss 1.9184
# step 4600: train loss 1.7895, val loss 1.9058
# step 4700: train loss 1.7880, val loss 1.9119
# step 4800: train loss 1.7765, val loss 1.9153
# step 4900: train loss 1.7756, val loss 1.9120
# step 5000: train loss 1.7698, val loss 1.8952
# step 5100: train loss 1.7684, val loss 1.8984
# step 5200: train loss 1.7618, val loss 1.8943
# step 5300: train loss 1.7713, val loss 1.8923
# step 5400: train loss 1.7576, val loss 1.8970
# step 5500: train loss 1.7492, val loss 1.8829
# step 5600: train loss 1.7608, val loss 1.8944
# step 5700: train loss 1.7517, val loss 1.8829
# step 5800: train loss 1.7451, val loss 1.8804
# step 5900: train loss 1.7535, val loss 1.8880
# step 6000: train loss 1.7451, val loss 1.8764
# step 6100: train loss 1.7458, val loss 1.8729
# step 6200: train loss 1.7476, val loss 1.8829
# step 6300: train loss 1.7378, val loss 1.8882
# step 6400: train loss 1.7307, val loss 1.8830
# step 6500: train loss 1.7277, val loss 1.8617
# step 6600: train loss 1.7279, val loss 1.8661
# step 6700: train loss 1.7225, val loss 1.8600
# step 6800: train loss 1.7327, val loss 1.8802
# step 6900: train loss 1.7237, val loss 1.8677
# step 7000: train loss 1.7164, val loss 1.8645
# step 7100: train loss 1.7223, val loss 1.8668
# step 7200: train loss 1.7083, val loss 1.8644
# step 7300: train loss 1.7146, val loss 1.8510
# step 7400: train loss 1.7208, val loss 1.8700
# step 7500: train loss 1.6964, val loss 1.8532
# step 7600: train loss 1.7052, val loss 1.8607
# step 7700: train loss 1.6993, val loss 1.8577
# step 7800: train loss 1.7094, val loss 1.8530
# step 7900: train loss 1.7090, val loss 1.8625
# step 8000: train loss 1.6970, val loss 1.8538
# step 8100: train loss 1.6978, val loss 1.8543
# step 8200: train loss 1.7033, val loss 1.8531
# step 8300: train loss 1.7014, val loss 1.8571
# step 8400: train loss 1.6937, val loss 1.8601
# step 8500: train loss 1.6954, val loss 1.8544
# step 8600: train loss 1.6948, val loss 1.8552
# step 8700: train loss 1.6884, val loss 1.8607
# step 8800: train loss 1.6782, val loss 1.8605
# step 8900: train loss 1.6907, val loss 1.8350
# step 9000: train loss 1.6836, val loss 1.8430
# step 9100: train loss 1.6763, val loss 1.8415
# step 9200: train loss 1.6947, val loss 1.8484
# step 9300: train loss 1.6702, val loss 1.8240
# step 9400: train loss 1.6735, val loss 1.8174
# step 9500: train loss 1.6810, val loss 1.8428
# step 9600: train loss 1.6797, val loss 1.8391
# step 9700: train loss 1.6745, val loss 1.8218
# step 9800: train loss 1.6659, val loss 1.8448
# step 9900: train loss 1.6707, val loss 1.8286
# step 9999: train loss 1.6704, val loss 1.8394

# %% [markdown]
# ### Train with 0.01 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.01):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_01 = []
val_losses_01 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_01.append(losses['train'].item())
        val_losses_01.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6798, val loss 2.6909
# step 200: train loss 2.5248, val loss 2.5208
# step 300: train loss 2.4550, val loss 2.4678
# step 400: train loss 2.3977, val loss 2.3995
# step 500: train loss 2.3481, val loss 2.3632
# step 600: train loss 2.3060, val loss 2.3081
# step 700: train loss 2.2712, val loss 2.2819
# step 800: train loss 2.2297, val loss 2.2454
# step 900: train loss 2.1964, val loss 2.2072
# step 1000: train loss 2.1768, val loss 2.1807
# step 1100: train loss 2.1483, val loss 2.1774
# step 1200: train loss 2.1250, val loss 2.1408
# step 1300: train loss 2.1198, val loss 2.1356
# step 1400: train loss 2.0866, val loss 2.1043
# step 1500: train loss 2.0610, val loss 2.0978
# step 1600: train loss 2.0414, val loss 2.0958
# step 1700: train loss 2.0432, val loss 2.0816
# step 1800: train loss 2.0155, val loss 2.0694
# step 1900: train loss 2.0043, val loss 2.0458
# step 2000: train loss 1.9832, val loss 2.0544
# step 2100: train loss 1.9731, val loss 2.0363
# step 2200: train loss 1.9563, val loss 2.0188
# step 2300: train loss 1.9517, val loss 2.0145
# step 2400: train loss 1.9454, val loss 1.9993
# step 2500: train loss 1.9255, val loss 2.0046
# step 2600: train loss 1.9349, val loss 1.9973
# step 2700: train loss 1.9178, val loss 1.9936
# step 2800: train loss 1.9093, val loss 1.9845
# step 2900: train loss 1.9002, val loss 1.9834
# step 3000: train loss 1.9002, val loss 1.9778
# step 3100: train loss 1.8720, val loss 1.9700
# step 3200: train loss 1.8613, val loss 1.9626
# step 3300: train loss 1.8606, val loss 1.9594
# step 3400: train loss 1.8579, val loss 1.9502
# step 3500: train loss 1.8470, val loss 1.9485
# step 3600: train loss 1.8337, val loss 1.9473
# step 3700: train loss 1.8416, val loss 1.9478
# step 3800: train loss 1.8267, val loss 1.9516
# step 3900: train loss 1.8275, val loss 1.9343
# step 4000: train loss 1.8172, val loss 1.9229
# step 4100: train loss 1.8140, val loss 1.9295
# step 4200: train loss 1.8066, val loss 1.9256
# step 4300: train loss 1.8174, val loss 1.9241
# step 4400: train loss 1.8072, val loss 1.9250
# step 4500: train loss 1.7932, val loss 1.9170
# step 4600: train loss 1.7904, val loss 1.8995
# step 4700: train loss 1.7895, val loss 1.9104
# step 4800: train loss 1.7743, val loss 1.9096
# step 4900: train loss 1.7809, val loss 1.9095
# step 5000: train loss 1.7706, val loss 1.8957
# step 5100: train loss 1.7731, val loss 1.8952
# step 5200: train loss 1.7656, val loss 1.8938
# step 5300: train loss 1.7707, val loss 1.8852
# step 5400: train loss 1.7609, val loss 1.8929
# step 5500: train loss 1.7494, val loss 1.8760
# step 5600: train loss 1.7628, val loss 1.8916
# step 5700: train loss 1.7530, val loss 1.8858
# step 5800: train loss 1.7486, val loss 1.8805
# step 5900: train loss 1.7596, val loss 1.8895
# step 6000: train loss 1.7429, val loss 1.8784
# step 6100: train loss 1.7494, val loss 1.8730
# step 6200: train loss 1.7525, val loss 1.8867
# step 6300: train loss 1.7351, val loss 1.8878
# step 6400: train loss 1.7314, val loss 1.8798
# step 6500: train loss 1.7321, val loss 1.8634
# step 6600: train loss 1.7281, val loss 1.8657
# step 6700: train loss 1.7252, val loss 1.8717
# step 6800: train loss 1.7328, val loss 1.8790
# step 6900: train loss 1.7242, val loss 1.8679
# step 7000: train loss 1.7225, val loss 1.8663
# step 7100: train loss 1.7239, val loss 1.8646
# step 7200: train loss 1.7116, val loss 1.8702
# step 7300: train loss 1.7160, val loss 1.8552
# step 7400: train loss 1.7171, val loss 1.8707
# step 7500: train loss 1.7002, val loss 1.8586
# step 7600: train loss 1.7142, val loss 1.8628
# step 7700: train loss 1.7043, val loss 1.8635
# step 7800: train loss 1.7095, val loss 1.8536
# step 7900: train loss 1.7113, val loss 1.8632
# step 8000: train loss 1.6991, val loss 1.8577
# step 8100: train loss 1.7027, val loss 1.8626
# step 8200: train loss 1.7068, val loss 1.8619
# step 8300: train loss 1.7062, val loss 1.8614
# step 8400: train loss 1.6967, val loss 1.8654
# step 8500: train loss 1.6971, val loss 1.8584
# step 8600: train loss 1.6981, val loss 1.8595
# step 8700: train loss 1.6929, val loss 1.8690
# step 8800: train loss 1.6807, val loss 1.8574
# step 8900: train loss 1.6909, val loss 1.8371
# step 9000: train loss 1.6881, val loss 1.8425
# step 9100: train loss 1.6820, val loss 1.8422
# step 9200: train loss 1.6948, val loss 1.8449
# step 9300: train loss 1.6726, val loss 1.8262
# step 9400: train loss 1.6790, val loss 1.8238
# step 9500: train loss 1.6803, val loss 1.8429
# step 9600: train loss 1.6816, val loss 1.8440
# step 9700: train loss 1.6753, val loss 1.8277
# step 9800: train loss 1.6698, val loss 1.8460
# step 9900: train loss 1.6711, val loss 1.8431
# step 9999: train loss 1.6726, val loss 1.8360

# %% [markdown]
# ### Train with 0.025 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.025):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_025 = []
val_losses_025 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_025.append(losses['train'].item())
        val_losses_025.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6821, val loss 2.6934
# step 200: train loss 2.5254, val loss 2.5212
# step 300: train loss 2.4565, val loss 2.4689
# step 400: train loss 2.4014, val loss 2.4026
# step 500: train loss 2.3497, val loss 2.3651
# step 600: train loss 2.3078, val loss 2.3097
# step 700: train loss 2.2739, val loss 2.2841
# step 800: train loss 2.2306, val loss 2.2471
# step 900: train loss 2.1994, val loss 2.2104
# step 1000: train loss 2.1780, val loss 2.1822
# step 1100: train loss 2.1510, val loss 2.1812
# step 1200: train loss 2.1278, val loss 2.1433
# step 1300: train loss 2.1220, val loss 2.1377
# step 1400: train loss 2.0895, val loss 2.1074
# step 1500: train loss 2.0653, val loss 2.1015
# step 1600: train loss 2.0453, val loss 2.0989
# step 1700: train loss 2.0485, val loss 2.0872
# step 1800: train loss 2.0199, val loss 2.0753
# step 1900: train loss 2.0075, val loss 2.0484
# step 2000: train loss 1.9896, val loss 2.0582
# step 2100: train loss 1.9776, val loss 2.0404
# step 2200: train loss 1.9603, val loss 2.0223
# step 2300: train loss 1.9573, val loss 2.0179
# step 2400: train loss 1.9529, val loss 2.0053
# step 2500: train loss 1.9318, val loss 2.0111
# step 2600: train loss 1.9373, val loss 2.0008
# step 2700: train loss 1.9227, val loss 1.9984
# step 2800: train loss 1.9133, val loss 1.9854
# step 2900: train loss 1.9086, val loss 1.9924
# step 3000: train loss 1.9055, val loss 1.9843
# step 3100: train loss 1.8777, val loss 1.9776
# step 3200: train loss 1.8678, val loss 1.9668
# step 3300: train loss 1.8651, val loss 1.9634
# step 3400: train loss 1.8614, val loss 1.9547
# step 3500: train loss 1.8537, val loss 1.9555
# step 3600: train loss 1.8405, val loss 1.9523
# step 3700: train loss 1.8483, val loss 1.9531
# step 3800: train loss 1.8305, val loss 1.9533
# step 3900: train loss 1.8341, val loss 1.9370
# step 4000: train loss 1.8229, val loss 1.9289
# step 4100: train loss 1.8194, val loss 1.9356
# step 4200: train loss 1.8104, val loss 1.9256
# step 4300: train loss 1.8204, val loss 1.9263
# step 4400: train loss 1.8161, val loss 1.9383
# step 4500: train loss 1.7977, val loss 1.9212
# step 4600: train loss 1.7968, val loss 1.9043
# step 4700: train loss 1.7935, val loss 1.9144
# step 4800: train loss 1.7776, val loss 1.9135
# step 4900: train loss 1.7841, val loss 1.9166
# step 5000: train loss 1.7762, val loss 1.9018
# step 5100: train loss 1.7782, val loss 1.9023
# step 5200: train loss 1.7681, val loss 1.9016
# step 5300: train loss 1.7762, val loss 1.8913
# step 5400: train loss 1.7655, val loss 1.9001
# step 5500: train loss 1.7544, val loss 1.8837
# step 5600: train loss 1.7677, val loss 1.8957
# step 5700: train loss 1.7578, val loss 1.8907
# step 5800: train loss 1.7525, val loss 1.8869
# step 5900: train loss 1.7634, val loss 1.8952
# step 6000: train loss 1.7502, val loss 1.8807
# step 6100: train loss 1.7534, val loss 1.8790
# step 6200: train loss 1.7564, val loss 1.8868
# step 6300: train loss 1.7397, val loss 1.8879
# step 6400: train loss 1.7353, val loss 1.8876
# step 6500: train loss 1.7374, val loss 1.8741
# step 6600: train loss 1.7314, val loss 1.8707
# step 6700: train loss 1.7302, val loss 1.8766
# step 6800: train loss 1.7378, val loss 1.8854
# step 6900: train loss 1.7301, val loss 1.8740
# step 7000: train loss 1.7249, val loss 1.8716
# step 7100: train loss 1.7244, val loss 1.8648
# step 7200: train loss 1.7153, val loss 1.8754
# step 7300: train loss 1.7159, val loss 1.8590
# step 7400: train loss 1.7229, val loss 1.8782
# step 7500: train loss 1.7006, val loss 1.8632
# step 7600: train loss 1.7157, val loss 1.8706
# step 7700: train loss 1.7079, val loss 1.8617
# step 7800: train loss 1.7145, val loss 1.8548
# step 7900: train loss 1.7102, val loss 1.8664
# step 8000: train loss 1.7016, val loss 1.8604
# step 8100: train loss 1.7035, val loss 1.8636
# step 8200: train loss 1.7118, val loss 1.8623
# step 8300: train loss 1.7071, val loss 1.8609
# step 8400: train loss 1.6987, val loss 1.8651
# step 8500: train loss 1.7006, val loss 1.8626
# step 8600: train loss 1.7021, val loss 1.8655
# step 8700: train loss 1.6945, val loss 1.8651
# step 8800: train loss 1.6852, val loss 1.8607
# step 8900: train loss 1.6938, val loss 1.8377
# step 9000: train loss 1.6898, val loss 1.8469
# step 9100: train loss 1.6841, val loss 1.8447
# step 9200: train loss 1.6990, val loss 1.8520
# step 9300: train loss 1.6729, val loss 1.8293
# step 9400: train loss 1.6799, val loss 1.8234
# step 9500: train loss 1.6854, val loss 1.8506
# step 9600: train loss 1.6849, val loss 1.8446
# step 9700: train loss 1.6766, val loss 1.8301
# step 9800: train loss 1.6745, val loss 1.8489
# step 9900: train loss 1.6780, val loss 1.8426
# step 9999: train loss 1.6783, val loss 1.8405

# %% [markdown]
# ### Train with 0.05 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.05):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_05 = []
val_losses_05 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_05.append(losses['train'].item())
        val_losses_05.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6832, val loss 2.6948
# step 200: train loss 2.5268, val loss 2.5226
# step 300: train loss 2.4584, val loss 2.4705
# step 400: train loss 2.4064, val loss 2.4073
# step 500: train loss 2.3538, val loss 2.3687
# step 600: train loss 2.3114, val loss 2.3121
# step 700: train loss 2.2786, val loss 2.2888
# step 800: train loss 2.2357, val loss 2.2532
# step 900: train loss 2.2053, val loss 2.2168
# step 1000: train loss 2.1821, val loss 2.1857
# step 1100: train loss 2.1549, val loss 2.1853
# step 1200: train loss 2.1350, val loss 2.1501
# step 1300: train loss 2.1274, val loss 2.1434
# step 1400: train loss 2.0944, val loss 2.1116
# step 1500: train loss 2.0725, val loss 2.1074
# step 1600: train loss 2.0520, val loss 2.1055
# step 1700: train loss 2.0544, val loss 2.0921
# step 1800: train loss 2.0265, val loss 2.0816
# step 1900: train loss 2.0136, val loss 2.0529
# step 2000: train loss 1.9955, val loss 2.0629
# step 2100: train loss 1.9823, val loss 2.0442
# step 2200: train loss 1.9632, val loss 2.0255
# step 2300: train loss 1.9624, val loss 2.0215
# step 2400: train loss 1.9563, val loss 2.0076
# step 2500: train loss 1.9368, val loss 2.0134
# step 2600: train loss 1.9456, val loss 2.0047
# step 2700: train loss 1.9265, val loss 1.9992
# step 2800: train loss 1.9200, val loss 1.9926
# step 2900: train loss 1.9153, val loss 1.9985
# step 3000: train loss 1.9157, val loss 1.9915
# step 3100: train loss 1.8833, val loss 1.9816
# step 3200: train loss 1.8747, val loss 1.9719
# step 3300: train loss 1.8719, val loss 1.9653
# step 3400: train loss 1.8691, val loss 1.9598
# step 3500: train loss 1.8611, val loss 1.9597
# step 3600: train loss 1.8474, val loss 1.9578
# step 3700: train loss 1.8593, val loss 1.9603
# step 3800: train loss 1.8375, val loss 1.9574
# step 3900: train loss 1.8418, val loss 1.9424
# step 4000: train loss 1.8304, val loss 1.9290
# step 4100: train loss 1.8262, val loss 1.9403
# step 4200: train loss 1.8205, val loss 1.9367
# step 4300: train loss 1.8270, val loss 1.9277
# step 4400: train loss 1.8193, val loss 1.9360
# step 4500: train loss 1.8059, val loss 1.9263
# step 4600: train loss 1.8051, val loss 1.9076
# step 4700: train loss 1.8026, val loss 1.9233
# step 4800: train loss 1.7890, val loss 1.9236
# step 4900: train loss 1.7925, val loss 1.9209
# step 5000: train loss 1.7844, val loss 1.9108
# step 5100: train loss 1.7842, val loss 1.9092
# step 5200: train loss 1.7783, val loss 1.9062
# step 5300: train loss 1.7842, val loss 1.8984
# step 5400: train loss 1.7751, val loss 1.9113
# step 5500: train loss 1.7615, val loss 1.8883
# step 5600: train loss 1.7756, val loss 1.8978
# step 5700: train loss 1.7671, val loss 1.9028
# step 5800: train loss 1.7615, val loss 1.8895
# step 5900: train loss 1.7715, val loss 1.8994
# step 6000: train loss 1.7590, val loss 1.8880
# step 6100: train loss 1.7606, val loss 1.8845
# step 6200: train loss 1.7649, val loss 1.8943
# step 6300: train loss 1.7515, val loss 1.8961
# step 6400: train loss 1.7458, val loss 1.8930
# step 6500: train loss 1.7467, val loss 1.8784
# step 6600: train loss 1.7400, val loss 1.8776
# step 6700: train loss 1.7370, val loss 1.8829
# step 6800: train loss 1.7459, val loss 1.8931
# step 6900: train loss 1.7381, val loss 1.8807
# step 7000: train loss 1.7335, val loss 1.8787
# step 7100: train loss 1.7376, val loss 1.8809
# step 7200: train loss 1.7235, val loss 1.8834
# step 7300: train loss 1.7277, val loss 1.8661
# step 7400: train loss 1.7327, val loss 1.8839
# step 7500: train loss 1.7105, val loss 1.8713
# step 7600: train loss 1.7218, val loss 1.8717
# step 7700: train loss 1.7150, val loss 1.8705
# step 7800: train loss 1.7254, val loss 1.8691
# step 7900: train loss 1.7208, val loss 1.8692
# step 8000: train loss 1.7126, val loss 1.8719
# step 8100: train loss 1.7120, val loss 1.8760
# step 8200: train loss 1.7224, val loss 1.8735
# step 8300: train loss 1.7163, val loss 1.8704
# step 8400: train loss 1.7079, val loss 1.8777
# step 8500: train loss 1.7097, val loss 1.8660
# step 8600: train loss 1.7110, val loss 1.8750
# step 8700: train loss 1.7049, val loss 1.8775
# step 8800: train loss 1.6920, val loss 1.8675
# step 8900: train loss 1.7010, val loss 1.8461
# step 9000: train loss 1.6979, val loss 1.8569
# step 9100: train loss 1.6965, val loss 1.8503
# step 9200: train loss 1.7087, val loss 1.8556
# step 9300: train loss 1.6824, val loss 1.8340
# step 9400: train loss 1.6874, val loss 1.8352
# step 9500: train loss 1.6926, val loss 1.8582
# step 9600: train loss 1.6925, val loss 1.8537
# step 9700: train loss 1.6843, val loss 1.8395
# step 9800: train loss 1.6804, val loss 1.8593
# step 9900: train loss 1.6847, val loss 1.8514
# step 9999: train loss 1.6885, val loss 1.8525

# %% [markdown]
# ### Train with 0.075 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.075):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_075 = []
val_losses_075 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_075.append(losses['train'].item())
        val_losses_075.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6861, val loss 2.6980
# step 200: train loss 2.5284, val loss 2.5244
# step 300: train loss 2.4598, val loss 2.4718
# step 400: train loss 2.4089, val loss 2.4099
# step 500: train loss 2.3570, val loss 2.3722
# step 600: train loss 2.3136, val loss 2.3146
# step 700: train loss 2.2853, val loss 2.2947
# step 800: train loss 2.2401, val loss 2.2571
# step 900: train loss 2.2094, val loss 2.2205
# step 1000: train loss 2.1875, val loss 2.1917
# step 1100: train loss 2.1620, val loss 2.1923
# step 1200: train loss 2.1395, val loss 2.1514
# step 1300: train loss 2.1312, val loss 2.1460
# step 1400: train loss 2.0986, val loss 2.1140
# step 1500: train loss 2.0784, val loss 2.1114
# step 1600: train loss 2.0553, val loss 2.1058
# step 1700: train loss 2.0583, val loss 2.0943
# step 1800: train loss 2.0300, val loss 2.0821
# step 1900: train loss 2.0192, val loss 2.0549
# step 2000: train loss 2.0028, val loss 2.0658
# step 2100: train loss 1.9901, val loss 2.0499
# step 2200: train loss 1.9718, val loss 2.0304
# step 2300: train loss 1.9703, val loss 2.0265
# step 2400: train loss 1.9639, val loss 2.0132
# step 2500: train loss 1.9427, val loss 2.0142
# step 2600: train loss 1.9546, val loss 2.0094
# step 2700: train loss 1.9372, val loss 2.0040
# step 2800: train loss 1.9292, val loss 1.9968
# step 2900: train loss 1.9251, val loss 2.0038
# step 3000: train loss 1.9219, val loss 1.9947
# step 3100: train loss 1.8914, val loss 1.9834
# step 3200: train loss 1.8836, val loss 1.9752
# step 3300: train loss 1.8790, val loss 1.9699
# step 3400: train loss 1.8800, val loss 1.9651
# step 3500: train loss 1.8730, val loss 1.9682
# step 3600: train loss 1.8568, val loss 1.9629
# step 3700: train loss 1.8663, val loss 1.9667
# step 3800: train loss 1.8460, val loss 1.9616
# step 3900: train loss 1.8480, val loss 1.9486
# step 4000: train loss 1.8398, val loss 1.9373
# step 4100: train loss 1.8363, val loss 1.9468
# step 4200: train loss 1.8270, val loss 1.9352
# step 4300: train loss 1.8369, val loss 1.9367
# step 4400: train loss 1.8306, val loss 1.9447
# step 4500: train loss 1.8159, val loss 1.9265
# step 4600: train loss 1.8106, val loss 1.9094
# step 4700: train loss 1.8099, val loss 1.9283
# step 4800: train loss 1.7947, val loss 1.9254
# step 4900: train loss 1.8025, val loss 1.9250
# step 5000: train loss 1.7910, val loss 1.9113
# step 5100: train loss 1.7936, val loss 1.9104
# step 5200: train loss 1.7894, val loss 1.9105
# step 5300: train loss 1.7904, val loss 1.8958
# step 5400: train loss 1.7815, val loss 1.9073
# step 5500: train loss 1.7691, val loss 1.8902
# step 5600: train loss 1.7847, val loss 1.9014
# step 5700: train loss 1.7758, val loss 1.9016
# step 5800: train loss 1.7680, val loss 1.8917
# step 5900: train loss 1.7776, val loss 1.9010
# step 6000: train loss 1.7641, val loss 1.8858
# step 6100: train loss 1.7688, val loss 1.8882
# step 6200: train loss 1.7699, val loss 1.8927
# step 6300: train loss 1.7614, val loss 1.8978
# step 6400: train loss 1.7538, val loss 1.8978
# step 6500: train loss 1.7520, val loss 1.8762
# step 6600: train loss 1.7465, val loss 1.8805
# step 6700: train loss 1.7436, val loss 1.8841
# step 6800: train loss 1.7544, val loss 1.8937
# step 6900: train loss 1.7451, val loss 1.8804
# step 7000: train loss 1.7417, val loss 1.8809
# step 7100: train loss 1.7455, val loss 1.8809
# step 7200: train loss 1.7356, val loss 1.8835
# step 7300: train loss 1.7315, val loss 1.8620
# step 7400: train loss 1.7387, val loss 1.8858
# step 7500: train loss 1.7173, val loss 1.8651
# step 7600: train loss 1.7299, val loss 1.8770
# step 7700: train loss 1.7201, val loss 1.8712
# step 7800: train loss 1.7277, val loss 1.8680
# step 7900: train loss 1.7270, val loss 1.8759
# step 8000: train loss 1.7181, val loss 1.8733
# step 8100: train loss 1.7199, val loss 1.8789
# step 8200: train loss 1.7276, val loss 1.8755
# step 8300: train loss 1.7211, val loss 1.8735
# step 8400: train loss 1.7152, val loss 1.8717
# step 8500: train loss 1.7134, val loss 1.8668
# step 8600: train loss 1.7201, val loss 1.8760
# step 8700: train loss 1.7108, val loss 1.8769
# step 8800: train loss 1.6971, val loss 1.8665
# step 8900: train loss 1.7070, val loss 1.8452
# step 9000: train loss 1.7009, val loss 1.8517
# step 9100: train loss 1.7001, val loss 1.8556
# step 9200: train loss 1.7114, val loss 1.8571
# step 9300: train loss 1.6897, val loss 1.8415
# step 9400: train loss 1.6929, val loss 1.8365
# step 9500: train loss 1.6994, val loss 1.8550
# step 9600: train loss 1.6986, val loss 1.8539
# step 9700: train loss 1.6930, val loss 1.8413
# step 9800: train loss 1.6924, val loss 1.8647
# step 9900: train loss 1.6961, val loss 1.8596
# step 9999: train loss 1.6944, val loss 1.8570

# %% [markdown]
# ### Train with 0.1 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.1):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_1 = []
val_losses_1 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_1.append(losses['train'].item())
        val_losses_1.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6886, val loss 2.7006
# step 200: train loss 2.5302, val loss 2.5262
# step 300: train loss 2.4626, val loss 2.4745
# step 400: train loss 2.4123, val loss 2.4132
# step 500: train loss 2.3601, val loss 2.3743
# step 600: train loss 2.3171, val loss 2.3174
# step 700: train loss 2.2903, val loss 2.2992
# step 800: train loss 2.2454, val loss 2.2626
# step 900: train loss 2.2147, val loss 2.2246
# step 1000: train loss 2.1918, val loss 2.1962
# step 1100: train loss 2.1674, val loss 2.1965
# step 1200: train loss 2.1442, val loss 2.1565
# step 1300: train loss 2.1351, val loss 2.1495
# step 1400: train loss 2.1054, val loss 2.1206
# step 1500: train loss 2.0819, val loss 2.1159
# step 1600: train loss 2.0612, val loss 2.1122
# step 1700: train loss 2.0650, val loss 2.0999
# step 1800: train loss 2.0364, val loss 2.0889
# step 1900: train loss 2.0252, val loss 2.0629
# step 2000: train loss 2.0088, val loss 2.0705
# step 2100: train loss 1.9964, val loss 2.0563
# step 2200: train loss 1.9794, val loss 2.0370
# step 2300: train loss 1.9752, val loss 2.0299
# step 2400: train loss 1.9706, val loss 2.0196
# step 2500: train loss 1.9512, val loss 2.0214
# step 2600: train loss 1.9599, val loss 2.0155
# step 2700: train loss 1.9429, val loss 2.0085
# step 2800: train loss 1.9371, val loss 2.0059
# step 2900: train loss 1.9293, val loss 2.0047
# step 3000: train loss 1.9258, val loss 1.9985
# step 3100: train loss 1.8997, val loss 1.9917
# step 3200: train loss 1.8872, val loss 1.9797
# step 3300: train loss 1.8863, val loss 1.9768
# step 3400: train loss 1.8857, val loss 1.9718
# step 3500: train loss 1.8783, val loss 1.9695
# step 3600: train loss 1.8631, val loss 1.9672
# step 3700: train loss 1.8732, val loss 1.9708
# step 3800: train loss 1.8549, val loss 1.9664
# step 3900: train loss 1.8562, val loss 1.9540
# step 4000: train loss 1.8472, val loss 1.9411
# step 4100: train loss 1.8434, val loss 1.9535
# step 4200: train loss 1.8322, val loss 1.9436
# step 4300: train loss 1.8439, val loss 1.9420
# step 4400: train loss 1.8397, val loss 1.9485
# step 4500: train loss 1.8233, val loss 1.9325
# step 4600: train loss 1.8205, val loss 1.9222
# step 4700: train loss 1.8190, val loss 1.9350
# step 4800: train loss 1.8041, val loss 1.9306
# step 4900: train loss 1.8108, val loss 1.9314
# step 5000: train loss 1.8000, val loss 1.9192
# step 5100: train loss 1.8025, val loss 1.9205
# step 5200: train loss 1.7953, val loss 1.9137
# step 5300: train loss 1.7990, val loss 1.9046
# step 5400: train loss 1.7901, val loss 1.9166
# step 5500: train loss 1.7761, val loss 1.9025
# step 5600: train loss 1.7918, val loss 1.9088
# step 5700: train loss 1.7828, val loss 1.9114
# step 5800: train loss 1.7761, val loss 1.9046
# step 5900: train loss 1.7840, val loss 1.9079
# step 6000: train loss 1.7732, val loss 1.8998
# step 6100: train loss 1.7774, val loss 1.8956
# step 6200: train loss 1.7766, val loss 1.8961
# step 6300: train loss 1.7652, val loss 1.9033
# step 6400: train loss 1.7597, val loss 1.9016
# step 6500: train loss 1.7606, val loss 1.8842
# step 6600: train loss 1.7551, val loss 1.8868
# step 6700: train loss 1.7514, val loss 1.8900
# step 6800: train loss 1.7599, val loss 1.8984
# step 6900: train loss 1.7534, val loss 1.8876
# step 7000: train loss 1.7507, val loss 1.8893
# step 7100: train loss 1.7523, val loss 1.8873
# step 7200: train loss 1.7385, val loss 1.8918
# step 7300: train loss 1.7404, val loss 1.8700
# step 7400: train loss 1.7458, val loss 1.8913
# step 7500: train loss 1.7254, val loss 1.8772
# step 7600: train loss 1.7363, val loss 1.8810
# step 7700: train loss 1.7302, val loss 1.8782
# step 7800: train loss 1.7371, val loss 1.8762
# step 7900: train loss 1.7351, val loss 1.8846
# step 8000: train loss 1.7245, val loss 1.8775
# step 8100: train loss 1.7273, val loss 1.8852
# step 8200: train loss 1.7349, val loss 1.8825
# step 8300: train loss 1.7319, val loss 1.8817
# step 8400: train loss 1.7236, val loss 1.8833
# step 8500: train loss 1.7229, val loss 1.8730
# step 8600: train loss 1.7246, val loss 1.8796
# step 8700: train loss 1.7176, val loss 1.8859
# step 8800: train loss 1.7074, val loss 1.8812
# step 8900: train loss 1.7144, val loss 1.8552
# step 9000: train loss 1.7097, val loss 1.8618
# step 9100: train loss 1.7070, val loss 1.8624
# step 9200: train loss 1.7214, val loss 1.8670
# step 9300: train loss 1.6963, val loss 1.8434
# step 9400: train loss 1.7041, val loss 1.8440
# step 9500: train loss 1.7059, val loss 1.8644
# step 9600: train loss 1.7046, val loss 1.8650
# step 9700: train loss 1.6990, val loss 1.8440
# step 9800: train loss 1.6996, val loss 1.8728
# step 9900: train loss 1.7025, val loss 1.8579
# step 9999: train loss 1.7066, val loss 1.8616

# %% [markdown]
# ### Train with 0.125 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.125):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_125 = []
val_losses_125 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_125.append(losses['train'].item())
        val_losses_125.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6901, val loss 2.7022
# step 200: train loss 2.5313, val loss 2.5272
# step 300: train loss 2.4654, val loss 2.4772
# step 400: train loss 2.4137, val loss 2.4150
# step 500: train loss 2.3628, val loss 2.3763
# step 600: train loss 2.3199, val loss 2.3194
# step 700: train loss 2.2906, val loss 2.2998
# step 800: train loss 2.2497, val loss 2.2656
# step 900: train loss 2.2191, val loss 2.2282
# step 1000: train loss 2.1966, val loss 2.2009
# step 1100: train loss 2.1716, val loss 2.1998
# step 1200: train loss 2.1499, val loss 2.1609
# step 1300: train loss 2.1414, val loss 2.1551
# step 1400: train loss 2.1113, val loss 2.1242
# step 1500: train loss 2.0884, val loss 2.1208
# step 1600: train loss 2.0687, val loss 2.1198
# step 1700: train loss 2.0732, val loss 2.1051
# step 1800: train loss 2.0428, val loss 2.0933
# step 1900: train loss 2.0327, val loss 2.0692
# step 2000: train loss 2.0151, val loss 2.0753
# step 2100: train loss 2.0043, val loss 2.0613
# step 2200: train loss 1.9872, val loss 2.0432
# step 2300: train loss 1.9841, val loss 2.0386
# step 2400: train loss 1.9795, val loss 2.0277
# step 2500: train loss 1.9594, val loss 2.0278
# step 2600: train loss 1.9700, val loss 2.0259
# step 2700: train loss 1.9511, val loss 2.0166
# step 2800: train loss 1.9453, val loss 2.0130
# step 2900: train loss 1.9373, val loss 2.0113
# step 3000: train loss 1.9298, val loss 2.0018
# step 3100: train loss 1.9072, val loss 1.9963
# step 3200: train loss 1.8936, val loss 1.9869
# step 3300: train loss 1.8934, val loss 1.9825
# step 3400: train loss 1.8939, val loss 1.9781
# step 3500: train loss 1.8862, val loss 1.9768
# step 3600: train loss 1.8714, val loss 1.9741
# step 3700: train loss 1.8807, val loss 1.9767
# step 3800: train loss 1.8615, val loss 1.9717
# step 3900: train loss 1.8620, val loss 1.9601
# step 4000: train loss 1.8555, val loss 1.9462
# step 4100: train loss 1.8515, val loss 1.9583
# step 4200: train loss 1.8447, val loss 1.9512
# step 4300: train loss 1.8525, val loss 1.9470
# step 4400: train loss 1.8452, val loss 1.9525
# step 4500: train loss 1.8318, val loss 1.9396
# step 4600: train loss 1.8260, val loss 1.9253
# step 4700: train loss 1.8270, val loss 1.9399
# step 4800: train loss 1.8078, val loss 1.9322
# step 4900: train loss 1.8174, val loss 1.9352
# step 5000: train loss 1.8059, val loss 1.9229
# step 5100: train loss 1.8081, val loss 1.9206
# step 5200: train loss 1.7997, val loss 1.9169
# step 5300: train loss 1.8042, val loss 1.9082
# step 5400: train loss 1.7959, val loss 1.9213
# step 5500: train loss 1.7816, val loss 1.9028
# step 5600: train loss 1.7987, val loss 1.9124
# step 5700: train loss 1.7891, val loss 1.9132
# step 5800: train loss 1.7837, val loss 1.9057
# step 5900: train loss 1.7924, val loss 1.9145
# step 6000: train loss 1.7819, val loss 1.9009
# step 6100: train loss 1.7846, val loss 1.9000
# step 6200: train loss 1.7816, val loss 1.8993
# step 6300: train loss 1.7728, val loss 1.9079
# step 6400: train loss 1.7685, val loss 1.9058
# step 6500: train loss 1.7672, val loss 1.8867
# step 6600: train loss 1.7601, val loss 1.8886
# step 6700: train loss 1.7588, val loss 1.8945
# step 6800: train loss 1.7661, val loss 1.9005
# step 6900: train loss 1.7607, val loss 1.8884
# step 7000: train loss 1.7574, val loss 1.8872
# step 7100: train loss 1.7600, val loss 1.8861
# step 7200: train loss 1.7442, val loss 1.8863
# step 7300: train loss 1.7487, val loss 1.8735
# step 7400: train loss 1.7551, val loss 1.8937
# step 7500: train loss 1.7314, val loss 1.8772
# step 7600: train loss 1.7427, val loss 1.8845
# step 7700: train loss 1.7363, val loss 1.8796
# step 7800: train loss 1.7432, val loss 1.8730
# step 7900: train loss 1.7380, val loss 1.8806
# step 8000: train loss 1.7296, val loss 1.8734
# step 8100: train loss 1.7344, val loss 1.8845
# step 8200: train loss 1.7416, val loss 1.8787
# step 8300: train loss 1.7347, val loss 1.8777
# step 8400: train loss 1.7273, val loss 1.8796
# step 8500: train loss 1.7289, val loss 1.8759
# step 8600: train loss 1.7289, val loss 1.8730
# step 8700: train loss 1.7237, val loss 1.8815
# step 8800: train loss 1.7123, val loss 1.8737
# step 8900: train loss 1.7200, val loss 1.8490
# step 9000: train loss 1.7166, val loss 1.8616
# step 9100: train loss 1.7162, val loss 1.8646
# step 9200: train loss 1.7275, val loss 1.8624
# step 9300: train loss 1.7028, val loss 1.8475
# step 9400: train loss 1.7085, val loss 1.8471
# step 9500: train loss 1.7141, val loss 1.8667
# step 9600: train loss 1.7128, val loss 1.8644
# step 9700: train loss 1.7080, val loss 1.8496
# step 9800: train loss 1.7015, val loss 1.8677
# step 9900: train loss 1.7089, val loss 1.8618
# step 9999: train loss 1.7085, val loss 1.8578

# %% [markdown]
# ### Train with 0.15 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.15):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_15 = []
val_losses_15 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_15.append(losses['train'].item())
        val_losses_15.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6933, val loss 2.7055
# step 200: train loss 2.5338, val loss 2.5295
# step 300: train loss 2.4679, val loss 2.4801
# step 400: train loss 2.4167, val loss 2.4180
# step 500: train loss 2.3687, val loss 2.3814
# step 600: train loss 2.3234, val loss 2.3230
# step 700: train loss 2.2963, val loss 2.3055
# step 800: train loss 2.2566, val loss 2.2717
# step 900: train loss 2.2255, val loss 2.2334
# step 1000: train loss 2.2028, val loss 2.2058
# step 1100: train loss 2.1777, val loss 2.2045
# step 1200: train loss 2.1581, val loss 2.1676
# step 1300: train loss 2.1485, val loss 2.1610
# step 1400: train loss 2.1189, val loss 2.1304
# step 1500: train loss 2.0960, val loss 2.1266
# step 1600: train loss 2.0755, val loss 2.1245
# step 1700: train loss 2.0810, val loss 2.1121
# step 1800: train loss 2.0519, val loss 2.1009
# step 1900: train loss 2.0389, val loss 2.0747
# step 2000: train loss 2.0223, val loss 2.0801
# step 2100: train loss 2.0113, val loss 2.0669
# step 2200: train loss 1.9938, val loss 2.0486
# step 2300: train loss 1.9909, val loss 2.0435
# step 2400: train loss 1.9864, val loss 2.0316
# step 2500: train loss 1.9676, val loss 2.0327
# step 2600: train loss 1.9766, val loss 2.0308
# step 2700: train loss 1.9580, val loss 2.0216
# step 2800: train loss 1.9510, val loss 2.0146
# step 2900: train loss 1.9439, val loss 2.0161
# step 3000: train loss 1.9374, val loss 2.0059
# step 3100: train loss 1.9157, val loss 2.0040
# step 3200: train loss 1.9032, val loss 1.9910
# step 3300: train loss 1.9054, val loss 1.9881
# step 3400: train loss 1.8997, val loss 1.9808
# step 3500: train loss 1.8958, val loss 1.9826
# step 3600: train loss 1.8790, val loss 1.9790
# step 3700: train loss 1.8872, val loss 1.9773
# step 3800: train loss 1.8678, val loss 1.9730
# step 3900: train loss 1.8688, val loss 1.9630
# step 4000: train loss 1.8634, val loss 1.9500
# step 4100: train loss 1.8612, val loss 1.9641
# step 4200: train loss 1.8506, val loss 1.9557
# step 4300: train loss 1.8591, val loss 1.9472
# step 4400: train loss 1.8528, val loss 1.9541
# step 4500: train loss 1.8381, val loss 1.9455
# step 4600: train loss 1.8349, val loss 1.9305
# step 4700: train loss 1.8328, val loss 1.9390
# step 4800: train loss 1.8232, val loss 1.9441
# step 4900: train loss 1.8229, val loss 1.9340
# step 5000: train loss 1.8157, val loss 1.9278
# step 5100: train loss 1.8168, val loss 1.9222
# step 5200: train loss 1.8078, val loss 1.9215
# step 5300: train loss 1.8128, val loss 1.9130
# step 5400: train loss 1.8035, val loss 1.9204
# step 5500: train loss 1.7894, val loss 1.9072
# step 5600: train loss 1.8065, val loss 1.9141
# step 5700: train loss 1.7978, val loss 1.9134
# step 5800: train loss 1.7909, val loss 1.9067
# step 5900: train loss 1.8007, val loss 1.9130
# step 6000: train loss 1.7876, val loss 1.8999
# step 6100: train loss 1.7915, val loss 1.8973
# step 6200: train loss 1.7928, val loss 1.9064
# step 6300: train loss 1.7818, val loss 1.9099
# step 6400: train loss 1.7754, val loss 1.9066
# step 6500: train loss 1.7707, val loss 1.8847
# step 6600: train loss 1.7712, val loss 1.8931
# step 6700: train loss 1.7663, val loss 1.8972
# step 6800: train loss 1.7772, val loss 1.9086
# step 6900: train loss 1.7683, val loss 1.8895
# step 7000: train loss 1.7629, val loss 1.8921
# step 7100: train loss 1.7686, val loss 1.8914
# step 7200: train loss 1.7539, val loss 1.8917
# step 7300: train loss 1.7533, val loss 1.8800
# step 7400: train loss 1.7587, val loss 1.8950
# step 7500: train loss 1.7390, val loss 1.8821
# step 7600: train loss 1.7547, val loss 1.8918
# step 7700: train loss 1.7422, val loss 1.8807
# step 7800: train loss 1.7541, val loss 1.8823
# step 7900: train loss 1.7495, val loss 1.8914
# step 8000: train loss 1.7399, val loss 1.8830
# step 8100: train loss 1.7381, val loss 1.8850
# step 8200: train loss 1.7501, val loss 1.8864
# step 8300: train loss 1.7419, val loss 1.8786
# step 8400: train loss 1.7378, val loss 1.8859
# step 8500: train loss 1.7383, val loss 1.8770
# step 8600: train loss 1.7424, val loss 1.8885
# step 8700: train loss 1.7325, val loss 1.8868
# step 8800: train loss 1.7191, val loss 1.8788
# step 8900: train loss 1.7298, val loss 1.8536
# step 9000: train loss 1.7232, val loss 1.8650
# step 9100: train loss 1.7253, val loss 1.8695
# step 9200: train loss 1.7361, val loss 1.8653
# step 9300: train loss 1.7110, val loss 1.8483
# step 9400: train loss 1.7141, val loss 1.8409
# step 9500: train loss 1.7194, val loss 1.8655
# step 9600: train loss 1.7195, val loss 1.8698
# step 9700: train loss 1.7154, val loss 1.8521
# step 9800: train loss 1.7127, val loss 1.8751
# step 9900: train loss 1.7167, val loss 1.8643
# step 9999: train loss 1.7158, val loss 1.8546

# %% [markdown]
# ### Train with 0.175 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.175):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_175 = []
val_losses_175 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_175.append(losses['train'].item())
        val_losses_175.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6952, val loss 2.7079
# step 200: train loss 2.5356, val loss 2.5314
# step 300: train loss 2.4705, val loss 2.4821
# step 400: train loss 2.4177, val loss 2.4197
# step 500: train loss 2.3712, val loss 2.3832
# step 600: train loss 2.3272, val loss 2.3265
# step 700: train loss 2.3004, val loss 2.3096
# step 800: train loss 2.2621, val loss 2.2775
# step 900: train loss 2.2314, val loss 2.2379
# step 1000: train loss 2.2070, val loss 2.2098
# step 1100: train loss 2.1819, val loss 2.2078
# step 1200: train loss 2.1619, val loss 2.1716
# step 1300: train loss 2.1562, val loss 2.1667
# step 1400: train loss 2.1260, val loss 2.1367
# step 1500: train loss 2.1008, val loss 2.1313
# step 1600: train loss 2.0830, val loss 2.1297
# step 1700: train loss 2.0867, val loss 2.1157
# step 1800: train loss 2.0576, val loss 2.1046
# step 1900: train loss 2.0476, val loss 2.0799
# step 2000: train loss 2.0305, val loss 2.0870
# step 2100: train loss 2.0176, val loss 2.0697
# step 2200: train loss 2.0009, val loss 2.0523
# step 2300: train loss 1.9987, val loss 2.0491
# step 2400: train loss 1.9948, val loss 2.0376
# step 2500: train loss 1.9759, val loss 2.0393
# step 2600: train loss 1.9805, val loss 2.0301
# step 2700: train loss 1.9663, val loss 2.0253
# step 2800: train loss 1.9600, val loss 2.0217
# step 2900: train loss 1.9533, val loss 2.0229
# step 3000: train loss 1.9469, val loss 2.0140
# step 3100: train loss 1.9234, val loss 2.0088
# step 3200: train loss 1.9135, val loss 1.9991
# step 3300: train loss 1.9146, val loss 1.9951
# step 3400: train loss 1.9081, val loss 1.9862
# step 3500: train loss 1.9054, val loss 1.9894
# step 3600: train loss 1.8884, val loss 1.9847
# step 3700: train loss 1.8979, val loss 1.9855
# step 3800: train loss 1.8776, val loss 1.9805
# step 3900: train loss 1.8798, val loss 1.9722
# step 4000: train loss 1.8716, val loss 1.9550
# step 4100: train loss 1.8675, val loss 1.9659
# step 4200: train loss 1.8642, val loss 1.9663
# step 4300: train loss 1.8729, val loss 1.9572
# step 4400: train loss 1.8637, val loss 1.9629
# step 4500: train loss 1.8495, val loss 1.9513
# step 4600: train loss 1.8454, val loss 1.9374
# step 4700: train loss 1.8436, val loss 1.9485
# step 4800: train loss 1.8337, val loss 1.9533
# step 4900: train loss 1.8322, val loss 1.9432
# step 5000: train loss 1.8245, val loss 1.9316
# step 5100: train loss 1.8284, val loss 1.9325
# step 5200: train loss 1.8196, val loss 1.9353
# step 5300: train loss 1.8202, val loss 1.9194
# step 5400: train loss 1.8113, val loss 1.9279
# step 5500: train loss 1.8017, val loss 1.9145
# step 5600: train loss 1.8163, val loss 1.9238
# step 5700: train loss 1.8055, val loss 1.9203
# step 5800: train loss 1.8006, val loss 1.9169
# step 5900: train loss 1.8080, val loss 1.9207
# step 6000: train loss 1.7982, val loss 1.9097
# step 6100: train loss 1.8013, val loss 1.9081
# step 6200: train loss 1.7992, val loss 1.9138
# step 6300: train loss 1.7877, val loss 1.9177
# step 6400: train loss 1.7834, val loss 1.9144
# step 6500: train loss 1.7814, val loss 1.8958
# step 6600: train loss 1.7799, val loss 1.9006
# step 6700: train loss 1.7752, val loss 1.9021
# step 6800: train loss 1.7842, val loss 1.9118
# step 6900: train loss 1.7768, val loss 1.9029
# step 7000: train loss 1.7735, val loss 1.9031
# step 7100: train loss 1.7810, val loss 1.9029
# step 7200: train loss 1.7601, val loss 1.8974
# step 7300: train loss 1.7644, val loss 1.8836
# step 7400: train loss 1.7706, val loss 1.9073
# step 7500: train loss 1.7494, val loss 1.8865
# step 7600: train loss 1.7582, val loss 1.8993
# step 7700: train loss 1.7532, val loss 1.8897
# step 7800: train loss 1.7590, val loss 1.8842
# step 7900: train loss 1.7591, val loss 1.9007
# step 8000: train loss 1.7500, val loss 1.8951
# step 8100: train loss 1.7492, val loss 1.8944
# step 8200: train loss 1.7585, val loss 1.8947
# step 8300: train loss 1.7534, val loss 1.8913
# step 8400: train loss 1.7469, val loss 1.9001
# step 8500: train loss 1.7460, val loss 1.8873
# step 8600: train loss 1.7464, val loss 1.8915
# step 8700: train loss 1.7427, val loss 1.8996
# step 8800: train loss 1.7295, val loss 1.8900
# step 8900: train loss 1.7376, val loss 1.8660
# step 9000: train loss 1.7305, val loss 1.8716
# step 9100: train loss 1.7336, val loss 1.8761
# step 9200: train loss 1.7458, val loss 1.8780
# step 9300: train loss 1.7187, val loss 1.8597
# step 9400: train loss 1.7227, val loss 1.8552
# step 9500: train loss 1.7285, val loss 1.8767
# step 9600: train loss 1.7268, val loss 1.8739
# step 9700: train loss 1.7240, val loss 1.8672
# step 9800: train loss 1.7203, val loss 1.8814
# step 9900: train loss 1.7220, val loss 1.8648
# step 9999: train loss 1.7260, val loss 1.8724

# %% [markdown]
# ### Train with 0.2 residual connection dropout rate

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.2):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_2 = []
val_losses_2 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_2.append(losses['train'].item())
        val_losses_2.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6977, val loss 2.7107
# step 200: train loss 2.5372, val loss 2.5333
# step 300: train loss 2.4734, val loss 2.4842
# step 400: train loss 2.4197, val loss 2.4212
# step 500: train loss 2.3751, val loss 2.3861
# step 600: train loss 2.3302, val loss 2.3289
# step 700: train loss 2.3039, val loss 2.3128
# step 800: train loss 2.2668, val loss 2.2818
# step 900: train loss 2.2388, val loss 2.2437
# step 1000: train loss 2.2131, val loss 2.2145
# step 1100: train loss 2.1905, val loss 2.2152
# step 1200: train loss 2.1683, val loss 2.1763
# step 1300: train loss 2.1627, val loss 2.1729
# step 1400: train loss 2.1317, val loss 2.1409
# step 1500: train loss 2.1069, val loss 2.1358
# step 1600: train loss 2.0887, val loss 2.1343
# step 1700: train loss 2.0955, val loss 2.1216
# step 1800: train loss 2.0635, val loss 2.1088
# step 1900: train loss 2.0520, val loss 2.0844
# step 2000: train loss 2.0332, val loss 2.0870
# step 2100: train loss 2.0225, val loss 2.0726
# step 2200: train loss 2.0091, val loss 2.0583
# step 2300: train loss 2.0046, val loss 2.0542
# step 2400: train loss 2.0020, val loss 2.0429
# step 2500: train loss 1.9807, val loss 2.0407
# step 2600: train loss 1.9882, val loss 2.0365
# step 2700: train loss 1.9734, val loss 2.0286
# step 2800: train loss 1.9667, val loss 2.0264
# step 2900: train loss 1.9617, val loss 2.0284
# step 3000: train loss 1.9509, val loss 2.0127
# step 3100: train loss 1.9298, val loss 2.0105
# step 3200: train loss 1.9196, val loss 2.0047
# step 3300: train loss 1.9188, val loss 1.9976
# step 3400: train loss 1.9143, val loss 1.9925
# step 3500: train loss 1.9121, val loss 1.9947
# step 3600: train loss 1.8944, val loss 1.9899
# step 3700: train loss 1.9018, val loss 1.9902
# step 3800: train loss 1.8839, val loss 1.9872
# step 3900: train loss 1.8854, val loss 1.9779
# step 4000: train loss 1.8764, val loss 1.9637
# step 4100: train loss 1.8727, val loss 1.9728
# step 4200: train loss 1.8689, val loss 1.9690
# step 4300: train loss 1.8752, val loss 1.9569
# step 4400: train loss 1.8668, val loss 1.9637
# step 4500: train loss 1.8555, val loss 1.9562
# step 4600: train loss 1.8499, val loss 1.9411
# step 4700: train loss 1.8491, val loss 1.9556
# step 4800: train loss 1.8374, val loss 1.9573
# step 4900: train loss 1.8399, val loss 1.9500
# step 5000: train loss 1.8281, val loss 1.9383
# step 5100: train loss 1.8322, val loss 1.9344
# step 5200: train loss 1.8245, val loss 1.9376
# step 5300: train loss 1.8251, val loss 1.9230
# step 5400: train loss 1.8183, val loss 1.9359
# step 5500: train loss 1.8059, val loss 1.9213
# step 5600: train loss 1.8217, val loss 1.9291
# step 5700: train loss 1.8092, val loss 1.9241
# step 5800: train loss 1.8053, val loss 1.9202
# step 5900: train loss 1.8149, val loss 1.9288
# step 6000: train loss 1.7997, val loss 1.9090
# step 6100: train loss 1.8087, val loss 1.9086
# step 6200: train loss 1.8030, val loss 1.9168
# step 6300: train loss 1.7918, val loss 1.9196
# step 6400: train loss 1.7905, val loss 1.9170
# step 6500: train loss 1.7851, val loss 1.9003
# step 6600: train loss 1.7841, val loss 1.9000
# step 6700: train loss 1.7814, val loss 1.9058
# step 6800: train loss 1.7894, val loss 1.9186
# step 6900: train loss 1.7850, val loss 1.9047
# step 7000: train loss 1.7782, val loss 1.9035
# step 7100: train loss 1.7865, val loss 1.9067
# step 7200: train loss 1.7669, val loss 1.9062
# step 7300: train loss 1.7685, val loss 1.8877
# step 7400: train loss 1.7759, val loss 1.9101
# step 7500: train loss 1.7526, val loss 1.8891
# step 7600: train loss 1.7628, val loss 1.9000
# step 7700: train loss 1.7613, val loss 1.8987
# step 7800: train loss 1.7674, val loss 1.8926
# step 7900: train loss 1.7629, val loss 1.9046
# step 8000: train loss 1.7562, val loss 1.8942
# step 8100: train loss 1.7537, val loss 1.8980
# step 8200: train loss 1.7623, val loss 1.8994
# step 8300: train loss 1.7589, val loss 1.8970
# step 8400: train loss 1.7521, val loss 1.8987
# step 8500: train loss 1.7499, val loss 1.8901
# step 8600: train loss 1.7533, val loss 1.8961
# step 8700: train loss 1.7497, val loss 1.9011
# step 8800: train loss 1.7334, val loss 1.8936
# step 8900: train loss 1.7425, val loss 1.8666
# step 9000: train loss 1.7381, val loss 1.8757
# step 9100: train loss 1.7365, val loss 1.8758
# step 9200: train loss 1.7486, val loss 1.8776
# step 9300: train loss 1.7268, val loss 1.8661
# step 9400: train loss 1.7310, val loss 1.8624
# step 9500: train loss 1.7347, val loss 1.8775
# step 9600: train loss 1.7331, val loss 1.8801
# step 9700: train loss 1.7301, val loss 1.8659
# step 9800: train loss 1.7228, val loss 1.8790
# step 9900: train loss 1.7312, val loss 1.8756
# step 9999: train loss 1.7291, val loss 1.8736

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
# plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')

# plt.plot(train_losses_01, label='Train Loss Test 0.01')
plt.plot(val_losses_01, label='Validation Loss Test 0.01')

# plt.plot(train_losses_025, label='Train Loss Test 0.025')
plt.plot(val_losses_025, label='Validation Loss Test 0.025')

# plt.plot(train_losses_05, label='Train Loss Test 0.05')
plt.plot(val_losses_05, label='Validation Loss Test 0.05')

# plt.plot(train_losses_075, label='Train Loss Test 0.075')
plt.plot(val_losses_075, label='Validation Loss Test 0.075')

# plt.plot(train_losses_1, label='Train Loss Test 0.1')
plt.plot(val_losses_1, label='Validation Loss Test 0.1')

# plt.plot(train_losses_125, label='Train Loss Test 0.125')
plt.plot(val_losses_125, label='Validation Loss Test 0.125')

# plt.plot(train_losses_15, label='Train Loss Test 0.15')
plt.plot(val_losses_15, label='Validation Loss Test 0.15')

# plt.plot(train_losses_175, label='Train Loss Test 0.175')
plt.plot(val_losses_175, label='Validation Loss Test 0.175')

# plt.plot(train_losses_2, label='Train Loss Test 0.2')
plt.plot(val_losses_2, label='Validation Loss Test 0.2')


plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
# plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')

# plt.plot(train_losses_01, label='Train Loss Test 0.01')
plt.plot(val_losses_01, label='Validation Loss Test 0.01')

# plt.plot(train_losses_025, label='Train Loss Test 0.025')
plt.plot(val_losses_025, label='Validation Loss Test 0.025')

# plt.plot(train_losses_05, label='Train Loss Test 0.05')
plt.plot(val_losses_05, label='Validation Loss Test 0.05')

# plt.plot(train_losses_075, label='Train Loss Test 0.075')
plt.plot(val_losses_075, label='Validation Loss Test 0.075')

# plt.plot(train_losses_1, label='Train Loss Test 0.1')
plt.plot(val_losses_1, label='Validation Loss Test 0.1')

# plt.plot(train_losses_125, label='Train Loss Test 0.125')
plt.plot(val_losses_125, label='Validation Loss Test 0.125')

# plt.plot(train_losses_15, label='Train Loss Test 0.15')
plt.plot(val_losses_15, label='Validation Loss Test 0.15')

# plt.plot(train_losses_175, label='Train Loss Test 0.175')
plt.plot(val_losses_175, label='Validation Loss Test 0.175')

# plt.plot(train_losses_2, label='Train Loss Test 0.2')
plt.plot(val_losses_2, label='Validation Loss Test 0.2')


plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
# plt.show()

# Focus on the latter half of the iterations
num_iterations = len(val_losses_original)  # Use the actual number of iterations
start_point = num_iterations // 2  # Starting from the halfway point

plt.xlim(start_point, num_iterations)  # Set x-axis limits to focus on the latter half

# Adjusting the y-axis range
# Calculate the maximum and minimum loss values in the focused range
max_loss = max(max(val_losses_original[start_point:]),
               max(val_losses_01[start_point:]),
               max(val_losses_025[start_point:]),
               max(val_losses_05[start_point:]),
               max(val_losses_075[start_point:]),
               max(val_losses_1[start_point:]),
               max(val_losses_125[start_point:]),
               max(val_losses_15[start_point:]),
               max(val_losses_175[start_point:]),
               max(val_losses_2[start_point:]))


min_loss = min(min(val_losses_original[start_point:]),
               min(val_losses_01[start_point:]),
               min(val_losses_025[start_point:]),
               min(val_losses_05[start_point:]),
               min(val_losses_075[start_point:]),
               min(val_losses_1[start_point:]),
               min(val_losses_125[start_point:]),
               min(val_losses_15[start_point:]),
               min(val_losses_175[start_point:]),
               min(val_losses_2[start_point:]))

plt.ylim(min_loss, max_loss)  # Set y-axis limits to enhance the loss variation

# Display the plot
plt.show()
