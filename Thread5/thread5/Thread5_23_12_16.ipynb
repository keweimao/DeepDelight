# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# --2023-12-16 19:36:05--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.1’
#
# input.txt.1         100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2023-12-16 19:36:05 (18.7 MB/s) - ‘input.txt.1’ saved [1115394/1115394]

# %%
# import the package
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.2

# %%
torch.manual_seed(1337)


# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# ### Original code

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_original = []
val_losses_original = []


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_original.append(losses['train'].item())
        val_losses_original.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6677, val loss 2.6603
# step 200: train loss 2.5293, val loss 2.5300
# step 300: train loss 2.4642, val loss 2.4621
# step 400: train loss 2.3982, val loss 2.4110
# step 500: train loss 2.3477, val loss 2.3403
# step 600: train loss 2.3117, val loss 2.3109
# step 700: train loss 2.2697, val loss 2.2759
# step 800: train loss 2.2393, val loss 2.2415
# step 900: train loss 2.2061, val loss 2.2231
# step 1000: train loss 2.1841, val loss 2.1947
# step 1100: train loss 2.1405, val loss 2.1648
# step 1200: train loss 2.1224, val loss 2.1445
# step 1300: train loss 2.1068, val loss 2.1328
# step 1400: train loss 2.0802, val loss 2.1174
# step 1500: train loss 2.0755, val loss 2.1085
# step 1600: train loss 2.0431, val loss 2.1001
# step 1700: train loss 2.0295, val loss 2.0767
# step 1800: train loss 2.0215, val loss 2.0624
# step 1900: train loss 2.0097, val loss 2.0469
# step 2000: train loss 1.9875, val loss 2.0374
# step 2100: train loss 1.9706, val loss 2.0327
# step 2200: train loss 1.9598, val loss 2.0318
# step 2300: train loss 1.9601, val loss 2.0254
# step 2400: train loss 1.9367, val loss 2.0224
# step 2500: train loss 1.9270, val loss 2.0068
# step 2600: train loss 1.9177, val loss 1.9827
# step 2700: train loss 1.9155, val loss 1.9971
# step 2800: train loss 1.9036, val loss 1.9769
# step 2900: train loss 1.8943, val loss 1.9790
# step 3000: train loss 1.8843, val loss 1.9778
# step 3100: train loss 1.8749, val loss 1.9593
# step 3200: train loss 1.8716, val loss 1.9744
# step 3300: train loss 1.8601, val loss 1.9598
# step 3400: train loss 1.8561, val loss 1.9603
# step 3500: train loss 1.8457, val loss 1.9548
# step 3600: train loss 1.8411, val loss 1.9503
# step 3700: train loss 1.8288, val loss 1.9484
# step 3800: train loss 1.8241, val loss 1.9464
# step 3900: train loss 1.8234, val loss 1.9368
# step 4000: train loss 1.8144, val loss 1.9322
# step 4100: train loss 1.8109, val loss 1.9312
# step 4200: train loss 1.8216, val loss 1.9374
# step 4300: train loss 1.8099, val loss 1.9228
# step 4400: train loss 1.8143, val loss 1.9371
# step 4500: train loss 1.7970, val loss 1.9354
# step 4600: train loss 1.7888, val loss 1.9198
# step 4700: train loss 1.7903, val loss 1.9115
# step 4800: train loss 1.7937, val loss 1.9214
# step 4900: train loss 1.7799, val loss 1.9160
# step 5000: train loss 1.7823, val loss 1.8994
# step 5100: train loss 1.7774, val loss 1.9070
# step 5200: train loss 1.7653, val loss 1.9123
# step 5300: train loss 1.7789, val loss 1.9076
# step 5400: train loss 1.7667, val loss 1.8985
# step 5500: train loss 1.7466, val loss 1.8826
# step 5600: train loss 1.7522, val loss 1.8841
# step 5700: train loss 1.7552, val loss 1.8964
# step 5800: train loss 1.7519, val loss 1.8922
# step 5900: train loss 1.7565, val loss 1.8850
# step 6000: train loss 1.7476, val loss 1.8861
# step 6100: train loss 1.7445, val loss 1.8825
# step 6200: train loss 1.7452, val loss 1.8888
# step 6300: train loss 1.7411, val loss 1.8946
# step 6400: train loss 1.7364, val loss 1.8700
# step 6500: train loss 1.7327, val loss 1.8821
# step 6600: train loss 1.7183, val loss 1.8619
# step 6700: train loss 1.7287, val loss 1.8810
# step 6800: train loss 1.7274, val loss 1.8703
# step 6900: train loss 1.7266, val loss 1.8691
# step 7000: train loss 1.7156, val loss 1.8807
# step 7100: train loss 1.7156, val loss 1.8719
# step 7200: train loss 1.7187, val loss 1.8657
# step 7300: train loss 1.7213, val loss 1.8546
# step 7400: train loss 1.7104, val loss 1.8531
# step 7500: train loss 1.7165, val loss 1.8683
# step 7600: train loss 1.7099, val loss 1.8580
# step 7700: train loss 1.7176, val loss 1.8556
# step 7800: train loss 1.7101, val loss 1.8469
# step 7900: train loss 1.6911, val loss 1.8637
# step 8000: train loss 1.7027, val loss 1.8574
# step 8100: train loss 1.7025, val loss 1.8515
# step 8200: train loss 1.7065, val loss 1.8447
# step 8300: train loss 1.6884, val loss 1.8387
# step 8400: train loss 1.6977, val loss 1.8578
# step 8500: train loss 1.6957, val loss 1.8494
# step 8600: train loss 1.6864, val loss 1.8439
# step 8700: train loss 1.6904, val loss 1.8427
# step 8800: train loss 1.7024, val loss 1.8458
# step 8900: train loss 1.6886, val loss 1.8486
# step 9000: train loss 1.6815, val loss 1.8444
# step 9100: train loss 1.6862, val loss 1.8279
# step 9200: train loss 1.6799, val loss 1.8442
# step 9300: train loss 1.6784, val loss 1.8454
# step 9400: train loss 1.6777, val loss 1.8486
# step 9500: train loss 1.6789, val loss 1.8554
# step 9600: train loss 1.6850, val loss 1.8222
# step 9700: train loss 1.6789, val loss 1.8152
# step 9800: train loss 1.6599, val loss 1.8251
# step 9900: train loss 1.6734, val loss 1.8239
# step 9999: train loss 1.6695, val loss 1.8364

# %% [markdown]
# ### Train with 0.01 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.01):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_01 = []
val_losses_01 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_01.append(losses['train'].item())
        val_losses_01.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6774, val loss 2.6770
# step 200: train loss 2.5235, val loss 2.5385
# step 300: train loss 2.4515, val loss 2.4569
# step 400: train loss 2.3863, val loss 2.3921
# step 500: train loss 2.3404, val loss 2.3551
# step 600: train loss 2.3100, val loss 2.3268
# step 700: train loss 2.2768, val loss 2.2816
# step 800: train loss 2.2392, val loss 2.2521
# step 900: train loss 2.1973, val loss 2.2119
# step 1000: train loss 2.1828, val loss 2.1884
# step 1100: train loss 2.1478, val loss 2.1814
# step 1200: train loss 2.1288, val loss 2.1493
# step 1300: train loss 2.1034, val loss 2.1406
# step 1400: train loss 2.0891, val loss 2.1131
# step 1500: train loss 2.0624, val loss 2.1120
# step 1600: train loss 2.0483, val loss 2.0890
# step 1700: train loss 2.0325, val loss 2.0748
# step 1800: train loss 2.0136, val loss 2.0605
# step 1900: train loss 2.0004, val loss 2.0460
# step 2000: train loss 1.9971, val loss 2.0474
# step 2100: train loss 1.9817, val loss 2.0470
# step 2200: train loss 1.9520, val loss 2.0301
# step 2300: train loss 1.9485, val loss 2.0117
# step 2400: train loss 1.9479, val loss 2.0022
# step 2500: train loss 1.9301, val loss 2.0107
# step 2600: train loss 1.9256, val loss 1.9941
# step 2700: train loss 1.9080, val loss 2.0041
# step 2800: train loss 1.9081, val loss 1.9937
# step 2900: train loss 1.8905, val loss 1.9715
# step 3000: train loss 1.8818, val loss 1.9760
# step 3100: train loss 1.8797, val loss 1.9649
# step 3200: train loss 1.8661, val loss 1.9609
# step 3300: train loss 1.8686, val loss 1.9489
# step 3400: train loss 1.8596, val loss 1.9547
# step 3500: train loss 1.8465, val loss 1.9486
# step 3600: train loss 1.8468, val loss 1.9372
# step 3700: train loss 1.8348, val loss 1.9321
# step 3800: train loss 1.8384, val loss 1.9438
# step 3900: train loss 1.8352, val loss 1.9332
# step 4000: train loss 1.8334, val loss 1.9433
# step 4100: train loss 1.8336, val loss 1.9327
# step 4200: train loss 1.8234, val loss 1.9310
# step 4300: train loss 1.8130, val loss 1.9254
# step 4400: train loss 1.7993, val loss 1.9249
# step 4500: train loss 1.7958, val loss 1.9233
# step 4600: train loss 1.8010, val loss 1.9119
# step 4700: train loss 1.7903, val loss 1.9080
# step 4800: train loss 1.7843, val loss 1.9189
# step 4900: train loss 1.7814, val loss 1.9033
# step 5000: train loss 1.7845, val loss 1.9084
# step 5100: train loss 1.7699, val loss 1.9180
# step 5200: train loss 1.7685, val loss 1.8967
# step 5300: train loss 1.7618, val loss 1.8959
# step 5400: train loss 1.7758, val loss 1.9085
# step 5500: train loss 1.7573, val loss 1.8978
# step 5600: train loss 1.7701, val loss 1.9014
# step 5700: train loss 1.7590, val loss 1.9023
# step 5800: train loss 1.7519, val loss 1.8974
# step 5900: train loss 1.7551, val loss 1.8796
# step 6000: train loss 1.7535, val loss 1.8930
# step 6100: train loss 1.7564, val loss 1.8908
# step 6200: train loss 1.7532, val loss 1.8847
# step 6300: train loss 1.7312, val loss 1.8794
# step 6400: train loss 1.7500, val loss 1.8877
# step 6500: train loss 1.7297, val loss 1.8833
# step 6600: train loss 1.7339, val loss 1.8888
# step 6700: train loss 1.7315, val loss 1.8735
# step 6800: train loss 1.7267, val loss 1.8757
# step 6900: train loss 1.7284, val loss 1.8827
# step 7000: train loss 1.7224, val loss 1.8826
# step 7100: train loss 1.7374, val loss 1.8673
# step 7200: train loss 1.7235, val loss 1.8729
# step 7300: train loss 1.7172, val loss 1.8698
# step 7400: train loss 1.7173, val loss 1.8602
# step 7500: train loss 1.7160, val loss 1.8556
# step 7600: train loss 1.7246, val loss 1.8811
# step 7700: train loss 1.7036, val loss 1.8578

# %% [markdown]
# ### Train with 0.2 residual connection dropout rate

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.2):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_2 = []
val_losses_2 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_2.append(losses['train'].item())
        val_losses_2.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6986, val loss 2.6985
# step 200: train loss 2.5389, val loss 2.5543
# step 300: train loss 2.4728, val loss 2.4759
# step 400: train loss 2.4122, val loss 2.4169
# step 500: train loss 2.3655, val loss 2.3792
# step 600: train loss 2.3352, val loss 2.3500
# step 700: train loss 2.3037, val loss 2.3058
# step 800: train loss 2.2761, val loss 2.2841
# step 900: train loss 2.2359, val loss 2.2466
# step 1000: train loss 2.2227, val loss 2.2214
# step 1100: train loss 2.1836, val loss 2.2116
# step 1200: train loss 2.1738, val loss 2.1854
# step 1300: train loss 2.1496, val loss 2.1795
# step 1400: train loss 2.1354, val loss 2.1496
# step 1500: train loss 2.1065, val loss 2.1427
# step 1600: train loss 2.0999, val loss 2.1278
# step 1700: train loss 2.0832, val loss 2.1126
# step 1800: train loss 2.0632, val loss 2.0972
# step 1900: train loss 2.0531, val loss 2.0865
# step 2000: train loss 2.0518, val loss 2.0856
# step 2100: train loss 2.0368, val loss 2.0870
# step 2200: train loss 2.0097, val loss 2.0737
# step 2300: train loss 2.0041, val loss 2.0534
# step 2400: train loss 2.0040, val loss 2.0470
# step 2500: train loss 1.9887, val loss 2.0464
# step 2600: train loss 1.9819, val loss 2.0341
# step 2700: train loss 1.9639, val loss 2.0413
# step 2800: train loss 1.9672, val loss 2.0303
# step 2900: train loss 1.9504, val loss 2.0177
# step 3000: train loss 1.9441, val loss 2.0195
# step 3100: train loss 1.9393, val loss 2.0063
# step 3200: train loss 1.9306, val loss 2.0032
# step 3300: train loss 1.9344, val loss 1.9956
# step 3400: train loss 1.9205, val loss 1.9960
# step 3500: train loss 1.9064, val loss 1.9904
# step 3600: train loss 1.9096, val loss 1.9790
# step 3700: train loss 1.8944, val loss 1.9742
# step 3800: train loss 1.9022, val loss 1.9854
# step 3900: train loss 1.8993, val loss 1.9792
# step 4000: train loss 1.8956, val loss 1.9875
# step 4100: train loss 1.8975, val loss 1.9747
# step 4200: train loss 1.8835, val loss 1.9679
# step 4300: train loss 1.8783, val loss 1.9649
# step 4400: train loss 1.8652, val loss 1.9689
# step 4500: train loss 1.8629, val loss 1.9619
# step 4600: train loss 1.8666, val loss 1.9515
# step 4700: train loss 1.8566, val loss 1.9484
# step 4800: train loss 1.8546, val loss 1.9673
# step 4900: train loss 1.8449, val loss 1.9415
# step 5000: train loss 1.8488, val loss 1.9457
# step 5100: train loss 1.8313, val loss 1.9503
# step 5200: train loss 1.8314, val loss 1.9416
# step 5300: train loss 1.8246, val loss 1.9392
# step 5400: train loss 1.8387, val loss 1.9472
# step 5500: train loss 1.8231, val loss 1.9378
# step 5600: train loss 1.8308, val loss 1.9442
# step 5700: train loss 1.8210, val loss 1.9439
# step 5800: train loss 1.8194, val loss 1.9380
# step 5900: train loss 1.8176, val loss 1.9235
# step 6000: train loss 1.8129, val loss 1.9318
# step 6100: train loss 1.8164, val loss 1.9261
# step 6200: train loss 1.8115, val loss 1.9208
# step 6300: train loss 1.7939, val loss 1.9182
# step 6400: train loss 1.8087, val loss 1.9226
# step 6500: train loss 1.7944, val loss 1.9210
# step 6600: train loss 1.7966, val loss 1.9244
# step 6700: train loss 1.7911, val loss 1.9047
# step 6800: train loss 1.7855, val loss 1.9162
# step 6900: train loss 1.7912, val loss 1.9248
# step 7000: train loss 1.7833, val loss 1.9251
# step 7100: train loss 1.7985, val loss 1.9108
# step 7200: train loss 1.7868, val loss 1.9181
# step 7300: train loss 1.7777, val loss 1.9124
# step 7400: train loss 1.7766, val loss 1.9004
# step 7500: train loss 1.7719, val loss 1.8964
# step 7600: train loss 1.7795, val loss 1.9114
# step 7700: train loss 1.7632, val loss 1.9020
# step 7800: train loss 1.7681, val loss 1.9059
# step 7900: train loss 1.7703, val loss 1.8955
# step 8000: train loss 1.7670, val loss 1.9013
# step 8100: train loss 1.7671, val loss 1.8996
# step 8200: train loss 1.7547, val loss 1.8881
# step 8300: train loss 1.7637, val loss 1.8924
# step 8400: train loss 1.7543, val loss 1.9005
# step 8500: train loss 1.7631, val loss 1.8830
# step 8600: train loss 1.7518, val loss 1.8945
# step 8700: train loss 1.7511, val loss 1.9099
# step 8800: train loss 1.7426, val loss 1.9056
# step 8900: train loss 1.7461, val loss 1.8874
# step 9000: train loss 1.7518, val loss 1.8942
# step 9100: train loss 1.7309, val loss 1.8949
# step 9200: train loss 1.7424, val loss 1.8919
# step 9300: train loss 1.7366, val loss 1.9004
# step 9400: train loss 1.7391, val loss 1.8899

# %% [markdown]
# ### Train with 0.5 residual connection dropout rate

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.5):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_5 = []
val_losses_5 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_5.append(losses['train'].item())
        val_losses_5.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# # generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.7622, val loss 2.7644
# step 200: train loss 2.5760, val loss 2.5907
# step 300: train loss 2.5172, val loss 2.5163
# step 400: train loss 2.4656, val loss 2.4717
# step 500: train loss 2.4244, val loss 2.4345
# step 600: train loss 2.3915, val loss 2.4046
# step 700: train loss 2.3666, val loss 2.3647
# step 800: train loss 2.3415, val loss 2.3476
# step 900: train loss 2.3075, val loss 2.3139
# step 1000: train loss 2.3021, val loss 2.2997
# step 1100: train loss 2.2604, val loss 2.2814
# step 1200: train loss 2.2536, val loss 2.2601
# step 1300: train loss 2.2309, val loss 2.2504
# step 1400: train loss 2.2212, val loss 2.2320
# step 1500: train loss 2.1924, val loss 2.2199
# step 1600: train loss 2.1946, val loss 2.2102
# step 1700: train loss 2.1720, val loss 2.1915
# step 1800: train loss 2.1555, val loss 2.1746
# step 1900: train loss 2.1482, val loss 2.1704
# step 2000: train loss 2.1474, val loss 2.1673
# step 2100: train loss 2.1374, val loss 2.1661
# step 2200: train loss 2.1087, val loss 2.1532
# step 2300: train loss 2.1057, val loss 2.1434
# step 2400: train loss 2.1073, val loss 2.1335
# step 2500: train loss 2.0861, val loss 2.1292
# step 2600: train loss 2.0852, val loss 2.1185
# step 2700: train loss 2.0662, val loss 2.1227
# step 2800: train loss 2.0723, val loss 2.1191
# step 2900: train loss 2.0589, val loss 2.1042
# step 3000: train loss 2.0463, val loss 2.0949
# step 3100: train loss 2.0429, val loss 2.0912
# step 3200: train loss 2.0358, val loss 2.0834
# step 3300: train loss 2.0371, val loss 2.0790
# step 3400: train loss 2.0297, val loss 2.0784
# step 3500: train loss 2.0099, val loss 2.0645
# step 3600: train loss 2.0164, val loss 2.0577
# step 3700: train loss 1.9962, val loss 2.0567
# step 3800: train loss 2.0079, val loss 2.0658
# step 3900: train loss 2.0015, val loss 2.0511
# step 4000: train loss 1.9981, val loss 2.0552
# step 4100: train loss 2.0001, val loss 2.0504
# step 4200: train loss 1.9879, val loss 2.0457
# step 4300: train loss 1.9817, val loss 2.0448
# step 4400: train loss 1.9709, val loss 2.0465
# step 4500: train loss 1.9675, val loss 2.0363
# step 4600: train loss 1.9735, val loss 2.0287
# step 4700: train loss 1.9590, val loss 2.0212
# step 4800: train loss 1.9562, val loss 2.0370
# step 4900: train loss 1.9501, val loss 2.0176
# step 5000: train loss 1.9543, val loss 2.0245
# step 5100: train loss 1.9392, val loss 2.0246
# step 5200: train loss 1.9358, val loss 2.0165
# step 5300: train loss 1.9334, val loss 2.0162
# step 5400: train loss 1.9424, val loss 2.0210
# step 5500: train loss 1.9303, val loss 2.0143
# step 5600: train loss 1.9348, val loss 2.0116
# step 5700: train loss 1.9234, val loss 2.0145
# step 5800: train loss 1.9171, val loss 2.0052
# step 5900: train loss 1.9237, val loss 1.9952
# step 6000: train loss 1.9139, val loss 2.0019
# step 6100: train loss 1.9191, val loss 1.9931
# step 6200: train loss 1.9126, val loss 1.9919
# step 6300: train loss 1.8977, val loss 1.9874
# step 6400: train loss 1.9130, val loss 1.9971
# step 6500: train loss 1.9016, val loss 1.9970
# step 6600: train loss 1.9000, val loss 2.0011
# step 6700: train loss 1.8946, val loss 1.9789
# step 6800: train loss 1.8917, val loss 1.9932
# step 6900: train loss 1.8946, val loss 2.0004
# step 7000: train loss 1.8898, val loss 1.9931
# step 7100: train loss 1.8982, val loss 1.9811
# step 7200: train loss 1.8883, val loss 1.9869
# step 7300: train loss 1.8803, val loss 1.9821
# step 7400: train loss 1.8791, val loss 1.9699
# step 7500: train loss 1.8720, val loss 1.9663
# step 7600: train loss 1.8835, val loss 1.9786
# step 7700: train loss 1.8651, val loss 1.9697
# step 7800: train loss 1.8706, val loss 1.9772
# step 7900: train loss 1.8753, val loss 1.9705
# step 8000: train loss 1.8714, val loss 1.9674
# step 8100: train loss 1.8742, val loss 1.9737
# step 8200: train loss 1.8569, val loss 1.9558
# step 8300: train loss 1.8621, val loss 1.9564
# step 8400: train loss 1.8514, val loss 1.9618
# step 8500: train loss 1.8632, val loss 1.9502
# step 8600: train loss 1.8520, val loss 1.9593
# step 8700: train loss 1.8529, val loss 1.9753
# step 8800: train loss 1.8434, val loss 1.9717

# %% [markdown]
# ### Train with 0.9 residual connection dropout

# %%
torch.manual_seed(1337)

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.9):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_9 = []
val_losses_9 = []


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_9.append(losses['train'].item())
        val_losses_9.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
# context = torch.zeros((1, 1), dtype=torch.long, device=device)
# print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 3.1329, val loss 3.1561
# step 200: train loss 2.8113, val loss 2.8406
# step 300: train loss 2.6662, val loss 2.6718
# step 400: train loss 2.6069, val loss 2.6155
# step 500: train loss 2.5669, val loss 2.5800
# step 600: train loss 2.5520, val loss 2.5604
# step 700: train loss 2.5303, val loss 2.5331
# step 800: train loss 2.5087, val loss 2.5148
# step 900: train loss 2.4893, val loss 2.4964
# step 1000: train loss 2.4832, val loss 2.4785
# step 1100: train loss 2.4557, val loss 2.4706
# step 1200: train loss 2.4483, val loss 2.4552
# step 1300: train loss 2.4345, val loss 2.4496
# step 1400: train loss 2.4327, val loss 2.4360
# step 1500: train loss 2.4022, val loss 2.4178
# step 1600: train loss 2.3979, val loss 2.4036
# step 1700: train loss 2.3838, val loss 2.3987
# step 1800: train loss 2.3708, val loss 2.3825
# step 1900: train loss 2.3578, val loss 2.3690
# step 2000: train loss 2.3542, val loss 2.3634
# step 2100: train loss 2.3432, val loss 2.3494
# step 2200: train loss 2.3276, val loss 2.3528
# step 2300: train loss 2.3175, val loss 2.3380
# step 2400: train loss 2.3200, val loss 2.3291
# step 2500: train loss 2.3073, val loss 2.3282
# step 2600: train loss 2.3030, val loss 2.3187
# step 2700: train loss 2.2909, val loss 2.3191
# step 2800: train loss 2.2932, val loss 2.3179
# step 2900: train loss 2.2846, val loss 2.3024
# step 3000: train loss 2.2722, val loss 2.2919
# step 3100: train loss 2.2708, val loss 2.2901
# step 3200: train loss 2.2708, val loss 2.2879
# step 3300: train loss 2.2681, val loss 2.2782
# step 3400: train loss 2.2598, val loss 2.2801
# step 3500: train loss 2.2483, val loss 2.2701
# step 3600: train loss 2.2506, val loss 2.2636
# step 3700: train loss 2.2358, val loss 2.2590
# step 3800: train loss 2.2422, val loss 2.2649
# step 3900: train loss 2.2427, val loss 2.2563
# step 4000: train loss 2.2362, val loss 2.2590
# step 4100: train loss 2.2344, val loss 2.2518
# step 4200: train loss 2.2290, val loss 2.2446
# step 4300: train loss 2.2249, val loss 2.2433
# step 4400: train loss 2.2125, val loss 2.2411
# step 4500: train loss 2.2181, val loss 2.2436
# step 4600: train loss 2.2186, val loss 2.2322
# step 4700: train loss 2.2089, val loss 2.2245
# step 4800: train loss 2.2039, val loss 2.2377

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
# plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')

# plt.plot(train_losses_01, label='Train Loss Test 0.01')
plt.plot(val_losses_01, label='Validation Loss Test 0.01')

# plt.plot(train_losses_2, label='Train Loss Test 0.2')
plt.plot(val_losses_2, label='Validation Loss Test 0.2')

# plt.plot(train_losses_2, label='Train Loss Test 0.5')
plt.plot(val_losses_5, label='Validation Loss Test 0.5')

# plt.plot(train_losses_2, label='Train Loss Test 0.9')
plt.plot(val_losses_9, label='Validation Loss Test 0.9')

plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
# plt.show()

# Focus on the latter half of the iterations
num_iterations = len(val_losses_original)  # Use the actual number of iterations
start_point = num_iterations // 2  # Starting from the halfway point

plt.xlim(start_point, num_iterations)  # Set x-axis limits to focus on the latter half

# Adjusting the y-axis range
# Calculate the maximum and minimum loss values in the focused range
max_loss = max(max(val_losses_original[start_point:]), max(val_losses_01[start_point:]), max(val_losses_2[start_point:]), max(val_losses_5[start_point:]), max(val_losses_9[start_point:]))
min_loss = min(min(val_losses_original[start_point:]), min(val_losses_01[start_point:]), min(val_losses_2[start_point:]), max(val_losses_5[start_point:]), min(val_losses_9[start_point:]))

plt.ylim(min_loss, max_loss)  # Set y-axis limits to enhance the loss variation

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 5))
# plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')

# plt.plot(train_losses_01, label='Train Loss Test 0.01')
plt.plot(val_losses_01, label='Validation Loss Test 0.01')

# plt.plot(train_losses_2, label='Train Loss Test 0.2')
plt.plot(val_losses_2, label='Validation Loss Test 0.2')

# plt.plot(train_losses_2, label='Train Loss Test 0.5')
plt.plot(val_losses_5, label='Validation Loss Test 0.5')

# plt.plot(train_losses_2, label='Train Loss Test 0.9')
plt.plot(val_losses_9, label='Validation Loss Test 0.9')

plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
plt.show()
