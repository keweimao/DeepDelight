# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# --2023-12-14 23:38:50--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.3’
#
# input.txt.3         100%[===================>]   1.06M  --.-KB/s    in 0.05s
#
# 2023-12-14 23:38:50 (21.9 MB/s) - ‘input.txt.3’ saved [1115394/1115394]

# %%
# import the package
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.2

# %%
torch.manual_seed(1337)


# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# ### Original code

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_original = []
val_losses_original = []


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_original.append(losses['train'].item())
        val_losses_original.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6677, val loss 2.6603
# step 200: train loss 2.5293, val loss 2.5300
# step 300: train loss 2.4642, val loss 2.4621
# step 400: train loss 2.3982, val loss 2.4110
# step 500: train loss 2.3477, val loss 2.3403
# step 600: train loss 2.3117, val loss 2.3109
# step 700: train loss 2.2697, val loss 2.2759
# step 800: train loss 2.2393, val loss 2.2415
# step 900: train loss 2.2061, val loss 2.2231
# step 1000: train loss 2.1841, val loss 2.1947
# step 1100: train loss 2.1405, val loss 2.1648
# step 1200: train loss 2.1224, val loss 2.1445
# step 1300: train loss 2.1068, val loss 2.1328
# step 1400: train loss 2.0802, val loss 2.1174
# step 1500: train loss 2.0755, val loss 2.1085
# step 1600: train loss 2.0431, val loss 2.1001
# step 1700: train loss 2.0295, val loss 2.0767
# step 1800: train loss 2.0215, val loss 2.0624
# step 1900: train loss 2.0097, val loss 2.0469
# step 2000: train loss 1.9875, val loss 2.0374
# step 2100: train loss 1.9706, val loss 2.0327
# step 2200: train loss 1.9598, val loss 2.0318
# step 2300: train loss 1.9601, val loss 2.0254
# step 2400: train loss 1.9367, val loss 2.0224
# step 2500: train loss 1.9270, val loss 2.0068
# step 2600: train loss 1.9177, val loss 1.9827
# step 2700: train loss 1.9155, val loss 1.9971
# step 2800: train loss 1.9036, val loss 1.9769
# step 2900: train loss 1.8943, val loss 1.9790
# step 3000: train loss 1.8843, val loss 1.9778
# step 3100: train loss 1.8749, val loss 1.9593
# step 3200: train loss 1.8716, val loss 1.9744
# step 3300: train loss 1.8601, val loss 1.9598
# step 3400: train loss 1.8561, val loss 1.9603
# step 3500: train loss 1.8457, val loss 1.9548
# step 3600: train loss 1.8411, val loss 1.9503
# step 3700: train loss 1.8288, val loss 1.9484
# step 3800: train loss 1.8241, val loss 1.9464
# step 3900: train loss 1.8234, val loss 1.9368
# step 4000: train loss 1.8144, val loss 1.9322
# step 4100: train loss 1.8109, val loss 1.9312
# step 4200: train loss 1.8216, val loss 1.9374
# step 4300: train loss 1.8099, val loss 1.9228
# step 4400: train loss 1.8143, val loss 1.9371
# step 4500: train loss 1.7970, val loss 1.9354
# step 4600: train loss 1.7888, val loss 1.9198
# step 4700: train loss 1.7903, val loss 1.9115
# step 4800: train loss 1.7937, val loss 1.9214
# step 4900: train loss 1.7799, val loss 1.9160
# step 5000: train loss 1.7823, val loss 1.8994
# step 5100: train loss 1.7774, val loss 1.9070
# step 5200: train loss 1.7653, val loss 1.9123
# step 5300: train loss 1.7789, val loss 1.9076
# step 5400: train loss 1.7667, val loss 1.8985
# step 5500: train loss 1.7466, val loss 1.8826
# step 5600: train loss 1.7522, val loss 1.8841
# step 5700: train loss 1.7552, val loss 1.8964
# step 5800: train loss 1.7519, val loss 1.8922
# step 5900: train loss 1.7565, val loss 1.8850
# step 6000: train loss 1.7476, val loss 1.8861
# step 6100: train loss 1.7445, val loss 1.8825
# step 6200: train loss 1.7452, val loss 1.8888
# step 6300: train loss 1.7411, val loss 1.8946
# step 6400: train loss 1.7364, val loss 1.8700
# step 6500: train loss 1.7327, val loss 1.8821
# step 6600: train loss 1.7183, val loss 1.8619
# step 6700: train loss 1.7287, val loss 1.8810
# step 6800: train loss 1.7274, val loss 1.8703
# step 6900: train loss 1.7266, val loss 1.8691
# step 7000: train loss 1.7156, val loss 1.8807
# step 7100: train loss 1.7156, val loss 1.8719
# step 7200: train loss 1.7187, val loss 1.8657
# step 7300: train loss 1.7213, val loss 1.8546
# step 7400: train loss 1.7104, val loss 1.8531
# step 7500: train loss 1.7165, val loss 1.8683
# step 7600: train loss 1.7099, val loss 1.8580
# step 7700: train loss 1.7176, val loss 1.8556
# step 7800: train loss 1.7101, val loss 1.8469
# step 7900: train loss 1.6911, val loss 1.8637
# step 8000: train loss 1.7027, val loss 1.8574
# step 8100: train loss 1.7025, val loss 1.8515
# step 8200: train loss 1.7065, val loss 1.8447
# step 8300: train loss 1.6884, val loss 1.8387
# step 8400: train loss 1.6977, val loss 1.8578
# step 8500: train loss 1.6957, val loss 1.8494
# step 8600: train loss 1.6864, val loss 1.8439
# step 8700: train loss 1.6904, val loss 1.8427
# step 8800: train loss 1.7024, val loss 1.8458
# step 8900: train loss 1.6886, val loss 1.8486
# step 9000: train loss 1.6815, val loss 1.8444
# step 9100: train loss 1.6862, val loss 1.8279
# step 9200: train loss 1.6799, val loss 1.8442
# step 9300: train loss 1.6784, val loss 1.8454
# step 9400: train loss 1.6777, val loss 1.8486
# step 9500: train loss 1.6789, val loss 1.8554
# step 9600: train loss 1.6850, val loss 1.8222
# step 9700: train loss 1.6789, val loss 1.8152
# step 9800: train loss 1.6599, val loss 1.8251
# step 9900: train loss 1.6734, val loss 1.8239
# step 9999: train loss 1.6695, val loss 1.8364
#
# Been dead turn youwich me, so-me an turl, no grance abouch wish a be Ware 'stingted a whichies;
# One to sunne beak. A rafaice my lead
# And mandler wome in him lack, thy gruch steady,
# Or,'
# Clorf will worme ban where to spray?
#
# Firse comes to frall not down hath her mear in this with sonquenterous, it wied by like for soland, lord, anged if you prayis are head;
# Nay, I would lift! Where romes he. give
# by our deepings on town mybraca, lorde fan hight:
# God in the lack in son your craise.
#
# PEYLANUS:
# Watch slagion our grumon'de QUize stayouscegedred should hark cherforn whone a powro bragoon? Biningingence of they twart wrom in sothing.
# Thy do warreick, did, if back this math tend.
#
# He WISlower:
# Make want my and here fight binor:
# Radda ease not are dother: knock tall placite to grapt as world 'us mimpeningelf suldelant, longure you hold beands, what our rutht her'sting him good; nig your ful makely handon my haisits
# Nd his some; have this was, you cond;
# Thou like heav imself my foce, in a flind. You mevene me foot sermal cat no
# Wiffe the be Isserves in that foen blord.
#
# PAMPErservod and not:
# Or loste man, rught Good not lew is morde t, this womanio dishall.
#
# KING RICHARD IER:
# The sab brague, but now fatherspicy,
# Which cruld night; in when, his bagore pass find stove womantlesselvar
# ow thos? mine herefirts that wish eldles ring,
# Lut, inate escrefull wark willow,
# Withouble the bring of a planicier, give and litt,
#
# ROMEO:
# Warwas I truld the propsagenguseabe a histry?
#
# COMIO:
# Flemen I will sputs armest-lake thank blought? bawfore you rearthing grip arl stoution; liend douk
# Mors in leman, uNbles nighter a lovens.
#
# WARWICHIO:
# No his mew--eluck your unto of maday sday you rack,--
#
# DUCHESS Of hat his rallEngll'd.
#
# ESBY:
# God not shall somfice your law,
# Thak Riff are ifts great a gonous hearts in pleadd thee
# We frear befixtecty soen the nevous, fights I arm fathee,
# And that this trues? Outs as sile stclausseder'd, fu,
# Are doth thes man.
# Sired mardlecl him of me shoispreck.
#
# Kig to mo

# %% [markdown]
# ### Train with 0.01 residual connection dropout

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.001):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_01 = []
val_losses_01 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_01.append(losses['train'].item())
        val_losses_01.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4349, val loss 4.4382
# step 100: train loss 2.7265, val loss 2.7188
# step 200: train loss 2.5507, val loss 2.5505
# step 300: train loss 2.4642, val loss 2.4730
# step 400: train loss 2.4068, val loss 2.4086
# step 500: train loss 2.3563, val loss 2.3554
# step 600: train loss 2.3126, val loss 2.3319
# step 700: train loss 2.2655, val loss 2.2717
# step 800: train loss 2.2327, val loss 2.2429
# step 900: train loss 2.2121, val loss 2.2179
# step 1000: train loss 2.1779, val loss 2.1916
# step 1100: train loss 2.1541, val loss 2.1813
# step 1200: train loss 2.1235, val loss 2.1571
# step 1300: train loss 2.0965, val loss 2.1458
# step 1400: train loss 2.0835, val loss 2.1137
# step 1500: train loss 2.0648, val loss 2.1105
# step 1600: train loss 2.0545, val loss 2.1019
# step 1700: train loss 2.0390, val loss 2.0826
# step 1800: train loss 2.0157, val loss 2.0678
# step 1900: train loss 2.0013, val loss 2.0416
# step 2000: train loss 1.9931, val loss 2.0628
# step 2100: train loss 1.9789, val loss 2.0363
# step 2200: train loss 1.9694, val loss 2.0367
# step 2300: train loss 1.9496, val loss 2.0210
# step 2400: train loss 1.9427, val loss 2.0273
# step 2500: train loss 1.9351, val loss 2.0129
# step 2600: train loss 1.9128, val loss 1.9992
# step 2700: train loss 1.9151, val loss 1.9985
# step 2800: train loss 1.9138, val loss 2.0039
# step 2900: train loss 1.8944, val loss 1.9811
# step 3000: train loss 1.8839, val loss 1.9836
# step 3100: train loss 1.8878, val loss 1.9838
# step 3200: train loss 1.8725, val loss 1.9693
# step 3300: train loss 1.8685, val loss 1.9579
# step 3400: train loss 1.8639, val loss 1.9683
# step 3500: train loss 1.8588, val loss 1.9623
# step 3600: train loss 1.8447, val loss 1.9595
# step 3700: train loss 1.8436, val loss 1.9545
# step 3800: train loss 1.8561, val loss 1.9465
# step 3900: train loss 1.8291, val loss 1.9402
# step 4000: train loss 1.8297, val loss 1.9395
# step 4100: train loss 1.8254, val loss 1.9339
# step 4200: train loss 1.8151, val loss 1.9353
# step 4300: train loss 1.8100, val loss 1.9409
# step 4400: train loss 1.8006, val loss 1.9231
# step 4500: train loss 1.8029, val loss 1.9263
# step 4600: train loss 1.7950, val loss 1.9289
# step 4700: train loss 1.7839, val loss 1.9226
# step 4800: train loss 1.7909, val loss 1.9167
# step 4900: train loss 1.7952, val loss 1.9116
# step 5000: train loss 1.7813, val loss 1.9051
# step 5100: train loss 1.7801, val loss 1.9076
# step 5200: train loss 1.7772, val loss 1.8984
# step 5300: train loss 1.7645, val loss 1.9028
# step 5400: train loss 1.7758, val loss 1.8943
# step 5500: train loss 1.7690, val loss 1.8936
# step 5600: train loss 1.7635, val loss 1.9093
# step 5700: train loss 1.7509, val loss 1.9010
# step 5800: train loss 1.7578, val loss 1.9053
# step 5900: train loss 1.7555, val loss 1.8957
# step 6000: train loss 1.7342, val loss 1.9004
# step 6100: train loss 1.7422, val loss 1.8879
# step 6200: train loss 1.7369, val loss 1.8870
# step 6300: train loss 1.7406, val loss 1.8733
# step 6400: train loss 1.7402, val loss 1.8856
# step 6500: train loss 1.7427, val loss 1.8742
# step 6600: train loss 1.7289, val loss 1.8633
# step 6700: train loss 1.7190, val loss 1.8767
# step 6800: train loss 1.7295, val loss 1.8761
# step 6900: train loss 1.7183, val loss 1.8679
# step 7000: train loss 1.7339, val loss 1.8784
# step 7100: train loss 1.7200, val loss 1.8669
# step 7200: train loss 1.7175, val loss 1.8822
# step 7300: train loss 1.7156, val loss 1.8681
# step 7400: train loss 1.7059, val loss 1.8667
# step 7500: train loss 1.7126, val loss 1.8570
# step 7600: train loss 1.7042, val loss 1.8703
# step 7700: train loss 1.7112, val loss 1.8576
# step 7800: train loss 1.7058, val loss 1.8724
# step 7900: train loss 1.7074, val loss 1.8635
# step 8000: train loss 1.7081, val loss 1.8436
# step 8100: train loss 1.7033, val loss 1.8564
# step 8200: train loss 1.6907, val loss 1.8402
# step 8300: train loss 1.6879, val loss 1.8611
# step 8400: train loss 1.7014, val loss 1.8540
# step 8500: train loss 1.6964, val loss 1.8432
# step 8600: train loss 1.6949, val loss 1.8589
# step 8700: train loss 1.6828, val loss 1.8409
# step 8800: train loss 1.6888, val loss 1.8436
# step 8900: train loss 1.7008, val loss 1.8431
# step 9000: train loss 1.6776, val loss 1.8408
# step 9100: train loss 1.6992, val loss 1.8421
# step 9200: train loss 1.6910, val loss 1.8294
# step 9300: train loss 1.6815, val loss 1.8598
# step 9400: train loss 1.6770, val loss 1.8360
# step 9500: train loss 1.6816, val loss 1.8504
# step 9600: train loss 1.6797, val loss 1.8363
# step 9700: train loss 1.6810, val loss 1.8362
# step 9800: train loss 1.6774, val loss 1.8337
# step 9900: train loss 1.6709, val loss 1.8330
# step 9999: train loss 1.6856, val loss 1.8286
#
# I'll you him my may heath much to Goder:
# In amal co reast I am that willl be
# hat sweet then I someath nerchosting these army friend
# Tho matishite he aspeep so eye? I, grave madewa?
#
# ISABELLLA:
# Nay, Plarer, and tell.
#
# DUKEN
# They spoke hast
# LEONTES:
# Not his kie, wastle, made lust bown?
#
# Nor how crees; you say seem many of so not, and should aforge's new:
# Herer, hear I sait soult how he plosuress; an wing arl ow I moved
# A love I will be holmsed pat
# Urervious, a dave you fit imband sir-combanen with side the not, you oat.
#
# FRINIUS:
# We oul:
# What now be blesight so I'll say?
#
# ISABELLANUS:
# There 'tis tesity say, I men life for my belife
# buntabunnery vilate, you the wombers.
#
# BRUTUS:
# He'll.
# But for you she lord;
# You not And argived  I his hure my do all worss:
# For him. I will pless is loves datay.
#
# FOLIXlHN VINCUT:
# Feath,' Ye you take, dend braith,
# Hat copers scan regetie.
# I four belar do meajeaciful, as pan'd
# As of Godge me;
# good wortan wake men thy rees or an the heavess yea; thou werd,
# Fiver acklevest and and is swoplease the ser, with you bout the do to boysbay
# Her show his spelf to my love on yor vilo, you be quidens
# As nor' a with; flught mine it sideed!
# Ald devaciester so.
# Whicrible hathed foosen hear ther almines the dead, arful for wind;
# Cor truined, onot yough with and, manised, marry frumpos a mothou chappamines, ye'll but
# Of me, Voyst and by wesven the mun skes within, as it you
# exesedo; her; there, 't?
#
# LRONCESTER:
# Well find you folt were this nignot Warlablaide
# Fathan this love ansbettys'ell as you show you have 'his with.
#
# BUSHISABENONF:
# Go, I casleve sknive, tho how tring, and live one.
#
# POMPEARD:
# And will k's an seat it dave frocess,
# On not frign able. These do celize:
# To, no strine was vower all he carnow as sitterout,
# Det him -norto thou fourst lend Let,
# Nave, as mevient is is us, and pricking: loves, my gaidives,
# Mincow a my to gine more perare eavom?
#
# LETHAMBEPINGBROKE:
# Is my drown spost
# This nore's that of the timend,
# Und I man must dam of your wuth sa

# %% [markdown]
# ### Train with 0.2 residual connection dropout rate

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block with custom residual dropout """

    def __init__(self, n_embd, n_head, residual_dropout=0.001):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.residual_dropout = nn.Dropout(residual_dropout)

    def forward(self, x):
        residual = x
        x = self.sa(self.ln1(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to residual connection
        residual = x
        x = self.ffwd(self.ln2(x))
        x = residual + self.residual_dropout(x)  # Apply custom dropout to another residual connection
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_2 = []
val_losses_2 = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_2.append(losses['train'].item())
        val_losses_2.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.3530, val loss 4.3568
# step 100: train loss 2.6749, val loss 2.7000
# step 200: train loss 2.5244, val loss 2.5356
# step 300: train loss 2.4479, val loss 2.4544
# step 400: train loss 2.3978, val loss 2.4036
# step 500: train loss 2.3539, val loss 2.3632
# step 600: train loss 2.3021, val loss 2.3197
# step 700: train loss 2.2686, val loss 2.2724
# step 800: train loss 2.2324, val loss 2.2513
# step 900: train loss 2.1832, val loss 2.2064
# step 1000: train loss 2.1755, val loss 2.1913
# step 1100: train loss 2.1425, val loss 2.1686
# step 1200: train loss 2.1337, val loss 2.1667
# step 1300: train loss 2.1060, val loss 2.1408
# step 1400: train loss 2.0918, val loss 2.1222
# step 1500: train loss 2.0644, val loss 2.1033
# step 1600: train loss 2.0513, val loss 2.0886
# step 1700: train loss 2.0258, val loss 2.0702
# step 1800: train loss 2.0069, val loss 2.0638
# step 1900: train loss 2.0055, val loss 2.0610
# step 2000: train loss 1.9922, val loss 2.0438
# step 2100: train loss 1.9800, val loss 2.0546
# step 2200: train loss 1.9690, val loss 2.0310
# step 2300: train loss 1.9640, val loss 2.0251
# step 2400: train loss 1.9484, val loss 2.0033
# step 2500: train loss 1.9360, val loss 2.0070
# step 2600: train loss 1.9269, val loss 2.0095
# step 2700: train loss 1.9125, val loss 1.9967
# step 2800: train loss 1.9061, val loss 1.9908
# step 2900: train loss 1.9198, val loss 2.0054
# step 3000: train loss 1.8967, val loss 1.9840
# step 3100: train loss 1.8832, val loss 1.9840
# step 3200: train loss 1.8805, val loss 1.9723
# step 3300: train loss 1.8727, val loss 1.9667
# step 3400: train loss 1.8574, val loss 1.9595
# step 3500: train loss 1.8568, val loss 1.9574
# step 3600: train loss 1.8520, val loss 1.9656
# step 3700: train loss 1.8504, val loss 1.9530
# step 3800: train loss 1.8454, val loss 1.9402
# step 3900: train loss 1.8342, val loss 1.9475
# step 4000: train loss 1.8254, val loss 1.9463
# step 4100: train loss 1.8238, val loss 1.9414
# step 4200: train loss 1.8096, val loss 1.9381
# step 4300: train loss 1.8142, val loss 1.9463
# step 4400: train loss 1.8054, val loss 1.9253
# step 4500: train loss 1.8074, val loss 1.9302
# step 4600: train loss 1.7970, val loss 1.9324
# step 4700: train loss 1.7917, val loss 1.9128
# step 4800: train loss 1.7985, val loss 1.9254
# step 4900: train loss 1.7906, val loss 1.9170
# step 5000: train loss 1.7835, val loss 1.9177
# step 5100: train loss 1.7768, val loss 1.9030
# step 5200: train loss 1.7890, val loss 1.9087
# step 5300: train loss 1.7818, val loss 1.9152
# step 5400: train loss 1.7700, val loss 1.9156
# step 5500: train loss 1.7522, val loss 1.8787
# step 5600: train loss 1.7572, val loss 1.8913
# step 5700: train loss 1.7528, val loss 1.9015
# step 5800: train loss 1.7490, val loss 1.8817
# step 5900: train loss 1.7486, val loss 1.8802
# step 6000: train loss 1.7468, val loss 1.8845
# step 6100: train loss 1.7500, val loss 1.8863
# step 6200: train loss 1.7326, val loss 1.8732
# step 6300: train loss 1.7428, val loss 1.8839
# step 6400: train loss 1.7372, val loss 1.8871
# step 6500: train loss 1.7420, val loss 1.8845
# step 6600: train loss 1.7237, val loss 1.8790
# step 6700: train loss 1.7388, val loss 1.8780
# step 6800: train loss 1.7352, val loss 1.8772
# step 6900: train loss 1.7403, val loss 1.8656
# step 7000: train loss 1.7150, val loss 1.8800
# step 7100: train loss 1.7230, val loss 1.8693
# step 7200: train loss 1.7311, val loss 1.8637
# step 7300: train loss 1.7301, val loss 1.8724
# step 7400: train loss 1.7266, val loss 1.8462
# step 7500: train loss 1.7206, val loss 1.8619
# step 7600: train loss 1.7082, val loss 1.8561
# step 7700: train loss 1.7035, val loss 1.8496
# step 7800: train loss 1.7196, val loss 1.8463
# step 7900: train loss 1.6918, val loss 1.8427
# step 8000: train loss 1.6993, val loss 1.8534
# step 8100: train loss 1.7049, val loss 1.8450
# step 8200: train loss 1.7048, val loss 1.8448
# step 8300: train loss 1.7010, val loss 1.8543
# step 8400: train loss 1.7089, val loss 1.8541
# step 8500: train loss 1.6987, val loss 1.8668
# step 8600: train loss 1.6899, val loss 1.8561
# step 8700: train loss 1.6961, val loss 1.8439
# step 8800: train loss 1.6868, val loss 1.8534
# step 8900: train loss 1.6944, val loss 1.8394
# step 9000: train loss 1.6832, val loss 1.8478
# step 9100: train loss 1.6829, val loss 1.8443
# step 9200: train loss 1.6785, val loss 1.8569
# step 9300: train loss 1.6759, val loss 1.8539
# step 9400: train loss 1.6815, val loss 1.8466
# step 9500: train loss 1.6767, val loss 1.8472
# step 9600: train loss 1.6830, val loss 1.8372
# step 9700: train loss 1.6846, val loss 1.8393
# step 9800: train loss 1.6711, val loss 1.8313
# step 9900: train loss 1.6686, val loss 1.8414
# step 9999: train loss 1.6677, val loss 1.8456
#
# YORK:
# Shor no, oucch and it not with the halm.
# staress perfery no seconce To his how now you,
# What which I wwell to in make of the kince;
# To not trult fice, and riptulne?
# At Huthen will thy kindid how
# wert pithis them trake toought soe.
#
# QUEE:
# And much earst fell Helpile, befell'd noble greads she wilch may feary sisted goors here burgerd, which do hiMher. Tall in--Till
# your dove oness sectendy, tohees
# in to gind lips reby the very padons dispeak,
# Sposs For when my runt Andiefs Milk neip offenct her noble is forg it is to tended
# Thirs art subt true, picdences chentred thinknowbring
# The pate more and fing and him.
#
# GLOUCESTER:
# Will thou soulther give well prayself is Clet know first them me!
# I'lt knockel ling your and of hir sun, I here Dukne?
# Cordon honds
# Becan, steal his he not so-strack not Cun.
#
# FLORIANTES:
# I to fair But I'll smy immorth are's infricks,
# Wen.
# Why, that onch in to abe near,
# But pieriends did lockle thou feel
# What in is reated from in 'fon eather my this neyd, what she be for Leer.
#
# JULIET:
# Distice, if here yould
# Am and spervery is cumeiven min,
# York dewer: no then. I destyalts,
# And she milt the hast-d hat in are himself, it oumit.
# Ah till py sworrd you, And too now again.
#
# PLIRET:
# My before the peep issictly sothale him sach;
# Aughty comes your will seel.
# Ow why siteel; his and stay's felly will your pervicg faide; foul my non from I s, gendle, he sack thing, and carvice.
#
# MENROMEY:
# Cain yours, Caurinst all unturn, and with endeed a my whuch
# Stairs and sto? Dows his noill, posd your then of what stile the back tul be park, why much at ensult ell where brouds
# And corninks cheger othin will me, grum, and you are soes trorne incoln, the sence!
# Whe
# 'tis most wid his gore your the enfees to from-Forrop!
# To you, baringly and do ingears and with By
# Lo, besated my fides leether hast a howixady to the perdes adisce,
# Hath neen thee,, on, wefes Nows,
# By grom what great arshad, and Fring have will to e meav:
# Sill knavangmany his you be pressece the heave let th

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
# plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')
# plt.plot(train_losses_01, label='Train Loss Test 0.01')
plt.plot(val_losses_01, label='Validation Loss Test 0.01')
# plt.plot(train_losses_2, label='Train Loss Test 0.2')
plt.plot(val_losses_2, label='Validation Loss Test 0.2')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
# plt.show()

# Focus on the latter half of the iterations
num_iterations = len(val_losses_original)  # Use the actual number of iterations
start_point = num_iterations // 2  # Starting from the halfway point

plt.xlim(start_point, num_iterations)  # Set x-axis limits to focus on the latter half

# Adjusting the y-axis range
# Calculate the maximum and minimum loss values in the focused range
max_loss = max(max(val_losses_original[start_point:]), max(val_losses_01[start_point:]), max(val_losses_2[start_point:]))
min_loss = min(min(val_losses_original[start_point:]), min(val_losses_01[start_point:]), min(val_losses_2[start_point:]))

plt.ylim(min_loss, max_loss)  # Set y-axis limits to enhance the loss variation

# Display the plot
plt.show()
