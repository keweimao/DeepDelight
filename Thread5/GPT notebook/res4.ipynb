# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 2
ff_dropout = 0.2
attn_dropout = 0.2

# %%
torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('./input/tinyshakespeare.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(attn_dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(attn_dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(ff_dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head, res1_dropout, res2_dropout, res4_dropout):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa1 = MultiHeadAttention(n_head, head_size)
        self.sa2 = MultiHeadAttention(n_head, head_size)
        self.ffwd1 = FeedFoward(n_embd)
        self.ffwd2 = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.ln3 = nn.LayerNorm(n_embd)
        self.ln4 = nn.LayerNorm(n_embd)
        self.dropout1 = nn.Dropout(res1_dropout)
        self.dropout2 = nn.Dropout(res2_dropout)
        self.dropout4 = nn.Dropout(res4_dropout)
        self.res1_dropout = res1_dropout
        self.res2_dropout = res2_dropout
        self.res4_dropout = res4_dropout
        


    def forward(self, x):
        # apply self attention and dropout
        x = self.ln1(x)
        y = self.dropout1(x) * (1 - self.res1_dropout) + self.sa1(x)
        # apply feedforward and dropout
        y = self.ln2(y)
        z = self.dropout2(x) * (1 - self.res2_dropout) + self.dropout1(y) * (1 - self.res1_dropout) + self.ffwd1(y)

        # apply self attention and dropout
        z = self.ln3(z)
        a = self.dropout1(z) * (1 - self.res1_dropout) + self.sa2(z)
        # apply feedforward and dropout
        a = self.ln4(a)
        b = self.dropout4(x) * (1 - self.res4_dropout) + self.dropout2(z) * (1 - self.res2_dropout) + self.dropout1(a) * (1 - self.res1_dropout) + self.ffwd2(y)
        return b


# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, res1_dropout=0.0, res2_dropout=0.0, res4_dropout=0.0):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, res1_dropout=res1_dropout, res2_dropout=res2_dropout, res4_dropout=res4_dropout) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

# %%
import json
import os
import time

res4_dropout_values = [0.0, 0.2, 0.5, 0.99]

for dropout in res4_dropout_values:
    print(f"Training model with dropout={dropout}")

    # Start timing the training process
    start_time = time.time()
    
    # Instantiate the model with the current dropout value
    model = BigramLanguageModel(res1_dropout=0.025, res2_dropout=0.99, res4_dropout=dropout).to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    
    # Lists to store the loss values for the current dropout experiment
    train_losses = []
    val_losses = []

    for iter in range(max_iters):
        # Evaluate the loss on training and validation sets at certain intervals
        if iter % eval_interval == 0 or iter == max_iters - 1:
            losses = estimate_loss()  # Ensure this function uses the model from the current loop
            train_losses.append(losses['train'].item())
            val_losses.append(losses['val'].item())
            print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        
        # Sample a batch of data
        xb, yb = get_batch('train')
        
        # Calculate the loss
        logits, loss = model(xb, yb)
        optimizer.zero_grad(set_to_none=True)
        loss.backward()
        optimizer.step()

    # End timing the training process
    end_time = time.time()
    training_time = end_time - start_time  # Calculate the total training time

    # Results for losses
    loss_results = {
        "train_losses": train_losses,
        "val_losses": val_losses,
    }

    # Result for training time
    time_result = {
        "training_time": training_time,
    }

    # Define the folder path
    folder_path = "./loss_time/res4"
    
    # Ensure the directory exists
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
    
    # Filename and path for losses
    loss_filename = f'res4_dropout_{dropout}_losses.json'
    loss_file_path = os.path.join(folder_path, loss_filename)
    
    # Write the loss results to the file
    with open(loss_file_path, 'w') as f:
        json.dump(loss_results, f)
    
    print(f"Loss results for res4 dropout={dropout} saved to {loss_file_path}")
    
    # Filename and path for training time
    time_filename = f'res4_dropout_{dropout}_training_time.json'
    time_file_path = os.path.join(folder_path, time_filename)
    
    # Write the training time to the file
    with open(time_file_path, 'w') as f:
        json.dump(time_result, f)
    
    print(f"Training time for res4 dropout={dropout} saved to {time_file_path}")
# Out:
# Training model with dropout=0.0
# step 0: train loss 4.3482, val loss 4.3418
# step 100: train loss 2.7039, val loss 2.7188
# step 200: train loss 2.5337, val loss 2.5299
# step 300: train loss 2.4609, val loss 2.4720
# step 400: train loss 2.4054, val loss 2.4100
# step 500: train loss 2.3606, val loss 2.3706
# step 600: train loss 2.3189, val loss 2.3205
# step 700: train loss 2.2937, val loss 2.3001
# step 800: train loss 2.2563, val loss 2.2665
# step 900: train loss 2.2262, val loss 2.2287
# step 1000: train loss 2.2043, val loss 2.2045
# step 1100: train loss 2.1808, val loss 2.2007
# step 1200: train loss 2.1635, val loss 2.1684
# step 1300: train loss 2.1459, val loss 2.1526
# step 1400: train loss 2.1219, val loss 2.1322
# step 1500: train loss 2.0919, val loss 2.1237
# step 1600: train loss 2.0732, val loss 2.1155
# step 1700: train loss 2.0751, val loss 2.1015
# step 1800: train loss 2.0475, val loss 2.0938
# step 1900: train loss 2.0379, val loss 2.0685
# step 2000: train loss 2.0240, val loss 2.0754
# step 2100: train loss 2.0068, val loss 2.0630
# step 2200: train loss 1.9944, val loss 2.0482
# step 2300: train loss 1.9932, val loss 2.0481
# step 2400: train loss 1.9828, val loss 2.0275
# step 2500: train loss 1.9713, val loss 2.0369
# step 2600: train loss 1.9731, val loss 2.0318
# step 2700: train loss 1.9569, val loss 2.0194
# step 2800: train loss 1.9456, val loss 2.0116
# step 2900: train loss 1.9422, val loss 2.0135
# step 3000: train loss 1.9365, val loss 2.0052
# step 3100: train loss 1.9121, val loss 1.9999
# step 3200: train loss 1.9027, val loss 1.9940
# step 3300: train loss 1.9043, val loss 1.9881
# step 3400: train loss 1.8982, val loss 1.9829
# step 3500: train loss 1.8915, val loss 1.9781
# step 3600: train loss 1.8800, val loss 1.9836
# step 3700: train loss 1.8827, val loss 1.9769
# step 3800: train loss 1.8722, val loss 1.9800
# step 3900: train loss 1.8685, val loss 1.9621
# step 4000: train loss 1.8642, val loss 1.9549
# step 4100: train loss 1.8613, val loss 1.9672
# step 4200: train loss 1.8518, val loss 1.9595
# step 4300: train loss 1.8582, val loss 1.9519
# step 4400: train loss 1.8541, val loss 1.9531
# step 4500: train loss 1.8377, val loss 1.9490
# step 4600: train loss 1.8398, val loss 1.9413
# step 4700: train loss 1.8308, val loss 1.9426
# step 4800: train loss 1.8287, val loss 1.9549
# step 4900: train loss 1.8239, val loss 1.9383
# step 4999: train loss 1.8115, val loss 1.9254
# Loss results for res4 dropout=0.0 saved to ./loss_time/res4\res4_dropout_0.0_losses.json
# Training time for res4 dropout=0.0 saved to ./loss_time/res4\res4_dropout_0.0_training_time.json
# Training model with dropout=0.2
# step 0: train loss 4.3542, val loss 4.3577
# step 100: train loss 2.6970, val loss 2.7161
# step 200: train loss 2.5592, val loss 2.5763
# step 300: train loss 2.4902, val loss 2.4951
# step 400: train loss 2.4299, val loss 2.4367
# step 500: train loss 2.3722, val loss 2.4051
# step 600: train loss 2.3473, val loss 2.3486
# step 700: train loss 2.3069, val loss 2.3373
# step 800: train loss 2.2866, val loss 2.3017
# step 900: train loss 2.2492, val loss 2.2564
# step 1000: train loss 2.2341, val loss 2.2512
# step 1100: train loss 2.1949, val loss 2.2344
# step 1200: train loss 2.1759, val loss 2.1991
# step 1300: train loss 2.1779, val loss 2.2084
# step 1400: train loss 2.1492, val loss 2.1680
# step 1500: train loss 2.1244, val loss 2.1474
# step 1600: train loss 2.1171, val loss 2.1408
# step 1700: train loss 2.0858, val loss 2.1118
# step 1800: train loss 2.0896, val loss 2.1077
# step 1900: train loss 2.0745, val loss 2.1125
# step 2000: train loss 2.0485, val loss 2.0909
# step 2100: train loss 2.0410, val loss 2.0796
# step 2200: train loss 2.0249, val loss 2.0696
# step 2300: train loss 2.0328, val loss 2.0715
# step 2400: train loss 2.0170, val loss 2.0591
# step 2500: train loss 2.0049, val loss 2.0631
# step 2600: train loss 1.9807, val loss 2.0339
# step 2700: train loss 1.9895, val loss 2.0368
# step 2800: train loss 1.9716, val loss 2.0286
# step 2900: train loss 1.9627, val loss 2.0259
# step 3000: train loss 1.9650, val loss 2.0200
# step 3100: train loss 1.9423, val loss 2.0122
# step 3200: train loss 1.9384, val loss 2.0129
# step 3300: train loss 1.9334, val loss 2.0159
# step 3400: train loss 1.9260, val loss 1.9991
# step 3500: train loss 1.9258, val loss 1.9973
# step 3600: train loss 1.9228, val loss 2.0004
# step 3700: train loss 1.9145, val loss 1.9906
# step 3800: train loss 1.9016, val loss 1.9691
# step 3900: train loss 1.9005, val loss 1.9779
# step 4000: train loss 1.8945, val loss 1.9829
# step 4100: train loss 1.8861, val loss 1.9803
# step 4200: train loss 1.8884, val loss 1.9578
# step 4300: train loss 1.8683, val loss 1.9581
# step 4400: train loss 1.8697, val loss 1.9551
# step 4500: train loss 1.8539, val loss 1.9640
# step 4600: train loss 1.8577, val loss 1.9719
# step 4700: train loss 1.8578, val loss 1.9675
# step 4800: train loss 1.8567, val loss 1.9580
# step 4900: train loss 1.8595, val loss 1.9391
# step 4999: train loss 1.8445, val loss 1.9316
# Loss results for res4 dropout=0.2 saved to ./loss_time/res4\res4_dropout_0.2_losses.json
# Training time for res4 dropout=0.2 saved to ./loss_time/res4\res4_dropout_0.2_training_time.json
# Training model with dropout=0.5
# step 0: train loss 4.3303, val loss 4.3315
# step 100: train loss 2.6997, val loss 2.7060
# step 200: train loss 2.5533, val loss 2.5540
# step 300: train loss 2.4908, val loss 2.4795
# step 400: train loss 2.4286, val loss 2.4387
# step 500: train loss 2.3879, val loss 2.4046
# step 600: train loss 2.3575, val loss 2.3593
# step 700: train loss 2.3177, val loss 2.3243
# step 800: train loss 2.2859, val loss 2.2996
# step 900: train loss 2.2612, val loss 2.2715
# step 1000: train loss 2.2439, val loss 2.2571
# step 1100: train loss 2.2208, val loss 2.2298
# step 1200: train loss 2.1913, val loss 2.2057
# step 1300: train loss 2.1756, val loss 2.1944
# step 1400: train loss 2.1507, val loss 2.1716
# step 1500: train loss 2.1435, val loss 2.1604
# step 1600: train loss 2.1272, val loss 2.1435
# step 1700: train loss 2.1079, val loss 2.1489
# step 1800: train loss 2.1031, val loss 2.1283
# step 1900: train loss 2.0734, val loss 2.1082
# step 2000: train loss 2.0724, val loss 2.1043
# step 2100: train loss 2.0523, val loss 2.0965
# step 2200: train loss 2.0592, val loss 2.0888
# step 2300: train loss 2.0475, val loss 2.0888
# step 2400: train loss 2.0293, val loss 2.0709
# step 2500: train loss 2.0217, val loss 2.0688
# step 2600: train loss 2.0101, val loss 2.0531
# step 2700: train loss 1.9973, val loss 2.0602
# step 2800: train loss 1.9903, val loss 2.0584
# step 2900: train loss 1.9847, val loss 2.0383
# step 3000: train loss 1.9774, val loss 2.0607
# step 3100: train loss 1.9777, val loss 2.0422
# step 3200: train loss 1.9597, val loss 2.0376
# step 3300: train loss 1.9533, val loss 2.0141
# step 3400: train loss 1.9443, val loss 2.0120
# step 3500: train loss 1.9472, val loss 2.0156
# step 3600: train loss 1.9399, val loss 2.0073
# step 3700: train loss 1.9385, val loss 2.0091
# step 3800: train loss 1.9261, val loss 2.0016
# step 3900: train loss 1.9210, val loss 2.0003
# step 4000: train loss 1.9024, val loss 2.0089
# step 4100: train loss 1.9017, val loss 1.9969
# step 4200: train loss 1.9081, val loss 1.9982
# step 4300: train loss 1.8854, val loss 2.0028
# step 4400: train loss 1.8984, val loss 1.9872
# step 4500: train loss 1.8936, val loss 1.9955
# step 4600: train loss 1.8814, val loss 1.9745
# step 4700: train loss 1.8778, val loss 1.9787
# step 4800: train loss 1.8789, val loss 1.9735
# step 4900: train loss 1.8756, val loss 1.9711
# step 4999: train loss 1.8593, val loss 1.9491
# Loss results for res4 dropout=0.5 saved to ./loss_time/res4\res4_dropout_0.5_losses.json
# Training time for res4 dropout=0.5 saved to ./loss_time/res4\res4_dropout_0.5_training_time.json
# Training model with dropout=0.99
# step 0: train loss 4.3632, val loss 4.3573
# step 100: train loss 2.6703, val loss 2.6637
# step 200: train loss 2.5230, val loss 2.5161
# step 300: train loss 2.4590, val loss 2.4496
# step 400: train loss 2.4186, val loss 2.4112
# step 500: train loss 2.3736, val loss 2.3750
# step 600: train loss 2.3191, val loss 2.3251
# step 700: train loss 2.2870, val loss 2.2825
# step 800: train loss 2.2598, val loss 2.2572
# step 900: train loss 2.2439, val loss 2.2465
# step 1000: train loss 2.2118, val loss 2.2200
# step 1100: train loss 2.1771, val loss 2.2074
# step 1200: train loss 2.1608, val loss 2.1783
# step 1300: train loss 2.1437, val loss 2.1685
# step 1400: train loss 2.1256, val loss 2.1584
# step 1500: train loss 2.1002, val loss 2.1407
# step 1600: train loss 2.0946, val loss 2.1205
# step 1700: train loss 2.0889, val loss 2.1124
# step 1800: train loss 2.0589, val loss 2.0925
# step 1900: train loss 2.0491, val loss 2.0874
# step 2000: train loss 2.0307, val loss 2.0804
# step 2100: train loss 2.0309, val loss 2.0770
# step 2200: train loss 2.0050, val loss 2.0643
# step 2300: train loss 2.0009, val loss 2.0736
# step 2400: train loss 1.9827, val loss 2.0499
# step 2500: train loss 1.9715, val loss 2.0307
# step 2600: train loss 1.9625, val loss 2.0322
# step 2700: train loss 1.9595, val loss 2.0233
# step 2800: train loss 1.9554, val loss 2.0251
# step 2900: train loss 1.9482, val loss 2.0226
# step 3000: train loss 1.9345, val loss 2.0057
# step 3100: train loss 1.9172, val loss 1.9938
# step 3200: train loss 1.9220, val loss 2.0035
# step 3300: train loss 1.9027, val loss 1.9936
# step 3400: train loss 1.9059, val loss 1.9899
# step 3500: train loss 1.8874, val loss 1.9848
# step 3600: train loss 1.8914, val loss 1.9938
# step 3700: train loss 1.8927, val loss 1.9865
# step 3800: train loss 1.8822, val loss 1.9814
# step 3900: train loss 1.8754, val loss 1.9809
# step 4000: train loss 1.8739, val loss 1.9850
# step 4100: train loss 1.8568, val loss 1.9772
# step 4200: train loss 1.8641, val loss 1.9760
# step 4300: train loss 1.8561, val loss 1.9759
# step 4400: train loss 1.8521, val loss 1.9781
# step 4500: train loss 1.8591, val loss 1.9616
# step 4600: train loss 1.8537, val loss 1.9538
# step 4700: train loss 1.8305, val loss 1.9454
# step 4800: train loss 1.8370, val loss 1.9510
# step 4900: train loss 1.8274, val loss 1.9504
# step 4999: train loss 1.8245, val loss 1.9412
# Loss results for res4 dropout=0.99 saved to ./loss_time/res4\res4_dropout_0.99_losses.json
# Training time for res4 dropout=0.99 saved to ./loss_time/res4\res4_dropout_0.99_training_time.json

# %%
import json
import matplotlib.pyplot as plt
import os

# Specify the folder path where the loss JSON files are stored
folder_path = "./loss_time/res4"
# Specify the path to save the visualization result
visualization_save_path = "./visualization/res4_loss_curves.png"

# Use a pattern or a specific part of the file name to identify loss files
# Assuming loss files contain '_losses' in their filenames
loss_files = [f for f in os.listdir(folder_path) if f.endswith('_losses.json')]

# Visualize the loss curves for each dropout configuration
plt.figure(figsize=(10, 6))

for file in loss_files:
    file_path = os.path.join(folder_path, file)
    
    # Read the loss values from the JSON file
    with open(file_path, 'r') as f:
        losses = json.load(f)
    
    # Plot the validation loss curves
    # Extracting the dropout value from the filename for labeling
    dropout_label = file.split('_')[2]  # Assumes format 'attn_dropout_{value}_losses.json'
    plt.plot(losses['val_losses'], label=f"Validation Loss Dropout {dropout_label}")

plt.title("Loss Curves for Different Residual_4 Dropout Configurations")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

# Save the image
plt.savefig(visualization_save_path)
plt.close()

print(f"Visualization saved to {visualization_save_path}")
# Out:
# Visualization saved to ./visualization/res4_loss_curves.png
