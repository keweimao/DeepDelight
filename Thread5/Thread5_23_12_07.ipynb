# %%
# We always start with a dataset to train on. Let's download the tiny shakespeare dataset
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Out:
# --2023-12-07 22:04:13--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.4’
#
# input.txt.4         100%[===================>]   1.06M  --.-KB/s    in 0.06s
#
# 2023-12-07 22:04:14 (17.0 MB/s) - ‘input.txt.4’ saved [1115394/1115394]

# %%
# read it in to inspect it
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
# import the package
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4

# %%
# train with a fixd dropout
dropout = 0.2
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


# cache of train loss and val loss
train_losses_original = []
val_losses_original = []


for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_original.append(losses['train'].item())
        val_losses_original.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6677, val loss 2.6603
# step 200: train loss 2.5294, val loss 2.5300
# step 300: train loss 2.4643, val loss 2.4622
# step 400: train loss 2.3982, val loss 2.4112
# step 500: train loss 2.3475, val loss 2.3404
# step 600: train loss 2.3118, val loss 2.3109
# step 700: train loss 2.2698, val loss 2.2761
# step 800: train loss 2.2395, val loss 2.2416
# step 900: train loss 2.2064, val loss 2.2231
# step 1000: train loss 2.1847, val loss 2.1951
# step 1100: train loss 2.1410, val loss 2.1649
# step 1200: train loss 2.1223, val loss 2.1444
# step 1300: train loss 2.1070, val loss 2.1332
# step 1400: train loss 2.0797, val loss 2.1176
# step 1500: train loss 2.0748, val loss 2.1076
# step 1600: train loss 2.0432, val loss 2.1009
# step 1700: train loss 2.0298, val loss 2.0770
# step 1800: train loss 2.0210, val loss 2.0623
# step 1900: train loss 2.0084, val loss 2.0455
# step 2000: train loss 1.9878, val loss 2.0384
# step 2100: train loss 1.9706, val loss 2.0321
# step 2200: train loss 1.9610, val loss 2.0326
# step 2300: train loss 1.9591, val loss 2.0241
# step 2400: train loss 1.9366, val loss 2.0223
# step 2500: train loss 1.9262, val loss 2.0065
# step 2600: train loss 1.9168, val loss 1.9820
# step 2700: train loss 1.9134, val loss 1.9961
# step 2800: train loss 1.9041, val loss 1.9791
# step 2900: train loss 1.8962, val loss 1.9823
# step 3000: train loss 1.8853, val loss 1.9780
# step 3100: train loss 1.8745, val loss 1.9599
# step 3200: train loss 1.8745, val loss 1.9772
# step 3300: train loss 1.8599, val loss 1.9591
# step 3400: train loss 1.8560, val loss 1.9626
# step 3500: train loss 1.8466, val loss 1.9558
# step 3600: train loss 1.8441, val loss 1.9565
# step 3700: train loss 1.8294, val loss 1.9518
# step 3800: train loss 1.8234, val loss 1.9468
# step 3900: train loss 1.8251, val loss 1.9405
# step 4000: train loss 1.8168, val loss 1.9354
# step 4100: train loss 1.8103, val loss 1.9319
# step 4200: train loss 1.8226, val loss 1.9409
# step 4300: train loss 1.8101, val loss 1.9263
# step 4400: train loss 1.8145, val loss 1.9405
# step 4500: train loss 1.7978, val loss 1.9397
# step 4600: train loss 1.7912, val loss 1.9234
# step 4700: train loss 1.7934, val loss 1.9134
# step 4800: train loss 1.7970, val loss 1.9234
# step 4900: train loss 1.7803, val loss 1.9171
# step 5000: train loss 1.7832, val loss 1.9048
# step 5100: train loss 1.7767, val loss 1.9058
# step 5200: train loss 1.7676, val loss 1.9165
# step 5300: train loss 1.7816, val loss 1.9098
# step 5400: train loss 1.7657, val loss 1.8988
# step 5500: train loss 1.7480, val loss 1.8887
# step 5600: train loss 1.7530, val loss 1.8868
# step 5700: train loss 1.7556, val loss 1.9008
# step 5800: train loss 1.7517, val loss 1.8953
# step 5900: train loss 1.7573, val loss 1.8893
# step 6000: train loss 1.7469, val loss 1.8851
# step 6100: train loss 1.7439, val loss 1.8828
# step 6200: train loss 1.7451, val loss 1.8946
# step 6300: train loss 1.7437, val loss 1.8967
# step 6400: train loss 1.7350, val loss 1.8696
# step 6500: train loss 1.7342, val loss 1.8836
# step 6600: train loss 1.7196, val loss 1.8653
# step 6700: train loss 1.7296, val loss 1.8824
# step 6800: train loss 1.7262, val loss 1.8688
# step 6900: train loss 1.7263, val loss 1.8695
# step 7000: train loss 1.7179, val loss 1.8834
# step 7100: train loss 1.7174, val loss 1.8737
# step 7200: train loss 1.7190, val loss 1.8678
# step 7300: train loss 1.7231, val loss 1.8583
# step 7400: train loss 1.7101, val loss 1.8562
# step 7500: train loss 1.7143, val loss 1.8714
# step 7600: train loss 1.7107, val loss 1.8617
# step 7700: train loss 1.7200, val loss 1.8606
# step 7800: train loss 1.7150, val loss 1.8526
# step 7900: train loss 1.6912, val loss 1.8637
# step 8000: train loss 1.7049, val loss 1.8591
# step 8100: train loss 1.7047, val loss 1.8531
# step 8200: train loss 1.7047, val loss 1.8434
# step 8300: train loss 1.6884, val loss 1.8394
# step 8400: train loss 1.7000, val loss 1.8621
# step 8500: train loss 1.6966, val loss 1.8559
# step 8600: train loss 1.6852, val loss 1.8413
# step 8700: train loss 1.6900, val loss 1.8441
# step 8800: train loss 1.7070, val loss 1.8549
# step 8900: train loss 1.6894, val loss 1.8511
# step 9000: train loss 1.6819, val loss 1.8453
# step 9100: train loss 1.6881, val loss 1.8287
# step 9200: train loss 1.6798, val loss 1.8451
# step 9300: train loss 1.6803, val loss 1.8469
# step 9400: train loss 1.6783, val loss 1.8525
# step 9500: train loss 1.6819, val loss 1.8544
# step 9600: train loss 1.6851, val loss 1.8211
# step 9700: train loss 1.6814, val loss 1.8152
# step 9800: train loss 1.6601, val loss 1.8279
# step 9900: train loss 1.6731, val loss 1.8250
# step 9999: train loss 1.6695, val loss 1.8381
#
# it glain to merceswers me, so-me an turl, no grance abould Kis longe With 'stay
# To life geneve;
# On pats, and bear. A raysell my lead
# And man'll windering will in other puse.
# Aganty O, 'gain friens worle ban in glot you lord'd
# This bid lead kgly now do her mane my bain of till disped quent.
#
# LUCETIO:
# Sir, govil for son;
# And like abbed if you pippiscare's bapsard,
# In good lift stall crosess from need hon so ment chan town ever: an lockt fan humst: for in the lacrince.
# I worm crassing to lives
# woldones thing outh amon; alay in him,
# onechged chase than ark cheepect whon you' wro braght was
# in sin ence of they twart wrom pkisonamen
# And of: whrie come life dest fathis mably end.
#
# HENRY IV:
# The thatwan:
# my as shall fight biner: Raddame slended trip.
#
# Groune can all planite to Ruleathers?
# On 'Honourted Hople suld land, longurs you hald be noth worser his for here-eno bequens bagnio your fulliarel our honome' an it moders is my for plopie such you cont;
# Thou lwilph an implifs
# The convirant sintand time whe mothed all mall-aflemble child my forself wail Mardors,
# Wravides hald red now and not: grack.
# Thin thrifume but not let is morn lo, this woo.
# Ki dishall in this breate beham?
# we so brage nor this
# so faccepts still bold, all spearing mustory down. Cold, for Gustlen's say, whoes are holI slament,
# prilints that wish eldles ringe.
#
# RANUS:
# God Sdest liech a drike, my for hopt
# Thy wood thanguare in us
# in therdly mere and mhy have, now I do have beavenguses?
#
# DARWICK:
# O, igre halself fair upop thing ent-lanter.
#
# APAULI:
# Wo barwild you prin, in whil marrise.
#
# EDve lieght will the in leman, uNbles Witrbecoar:
# Eld till have I fadient, my clesult yierner seeprainst sday you rack,--
# Bich this which his rale of feaunted must deated.
#
# GUER:
# O yety hausate my happe, and if
# Joine his gonous hearts in pleadd thee grank'd to thine?
#
# CLAUNI:
# None, as, fights I asway, will, here days if tread?
# Or sigonstle swell
# Ose eyour furstrend oun this deed
# Sire of thee light Gidme shoul.
# I know he promi

# %%
torch.manual_seed(1337)
dropout_rates = [0.1, 0.2, 0.3, 0.4]


# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size, dropout_rate):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size, dropout_rate):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size, dropout_rate) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd, dropout_rate):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout_rate),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head, dropout_rate):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size, dropout_rate)
        self.ffwd = FeedFoward(n_embd, dropout_rate)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table

        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        # dropout_rates = [0.2, 0.3, 0.4, 0.5]
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, dropout_rates[i]) for i in range(n_layer)])

        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# cache of train loss and val loss
train_losses_test = []
val_losses_test = []

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses_test.append(losses['train'].item())
        val_losses_test.append(losses['val'].item())
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.209729 M parameters
# step 0: train loss 4.4116, val loss 4.4022
# step 100: train loss 2.6732, val loss 2.6663
# step 200: train loss 2.5311, val loss 2.5335
# step 300: train loss 2.4646, val loss 2.4629
# step 400: train loss 2.3962, val loss 2.4092
# step 500: train loss 2.3470, val loss 2.3416
# step 600: train loss 2.3084, val loss 2.3085
# step 700: train loss 2.2623, val loss 2.2697
# step 800: train loss 2.2374, val loss 2.2398
# step 900: train loss 2.2051, val loss 2.2231
# step 1000: train loss 2.1823, val loss 2.1922
# step 1100: train loss 2.1407, val loss 2.1663
# step 1200: train loss 2.1210, val loss 2.1406
# step 1300: train loss 2.1081, val loss 2.1351
# step 1400: train loss 2.0780, val loss 2.1186
# step 1500: train loss 2.0735, val loss 2.1068
# step 1600: train loss 2.0420, val loss 2.0997
# step 1700: train loss 2.0314, val loss 2.0775
# step 1800: train loss 2.0188, val loss 2.0624
# step 1900: train loss 2.0136, val loss 2.0501
# step 2000: train loss 1.9898, val loss 2.0432
# step 2100: train loss 1.9753, val loss 2.0393
# step 2200: train loss 1.9568, val loss 2.0240
# step 2300: train loss 1.9580, val loss 2.0245
# step 2400: train loss 1.9370, val loss 2.0228
# step 2500: train loss 1.9249, val loss 2.0063
# step 2600: train loss 1.9164, val loss 1.9842
# step 2700: train loss 1.9161, val loss 1.9990
# step 2800: train loss 1.9055, val loss 1.9825
# step 2900: train loss 1.8941, val loss 1.9845
# step 3000: train loss 1.8876, val loss 1.9789
# step 3100: train loss 1.8792, val loss 1.9598
# step 3200: train loss 1.8766, val loss 1.9796
# step 3300: train loss 1.8614, val loss 1.9639
# step 3400: train loss 1.8556, val loss 1.9589
# step 3500: train loss 1.8469, val loss 1.9544
# step 3600: train loss 1.8412, val loss 1.9556
# step 3700: train loss 1.8289, val loss 1.9526
# step 3800: train loss 1.8205, val loss 1.9480
# step 3900: train loss 1.8256, val loss 1.9424
# step 4000: train loss 1.8131, val loss 1.9347
# step 4100: train loss 1.8099, val loss 1.9357
# step 4200: train loss 1.8216, val loss 1.9420
# step 4300: train loss 1.8090, val loss 1.9271
# step 4400: train loss 1.8106, val loss 1.9463
# step 4500: train loss 1.7976, val loss 1.9419
# step 4600: train loss 1.7921, val loss 1.9277
# step 4700: train loss 1.7929, val loss 1.9153
# step 4800: train loss 1.7971, val loss 1.9283
# step 4900: train loss 1.7790, val loss 1.9169
# step 5000: train loss 1.7786, val loss 1.9023
# step 5100: train loss 1.7746, val loss 1.9117
# step 5200: train loss 1.7653, val loss 1.9123
# step 5300: train loss 1.7741, val loss 1.9120
# step 5400: train loss 1.7648, val loss 1.9063
# step 5500: train loss 1.7455, val loss 1.8873
# step 5600: train loss 1.7543, val loss 1.8922
# step 5700: train loss 1.7496, val loss 1.8954
# step 5800: train loss 1.7482, val loss 1.8926
# step 5900: train loss 1.7563, val loss 1.8890
# step 6000: train loss 1.7465, val loss 1.8865
# step 6100: train loss 1.7411, val loss 1.8846
# step 6200: train loss 1.7450, val loss 1.8967
# step 6300: train loss 1.7428, val loss 1.8991
# step 6400: train loss 1.7374, val loss 1.8820
# step 6500: train loss 1.7287, val loss 1.8865
# step 6600: train loss 1.7198, val loss 1.8668
# step 6700: train loss 1.7263, val loss 1.8861
# step 6800: train loss 1.7288, val loss 1.8809
# step 6900: train loss 1.7293, val loss 1.8827
# step 7000: train loss 1.7203, val loss 1.8947
# step 7100: train loss 1.7144, val loss 1.8758
# step 7200: train loss 1.7202, val loss 1.8733
# step 7300: train loss 1.7221, val loss 1.8581
# step 7400: train loss 1.7114, val loss 1.8572
# step 7500: train loss 1.7142, val loss 1.8753
# step 7600: train loss 1.7102, val loss 1.8613
# step 7700: train loss 1.7138, val loss 1.8627
# step 7800: train loss 1.7122, val loss 1.8521
# step 7900: train loss 1.6915, val loss 1.8705
# step 8000: train loss 1.7038, val loss 1.8667
# step 8100: train loss 1.7064, val loss 1.8627
# step 8200: train loss 1.7004, val loss 1.8473
# step 8300: train loss 1.6905, val loss 1.8495
# step 8400: train loss 1.6960, val loss 1.8688
# step 8500: train loss 1.6959, val loss 1.8563
# step 8600: train loss 1.6858, val loss 1.8432
# step 8700: train loss 1.6923, val loss 1.8547
# step 8800: train loss 1.7021, val loss 1.8464
# step 8900: train loss 1.6883, val loss 1.8509
# step 9000: train loss 1.6793, val loss 1.8523
# step 9100: train loss 1.6821, val loss 1.8318
# step 9200: train loss 1.6785, val loss 1.8499
# step 9300: train loss 1.6800, val loss 1.8445
# step 9400: train loss 1.6767, val loss 1.8488
# step 9500: train loss 1.6802, val loss 1.8591
# step 9600: train loss 1.6811, val loss 1.8360
# step 9700: train loss 1.6804, val loss 1.8238
# step 9800: train loss 1.6599, val loss 1.8310
# step 9900: train loss 1.6721, val loss 1.8297
# step 9999: train loss 1.6679, val loss 1.8365
#
# it in my stude youur lord, so-may a turl, no grance abbutendices in make us
# upon pray which he; marrath, and beyed dary agar,
# 'Olsay should delberedering was mine to may:
# Or tea. Purt,'
# Clarf in strange ban in glates,; someln kning, follow reasunters
# When mane my bain of tile greath quenteroun, if where foling for monans,
# Threemabee air?
# So pepars! why, And as his holmer;
# Stain that nave he have your kings plays leave
# The pracas lord, fan humsinself in the cward
# I so? How hour shall is by his lookes,
# Give our greater exfervious, onece;
# Are he hayself my serves. Thou may by the grouns brings, now my for eyet a too trriking amend. Dine his feigon, life a say' wast make tend.
#
# He WIIIV:
# No, tha, bettent sashter, ill plinge:
# Radefor slence, tumplio them to quake percite to Rul lear worlvo's not,
# To Hople suldelant, longurs you hold beands, wouldo his 'ttherry-enoubs't on stand if.
#
# A Romeakely hand not what it mode spiss now a plasie our, you cond;
# Thou lordph accion! fing foce, if all Marciustion what be the semmalleat no
# Wifch the ker son our igant, thou lrgerd.
#
# ELaverse: how my not:
# Or loster; therefore queen o' now;
# Melse go, thou woulder disbawhare,
# Liff a pance ham?
# were prove me! Pring wis shampis still boling in spophinge.
# Willd down. Colds fficlust before parts,
# As expostem, am all premirt, that diemalteln, for panut,
# Your heards'd liecks were of my for hope
# To ray; and will grier, gionsent on mere affemh besconscapporders and wai
# Fiurtabs a his bear, igre halselo foigh is up-lay,
# To-ldanercans bling hour world you reall: woll dreatioss.
#
# ED? ThrRy Live my longe, ever, usbals nighter a loven'd some as day die true.
#
# JULIET:
# Morne to ofram, of day you rack,--shich this
# And your shall holld unighter in ence.
# And swoon: bly hausat, my maR
# To bellifts in allamio of my lear in peryou thee grank'd toe
# To exputs end upon ands, for Tycioary,
# Let good vooun! Tybert tay? O thimsastle stake
# Of seeclove joye for down shy came,
# Well to he lis full'd bestis. I kill; do thei

# %%
import matplotlib.pyplot as plt

# %%
# train_losses_original
# val_losses_original
# train_losses_test
# val_losses_test

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses_original, label='Train Loss Origin')
plt.plot(val_losses_original, label='Validation Loss Origin')
plt.plot(train_losses_test, label='Train Loss Test')
plt.plot(val_losses_test, label='Validation Loss Test')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss vs. Iterations')
plt.legend()
plt.show()
